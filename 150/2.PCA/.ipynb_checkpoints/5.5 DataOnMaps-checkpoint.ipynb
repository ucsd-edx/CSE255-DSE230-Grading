# %% [markdown]
# ## iPyLeaflet
# [ipyleaflet](https://github.com/ellisonbg/ipyleaflet) is a bridge between jupyter notebooks and the [leaflet](http://leafletjs.com/)  javascript library for drawing maps.
#
# ipyleaflet comes with a few examples notebooks (this notebook was derived from one) but very little documentation,
# for more documentation read the [Leaflet IPA](http://leafletjs.com/reference.html)
#
# For installation directions, see the README on [ipyleaflet](https://github.com/ellisonbg/ipyleaflet)
#
# [GeoJson](https://tools.ietf.org/html/rfc7946#section-3.1.7) is a good way to add data on top of an ipyleaflet map.
#
# For other backgrounds than open streets, you can alter the ipyleaflet.py file to point to one of [these map providers](https://leaflet-extras.github.io/leaflet-providers/preview/)

# %%
from ipyleaflet import (
    Map,
    Marker,
    TileLayer, ImageOverlay,
    Polyline, Polygon, Rectangle, Circle, CircleMarker,
    GeoJSON,
    DrawControl
)

# %% [markdown]
# ## Visualizing the distribution of the observations
#
# ## Load the required libraries

# %%
import pandas as pd
import numpy as np
import sklearn as sk
import urllib
import math
import pylab as plt

import sys
sys.path.append('./lib')

from leaflet import *

# %%
data_dir = "../../Data/Weather/"
from pickle import load
with open(data_dir+'/PRCP_residuals_PCA.pickle','rb') as file:
    Res_eig=load(file)
print Res_eig.keys()

#stations.pkl
with open(data_dir+'/stations.pkl','rb') as file:
    Stations=load(file)
Stations.head()
# Out:
# ['eigen-vecs', 'stations']
#              latitude  longitude  elevation state                   name  \
# ACW00011604   17.1167   -61.7833       10.1   NaN  ST JOHNS COOLIDGE FLD
# ACW00011647   17.1333   -61.7833       19.2   NaN               ST JOHNS
# AE000041196   25.3330    55.5170       34.0   NaN    SHARJAH INTER. AIRP
# AF000040930   35.3170    69.0170     3366.0   NaN           NORTH-SALANG
# AG000060390   36.7167     3.2500       24.0   NaN     ALGER-DAR EL BEIDA
#
#             GSNFLAG HCNFLAG    WMOID
# ACW00011604     NaN     NaN      NaN
# ACW00011647     NaN     NaN      NaN
# AE000041196     GSN     NaN  41196.0
# AF000040930     GSN     NaN  40930.0
# AG000060390     GSN     NaN  60390.0

# %%
import pandas as pd
Eig=pd.DataFrame(Res_eig['eigen-vecs'].transpose())
Eig.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.141024 -0.068076  0.088963 -0.006124 -0.032068  0.055181 -0.093328
# 1 -0.156103 -0.079793  0.097287 -0.004228 -0.038719  0.070318 -0.100147
# 2 -0.078058 -0.028036  0.040801 -0.024644 -0.042237  0.051049 -0.075976
# 3 -0.143601 -0.097572  0.071770 -0.085607  0.016824 -0.050981  0.097190
# 4 -0.174711 -0.085324  0.093069 -0.047747 -0.022480 -0.009072  0.077869
#
#           7
# 0  0.112006
# 1  0.109303
# 2  0.050576
# 3  0.140906
# 4 -0.062308

# %%
Eig['station']=Res_eig['stations']
Eig=Eig.set_index('station')
print Res_eig['stations'][:5]
Eig.head()
# Out:
# [u'USC00012188', u'USC00011810', u'USC00016335', u'USC00016334', u'USW00063874']
#                     0         1         2         3         4         5  \
# station
# USC00012188 -0.141024 -0.068076  0.088963 -0.006124 -0.032068  0.055181
# USC00011810 -0.156103 -0.079793  0.097287 -0.004228 -0.038719  0.070318
# USC00016335 -0.078058 -0.028036  0.040801 -0.024644 -0.042237  0.051049
# US1ALMY0006  0.037330 -0.001086   32.0323   -86.2056      158.8     L
#
#                                name GSNFLAG HCNFLAG  WMOID
# station
# USC00012188              DAYTON 1 N     NaN     NaN    NaN
# USC00011810         COFFEEVILLE L&D     NaN     NaN    NaN
# USC00016335       PENNINGTON LOCK 2     NaN     NaN    NaN
# USC00016334         PENNINGTON 2 NE     NaN     NaN    NaN
# USW00063874  GREENVILLE CRENSHAW AP     NaN     NaN    NaN
# USC00221174         BUCKATUNNA 1 NE     NaN     NaN    NaN
# US1ALEL0022        WETUMPKA 5.4 WNW     NaN     NaN    NaN
# US1ALEL0024        MILLBROOK 1.7 NW     NaN     NaN    NaN
# USC00018178             THOMASVILLE     NaN     HCN    NaN
# USC00011315                CAMPBELL     NaN     NaN    NaN
# USC00015354                  MELVIN     NaN     NaN    NaN
# USW00023802         THOMASVILLE 2 S     NaN     NaN    NaN
# USW00023801                TROY 2 W     NaN     NaN    NaN
# USC00015449             MINTER 3 NW     NaN     NaN    NaN
# USC00016684           PRIMROSE FARM     NaN     NaN    NaN
# US1ALLE0007            AUBURN 6.6 W     NaN     NaN    NaN
# USC00012079                    CUBA     NaN     NaN    NaN
# USC00010140                 ALBERTA     NaN     NaN    NaN
# USC00014835       PENNINGTON LOCK 2     NaN     NaN    NaN
# US1ALEL0016         ECLECTIC 5.2 SW     NaN     NaN    NaN
# USC00014830                  LOCK 1     NaN     NaN    NaN
# US1ALEL0010        WETUMPKA 4.7 SSE     NaN     NaN    NaN
# USC00011301             CAMDEN 3 NW     NaN     NaN    NaN
# USC00011300            CAMDEN 3 NNW     NaN     NaN    NaN
# USC00015116     MARION JUNCTION 2 E     NaN     NaN    NaN
# USC00016436              PINE APPLE     NaN     NaN    NaN
# USC00017620               SNOW HILL     NaN     NaN    NaN
# USW00063897             SELMA 6 SSE     NaN     NaN    NaN
# USC00013816           HIGHLAND HOME     NaN     HCN    NaN
# USC00015439                MILSTEAD     NaN     NaN    NaN
# ...                             ...     ...     ...    ...
# USC00011178               BRUNDIDGE     NaN     NaN    NaN
# USC00016719              PUSHMATAHA     NaN     NaN    NaN
# US1ALAT0002      PRATTVILLE 1.1 NNE     NaN     NaN    NaN
# USC00016640              PRATTVILLE     NaN     NaN    NaN
# USC00016643         PRATTVILLE 3 SW     NaN     NaN    NaN
# USC00014274         JONES BLUFF L&D     NaN     NaN    NaN
# USW00013821             MAXWELL FLD     NaN     NaN    NaN
# US1ALDS0001           SELMA 1.5 WSW     NaN     NaN    NaN
# USC00018438       UNION SPRINGS 9 S     NaN     HCN    NaN
# USC00010616                BEATRICE     NaN     NaN    NaN
# USC00011069                BRANTLEY     NaN     NaN    NaN
# USC00018323                    TROY     NaN     HCN    NaN
# USW00003878            TROY MUNI AP     NaN     NaN    NaN
# USC00018398                TUSKEGEE     NaN     NaN    NaN
# USW00013850               CRAIG AFB     NaN     NaN    NaN
# USW00063858            SELMA 13 WNW     NaN     NaN    NaN
# USC00018403            TUSKEGEE 3 S     NaN     NaN    NaN
# USC00015004                MAGNOLIA     NaN     NaN    NaN
# USC00014840        WHITFIELD LOCK 3     NaN     NaN    NaN
# USC00018925        WHITFIELD LOCK 3     NaN     NaN    NaN
# USC00018867                 WHATLEY     NaN     NaN    NaN
# USC00018862           WETUMPKA 8 SE     NaN     NaN    NaN
# USC00019103         YATES HYDRO PLT     NaN     NaN    NaN
# USC00013024              FT DEPOSIT     NaN     NaN    NaN
# USC00015172                 MATHEWS     NaN     NaN    NaN
# USC00014192          JACKSON LOCK 1     NaN     NaN    NaN
# USC00013748              HAYNEVILLE     NaN     NaN    NaN
# US1ALEL0004       MILLBROOK 4.0 NNW     NaN     NaN    NaN
# US1ALMY0007       MONTGOMERY 2.2 NE     NaN     NaN    NaN
# US1ALMY0006            RAMER 1.5 SE     NaN     NaN    NaN
#
# [100 rows x 16 columns]

# %%
table=table[['name','latitude','longitude','elevation',0,1,2,3,4,5,6,7]]
table.head(4)
# Out:
#                           name  latitude  longitude  elevation         0  \
# station
# USC00012188         DAYTON 1 N   32.3667   -87.6500       70.1 -0.141024
# USC00011810    COFFEEVILLE L&D   31.7561   -88.1289       14.0 -0.156103
# USC00016335  PENNINGTON LOCK 2   32.1333   -88.0333        6.1 -0.078058
# USC00016334    PENNINGTON 2 NE   32.2258   -88.0281       25.9 -0.143601
#
#                     1         2         3         4         5         6  \
# station
# USC00012188 -0.068076  0.088963 -0.006124 -0.032068  0.055181 -0.093328
# USC00011810 -0.079793  0.097287 -0.004228 -0.038719  0.070318 -0.100147
# USC00016335 -0.028036  0.040801 -0.024644 -0.042237  0.051049 -0.075976
# USC00016334 -0.097572  0.071770 -0.085607  0.016824 -0.050981  0.097190
#
#                     7
# station
# USC00012188  0.112006
# USC00011810  0.109303
# USC00016335  0.050576
# USC00016334  0.140906

# %%
import pylab as plt
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']

# %%
minlat = min(table['latitude'])
maxlat = max(table['latitude'])
minlong = min(table['longitude'])
maxlong = max(table['longitude'])

# %%
print(minlat, maxlat, minlong, maxlong)
# Out:
# (31.533300000000001, 32.613100000000003, -88.517200000000003, -85.549999999999997)

# %% [markdown]
# ## Map

# %%
#min_lat,max_lat,min_long,max_long = box = (42.1103, 42.6167, -72.6, -70.8)
min_lat,max_lat,min_long,max_long = box = (minlat, maxlat, minlong, maxlong)
center = [(min_lat+max_lat)/2, (min_long+max_long)/2]
zoom = 9
m = Map(default_tiles=TileLayer(opacity=0.6), center=center, zoom=zoom)
r = Rectangle(bounds=[[min_lat,min_long],[max_lat,max_long]], weight=5, fill_opacity=0.0)
m += r

lat_margin=(max_lat-min_lat)/4
long_margin=(max_long-min_long)/4
for index,row in table.iterrows():
    _lat=row['latitude']
    _long=row['longitude']
    for col in range(4):
        _coef=row[col]
        if np.isnan(_coef):
            continue
        r=abs(_coef)/5
        #print r
        color=colors[col]
        signs=[[+1,+1],[+1,-1],[-1,-1],[-1,+1]]
        lat_sign,long_sign=signs[col]
        triangle=[(_lat,_long),(_lat+lat_sign*r,_long),(_lat,_long+long_sign*r),(_lat,_long)]
        if _coef<0:
            poly= Polygon(locations=triangle, weight=0,
                    color=color, opacity=0, fill_opacity=0.7,
                    fill_color=color)
        else:
            poly= Polygon(locations=triangle, weight=2,
                    color=color, opacity=0.8, fill_opacity=0,
                    fill_color=color)
        m +=poly   
m

# %% [markdown]
# ### excercises:
# * Add a legend that relates the colors to values.
# * Leaflet supports a variety of maps. See if you can get a topographical map as the background.
