# %% [markdown]
# ### Visualizing the distribution of the observations
#
# ### Load the required libraries

# %%
import pandas as pd
import numpy as np
import sklearn as sk
import urllib
import math
# %pylab inline
# %matplotlib inline

import findspark
findspark.init()

from pyspark import SparkContext
#sc.stop()
sc = SparkContext(master="local[3]",pyFiles=['lib/numpy_pack.py','lib/spark_PCA.py','lib/computeStats.py'])

from pyspark import SparkContext
from pyspark.sql import *
sqlContext = SQLContext(sc)

import sys
sys.path.append('./lib')

import numpy as np
from numpy_pack import packArray,unpackArray
from spark_PCA import computeCov
from computeStats import computeOverAllDist, STAT_Descriptions

### Read the data frame from pickle file

data_dir='../../Data/Weather'
file_index='SSSSBBSS'
#AL = SSSSBBSS

from pickle import load

#read statistics
filename=data_dir+'/STAT_%s.pickle'%file_index
STAT,STAT_Descriptions = load(open(filename,'rb'))
print 'keys from STAT=',STAT.keys()

#read data
filename=data_dir+'/US_Weather_%s.parquet'%file_index

df=sqlContext.read.parquet(filename)
print df.count()
df.show(5)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# keys from STAT= ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'SNWD', 'PRCP']
# 12112
# +---------+--------+---------+-----------+-----------+------+--------------------+------+--------+
# |elevation|latitude|longitude|measurement|    station|undefs|              vector|  year|   label|
# +---------+--------+---------+-----------+-----------+------+--------------------+------+--------+
# |   2038.2| 33.8833|-108.5333|       TMAX|USC00290512|     0|[40 52 00 53 00 5...|1910.0|SSSSBBSS|
# |   2038.2| 33.8833|-108.5333|       TMAX|USC00290512|    41|[00 7E 40 4C 80 5...|1911.0|SSSSBBSS|
# |   2038.2| 33.8833|-108.5333|       TMAX|USC00290512|     0|[80 C9 80 4D E0 5...|1912.0|SSSSBBSS|
# |   2038.2| 33.8833|-108.5333|       TMAX|USC00290512|    20|[A0 56 90 55 B0 5...|1913.0|SSSSBBSS|
# |   2038.2| 33.8833|-108.5333|       TMAX|USC00290512|    17|[50 57 40 56 00 5...|1914.0|SSSSBBSS|
# ...

# %% [markdown]
# ### Select data for a particular station and measurement type

# %%
sqlContext.registerDataFrameAsTable(df,'weather')
#Query="SELECT * FROM weather\n\tWHERE measurement='%s' and station='%s'"%('TMIN','USC00290512')
Query="SELECT * FROM weather\n\tWHERE measurement='%s' and station='%s'"%('PRCP','USC00290512')

print Query
df1 = sqlContext.sql(Query)
print df1.count(),'rows'
df1.show(2)
rows=df1.rdd.map(lambda row:unpackArray(row['vector'],np.float16)).collect()
T=np.vstack(rows)
T=T/10.  # scaling to make the temperature be in centingrates
shape(T)
# Out:
# SELECT * FROM weather
# 	WHERE measurement='PRCP' and station='USC00290512'
# 13 rows
# +---------+--------+---------+-----------+-----------+------+--------------------+------+--------+
# |elevation|latitude|longitude|measurement|    station|undefs|              vector|  year|   label|
# +---------+--------+---------+-----------+-----------+------+--------------------+------+--------+
# |   2038.2| 33.8833|-108.5333|       PRCP|USC00290512|     0|[00 00 2C 5C 00 0...|1910.0|SSSSBBSS|
# |   2038.2| 33.8833|-108.5333|       PRCP|USC00290512|    32|[00 00 00 00 00 0...|1911.0|SSSSBBSS|
# +---------+--------+---------+-----------+-----------+------+--------------------+------+--------+
# only showing top 2 rows
# (13, 365)

# %%
def find_avrg(meas):
    Query="SELECT * FROM weather\n\tWHERE measurement='%s'"%(meas)
    df_tmp = sqlContext.sql(Query)
    rows_tmp=df_tmp.rdd.map(lambda row:[np.nanmean(unpackArray(row['vector'],np.float16)), row['elevation'], row['latitude'], \
                                 row['longitude'], row['station'], row['year'] ]).collect()
    pdf_tmp = pd.DataFrame(rows_tmp)
    pdf_tmp.columns = [meas+'_Average', 'elevation', 'latitude', 'longitude','station','year' ]
    shape(pdf_tmp)
    pdf_tmp.head(5)
    return pdf_tmp

# %%
t_SNWD = find_avrg('SNWD')
print t_SNWD.shape
t_SNWD.head(5)
# Out:
# (1991, 6)
#    SNWD_Average  elevation  latitude  longitude      station    year
# 0      1.874023     2194.6   34.1239  -109.9219  USC00026601  1950.0
# 1     15.632812     2194.6   34.1239  -109.9219  USC00026601  1961.0
# 2      3.185547     2194.6   34.1239  -109.9219  USC00026601  1963.0
# 3      0.000000     2194.6   34.1239  -109.9219  USC00026601  1964.0
# 4      2.285156     2194.6   34.1239  -109.9219  USC00026601  1966.0

# %%
t_SNWD.plot.scatter(x='elevation', y ='SNWD_Average', title = 'Yearly Average of SNWD with respect Elevation ');

# %%
t_TMIN = find_avrg('TMIN')
print t_TMIN.shape
t_TMIN.head(2)
# Out:
# (1907, 6)
#    TMIN_Average  elevation  latitude  longitude      station    year
# 0    -22.812500     2038.2   33.8833  -108.5333  USC00290512  1910.0
# 1    -26.828125     2038.2   33.8833  -108.5333  USC00290512  1911.0

# %%
t_TMIN.plot.scatter(x='elevation', y ='TMIN_Average', title = 'Yearly Average of TMIN with respect Elevation ');

# %%
t_TOBS = find_avrg('TOBS')
print t_TOBS.shape
t_TOBS.head(2)
# Out:
# (1422, 6)
#    TOBS_Average  elevation  latitude  longitude      station    year
# 0       155.125     2038.2   33.8833  -108.5333  USC00290512  1910.0
# 1       130.500     2038.2   33.8833  -108.5333  USC00290512  1911.0

# %%
t_TOBS.plot.scatter(x='elevation', y ='TOBS_Average', title = 'Yearly Average of TOBS with respect Elevation ');

# %%
t_SNOW = find_avrg('SNOW')
print t_SNOW.shape
t_SNOW.head(5)
# Out:
# (2280, 6)
#    SNOW_Average  elevation  latitude  longitude      station    year
# 0      0.000000      485.2   33.3960  -111.5807  US1AZPN0020  2010.0
# 1      1.386719     2038.2   33.8833  -108.5333  USC00290512  1912.0
# 2      3.929688     2038.2   33.8833  -108.5333  USC00290512  1913.0
# 3      2.859375     2038.2   33.8833  -108.5333  USC00290512  1915.0
# 4      1.602539     2038.2   33.8833  -108.5333  USC00290512  1917.0

# %%
t_SNOW.plot.scatter(x='elevation', y ='SNOW_Average', title = 'Yearly Average of SNOW fall with respect Elevation ');

# %% [markdown]
# ### Script for plotting yearly plots

# %%
from YearPlotter import YearPlotter
fig, ax = plt.subplots(figsize=(10,7));
YP=YearPlotter()
YP.plot(T[:2,:].transpose(),fig,ax,title='PRCP')
#title('A sample of graphs');

# %% [markdown]
# ### Distribution of missing observations
# The distribution of missing observations is not uniform throughout the year. We visualize it below.

# %%
def plot_pair(pair,func):
    j=0
    fig,X=subplots(1,2,figsize=(16,6))
    axes=X.reshape(2)
    for m in pair:
        axis = axes[j]
        j+=1
        func(m,fig,axis)
        
def plot_valid(m,fig,axis):
    valid_m=STAT[m]['NE']
    YP.plot(valid_m,fig,axis,title='valid-counts '+m)

# %%
plot_pair(['TMIN','TMAX'],plot_valid)
# Out:
# /Users/aluthra/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
plot_pair(['TOBS','PRCP'],plot_valid)

# %%
plot_pair(['SNOW', 'SNWD'],plot_valid)

# %% [markdown]
# ### Plots of mean and std of observations

# %%
def plot_mean_std(m,fig,axis):
    mean=STAT[m]['Mean']
    std=np.sqrt(STAT[m]['Var'])
    graphs=np.vstack([mean-std,mean,mean+std]).transpose()
    if m in ['TOBS','TMIN','TMAX','PRCP']:
        graphs/=10
    YP.plot(graphs,fig,axis,title='Mean+-std   '+m)

# %%
plot_pair(['TMIN','TMAX'],plot_mean_std)

# %%
plot_pair(['TOBS','PRCP'],plot_mean_std)

# %%
plot_pair(['SNOW', 'SNWD'],plot_mean_std)

# %% [markdown]
# ### plotting top 3 eigenvectors

# %%
def plot_eigen(m,fig,axis):
    EV=STAT[m]['eigvec']
    YP.plot(EV[:,:3],fig,axis,title='Top Eigenvectors '+m)

# %%
plot_pair(['TMIN','TMAX'],plot_eigen)

# %%
plot_pair(['TOBS','PRCP'],plot_eigen)

# %%
plot_pair(['SNOW', 'SNWD'],plot_eigen)

# %% [markdown]
# ### Script for plotting percentage of variance explained

# %%
def pltVarExplained(j):
    subplot(1,3,j)
    EV=STAT[m]['eigval']
    k=10 #5 original value
    plot(([0,]+list(cumsum(EV[:k])))/sum(EV))
    title('Percentage of Variance Explained for '+ m)
    ylabel('Percentage of Variance')
    xlabel('# Eigenvector')
    grid()

# %%
f=plt.figure(figsize=(15,4))
j=1
for m in ['TMIN', 'TOBS', 'TMAX']: #,
    pltVarExplained(j)
    j+=1

# %%
f=plt.figure(figsize=(15,4))
j=1
for m in ['SNOW', 'SNWD', 'PRCP']:
    pltVarExplained(j)
    j+=1

# %%
sc.stop()
