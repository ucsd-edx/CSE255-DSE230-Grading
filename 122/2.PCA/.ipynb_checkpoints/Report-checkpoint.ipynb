# %%
L=!ls my_figures/4.4/
for l in L:
    print "![%s](my_figures/4.4/%s)"%(l,l)
L=!ls my_figures/4.5/
for l in L:
    print "![%s](my_figures/4.5/%s)"%(l,l)
L=!ls my_figures/5/
for l in L:
    print "![%s](my_figures/5/%s)"%(l,l)
L=!ls my_figures/7/
for l in L:
    print "![%s](my_figures/7/%s)"%(l,l)
# Out:
# ![4.yearPlot.png](my_figures/4.4/4.yearPlot.png)
# ![5.SNOW_SNWD.png](my_figures/4.4/5.SNOW_SNWD.png)
# ![5.TOBS_PRCP.png](my_figures/4.4/5.TOBS_PRCP.png)
# ![5.Tminmax.png](my_figures/4.4/5.Tminmax.png)
# ![6.PRCP.png](my_figures/4.4/6.PRCP.png)
# ![6.SNOW_SNWD.png](my_figures/4.4/6.SNOW_SNWD.png)
# ![6.TOBS_PRCP.png](my_figures/4.4/6.TOBS_PRCP.png)
# ![6.Tminmax.png](my_figures/4.4/6.Tminmax.png)
# ![7.SNOW_SNWD.png](my_figures/4.4/7.SNOW_SNWD.png)
# ![7.TOBS_PRCP.png](my_figures/4.4/7.TOBS_PRCP.png)
# ![7.Tminmax.png](my_figures/4.4/7.Tminmax.png)
# ![8.1.png](my_figures/4.4/8.1.png)
# ![8.2.png](my_figures/4.4/8.2.png)
# ![4.1.SNWD_mean_eigs.png](my_figures/4.5/4.1.SNWD_mean_eigs.png)

# %% [markdown]
# # Weather Analysis
#
# This report analyzes the weather patterns in part of the area of the state of Massachusets in the past few years.
#
# You can find the data we use here from [NOAA](https://www.ncdc.noaa.gov/). Specifically, you can download it from [FTP site](ftp://ftp.ncdc.noaa.gov/pub/data/ghcn/daily/).
#
# We focused on six measurements:
# * **TMIN, TMAX:** the daily minimum and maximum temperature.
# * **TOBS:** The average temperature for each day.
# * **PRCP:** Daily Percipitation (in mm)
# * **SNOW:** Daily snowfall (in mm)
# * **SNWD:** The depth of accumulated snow.
#
# ## Sanity-check: comparison with outside sources
#
# Firstly, we will compare some general statistics with the graph we obtained from this site <a href="http://www.usclimatedata.com/climate/boston/massachusetts/united-states/usma0046" target="_blank">US Climate Data</a> The graph below shows the daily minimum and maximum temperatures for each month, as well as the total precipitation for each month.
#
# <img alt="Climate_Boston_-_Massachusetts_and_Weather_averages_Boston.jpg" src="r_figures/Climate_Boston_-_Massachusetts_and_Weather_averages_Boston.jpg" />
#
# We see that the min and max daily temperature agree with the ones we got from our data, once we translate tenths of Centigrade to Centigrade.
#
# <img alt="TMIN,TMAX.png" src="my_figures/4.4/6.Tminmax.png" style="height:300px; width:800px" />
#
# According to US-Climate-Data, the rainfall is heavy during the spring, fall and winter, but there's little rainfall during the summer.This pattern is consistent with what we got from our data.
#
# <img alt="PRCP.png" src="my_figures/4.4/6.PRCP.png" style="height:450px; width:600px" />

# %% [markdown]
# ## PCA analysis
#
# For each of the six measurement, we compute the percentage of the variance explained as a function of the number of eigen-vectors used.
#
# ### Percentage of variance explained.
# ![8.1.png](my_figures/4.4/8.1.png)
# We see that the top 5 eigen-vectors explain 38% of variance for TMIN, 61% for TOBS and 48% for TMAX.
#
# We conclude that of the three, TOBS is best explained by the top 5 eigenvectors. This is especially true for the first eigen-vector which, by itself, explains 49% of the variance.
#
# ![8.2.png](my_figures/4.4/8.2.png)
#
# The top 5 eigenvectors explain 16% of the variance for PRCP and 30% for SNOW. Both are low values. On the other hand the top 5 eigenvectors explain %49 of the variance for SNWD. This means that these top 5 eigenvectors capture a large amount of the variation in the snow signals.
#
# It makes sense that SNWD would be less noisy than SNOW. That is because SNWD is a decaying integral of SNOW and, as such, varies less between days and between the same date on diffferent years.

# %% [markdown]
# ## Analysis of snow depth
#
# We choose to analyze the eigen-decomposition for snow-depth because the first 5 eigen-vectors explain 49% of the variance.
#
# First, we graph the mean and the top 5 eigen-vectors.
#
# We observe that the snow season is from mid-november to the end of May, where the begin of March marks the peak of the snow-depth.
# ![4.1.SNWD_mean_eigs.png](my_figures/4.5/4.1.SNWD_mean_eigs.png)
#
# Next we interpret the eigen-functions. The first eigen-function (eig1) has a shape very similar to the mean function. The main difference is that the eigen-function is close to zero during december-january while the mean is not. The interpretation of this shape is that eig1 represents the overall amount of snow above/below the mean, but without changing the distribution over time.
#
# **eig2,eig3,eig4 and eig5** are similar in the following way. They all oscilate between positive and negative values. In other words, they correspond to changing the distribution of the snow depth over the winter months, but they don't change the total (much).
#
# They can be interpreted as follows:
# * **eig2:** more snow in may.
# * **eig3:** more snow in dec - jan.
# * **eig4:** more snow in jan - feb, less snow in mar.
# * **eig5:** more snow in jan and mar, less snow in feb.

# %% [markdown]
# ### Examples of reconstructions
#
# #### Coeff1
# Coeff1: most positive
# ![SNWD_grid_Pos_coeff1.png](my_figures/4.5/SNWD_grid_Pos_coeff1.png)
# Coeff1: most negative
# ![SNWD_grid_neg_coeff1.png](my_figures/4.5/SNWD_grid_neg_coeff1.png)
# Large positive values of coeff1 contributes most to the target snow. Negative values contributes nearly nothing to target snow.
#
# #### Coeff2
# Coeff2: most positive
# ![SNWD_grid_Pos_coeff2.png](my_figures/4.5/SNWD_grid_Pos_coeff2.png)
# Coeff2: most negative
# ![SNWD_grid_neg_coeff2.png](my_figures/4.5/SNWD_grid_neg_coeff2.png)
#
# Large positive values of coeff2 correspond to a snow season with two spikes: one in the start of feb, the other at the start of march. Negative values of coeff2 correspond to a snow season with two spikes: one in the start of january, the other at the start of april.
#
# #### Coeff3
# Coeff3: most positive
# ![SNWD_grid_Pos_coeff3.png](my_figures/4.5/SNWD_grid_Pos_coeff3.png)
# Coeff3: most negative
# ![SNWD_grid_neg_coeff3.png](my_figures/4.5/SNWD_grid_neg_coeff3.png)
#
# Large positive values of coeff2 correspond to a season with a single peak at the end of Dec. Negative values of coeff3 correspond to a snow season with two spikes: one in the start of january, the other at the end of february.

# %% [markdown]
# ### Geographical distribution of coefficient_1.
#
# #### Coeff1 distribution over elevation
# ![elev_coef.png](my_figures/5/elev_coef.png)
#
# We can see that most coeff1 fall between 0 - 200. Some of them fall between 200 - 800. Only few fall beyond 1200. Besides, small coeff1 tends to fall at lower elevation.
#
# #### Coeff1 distribution over latitude
# ![lat_coef.png](my_figures/5/lat_coef.png)
#
# For latitude, we can see that the distribution of coeff1 is more randomly than elevation.Coeff1 is a little more tend to fall at higher latitude here.
#
# #### Coeff1 distribution over longitude
# ![longitude_coef.png](my_figures/5/longitude_coef.png)
#
# For longitude, we can see that the distribution of coeff1 is also more randomly than elevation.Coeff1 is a little more tend to fall at lower longitude here.

# %% [markdown]
# ## Analysis of precipitation
#
# In this part, we will analyze the eigen-decomposition for precipitation.
#
# First, we graph the mean and the top 3 eigen-vectors.
#
# We observe that the rainfall season is from the begin of October to the end of May, where the mid-January marks the peak of the rainfall.
#
# ![4.1.PRCP_mean_eigs.png](my_figures/4.5/4.1.PRCP_mean_eigs.png)
#
# Next we interpret the eigen-functions. The first eigen-function (eig1) has a shape very similar to the mean function. The main difference is that the eigen-function is small during october-april compared with the mean. The interpretation of this shape is that eig1 represents the overall amount of rainfall above/below the mean, but without changing the distribution over time.
#
# **eig2 and eig3** are similar in the following way. They all oscilate between positive and negative values. In other words, they correspond to changing the distribution of the rainfall over the non-summer months, but they don't change the total (much).
#
# They can be interpreted as follows:
# * **eig2:** more rainfall in start of jan, mid-feb and end of mar. less snow in mid-jan, begin of mar, late dec.
# * **eig3:** more rainfall in mid-feb, begin of mar, less in many other months.

# %% [markdown]
# ### Examples of reconstructions
#
# ![PRCP_recon.png](my_figures/4.5/PRCP_recon.png)
#
# We can see that by adding more eigen vectors, the residuals keep decreasing. That is, the reconstruction drawing much near to the target.

# %% [markdown]
# ## Analysis of correlation between percipitation across locations
#
# ### Definition of statistical test
#
# We want to find a statistical test for rejecting the null hypothesis that says that the rainfall in the two locations is independent.
#
# Using the inner product is too noisy, because you multiply the rainfall on the same day in two locations and that product can be very large - leading to a large variance and poor ability to discriminate.
# An alternative is to ignore the amount of rain, and just ask whether it rained in both locations. We can then compute the probability associated with the number of overlaps under the null hypothesis.
#
# Fix two stations. We restrict our attention to the days for which we have measurements for both stations, and define the following notation:
# * $m$ : the total number of days (for which we have measurements for both stations).
# * $n_1$ : the number of days that it rained on station 1
# * $n_2$ : the number of days that it rained on station 2
# * $l$ : the number of days that it rained on both stations.
#
# We want to calculate the probability that the number of overlap days is $l$ given $m,n_1,n_2$.
#
# The answer is:
# $$
# P = {m \choose l,n_1-l,n_2-l,m-n_1-n_2+l} /{m \choose n_1}{m \choose n_2}
# $$
#
# Where
# $$
# {m \choose l,n_1-l,n_2-l,m-n_1-n_2+l} = \frac{m!}{l! (n_1-l)! (n_2-l)! (m-n_1-n_2+l)!}
# $$
#
# We use the fact that $\Gamma(n+1) = n!$ and denote $G(n) \doteq \log \Gamma(n+1)$
# $$
# \log P = \left[G(m) - G(l) -G(n_1-l) -G(n_2-l) -G(m-n_1-n_2+l) \right] -
# \left[G(m)-G(n_1)-G(m-n_1)\right] - \left[G(m)-G(n_2)-G(m-n_2)\right]
# $$
# Which slightly simplifies to
# $$
# \log P = -G(l) -G(n_1-l) -G(n_2-l) -G(m-n_1-n_2+l) - G(m)+G(n_1)+G(m-n_1) +G(n_2)+G(m-n_2)
# $$
#
# The log probability scales with $m$ the length of the overlap. So to get a per-day significance we consider $
# \frac{1}{m} \log P $
#
# ### Significance distribution
#
# ![significance.png](my_figures/7/significance.png)
#
#
# ### correlations matrix
#
# ![nlp_matrix.png](my_figures/7/nlp_matrix.png)
#
# We see immediately the first 32 stations are highly correlated with each other, and the latter 88 stations are somewhat correlated with each other. While the most of the first 32 stations are not correlated with the latter 88 stations.
#
# To find more correlations we use SVD (the term PCA is reserved for decomposition of the covariance matrix). As we shall see that the top 10 eigenvectors explain about 80% of the square magnitude of the matrix.
#
# ![SVD_matrix.png](my_figures/7/SVD_matrix.png)
#
# When we reorder the rows and columns of the matrix using one of the eigenvectors, the grouping of the stations becomes more evident. For example, consider the third matrix. The stations at positions 76-96 are clearly strongly correlated with each other. Even though there is a station, in positions 88, which is not related to the rest of this block.
#
#
# ### PCA analysis
#
# ### Geographical distribution of top 4 coefficients.
