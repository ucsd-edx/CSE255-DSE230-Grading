# %%
#setup
data_dir='../../Data/Weather'
#file_index='BBBSBBBB'
file_index='BSBSSSBB'
meas='TOBS'

# %% [markdown]
# # Reconstruction using top eigen-vectors
# For measurement = {{meas}}

# %% [markdown]
# ## Load the required libraries

# %%
# Enable automiatic reload of libraries
#%load_ext autoreload
#%autoreload 2 # means that all modules are reloaded before every command

# %%
# %pylab inline
import numpy as np

import findspark
findspark.init()

import sys
sys.path.append('./lib')

from numpy_pack import packArray,unpackArray

from Eigen_decomp import Eigen_decomp
from YearPlotter import YearPlotter
from recon_plot import recon_plot

from import_modules import import_modules,modules
import_modules(modules)

from ipywidgets import interactive,widgets
# Out:
# Populating the interactive namespace from numpy and matplotlib
#     pandas as    pd 	version=0.19.2 	required version>=0.19.2
#      numpy as    np 	version=1.11.3 	required version>=1.12.0 ******* Update Version ******
#    sklearn as    sk 	version=0.18.1 	required version>=0.18.1
#     urllib as urllib 	version=1.17 	required version>=1.17
#    pyspark as pyspark 	version=2.1.0+hadoop2.7 	required version>=2.1.0
# ipywidgets as ipywidgets 	version=6.0.0 	required version>=6.0.0

# %%
from pyspark import SparkContext
#sc.stop()

sc = SparkContext(master="local[3]",pyFiles=['lib/numpy_pack.py','lib/spark_PCA.py','lib/computeStats.py','lib/recon_plot.py','lib/Eigen_decomp.py'])

from pyspark import SparkContext
from pyspark.sql import *
sqlContext = SQLContext(sc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-da1c4f2f274c> in <module>()
#       2 #sc.stop()
#       3
# ----> 4 sc = SparkContext(master="local[3]",pyFiles=['lib/numpy_pack.py','lib/spark_PCA.py','lib/computeStats.py','lib/recon_plot.py','lib/Eigen_decomp.py'])
#       5
#       6 from pyspark import SparkContext
#
# /lib/spark-2.1.0-bin-hadoop2.7/python/pyspark/context.py in __init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls)
#     113         """
#     114         self._callsite = first_spark_call() or CallSite(None, None, None)
# --> 115         SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     116         try:
#     117             self._do_init(master, appName, sparkHome, pyFiles, environment, batchSize, serializer,
#
# /lib/spark-2.1.0-bin-hadoop2.7/python/pyspark/context.py in _ensure_initialized(cls, instance, gateway, conf)
#     270                         " created by %s at %s:%s "
#     271                         % (currentAppName, currentMaster,
# --> 272                             callsite.function, callsite.file, callsite.linenum))
#     273                 else:
#     274                     SparkContext._active_spark_context = instance
#
# ValueError: Cannot run multiple SparkContexts at once; existing SparkContext(app=pyspark-shell, master=local[3]) created by __init__ at <ipython-input-4-da1c4f2f274c>:4

# %% [markdown]
# ## Read Statistics File

# %%
from pickle import load

#read statistics
filename=data_dir+'/STAT_%s.pickle'%file_index
STAT,STAT_Descriptions = load(open(filename,'rb'))
measurements=STAT.keys()
print 'keys from STAT=',measurements
# Out:
# keys from STAT= ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'SNWD', 'PRCP']

# %% [markdown]
# ## Read data file into a spark DataFrame
# We focus on the snow-depth records, because the eigen-vectors for them make sense.

# %%
#read data
filename=data_dir+'/decon_%s_%s.parquet'%(file_index,meas)
df_in=sqlContext.read.parquet(filename)
#filter in 
df=df_in.filter(df_in.measurement==meas)
df.show(5)
# Out:
# +------------------+------------------+-------------------+---------+--------+--------+---------+-----------+-------------------+-------------------+-------------------+-------------------+-----------+-----------+------+--------------------+------+
# |           coeff_1|           coeff_2|            coeff_3|elevation|   label|latitude|longitude|measurement|              res_1|              res_2|              res_3|           res_mean|    station|  total_var|undefs|              vector|  year|
# +------------------+------------------+-------------------+---------+--------+--------+---------+-----------+-------------------+-------------------+-------------------+-------------------+-----------+-----------+------+--------------------+------+
# | 951.3156042742843|-36.86447687289478|-232.83629691576016|     46.9|BSBSSSBB| 31.0833| -82.5653|       TOBS| 0.4872809225033287| 0.4865110011103735| 0.4557973389173408|0.19826879475154144|USC00095492|  8902570.0|     0|[80 54 38 59 40 C...|2011.0|
# | 862.3642009136354|336.05427233388633|  -203.480607470735|     36.6|BSBSSSBB| 31.9297| -82.6792|       TOBS| 0.5494314798449891| 0.4810090884690779|  0.455923432746413| 0.1889860649917068|USC00095386|  8733550.0|     0|[A0 53 E0 58 A0 5...|1972.0|
# |-921.4317214854921|  84.7870923280904| -62.35786054988607|     61.0|BSBSSSBB| 31.7078| -82.1969|       TOBS| 0.4641490541750649| 0.4586976354158956| 0.4559973146614423|0.07569118036401214|USC00098476|2.1236624E7|     1|[98 5A 58 58 28 5...|1967.0|
# |-683.0455129943923|-264.4610271548915|-229.68698929039638|     36.6|BSBSSSBB|   30.74| -82.1278|       TOBS| 0.5419061090538881|0.49384305287358654|0.45605636254155096|0.07042153652897415|USC00093465|2.0221562E7|    15|[50 57 30 54 F0 5...|1978.0|
# |1131.0255047268342| 40.88850526749031| 15.923265261165586|    112.2|BSBSSSBB| 33.0831| -83.2497|       TOBS|0.45667900862829386| 0.4568872650481287|0.45683285989123884|0.26161013126913374|USC00095874|  8278040.0|     6|[30 54 00 53 E0 5...|1991.0|
# +------------------+------------------+-------------------+---------+--------+--------+---------+-----------+-------------------+-------------------+-------------------+-------------------+-----------+-----------+------+--------------------+------+
# only showing top 5 rows

# %% [markdown]
# ### Plot Mean and Eigenvecs

# %%
m=meas
fig,axes=plt.subplots(2,1, sharex='col', sharey='row',figsize=(10,6));
k=3
EigVec=np.matrix(STAT[m]['eigvec'][:,:k])
Mean=STAT[m]['Mean']
YearPlotter().plot(Mean,fig,axes[0],label='Mean',title=m+' Mean')
YearPlotter().plot(EigVec,fig,axes[1],title=m+' Eigs',labels=['eig'+str(i+1) for i in range(k)])

# %% [markdown]
# ### plot the percent of residual variance on average

# %%
#  x=0 in the graphs below correspond to the fraction of the variance explained by the mean alone
#  x=1,2,3,... are the residuals for eig1, eig1+eig2, eig1+eig2+eig3 ...
fig,ax=plt.subplots(1,1);
eigvals=STAT[m]['eigval']; eigvals/=sum(eigvals); cumvar=cumsum(eigvals); cumvar=100*np.insert(cumvar,0,0)
ax.plot(cumvar[:10]); 
ax.grid(); 
ax.set_ylabel('Percent of variance explained')
ax.set_xlabel('number of eigenvectors')
ax.set_title('Percent of variance explained');

# %% [markdown]
# ### How well-explained are the vectors in this collection?
#
# To answer this question we extract all of the values of `res_3` which is the residual variance after the Mean and the
# first two Eigen-vectors have been subtracted out. We rely here on the fact that `df3` is already sorted according to `res_3`

# %%
# A function for plotting the CDF of a given feature
def plot_CDF(df,feat):
    rows=df.select(feat).sort(feat).collect()
    vals=[r[feat] for r in rows]
    P=np.arange(0,1,1./(len(vals)))
    while len(vals)< len(P):
        vals=[vals[0]]+vals
    plot(vals,P)
    title('cumulative distribution of '+feat)
    ylabel('fraction of instances')
    xlabel(feat)
    grid()

# %%
plot_CDF(df,'res_3')

# %%
rows=df.rdd.map(lambda row:(row.station,row.year,unpackArray(row['vector'],np.float16))).collect()
rows[0][:2]
# Out:
# (u'USC00095492', 2011.0)

# %%
days=set([r[1] for r in rows])
miny=min(days)
maxy=max(days)
record_len=int((maxy-miny+1)*365)
record_len
# Out:
# 40880

# %%
## combine the measurements for each station into a single long array with an entry for each day of each day
All={}  # a dictionary with a numpy array for each day of each day
i=0
for station,day,vector in rows:
    i+=1; 
    # if i%1000==0: print i,len(All)
    if not station in All:
        a=np.zeros(record_len)
        a.fill(np.nan)
        All[station]=a
    loc = int((day-miny)*365)
    All[station][loc:loc+365]=vector

# %%
from datetime import date
d=datetime.date(int(miny), month=1, day=1)
start=d.toordinal()
dates=[date.fromordinal(i) for i in range(start,start+record_len)]

# %%
for station in All:
    print station, np.count_nonzero(~np.isnan(All[station]))
# Out:
# USC00094238 1095
# USC00098351 1762
# USW00093845 1448
# USC00094255 364
# USC00094429 18465
# USC00092839 29409
# USC00095858 342
# USC00095811 9764
# USC00090670 2885
# USC00096255 728
# USC00098476 14860
# USC00095696 1442
# USC00093325 6005
# USC00094110 3619
# USC00095401 336
# USC00095874 20730
# USC00097777 15617
# USC00093312 707
# USC00096237 7167
# USC00099020 365
# USC00092865 2186
# USC00089640 357
# USC00094862 2470
# USC00084393 2542
# USC00099451 1086
# USC00093386 20622
# USC00090131 8468
# USC00092966 21720
# USC00092844 726
# USC00097171 4358
# USC00094170 28119
# USC00090010 2125
# USC00099186 27541
# USC00093465 16820
# USC00094971 1094
# USC00094594 12141
# USC00094204 9380
# USC00095386 9976
# USC00096244 3243
# USC00084731 29542
# USC00098974 10452
# USC00090090 3460
# USC00095863 6518
# USC00085275 28957
# USC00098972 4371
# USC00084394 19786
# USC00092783 20352
# USC00095492 730
# USC00098496 9222
# USC00085099 19453
# USC00096650 730
# USW00013861 2189
# USC00083470 22256
# USC00095314 23227

# %%
Stations=sorted(All.keys())
A=[]
for station in Stations:
    A.append(All[station])

day_station_table=np.hstack([A])
print shape(day_station_table)
# Out:
# (54, 40880)

# %%
def RMS(Mat):
    return np.sqrt(np.nanmean(Mat**2))

mean_by_day=np.nanmean(day_station_table,axis=0)
mean_by_station=np.nanmean(day_station_table,axis=1)
tbl_minus_day = day_station_table-mean_by_day
tbl_minus_station = (day_station_table.transpose()-mean_by_station).transpose()

print 'total RMS                   = ',RMS(day_station_table)
print 'RMS removing mean-by-station= ',RMS(tbl_minus_station)
print 'RMS removing mean-by-day   = ',RMS(tbl_minus_day)
# Out:
# total RMS                   =  203.171356213
# RMS removing mean-by-station=  81.5408358551
# RMS removing mean-by-day   =  45.6835640248

# %%
RT=day_station_table
F=RT.flatten()
NN=F[~np.isnan(F)]

NN.sort()
P=np.arange(0.,1.,1./len(NN))
plot(NN,P)
grid()
title('CDF of daily rainfall')
xlabel('daily rainfall')
ylabel('cumulative probability')

# %% [markdown]
# ### Conclusions
# It is likely to be hard to find correlations between the **amount** of rain on the same day in different stations. Because amounts of rain vary a lot between even close locations. It is more reasonable to try to compare whether or not it rained on the same day in different stations. As we see from the graph above, in our region it rains in about one third of the days.
#
# ### measuring statistical significance
# We want to find a statistical test for rejecting the null hypothesis that says that the rainfall in the two locations is independent.
#
# Using the inner product is too noisy, because you multiply the rainfall on the same day in two locations and that product can be very large - leading to a large variance and poor ability to discriminate.
#
# An alternative is to ignore the amount of rain, and just ask whether it rained in both locations. We can then compute the probability associated with the number of overlaps under the null hypothesis.

# %% [markdown]
# Fix two stations. We restrict our attention to the days for which we have measurements for both stations, and define the following notation:
# * $m$ : the total number of days (for which we have measurements for both stations).
# * $n_1$ : the number of days that it rained on station 1
# * $n_2$ : the number of days that it rained on station 2
# * $l$ : the number of days that it rained on both stations.
#
# We want to calculate the probability that the number of overlap days is $l$ given $m,n_1,n_2$.
#
# The answer is:
# $$
# P = {m \choose l,n_1-l,n_2-l,m-n_1-n_2+l} /{m \choose n_1}{m \choose n_2}
# $$
#
# Where
# $$
# {m \choose l,n_1-l,n_2-l,m-n_1-n_2+l} = \frac{m!}{l! (n_1-l)! (n_2-l)! (m-n_1-n_2+l)!}
# $$
#
# We use the fact that $\Gamma(n+1) = n!$ and denote $G(n) \doteq \log \Gamma(n+1)$
# $$
# \log P = \left[G(m) - G(l) -G(n_1-l) -G(n_2-l) -G(m-n_1-n_2+l) \right] -
# \left[G(m)-G(n_1)-G(m-n_1)\right] - \left[G(m)-G(n_2)-G(m-n_2)\right]
# $$
# Which slightly simplifies to
# $$
# \log P = -G(l) -G(n_1-l) -G(n_2-l) -G(m-n_1-n_2+l) - G(m)+G(n_1)+G(m-n_1) +G(n_2)+G(m-n_2)
# $$
#
# The log probability scales with $m$ the length of the overlap. So to get a per-day significance we consider $
# \frac{1}{m} \log P $

# %%
from scipy.special import gammaln,factorial
#for i in range(10):
#    print exp(gammaln(i+1))-factorial(i)
def G(n):
    return gammaln(n+1)
def LogProb(m,l,n1,n2):
    logP=-G(l)-G(n1-l)-G(n2-l)-G(m-n1-n2+l)-G(m)+G(n1)+G(m-n1)+G(n2)+G(m-n2)
    return logP/m
exp(LogProb(1000,0,500,500))
# Out:
# 0.501843349103545

# %%
#USC00193270 21482
#USC00193702 28237
#USC00094238 1424
#USC00098351 3393
X=copy(All['USC00092783'])
Y=copy(All['USC00098351'])
print sum(~np.isnan(X))
print sum(~np.isnan(Y))
X[np.isnan(Y)]=np.nan
Y[np.isnan(X)]=np.nan
print sum(~np.isnan(X))
print sum(~np.isnan(Y))
# Out:
# 20352
# 1762
# 365
# 365

# %%
constant_val = 250.0
def computeLogProb(X,Y):
    X[np.isnan(Y)]=np.nan
    Y[np.isnan(X)]=np.nan
    G=~isnan(X)
    m=sum(G)
    XG=X[G]>constant_val
    YG=Y[G]>constant_val
    
    n1=sum(XG)
    n2=sum(YG)
    l=sum(XG*YG)
    logprob=LogProb(m,l,n1,n2)
    print 'm=%d,l=%d,n1=%d,n2=%d,LogPval=%f'%(m,l,n1,n2,logprob)
    return logprob,m
print computeLogProb(X,Y)
# Out:
# m=0,l=0,n1=0,n2=0,LogPval=nan
# (nan, 0)
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in double_scalars

# %% [markdown]
# ### calculate the normalized log probability for each pair of stations.

# %%
L=len(Stations)
Pvals=np.zeros([L,L])
Length=np.zeros([L,L])
P_norm=np.zeros([L,L])
for i in range(L):
    print i,
    for j in range(L):
        if i==j:
            P_norm[i,j]=-0.4
            continue
        X=copy(All[Stations[i]])
        Y=copy(All[Stations[j]])
        P_norm[i,j],Length[i,j]=computeLogProb(X,Y)
        if Length[i,j]<200:
            P_norm[i,j]=np.nan
# Out:
# 0 m=693,l=195,n1=262,n2=239,LogPval=-0.227411
# m=12667,l=1730,n1=2375,n2=2037,LogPval=-0.222613
# m=18385,l=2880,n1=4102,n2=4357,LogPval=-0.153573
# m=11940,l=1674,n1=2205,n2=5528,LogPval=-0.041441
# m=18913,l=1781,n1=5136,n2=3501,LogPval=-0.029767
# m=355,l=3,n1=9,n2=17,LogPval=-0.014390
# m=1713,l=3,n1=34,n2=12,LogPval=-0.003864
# m=2740,l=246,n1=987,n2=570,LogPval=-0.004041
# m=5975,l=195,n1=2595,n2=352,LogPval=-0.002327
# m=2462,l=23,n1=47,n2=191,LogPval=-0.012748
# m=12457,l=432,n1=2216,n2=575,LogPval=-0.039112
# m=17134,l=2075,n1=4392,n2=2913,LogPval=-0.098469
# m=708,l=3,n1=24,n2=21,LogPval=-0.005137
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=14541,l=1037,n1=3036,n2=1325,LogPval=-0.078713
# m=696,l=56,n1=166,n2=144,LogPval=-0.018622
# m=4848,l=42,n1=108,n2=309,LogPval=-0.010837
# m=11009,l=2149,n1=2958,n2=2686,LogPval=-0.219111
# m=11612,l=1505,n1=1856,n2=5571,LogPval=-0.044468
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=19148,l=2321,n1=5027,n2=3021,LogPval=-0.109484
# m=6733,l=244,n1=338,n2=1158,LogPval=-0.040142
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=10586,l=849,n1=1392,n2=1131,LogPval=-0.133166
# m=5944,l=232,n1=347,n2=1774,LogPval=-0.018685
# m=2058,l=9,n1=37,n2=86,LogPval=-0.005555
# m=1051,l=4,n1=26,n2=8,LogPval=-0.010343
# m=15340,l=2193,n1=3588,n2=3993,LogPval=-0.089322
# m=5273,l=379,n1=2258,n2=440,LogPval=-0.037317
# m=326,l=1,n1=6,n2=28,LogPval=-0.003372
# m=718,l=1,n1=19,n2=5,LogPval=-0.002959
# m=1426,l=100,n1=652,n2=115,LogPval=-0.034029
# m=4993,l=1263,n1=1543,n2=2198,LogPval=-0.136583
# m=329,l=8,n1=22,n2=32,LogPval=-0.024151
# m=3964,l=740,n1=1167,n2=1003,LogPval=-0.153108
# m=13387,l=77,n1=2673,n2=130,LogPval=-0.003827
# m=2454,l=810,n1=969,n2=1076,LogPval=-0.226006
# m=2816,l=112,n1=123,n2=1307,LogPval=-0.021339
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=703,l=1,n1=20,n2=21,LogPval=-0.001524
# m=3878,l=5,n1=80,n2=19,LogPval=-0.002693
# m=8147,l=391,n1=881,n2=569,LogPval=-0.076714
# m=1040,l=113,n1=188,n2=299,LogPval=-0.050949
# m=8528,l=1301,n1=1661,n2=3690,LogPval=-0.062378
# m=5608,l=963,n1=1448,n2=2175,LogPval=-0.056209
# m=350,l=14,n1=16,n2=182,LogPval=-0.017161
# m=7066,l=1401,n1=2064,n2=1727,LogPval=-0.202607
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=19247,l=2276,n1=4585,n2=3210,LogPval=-0.105261
# m=1046,l=0,n1=18,n2=2,LogPval=-0.000033
# m=711,l=7,n1=27,n2=29,LogPval=-0.014203
# m=1432,l=7,n1=658,n2=7,LogPval=-0.003813
# 1 m=693,l=195,n1=239,n2=262,LogPval=-0.227411
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1441,l=193,n1=488,n2=234,LogPval=-0.100711
# m=362,l=97,n1=131,n2=111,LogPval=-0.267855
# m=721,l=153,n1=250,n2=162,LogPval=-0.241723
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1084,l=189,n1=312,n2=242,LogPval=-0.162050
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=723,l=188,n1=287,n2=219,LogPval=-0.205901
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=358,l=90,n1=139,n2=102,LogPval=-0.220442
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1426,l=316,n1=528,n2=392,LogPval=-0.157912
# m=1079,l=193,n1=390,n2=221,LogPval=-0.150068
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=726,l=83,n1=286,n2=91,LogPval=-0.087571
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=726,l=187,n1=251,n2=217,LogPval=-0.262286
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 2 m=12667,l=1730,n1=2037,n2=2375,LogPval=-0.222613
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=15703,l=1174,n1=1618,n2=2945,LogPval=-0.083093
# m=15286,l=1566,n1=1915,n2=7302,LogPval=-0.035453
# m=15366,l=1042,n1=2701,n2=3763,LogPval=-0.010854
# m=357,l=3,n1=7,n2=17,LogPval=-0.016576
# m=2125,l=6,n1=15,n2=15,LogPval=-0.010534
# m=2398,l=240,n1=599,n2=704,LogPval=-0.010215
# m=5551,l=286,n1=2199,n2=657,LogPval=-0.001039
# m=2884,l=13,n1=29,n2=212,LogPval=-0.006034
# m=16584,l=200,n1=2030,n2=298,LogPval=-0.015372
# m=14330,l=487,n1=2055,n2=647,LogPval=-0.046125
# m=726,l=1,n1=1,n2=21,LogPval=-0.004880
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=17533,l=925,n1=2356,n2=2262,LogPval=-0.036661
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5990,l=22,n1=58,n2=378,LogPval=-0.004562
# m=14940,l=2211,n1=2682,n2=3918,LogPval=-0.161061
# m=15192,l=1441,n1=1834,n2=7200,LogPval=-0.028206
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=14494,l=1007,n1=2565,n2=1353,LogPval=-0.083872
# m=5080,l=16,n1=36,n2=392,LogPval=-0.003959
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16805,l=1269,n1=1692,n2=3567,LogPval=-0.077191
# m=10203,l=482,n1=663,n2=3652,LogPval=-0.019980
# m=2469,l=13,n1=29,n2=101,LogPval=-0.010077
# m=1094,l=1,n1=2,n2=8,LogPval=-0.003868
# m=17184,l=1702,n1=2663,n2=4735,LogPval=-0.054550
# m=8385,l=284,n1=2076,n2=335,LogPval=-0.033944
# m=336,l=0,n1=0,n2=32,LogPval=-0.000000
# m=730,l=1,n1=7,n2=5,LogPval=-0.004207
# m=1407,l=113,n1=629,n2=115,LogPval=-0.063470
# m=8601,l=1435,n1=1698,n2=3815,LogPval=-0.085072
# m=339,l=3,n1=8,n2=31,LogPval=-0.010853
# m=5731,l=965,n1=1486,n2=1657,LogPval=-0.104656
# m=17304,l=14,n1=2625,n2=77,LogPval=-0.000139
# m=6399,l=1237,n1=1407,n2=2886,LogPval=-0.112889
# m=2781,l=16,n1=19,n2=1215,LogPval=-0.002925
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=730,l=0,n1=2,n2=22,LogPval=-0.000084
# m=4357,l=6,n1=32,n2=23,LogPval=-0.004259
# m=13621,l=654,n1=1183,n2=1771,LogPval=-0.051119
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=12888,l=1596,n1=1967,n2=5578,LogPval=-0.054569
# m=7310,l=923,n1=1511,n2=2775,LogPval=-0.029317
# m=2875,l=76,n1=85,n2=1255,LogPval=-0.014784
# m=6407,l=1343,n1=1800,n2=1505,LogPval=-0.276917
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16480,l=703,n1=2361,n2=944,LogPval=-0.058360
# m=1086,l=0,n1=1,n2=2,LogPval=-0.000002
# m=2168,l=31,n1=97,n2=119,LogPval=-0.017778
# m=1418,l=7,n1=635,n2=7,LogPval=-0.003979
# 3 m=18385,l=2880,n1=4357,n2=4102,LogPval=-0.153573
# m=1441,l=193,n1=234,n2=488,LogPval=-0.100711
# m=15703,l=1174,n1=2945,n2=1618,LogPval=-0.083093
# m=15350,l=2645,n1=3042,n2=7133,LogPval=-0.088099
# m=22092,l=2740,n1=5325,n2=5037,LogPval=-0.066883
# m=344,l=12,n1=78,n2=17,LogPval=-0.031656
# m=2113,l=11,n1=259,n2=15,LogPval=-0.007838
# m=3058,l=317,n1=1031,n2=574,LogPval=-0.023859
# m=5909,l=300,n1=1946,n2=758,LogPval=-0.002017
# m=2845,l=120,n1=340,n2=209,LogPval=-0.050734
# m=15857,l=367,n1=2964,n2=546,LogPval=-0.020548
# m=22962,l=2286,n1=5293,n2=3278,LogPval=-0.086097
# m=711,l=2,n1=4,n2=20,LogPval=-0.007667
# m=1093,l=94,n1=113,n2=358,LogPval=-0.065191
# m=16882,l=1265,n1=3346,n2=2124,LogPval=-0.057618
# m=351,l=31,n1=91,n2=42,LogPval=-0.075303
# m=5274,l=170,n1=670,n2=348,LogPval=-0.028867
# m=14347,l=1987,n1=3222,n2=3553,LogPval=-0.095424
# m=13882,l=2249,n1=2539,n2=6704,LogPval=-0.080419
# m=1443,l=119,n1=203,n2=316,LogPval=-0.055860
# m=21355,l=2102,n1=5003,n2=2848,LogPval=-0.091548
# m=7809,l=913,n1=1392,n2=1497,LogPval=-0.123846
# m=364,l=3,n1=4,n2=126,LogPval=-0.006123
# m=364,l=34,n1=75,n2=54,LogPval=-0.083492
# m=14358,l=1289,n1=2471,n2=2721,LogPval=-0.062105
# m=9230,l=1094,n1=1351,n2=3375,LogPval=-0.072125
# m=2440,l=57,n1=318,n2=101,LogPval=-0.024323
# m=1093,l=5,n1=118,n2=8,LogPval=-0.006872
# m=17614,l=2637,n1=3827,n2=5077,LogPval=-0.100752
# m=7759,l=316,n1=2064,n2=392,LogPval=-0.034547
# m=336,l=12,n1=34,n2=32,LogPval=-0.034859
# m=707,l=5,n1=81,n2=5,LogPval=-0.015480
# m=1060,l=76,n1=451,n2=92,LogPval=-0.034299
# m=7142,l=1511,n1=1682,n2=3234,LogPval=-0.135075
# m=341,l=19,n1=57,n2=32,LogPval=-0.055329
# m=5029,l=732,n1=1075,n2=1440,LogPval=-0.096156
# m=15610,l=98,n1=3092,n2=149,LogPval=-0.004985
# m=4993,l=999,n1=1109,n2=2262,LogPval=-0.126904
# m=2861,l=327,n1=356,n2=1348,LogPval=-0.065365
# m=361,l=36,n1=78,n2=49,LogPval=-0.106887
# m=729,l=14,n1=82,n2=22,LogPval=-0.027117
# m=4316,l=17,n1=493,n2=23,LogPval=-0.006096
# m=12974,l=742,n1=2232,n2=1648,LogPval=-0.032094
# m=1017,l=147,n1=207,n2=279,LogPval=-0.113374
# m=10443,l=1780,n1=2057,n2=4575,LogPval=-0.096847
# m=7028,l=1277,n1=1604,n2=2890,LogPval=-0.092653
# m=2177,l=323,n1=361,n2=995,LogPval=-0.085127
# m=8176,l=1238,n1=1809,n2=1809,LogPval=-0.155924
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=21058,l=2262,n1=4878,n2=3198,LogPval=-0.096352
# m=1086,l=0,n1=114,n2=2,LogPval=-0.000204
# m=1795,l=84,n1=406,n2=92,LogPval=-0.060470
# m=1054,l=5,n1=453,n2=7,LogPval=-0.002187
# 4 m=11940,l=1674,n1=5528,n2=2205,LogPval=-0.041441
# m=362,l=97,n1=111,n2=131,LogPval=-0.267855
# m=15286,l=1566,n1=7302,n2=1915,LogPval=-0.035453
# m=15350,l=2645,n1=7133,n2=3042,LogPval=-0.088099
# m=13963,l=3229,n1=6407,n2=3539,LogPval=-0.155671
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1733,l=10,n1=967,n2=11,LogPval=-0.002463
# m=2741,l=596,n1=1166,n2=704,LogPval=-0.132432
# m=5632,l=776,n1=2333,n2=869,LogPval=-0.091950
# m=1393,l=124,n1=825,n2=125,LogPval=-0.046683
# m=15092,l=193,n1=7357,n2=224,LogPval=-0.004826
# m=14000,l=598,n1=6591,n2=731,LogPval=-0.014386
# m=350,l=13,n1=226,n2=13,LogPval=-0.016607
# m=361,l=36,n1=51,n2=133,LogPval=-0.044422
# m=15428,l=1690,n1=7414,n2=1958,LogPval=-0.046648
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4474,l=271,n1=2431,n2=289,LogPval=-0.026947
# m=14746,l=3334,n1=6763,n2=4004,LogPval=-0.111128
# m=13765,l=5623,n1=6669,n2=6499,LogPval=-0.288722
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=12751,l=1189,n1=5820,n2=1440,LogPval=-0.037141
# m=3903,l=344,n1=2138,n2=380,LogPval=-0.033227
# m=362,l=34,n1=51,n2=125,LogPval=-0.041085
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=15374,l=3207,n1=7481,n2=3559,LogPval=-0.115407
# m=10933,l=3510,n1=5457,n2=4016,LogPval=-0.178343
# m=1015,l=27,n1=567,n2=27,LogPval=-0.015765
# m=1066,l=7,n1=582,n2=8,LogPval=-0.002773
# m=15778,l=4200,n1=7505,n2=4825,LogPval=-0.149236
# m=7481,l=204,n1=3241,n2=272,LogPval=-0.008189
# m=317,l=29,n1=175,n2=31,LogPval=-0.043033
# m=352,l=1,n1=228,n2=1,LogPval=-0.001234
# m=1427,l=95,n1=521,n2=114,LogPval=-0.042036
# m=8233,l=3030,n1=3628,n2=3667,LogPval=-0.265539
# m=341,l=30,n1=193,n2=32,LogPval=-0.039361
# m=5365,l=1387,n1=2404,n2=1638,LogPval=-0.150451
# m=15548,l=45,n1=7350,n2=46,LogPval=-0.001968
# m=5706,l=2163,n1=2590,n2=2522,LogPval=-0.288651
# m=2796,l=1153,n1=1344,n2=1304,LogPval=-0.322005
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=722,l=21,n1=391,n2=22,LogPval=-0.014947
# m=2820,l=15,n1=1603,n2=15,LogPval=-0.003015
# m=13595,l=1771,n1=6652,n2=2036,LogPval=-0.056244
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=13237,l=4968,n1=6210,n2=5718,LogPval=-0.269080
# m=8421,l=2786,n1=3826,n2=3235,LogPval=-0.226024
# m=3613,l=1493,n1=1824,n2=1616,LogPval=-0.325233
# m=6072,l=1396,n1=2561,n2=1635,LogPval=-0.148682
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=14705,l=718,n1=7063,n2=831,LogPval=-0.019582
# m=1053,l=2,n1=578,n2=2,LogPval=-0.001140
# m=1812,l=77,n1=867,n2=80,LogPval=-0.027102
# m=1433,l=6,n1=524,n2=7,LogPval=-0.003182
# 5 m=18913,l=1781,n1=3501,n2=5136,LogPval=-0.029767
# m=721,l=153,n1=162,n2=250,LogPval=-0.241723
# m=15366,l=1042,n1=3763,n2=2701,LogPval=-0.010854
# m=22092,l=2740,n1=5037,n2=5325,LogPval=-0.066883
# m=13963,l=3229,n1=3539,n2=6407,LogPval=-0.155671
# m=350,l=11,n1=71,n2=17,LogPval=-0.028457
# m=1384,l=3,n1=69,n2=7,LogPval=-0.004103
# m=3459,l=487,n1=840,n2=713,LogPval=-0.121939
# m=7399,l=302,n1=1189,n2=569,LogPval=-0.031666
# m=1761,l=86,n1=204,n2=140,LogPval=-0.066852
# m=15538,l=250,n1=4012,n2=528,LogPval=-0.003983
# m=22011,l=1784,n1=5151,n2=3696,LogPval=-0.030946
# m=712,l=18,n1=95,n2=21,LogPval=-0.043426
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=17254,l=1607,n1=4003,n2=2541,LogPval=-0.066137
# m=340,l=74,n1=95,n2=102,LogPval=-0.212460
# m=4515,l=137,n1=896,n2=301,LogPval=-0.012841
# m=14801,l=1861,n1=3952,n2=4072,LogPval=-0.033319
# m=12775,l=2666,n1=3105,n2=6047,LogPval=-0.103066
# m=348,l=19,n1=35,n2=83,LogPval=-0.029870
# m=23271,l=1749,n1=4787,n2=3612,LogPval=-0.037204
# m=7455,l=782,n1=1004,n2=1639,LogPval=-0.116999
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=13318,l=2096,n1=3762,n2=2981,LogPval=-0.116669
# m=8549,l=2278,n1=2830,n2=3118,LogPval=-0.214006
# m=1383,l=41,n1=148,n2=71,LogPval=-0.038806
# m=724,l=1,n1=30,n2=2,LogPval=-0.003496
# m=17701,l=3012,n1=3976,n2=5170,LogPval=-0.142472
# m=8853,l=209,n1=2321,n2=463,LogPval=-0.004962
# m=332,l=4,n1=10,n2=31,LogPval=-0.014579
# m=716,l=5,n1=126,n2=5,LogPval=-0.012225
# m=1425,l=57,n1=197,n2=112,LogPval=-0.036281
# m=8297,l=2301,n1=2719,n2=3673,LogPval=-0.171313
# m=342,l=9,n1=21,n2=32,LogPval=-0.031400
# m=4707,l=631,n1=810,n2=1387,LogPval=-0.108755
# m=16008,l=75,n1=3737,n2=149,LogPval=-0.001781
# m=5719,l=1531,n1=1698,n2=2581,LogPval=-0.189763
# m=2524,l=879,n1=1110,n2=1100,LogPval=-0.218282
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=364,l=3,n1=20,n2=9,LogPval=-0.012949
# m=2855,l=6,n1=237,n2=11,LogPval=-0.003250
# m=11203,l=899,n1=3672,n2=1359,LogPval=-0.032852
# m=1397,l=220,n1=281,n2=425,LogPval=-0.129992
# m=11921,l=2852,n1=3413,n2=5206,LogPval=-0.136560
# m=6691,l=1601,n1=2007,n2=2562,LogPval=-0.159676
# m=2912,l=1218,n1=1400,n2=1342,LogPval=-0.357903
# m=8907,l=1054,n1=1339,n2=2290,LogPval=-0.114339
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=22660,l=1706,n1=4830,n2=3850,LogPval=-0.028392
# m=1081,l=0,n1=30,n2=2,LogPval=-0.000052
# m=2187,l=118,n1=1027,n2=119,LogPval=-0.040591
# m=1431,l=4,n1=197,n2=7,LogPval=-0.003382
# 6 m=355,l=3,n1=17,n2=9,LogPval=-0.014390
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=3,n1=17,n2=7,LogPval=-0.016576
# m=344,l=12,n1=17,n2=78,LogPval=-0.031656
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=350,l=11,n1=17,n2=71,LogPval=-0.028457
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=355,l=8,n1=17,n2=50,LogPval=-0.020475
# m=357,l=5,n1=17,n2=17,LogPval=-0.021107
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in double_scalars
# m=357,l=2,n1=17,n2=4,LogPval=-0.012441
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=8,n1=17,n2=28,LogPval=-0.033131
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=17,n1=17,n2=208,LogPval=-0.026522
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=5,n1=17,n2=14,LogPval=-0.023968
# m=355,l=8,n1=17,n2=44,LogPval=-0.023097
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=350,l=0,n1=17,n2=1,LogPval=-0.000142
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=351,l=6,n1=16,n2=27,LogPval=-0.021632
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=6,n1=17,n2=22,LogPval=-0.023872
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=1,n1=17,n2=4,LogPval=-0.005032
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=8,n1=17,n2=30,LogPval=-0.031513
# m=357,l=1,n1=17,n2=6,LogPval=-0.004157
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=1,n1=17,n2=2,LogPval=-0.006715
# m=353,l=2,n1=17,n2=8,LogPval=-0.008657
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=339,l=6,n1=17,n2=19,LogPval=-0.026977
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=4,n1=17,n2=5,LogPval=-0.030726
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 7 m=1713,l=3,n1=12,n2=34,LogPval=-0.003864
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2125,l=6,n1=15,n2=15,LogPval=-0.010534
# m=2113,l=11,n1=15,n2=259,LogPval=-0.007838
# m=1733,l=10,n1=11,n2=967,LogPval=-0.002463
# m=1384,l=3,n1=7,n2=69,LogPval=-0.004103
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1052,l=5,n1=9,n2=85,LogPval=-0.007767
# m=1765,l=1,n1=12,n2=6,LogPval=-0.001830
# m=1404,l=1,n1=9,n2=7,LogPval=-0.002235
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2122,l=4,n1=15,n2=14,LogPval=-0.006307
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1743,l=4,n1=12,n2=102,LogPval=-0.003253
# m=681,l=1,n1=5,n2=10,LogPval=-0.003913
# m=2113,l=12,n1=15,n2=1159,LogPval=-0.001648
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=703,l=2,n1=6,n2=12,LogPval=-0.007932
# m=2117,l=8,n1=15,n2=161,LogPval=-0.005920
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2104,l=4,n1=15,n2=6,LogPval=-0.008322
# m=1044,l=0,n1=6,n2=2,LogPval=-0.000011
# m=1042,l=3,n1=9,n2=36,LogPval=-0.005702
# m=1054,l=2,n1=6,n2=8,LogPval=-0.006840
# m=1767,l=5,n1=12,n2=38,LogPval=-0.007314
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=333,l=1,n1=1,n2=32,LogPval=-0.007034
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1754,l=1,n1=12,n2=21,LogPval=-0.001178
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=693,l=1,n1=5,n2=22,LogPval=-0.002834
# m=2112,l=6,n1=15,n2=18,LogPval=-0.009967
# m=1377,l=0,n1=9,n2=1,LogPval=-0.000005
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=353,l=1,n1=1,n2=168,LogPval=-0.002103
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1371,l=6,n1=13,n2=37,LogPval=-0.010798
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2110,l=5,n1=15,n2=14,LogPval=-0.008490
# m=693,l=0,n1=1,n2=2,LogPval=-0.000004
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 8 m=2740,l=246,n1=570,n2=987,LogPval=-0.004041
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2398,l=240,n1=704,n2=599,LogPval=-0.010215
# m=3058,l=317,n1=574,n2=1031,LogPval=-0.023859
# m=2741,l=596,n1=704,n2=1166,LogPval=-0.132432
# m=3459,l=487,n1=713,n2=840,LogPval=-0.121939
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1672,l=5,n1=145,n2=6,LogPval=-0.006331
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2404,l=3,n1=701,n2=176,LogPval=-0.021680
# m=3100,l=16,n1=576,n2=481,LogPval=-0.019723
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3096,l=187,n1=572,n2=720,LogPval=-0.006358
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=312,l=14,n1=113,n2=15,LogPval=-0.039929
# m=3093,l=264,n1=559,n2=995,LogPval=-0.011996
# m=1671,l=524,n1=679,n2=681,LogPval=-0.200018
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3079,l=153,n1=574,n2=570,LogPval=-0.005702
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1714,l=502,n1=693,n2=589,LogPval=-0.233357
# m=682,l=273,n1=299,n2=305,LogPval=-0.399059
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3448,l=551,n1=711,n2=1199,LogPval=-0.102531
# m=2023,l=32,n1=395,n2=91,LogPval=-0.004357
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=342,l=23,n1=136,n2=23,LogPval=-0.065571
# m=2058,l=625,n1=701,n2=871,LogPval=-0.253558
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=687,l=190,n1=275,n2=228,LogPval=-0.206682
# m=2363,l=0,n1=576,n2=2,LogPval=-0.000237
# m=674,l=243,n1=274,n2=318,LogPval=-0.264720
# m=349,l=134,n1=153,n2=150,LogPval=-0.364158
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1379,l=2,n1=429,n2=92,LogPval=-0.020875
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1383,l=469,n1=575,n2=563,LogPval=-0.268784
# m=1330,l=283,n1=417,n2=463,LogPval=-0.110743
# m=336,l=113,n1=125,n2=146,LogPval=-0.299283
# m=1022,l=192,n1=274,n2=383,LogPval=-0.084642
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3427,l=41,n1=713,n2=531,LogPval=-0.012226
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1036,l=36,n1=425,n2=37,LogPval=-0.028831
# m=350,l=0,n1=137,n2=0,LogPval=0.000000
# 9 m=5975,l=195,n1=352,n2=2595,LogPval=-0.002327
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5551,l=286,n1=657,n2=2199,LogPval=-0.001039
# m=5909,l=300,n1=758,n2=1946,LogPval=-0.002017
# m=5632,l=776,n1=869,n2=2333,LogPval=-0.091950
# m=7399,l=302,n1=569,n2=1189,LogPval=-0.031666
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1672,l=5,n1=6,n2=145,LogPval=-0.006331
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5570,l=11,n1=957,n2=263,LogPval=-0.004319
# m=7030,l=124,n1=1077,n2=934,LogPval=-0.000709
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6634,l=143,n1=832,n2=1087,LogPval=-0.000521
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=7361,l=907,n1=976,n2=3211,LogPval=-0.084312
# m=4496,l=517,n1=683,n2=1829,LogPval=-0.046225
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=7654,l=116,n1=727,n2=1366,LogPval=-0.000545
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3841,l=611,n1=722,n2=1503,LogPval=-0.103429
# m=2085,l=649,n1=760,n2=840,LogPval=-0.261768
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=8024,l=767,n1=938,n2=2730,LogPval=-0.064947
# m=5168,l=13,n1=561,n2=364,LogPval=-0.003103
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1044,l=5,n1=14,n2=88,LogPval=-0.005387
# m=3900,l=321,n1=351,n2=1701,LogPval=-0.051256
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4214,l=638,n1=793,n2=1475,LogPval=-0.103539
# m=6925,l=1,n1=958,n2=9,LogPval=-0.000140
# m=3421,l=496,n1=584,n2=1497,LogPval=-0.075472
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3511,l=715,n1=952,n2=1176,LogPval=-0.142621
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4545,l=542,n1=638,n2=1867,LogPval=-0.067795
# m=3747,l=433,n1=623,n2=1302,LogPval=-0.051554
# m=679,l=280,n1=339,n2=304,LogPval=-0.331861
# m=4236,l=270,n1=327,n2=1543,LogPval=-0.038424
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6968,l=122,n1=747,n2=1250,LogPval=-0.000564
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1042,l=1,n1=14,n2=6,LogPval=-0.002477
# 10 m=2462,l=23,n1=191,n2=47,LogPval=-0.012748
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2884,l=13,n1=212,n2=29,LogPval=-0.006034
# m=2845,l=120,n1=209,n2=340,LogPval=-0.050734
# m=1393,l=124,n1=125,n2=825,LogPval=-0.046683
# m=1761,l=86,n1=140,n2=204,LogPval=-0.066852
# m=355,l=8,n1=50,n2=17,LogPval=-0.020475
# m=1052,l=5,n1=85,n2=9,LogPval=-0.007767
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2146,l=25,n1=147,n2=46,LogPval=-0.018979
# m=700,l=3,n1=63,n2=5,LogPval=-0.007351
# m=721,l=12,n1=60,n2=21,LogPval=-0.026304
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2485,l=11,n1=192,n2=14,LogPval=-0.009162
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2484,l=71,n1=192,n2=163,LogPval=-0.036888
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2154,l=186,n1=192,n2=1182,LogPval=-0.045558
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1804,l=28,n1=126,n2=36,LogPval=-0.033695
# m=2866,l=111,n1=211,n2=230,LogPval=-0.059853
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2827,l=4,n1=210,n2=5,LogPval=-0.003146
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2440,l=44,n1=155,n2=101,LogPval=-0.026129
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2501,l=59,n1=191,n2=89,LogPval=-0.043315
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=722,l=5,n1=102,n2=5,LogPval=-0.013672
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1081,l=32,n1=106,n2=51,LogPval=-0.045296
# m=2161,l=14,n1=155,n2=36,LogPval=-0.007819
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2874,l=10,n1=212,n2=14,LogPval=-0.006838
# m=1411,l=12,n1=124,n2=14,LogPval=-0.017959
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2092,l=34,n1=193,n2=53,LogPval=-0.025322
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2881,l=14,n1=212,n2=19,LogPval=-0.009696
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 11 m=12457,l=432,n1=575,n2=2216,LogPval=-0.039112
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16584,l=200,n1=298,n2=2030,LogPval=-0.015372
# m=15857,l=367,n1=546,n2=2964,LogPval=-0.020548
# m=15092,l=193,n1=224,n2=7357,LogPval=-0.004826
# m=15538,l=250,n1=528,n2=4012,LogPval=-0.003983
# m=357,l=5,n1=17,n2=17,LogPval=-0.021107
# m=1765,l=1,n1=6,n2=12,LogPval=-0.001830
# m=2404,l=3,n1=176,n2=701,LogPval=-0.021680
# m=5570,l=11,n1=263,n2=957,LogPval=-0.004319
# m=2146,l=25,n1=46,n2=147,LogPval=-0.018979
# m=15173,l=265,n1=402,n2=542,LogPval=-0.046612
# m=354,l=6,n1=20,n2=13,LogPval=-0.030709
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=17403,l=224,n1=336,n2=1973,LogPval=-0.017277
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5270,l=25,n1=52,n2=317,LogPval=-0.007389
# m=14851,l=254,n1=271,n2=3794,LogPval=-0.019973
# m=14687,l=94,n1=100,n2=6987,LogPval=-0.003616
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=13969,l=284,n1=515,n2=1068,LogPval=-0.030898
# m=4675,l=66,n1=105,n2=387,LogPval=-0.022662
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16632,l=44,n1=104,n2=3598,LogPval=-0.000827
# m=11435,l=26,n1=35,n2=4210,LogPval=-0.001055
# m=1751,l=11,n1=26,n2=69,LogPval=-0.012011
# m=1094,l=0,n1=3,n2=8,LogPval=-0.000020
# m=17005,l=260,n1=352,n2=4998,LogPval=-0.009100
# m=6709,l=82,n1=244,n2=346,LogPval=-0.015932
# m=336,l=0,n1=1,n2=32,LogPval=-0.000298
# m=721,l=1,n1=37,n2=5,LogPval=-0.002172
# m=1076,l=8,n1=17,n2=94,LogPval=-0.009704
# m=8659,l=48,n1=50,n2=3894,LogPval=-0.003764
# m=342,l=0,n1=0,n2=32,LogPval=-0.000000
# m=5430,l=42,n1=66,n2=1550,LogPval=-0.003680
# m=16789,l=6,n1=284,n2=67,LogPval=-0.000425
# m=6075,l=39,n1=40,n2=2736,LogPval=-0.004636
# m=3243,l=1,n1=1,n2=1456,LogPval=-0.000247
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=730,l=0,n1=2,n2=22,LogPval=-0.000084
# m=3618,l=3,n1=50,n2=19,LogPval=-0.001724
# m=14141,l=28,n1=83,n2=1944,LogPval=-0.000926
# m=365,l=47,n1=51,n2=119,LogPval=-0.133579
# m=13038,l=46,n1=52,n2=5689,LogPval=-0.001905
# m=8521,l=153,n1=177,n2=3258,LogPval=-0.010878
# m=3999,l=4,n1=4,n2=1802,LogPval=-0.000798
# m=5359,l=152,n1=218,n2=1378,LogPval=-0.018648
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16638,l=358,n1=502,n2=908,LogPval=-0.049684
# m=1086,l=1,n1=2,n2=2,LogPval=-0.005161
# m=1824,l=2,n1=10,n2=92,LogPval=-0.001417
# m=1091,l=1,n1=17,n2=5,LogPval=-0.002394
# 12 m=17134,l=2075,n1=2913,n2=4392,LogPval=-0.098469
# m=1084,l=189,n1=242,n2=312,LogPval=-0.162050
# m=14330,l=487,n1=647,n2=2055,LogPval=-0.046125
# m=22962,l=2286,n1=3278,n2=5293,LogPval=-0.086097
# m=14000,l=598,n1=731,n2=6591,LogPval=-0.014386
# m=22011,l=1784,n1=3696,n2=5151,LogPval=-0.030946
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1404,l=1,n1=7,n2=9,LogPval=-0.002235
# m=3100,l=16,n1=481,n2=576,LogPval=-0.019723
# m=7030,l=124,n1=934,n2=1077,LogPval=-0.000709
# m=700,l=3,n1=5,n2=63,LogPval=-0.007351
# m=15173,l=265,n1=542,n2=402,LogPval=-0.046612
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16934,l=889,n1=1277,n2=2539,LogPval=-0.065137
# m=704,l=109,n1=229,n2=141,LogPval=-0.112435
# m=3824,l=9,n1=35,n2=229,LogPval=-0.002344
# m=14800,l=913,n1=1015,n2=4159,LogPval=-0.063374
# m=11746,l=276,n1=319,n2=5435,LogPval=-0.010122
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=21168,l=2188,n1=3418,n2=2887,LogPval=-0.153852
# m=6456,l=1075,n1=1229,n2=1603,LogPval=-0.224071
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=12976,l=37,n1=95,n2=3209,LogPval=-0.000553
# m=10311,l=62,n1=77,n2=3827,LogPval=-0.003185
# m=691,l=0,n1=5,n2=19,LogPval=-0.000202
# m=1082,l=0,n1=6,n2=8,LogPval=-0.000041
# m=16621,l=1184,n1=1315,n2=5314,LogPval=-0.064239
# m=7819,l=181,n1=735,n2=281,LogPval=-0.035523
# m=335,l=1,n1=2,n2=31,LogPval=-0.005317
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=363,l=5,n1=7,n2=34,LogPval=-0.025469
# m=7552,l=165,n1=177,n2=3364,LogPval=-0.013346
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4308,l=30,n1=34,n2=1490,LogPval=-0.005332
# m=14915,l=67,n1=887,n2=102,LogPval=-0.008742
# m=5727,l=37,n1=38,n2=2559,LogPval=-0.004697
# m=2856,l=37,n1=39,n2=1279,LogPval=-0.008603
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=719,l=3,n1=4,n2=22,LogPval=-0.012849
# m=2144,l=2,n1=13,n2=13,LogPval=-0.002794
# m=11953,l=104,n1=195,n2=1916,LogPval=-0.006366
# m=1392,l=314,n1=434,n2=401,LogPval=-0.208886
# m=10852,l=86,n1=90,n2=4751,LogPval=-0.005436
# m=6722,l=169,n1=180,n2=2666,LogPval=-0.018681
# m=3263,l=20,n1=21,n2=1487,LogPval=-0.004090
# m=6472,l=583,n1=848,n2=1750,LogPval=-0.059068
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=21242,l=2618,n1=3227,n2=3724,LogPval=-0.195069
# m=1079,l=0,n1=4,n2=2,LogPval=-0.000007
# m=1823,l=8,n1=11,n2=92,LogPval=-0.010546
# m=363,l=0,n1=7,n2=1,LogPval=-0.000054
# 13 m=708,l=3,n1=21,n2=24,LogPval=-0.005137
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=726,l=1,n1=21,n2=1,LogPval=-0.004880
# m=711,l=2,n1=20,n2=4,LogPval=-0.007667
# m=350,l=13,n1=13,n2=226,LogPval=-0.016607
# m=712,l=18,n1=21,n2=95,LogPval=-0.043426
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=721,l=12,n1=21,n2=60,LogPval=-0.026304
# m=354,l=6,n1=13,n2=20,LogPval=-0.030709
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=691,l=1,n1=18,n2=2,LogPval=-0.004312
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=696,l=10,n1=19,n2=71,LogPval=-0.018442
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=363,l=13,n1=13,n2=208,LogPval=-0.020398
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=724,l=8,n1=20,n2=19,LogPval=-0.026582
# m=724,l=17,n1=21,n2=65,LogPval=-0.047884
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=711,l=0,n1=21,n2=0,LogPval=-0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=352,l=6,n1=8,n2=20,LogPval=-0.041889
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=705,l=14,n1=21,n2=22,LogPval=-0.059910
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=363,l=1,n1=13,n2=1,LogPval=-0.009172
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=363,l=7,n1=13,n2=14,LogPval=-0.047407
# m=722,l=3,n1=21,n2=11,LogPval=-0.008110
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=720,l=0,n1=21,n2=0,LogPval=0.000000
# m=363,l=3,n1=13,n2=5,LogPval=-0.021986
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=708,l=1,n1=21,n2=7,LogPval=-0.002464
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=725,l=1,n1=21,n2=4,LogPval=-0.003089
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 14 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=723,l=188,n1=219,n2=287,LogPval=-0.205901
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1093,l=94,n1=358,n2=113,LogPval=-0.065191
# m=361,l=36,n1=133,n2=51,LogPval=-0.044422
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=703,l=106,n1=224,n2=119,LogPval=-0.152111
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1820,l=391,n1=587,n2=449,LogPval=-0.226091
# m=1065,l=149,n1=329,n2=185,LogPval=-0.116225
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1094,l=338,n1=398,n2=396,LogPval=-0.319731
# m=364,l=47,n1=102,n2=54,LogPval=-0.142212
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=727,l=112,n1=203,n2=125,LogPval=-0.185662
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 15 m=14541,l=1037,n1=1325,n2=3036,LogPval=-0.078713
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=17533,l=925,n1=2262,n2=2356,LogPval=-0.036661
# m=16882,l=1265,n1=2124,n2=3346,LogPval=-0.057618
# m=15428,l=1690,n1=1958,n2=7414,LogPval=-0.046648
# m=17254,l=1607,n1=2541,n2=4003,LogPval=-0.066137
# m=357,l=2,n1=4,n2=17,LogPval=-0.012441
# m=2122,l=4,n1=14,n2=15,LogPval=-0.006307
# m=3096,l=187,n1=720,n2=572,LogPval=-0.006358
# m=6634,l=143,n1=1087,n2=832,LogPval=-0.000521
# m=2485,l=11,n1=14,n2=192,LogPval=-0.009162
# m=17403,l=224,n1=1973,n2=336,LogPval=-0.017277
# m=16934,l=889,n1=2539,n2=1277,LogPval=-0.065137
# m=691,l=1,n1=2,n2=18,LogPval=-0.004312
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5601,l=68,n1=334,n2=358,LogPval=-0.007539
# m=16563,l=1878,n1=2605,n2=4415,LogPval=-0.087422
# m=15000,l=1008,n1=1200,n2=7097,LogPval=-0.025431
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16009,l=897,n1=1738,n2=1653,LogPval=-0.072516
# m=4684,l=27,n1=40,n2=357,LogPval=-0.010286
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16236,l=1302,n1=1656,n2=3280,LogPval=-0.093959
# m=11049,l=1127,n1=1260,n2=4021,LogPval=-0.079599
# m=2095,l=6,n1=13,n2=93,LogPval=-0.005583
# m=1092,l=2,n1=6,n2=8,LogPval=-0.006666
# m=18763,l=1890,n1=2239,n2=5401,LogPval=-0.093267
# m=8129,l=199,n1=1945,n2=416,LogPval=-0.007720
# m=336,l=4,n1=6,n2=32,LogPval=-0.020984
# m=717,l=1,n1=5,n2=4,LogPval=-0.005016
# m=1441,l=76,n1=165,n2=115,LogPval=-0.079808
# m=7931,l=1108,n1=1231,n2=3530,LogPval=-0.084353
# m=342,l=10,n1=30,n2=32,LogPval=-0.027263
# m=5427,l=281,n1=323,n2=1537,LogPval=-0.048671
# m=17430,l=23,n1=2015,n2=75,LogPval=-0.000697
# m=5348,l=898,n1=986,n2=2411,LogPval=-0.106925
# m=3237,l=67,n1=71,n2=1456,LogPval=-0.013255
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=728,l=0,n1=0,n2=22,LogPval=0.000000
# m=3954,l=4,n1=20,n2=23,LogPval=-0.003150
# m=14129,l=806,n1=1690,n2=2018,LogPval=-0.046337
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=12328,l=1196,n1=1356,n2=5363,LogPval=-0.054104
# m=8157,l=820,n1=996,n2=3112,LogPval=-0.057889
# m=3269,l=719,n1=832,n2=1482,LogPval=-0.125228
# m=6047,l=387,n1=492,n2=1353,LogPval=-0.065500
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=17615,l=860,n1=2178,n2=1491,LogPval=-0.057615
# m=1085,l=0,n1=6,n2=2,LogPval=-0.000010
# m=1459,l=39,n1=206,n2=87,LogPval=-0.019474
# m=1447,l=6,n1=165,n2=7,LogPval=-0.007796
# 16 m=696,l=56,n1=144,n2=166,LogPval=-0.018622
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=351,l=31,n1=42,n2=91,LogPval=-0.075303
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=340,l=74,n1=102,n2=95,LogPval=-0.212460
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=704,l=109,n1=141,n2=229,LogPval=-0.112435
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=707,l=87,n1=144,n2=166,LogPval=-0.088700
# m=350,l=88,n1=102,n2=146,LogPval=-0.182672
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=678,l=109,n1=138,n2=216,LogPval=-0.127922
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=691,l=127,n1=144,n2=282,LogPval=-0.131631
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 17 m=4848,l=42,n1=309,n2=108,LogPval=-0.010837
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5990,l=22,n1=378,n2=58,LogPval=-0.004562
# m=5274,l=170,n1=348,n2=670,LogPval=-0.028867
# m=4474,l=271,n1=289,n2=2431,LogPval=-0.026947
# m=4515,l=137,n1=301,n2=896,LogPval=-0.012841
# m=357,l=8,n1=28,n2=17,LogPval=-0.033131
# m=1743,l=4,n1=102,n2=12,LogPval=-0.003253
# m=312,l=14,n1=15,n2=113,LogPval=-0.039929
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2484,l=71,n1=163,n2=192,LogPval=-0.036888
# m=5270,l=25,n1=317,n2=52,LogPval=-0.007389
# m=3824,l=9,n1=229,n2=35,LogPval=-0.002344
# m=696,l=10,n1=71,n2=19,LogPval=-0.018442
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5601,l=68,n1=358,n2=334,LogPval=-0.007539
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2431,l=6,n1=123,n2=25,LogPval=-0.002830
# m=4916,l=286,n1=294,n2=2657,LogPval=-0.031411
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4199,l=23,n1=265,n2=68,LogPval=-0.006179
# m=4584,l=117,n1=319,n2=359,LogPval=-0.026791
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5589,l=52,n1=341,n2=279,LogPval=-0.005427
# m=2759,l=47,n1=161,n2=461,LogPval=-0.003952
# m=2083,l=27,n1=120,n2=86,LogPval=-0.015219
# m=1066,l=4,n1=73,n2=8,LogPval=-0.006401
# m=4929,l=66,n1=334,n2=388,LogPval=-0.005880
# m=678,l=4,n1=52,n2=11,LogPval=-0.007524
# m=323,l=11,n1=28,n2=31,LogPval=-0.036843
# m=710,l=3,n1=66,n2=5,LogPval=-0.007117
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1369,l=53,n1=59,n2=593,LogPval=-0.022843
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1071,l=23,n1=86,n2=48,LogPval=-0.029422
# m=4561,l=12,n1=277,n2=36,LogPval=-0.003144
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=702,l=4,n1=7,n2=258,LogPval=-0.002597
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=716,l=6,n1=44,n2=22,LogPval=-0.009416
# m=3912,l=11,n1=265,n2=19,LogPval=-0.004886
# m=4172,l=11,n1=249,n2=19,LogPval=-0.004903
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2431,l=141,n1=153,n2=1125,LogPval=-0.033110
# m=362,l=1,n1=1,n2=175,LogPval=-0.002008
# m=689,l=21,n1=24,n2=303,LogPval=-0.016965
# m=2077,l=22,n1=140,n2=56,LogPval=-0.013332
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5649,l=19,n1=344,n2=46,LogPval=-0.004639
# m=1056,l=0,n1=90,n2=2,LogPval=-0.000169
# m=338,l=7,n1=18,n2=18,LogPval=-0.034956
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 18 m=11009,l=2149,n1=2686,n2=2958,LogPval=-0.219111
# m=358,l=90,n1=102,n2=139,LogPval=-0.220442
# m=14940,l=2211,n1=3918,n2=2682,LogPval=-0.161061
# m=14347,l=1987,n1=3553,n2=3222,LogPval=-0.095424
# m=14746,l=3334,n1=4004,n2=6763,LogPval=-0.111128
# m=14801,l=1861,n1=4072,n2=3952,LogPval=-0.033319
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=681,l=1,n1=10,n2=5,LogPval=-0.003913
# m=3093,l=264,n1=995,n2=559,LogPval=-0.011996
# m=7361,l=907,n1=3211,n2=976,LogPval=-0.084312
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=14851,l=254,n1=3794,n2=271,LogPval=-0.019973
# m=14800,l=913,n1=4159,n2=1015,LogPval=-0.063374
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=703,l=106,n1=119,n2=224,LogPval=-0.152111
# m=16563,l=1878,n1=4415,n2=2605,LogPval=-0.087422
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2431,l=6,n1=25,n2=123,LogPval=-0.002830
# m=12752,l=2538,n1=3244,n2=5707,LogPval=-0.080090
# m=1749,l=258,n1=342,n2=432,LogPval=-0.150498
# m=14564,l=1525,n1=3703,n2=1777,LogPval=-0.116666
# m=1074,l=6,n1=13,n2=75,LogPval=-0.008549
# m=352,l=101,n1=104,n2=134,LogPval=-0.352177
# m=350,l=9,n1=14,n2=52,LogPval=-0.031046
# m=14076,l=2705,n1=3361,n2=3773,LogPval=-0.216770
# m=10646,l=1992,n1=2391,n2=4170,LogPval=-0.121132
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=716,l=0,n1=10,n2=6,LogPval=-0.000118
# m=16932,l=3501,n1=4726,n2=5708,LogPval=-0.138912
# m=9223,l=333,n1=3457,n2=375,LogPval=-0.024580
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1427,l=106,n1=628,n2=112,LogPval=-0.051743
# m=9020,l=2360,n1=2603,n2=4008,LogPval=-0.192484
# m=340,l=4,n1=7,n2=32,LogPval=-0.018636
# m=5407,l=1766,n1=2422,n2=1854,LogPval=-0.308399
# m=16314,l=50,n1=4888,n2=90,LogPval=-0.000933
# m=6790,l=2333,n1=2632,n2=3014,LogPval=-0.277043
# m=2841,l=16,n1=17,n2=1274,LogPval=-0.003745
# m=714,l=79,n1=120,n2=143,LogPval=-0.111650
# m=717,l=2,n1=10,n2=22,LogPval=-0.004790
# m=707,l=2,n1=10,n2=5,LogPval=-0.008985
# m=12662,l=2141,n1=3069,n2=2264,LogPval=-0.269276
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=12971,l=2820,n1=3322,n2=5555,LogPval=-0.130858
# m=9170,l=2145,n1=2948,n2=3522,LogPval=-0.119529
# m=4358,l=1051,n1=1233,n2=1954,LogPval=-0.139005
# m=5036,l=1557,n1=2049,n2=1694,LogPval=-0.304473
# m=362,l=28,n1=70,n2=33,LogPval=-0.109188
# m=15115,l=1244,n1=4212,n2=1487,LogPval=-0.075574
# m=357,l=0,n1=2,n2=1,LogPval=-0.000016
# m=1448,l=19,n1=39,n2=105,LogPval=-0.019174
# m=1433,l=5,n1=633,n2=6,LogPval=-0.002011
# 19 m=11612,l=1505,n1=5571,n2=1856,LogPval=-0.044468
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=15192,l=1441,n1=7200,n2=1834,LogPval=-0.028206
# m=13882,l=2249,n1=6704,n2=2539,LogPval=-0.080419
# m=13765,l=5623,n1=6499,n2=6669,LogPval=-0.288722
# m=12775,l=2666,n1=6047,n2=3105,LogPval=-0.103066
# m=357,l=17,n1=208,n2=17,LogPval=-0.026522
# m=2113,l=12,n1=1159,n2=15,LogPval=-0.001648
# m=1671,l=524,n1=681,n2=679,LogPval=-0.200018
# m=4496,l=517,n1=1829,n2=683,LogPval=-0.046225
# m=2154,l=186,n1=1182,n2=192,LogPval=-0.045558
# m=14687,l=94,n1=6987,n2=100,LogPval=-0.003616
# m=11746,l=276,n1=5435,n2=319,LogPval=-0.010122
# m=363,l=13,n1=208,n2=13,LogPval=-0.020398
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=15000,l=1008,n1=7097,n2=1200,LogPval=-0.025431
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4916,l=286,n1=2657,n2=294,LogPval=-0.031411
# m=12752,l=2538,n1=5707,n2=3244,LogPval=-0.080090
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=12370,l=907,n1=5789,n2=1060,LogPval=-0.030811
# m=4352,l=328,n1=2392,n2=336,LogPval=-0.040694
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=14591,l=2290,n1=6963,n2=2747,LogPval=-0.063172
# m=9133,l=2629,n1=4351,n2=3211,LogPval=-0.135140
# m=1762,l=72,n1=941,n2=73,LogPval=-0.024354
# m=1086,l=8,n1=613,n2=8,LogPval=-0.004231
# m=14976,l=3602,n1=7122,n2=4243,LogPval=-0.118460
# m=5545,l=206,n1=2339,n2=254,LogPval=-0.015782
# m=336,l=31,n1=186,n2=32,LogPval=-0.049993
# m=730,l=5,n1=420,n2=5,LogPval=-0.003800
# m=1398,l=101,n1=618,n2=114,LogPval=-0.039873
# m=8101,l=2963,n1=3566,n2=3683,LogPval=-0.244422
# m=340,l=30,n1=205,n2=31,LogPval=-0.039674
# m=6086,l=1457,n1=2621,n2=1754,LogPval=-0.138741
# m=15459,l=68,n1=7236,n2=71,LogPval=-0.002763
# m=4910,l=1786,n1=2083,n2=2207,LogPval=-0.272585
# m=3185,l=1271,n1=1619,n2=1434,LogPval=-0.260335
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=722,l=21,n1=411,n2=22,LogPval=-0.013545
# m=3625,l=21,n1=2004,n2=23,LogPval=-0.002361
# m=12084,l=1247,n1=5803,n2=1513,LogPval=-0.036437
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=11702,l=4430,n1=5438,n2=5128,LogPval=-0.275917
# m=7283,l=2397,n1=3196,n2=2890,LogPval=-0.218792
# m=2424,l=944,n1=1122,n2=1110,LogPval=-0.283285
# m=6013,l=1210,n1=2734,n2=1477,LogPval=-0.091989
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=13552,l=504,n1=6561,n2=564,LogPval=-0.016625
# m=1086,l=2,n1=602,n2=2,LogPval=-0.001087
# m=1740,l=88,n1=820,n2=90,LogPval=-0.035453
# m=1404,l=6,n1=623,n2=7,LogPval=-0.002511
# 20 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1426,l=316,n1=392,n2=528,LogPval=-0.157912
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1443,l=119,n1=316,n2=203,LogPval=-0.055860
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=348,l=19,n1=83,n2=35,LogPval=-0.029870
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1820,l=391,n1=449,n2=587,LogPval=-0.226091
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1749,l=258,n1=432,n2=342,LogPval=-0.150498
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1423,l=156,n1=316,n2=215,LogPval=-0.110556
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=729,l=155,n1=170,n2=270,LogPval=-0.202477
# m=363,l=44,n1=83,n2=54,LogPval=-0.148212
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1424,l=202,n1=387,n2=235,LogPval=-0.158719
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=338,l=43,n1=94,n2=47,LogPval=-0.155089
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=727,l=101,n1=154,n2=146,LogPval=-0.151291
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=364,l=31,n1=94,n2=33,LogPval=-0.110979
# m=365,l=32,n1=60,n2=50,LogPval=-0.103449
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 21 m=19148,l=2321,n1=3021,n2=5027,LogPval=-0.109484
# m=1079,l=193,n1=221,n2=390,LogPval=-0.150068
# m=14494,l=1007,n1=1353,n2=2565,LogPval=-0.083872
# m=21355,l=2102,n1=2848,n2=5003,LogPval=-0.091548
# m=12751,l=1189,n1=1440,n2=5820,LogPval=-0.037141
# m=23271,l=1749,n1=3612,n2=4787,LogPval=-0.037204
# m=357,l=5,n1=14,n2=17,LogPval=-0.023968
# m=703,l=2,n1=12,n2=6,LogPval=-0.007932
# m=3079,l=153,n1=570,n2=574,LogPval=-0.005702
# m=7654,l=116,n1=1366,n2=727,LogPval=-0.000545
# m=1804,l=28,n1=36,n2=126,LogPval=-0.033695
# m=13969,l=284,n1=1068,n2=515,LogPval=-0.030898
# m=21168,l=2188,n1=2887,n2=3418,LogPval=-0.153852
# m=724,l=8,n1=19,n2=20,LogPval=-0.026582
# m=1065,l=149,n1=185,n2=329,LogPval=-0.116225
# m=16009,l=897,n1=1653,n2=1738,LogPval=-0.072516
# m=707,l=87,n1=166,n2=144,LogPval=-0.088700
# m=4199,l=23,n1=68,n2=265,LogPval=-0.006179
# m=14564,l=1525,n1=1777,n2=3703,LogPval=-0.116666
# m=12370,l=907,n1=1060,n2=5789,LogPval=-0.030811
# m=1423,l=156,n1=215,n2=316,LogPval=-0.110556
# m=6463,l=586,n1=673,n2=1394,LogPval=-0.119686
# m=347,l=55,n1=66,n2=123,LogPval=-0.121598
# m=359,l=16,n1=25,n2=54,LogPval=-0.052875
# m=12490,l=542,n1=825,n2=2321,LogPval=-0.039091
# m=8103,l=159,n1=194,n2=3005,LogPval=-0.010738
# m=1399,l=10,n1=18,n2=62,LogPval=-0.015380
# m=716,l=2,n1=12,n2=7,LogPval=-0.007387
# m=17187,l=1641,n1=2055,n2=4875,LogPval=-0.079696
# m=7682,l=297,n1=1376,n2=437,LogPval=-0.037875
# m=336,l=5,n1=6,n2=32,LogPval=-0.030799
# m=730,l=2,n1=31,n2=5,LogPval=-0.005711
# m=1417,l=97,n1=502,n2=109,LogPval=-0.053611
# m=7506,l=822,n1=873,n2=3320,LogPval=-0.075619
# m=334,l=12,n1=28,n2=32,LogPval=-0.042312
# m=5730,l=534,n1=677,n2=1606,LogPval=-0.077113
# m=15167,l=83,n1=1678,n2=133,LogPval=-0.006906
# m=4562,l=587,n1=633,n2=2022,LogPval=-0.085837
# m=2836,l=59,n1=60,n2=1262,LogPval=-0.015873
# m=356,l=20,n1=30,n2=47,LogPval=-0.079610
# m=351,l=2,n1=6,n2=13,LogPval=-0.011651
# m=2890,l=5,n1=48,n2=13,LogPval=-0.004727
# m=10053,l=332,n1=590,n2=1082,LogPval=-0.040941
# m=1762,l=327,n1=438,n2=525,LogPval=-0.152923
# m=11073,l=897,n1=1026,n2=4775,LogPval=-0.043783
# m=6278,l=656,n1=864,n2=2337,LogPval=-0.050479
# m=1080,l=22,n1=26,n2=512,LogPval=-0.008836
# m=8184,l=970,n1=1258,n2=2152,LogPval=-0.107143
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=21104,l=2188,n1=3150,n2=3779,LogPval=-0.123658
# m=723,l=0,n1=6,n2=1,LogPval=-0.000012
# m=1808,l=18,n1=50,n2=100,LogPval=-0.013628
# m=1422,l=4,n1=504,n2=6,LogPval=-0.001631
# 22 m=6733,l=244,n1=1158,n2=338,LogPval=-0.040142
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5080,l=16,n1=392,n2=36,LogPval=-0.003959
# m=7809,l=913,n1=1497,n2=1392,LogPval=-0.123846
# m=3903,l=344,n1=380,n2=2138,LogPval=-0.033227
# m=7455,l=782,n1=1639,n2=1004,LogPval=-0.116999
# m=355,l=8,n1=44,n2=17,LogPval=-0.023097
# m=2117,l=8,n1=161,n2=15,LogPval=-0.005920
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2866,l=111,n1=230,n2=211,LogPval=-0.059853
# m=4675,l=66,n1=387,n2=105,LogPval=-0.022662
# m=6456,l=1075,n1=1603,n2=1229,LogPval=-0.224071
# m=724,l=17,n1=65,n2=21,LogPval=-0.047884
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4684,l=27,n1=357,n2=40,LogPval=-0.010286
# m=350,l=88,n1=146,n2=102,LogPval=-0.182672
# m=4584,l=117,n1=359,n2=319,LogPval=-0.026791
# m=1074,l=6,n1=75,n2=13,LogPval=-0.008549
# m=4352,l=328,n1=336,n2=2392,LogPval=-0.040694
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6463,l=586,n1=1394,n2=673,LogPval=-0.119686
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4641,l=7,n1=360,n2=10,LogPval=-0.002887
# m=1781,l=11,n1=140,n2=15,LogPval=-0.012034
# m=2452,l=55,n1=187,n2=101,LogPval=-0.034805
# m=1090,l=6,n1=87,n2=8,LogPval=-0.011150
# m=4693,l=89,n1=372,n2=122,LogPval=-0.036148
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=335,l=12,n1=32,n2=32,LogPval=-0.037110
# m=728,l=5,n1=81,n2=5,LogPval=-0.015235
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1091,l=37,n1=96,n2=51,LogPval=-0.064409
# m=4324,l=26,n1=337,n2=46,LogPval=-0.009115
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=727,l=11,n1=54,n2=22,LogPval=-0.023157
# m=4334,l=17,n1=337,n2=23,LogPval=-0.007554
# m=2853,l=12,n1=232,n2=18,LogPval=-0.007373
# m=1043,l=239,n1=338,n2=319,LogPval=-0.183049
# m=1443,l=97,n1=103,n2=689,LogPval=-0.040130
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3508,l=235,n1=539,n2=291,LogPval=-0.102221
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=8254,l=986,n1=1523,n2=1258,LogPval=-0.169474
# m=1080,l=1,n1=71,n2=2,LogPval=-0.001941
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 23 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=364,l=3,n1=126,n2=4,LogPval=-0.006123
# m=362,l=34,n1=125,n2=51,LogPval=-0.041085
# m=0,l=0,n1=0,n2=0,LogPval=nan
# ...
# m=11886,l=422,n1=5192,n2=450,LogPval=-0.022911
# m=714,l=1,n1=334,n2=1,LogPval=-0.001064
# m=1822,l=98,n1=791,n2=100,LogPval=-0.042759
# m=1437,l=5,n1=574,n2=7,LogPval=-0.001787
# 46 m=5608,l=963,n1=2175,n2=1448,LogPval=-0.056209
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=7310,l=923,n1=2775,n2=1511,LogPval=-0.029317
# m=7028,l=1277,n1=2890,n2=1604,LogPval=-0.092653
# m=8421,l=2786,n1=3235,n2=3826,LogPval=-0.226024
# m=6691,l=1601,n1=2562,n2=2007,LogPval=-0.159676
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1330,l=283,n1=463,n2=417,LogPval=-0.110743
# m=3747,l=433,n1=1302,n2=623,LogPval=-0.051554
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=8521,l=153,n1=3258,n2=177,LogPval=-0.010878
# m=6722,l=169,n1=2666,n2=180,LogPval=-0.018681
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=8157,l=820,n1=3112,n2=996,LogPval=-0.057889
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=362,l=1,n1=175,n2=1,LogPval=-0.002008
# m=9170,l=2145,n1=3522,n2=2948,LogPval=-0.119529
# m=7283,l=2397,n1=2890,n2=3196,LogPval=-0.218792
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6278,l=656,n1=2337,n2=864,LogPval=-0.050479
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=8175,l=1659,n1=3119,n2=2259,LogPval=-0.100936
# m=6269,l=2244,n1=2560,n2=2733,LogPval=-0.302138
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=8462,l=2744,n1=3244,n2=3202,LogPval=-0.315516
# m=4422,l=168,n1=1568,n2=236,LogPval=-0.015560
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1404,l=94,n1=400,n2=114,LogPval=-0.058038
# m=5606,l=2062,n1=2169,n2=2594,LogPval=-0.350601
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3513,l=985,n1=1169,n2=1233,LogPval=-0.278696
# m=9041,l=6,n1=3463,n2=8,LogPval=-0.000375
# m=3094,l=974,n1=1074,n2=1431,LogPval=-0.234652
# m=2489,l=979,n1=1098,n2=1180,LogPval=-0.310655
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=7097,l=1332,n1=2814,n2=1594,LogPval=-0.119963
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=7739,l=2596,n1=2933,n2=3327,LogPval=-0.283780
# m=2462,l=893,n1=1031,n2=1142,LogPval=-0.258177
# m=3137,l=858,n1=1072,n2=1158,LogPval=-0.215811
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=7443,l=378,n1=2817,n2=419,LogPval=-0.036270
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=353,l=19,n1=152,n2=19,LogPval=-0.047280
# m=1415,l=6,n1=400,n2=7,LogPval=-0.004233
# 47 m=350,l=14,n1=182,n2=16,LogPval=-0.017161
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2875,l=76,n1=1255,n2=85,LogPval=-0.014784
# m=2177,l=323,n1=995,n2=361,LogPval=-0.085127
# m=3613,l=1493,n1=1616,n2=1824,LogPval=-0.325233
# m=2912,l=1218,n1=1342,n2=1400,LogPval=-0.357903
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=336,l=113,n1=146,n2=125,LogPval=-0.299283
# m=679,l=280,n1=304,n2=339,LogPval=-0.331861
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3999,l=4,n1=1802,n2=4,LogPval=-0.000798
# m=3263,l=20,n1=1487,n2=21,LogPval=-0.004090
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3269,l=719,n1=1482,n2=832,LogPval=-0.125228
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=689,l=21,n1=303,n2=24,LogPval=-0.016965
# m=4358,l=1051,n1=1954,n2=1233,LogPval=-0.139005
# m=2424,l=944,n1=1110,n2=1122,LogPval=-0.283285
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1080,l=22,n1=512,n2=26,LogPval=-0.008836
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4361,l=1376,n1=1954,n2=1527,LogPval=-0.246735
# m=3547,l=1349,n1=1626,n2=1595,LogPval=-0.272403
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2880,l=1072,n1=1338,n2=1223,LogPval=-0.279408
# m=1769,l=12,n1=791,n2=14,LogPval=-0.003599
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2516,l=978,n1=1145,n2=1129,LogPval=-0.310885
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=341,l=117,n1=150,n2=135,LogPval=-0.269759
# m=3184,l=0,n1=1417,n2=0,LogPval=0.000000
# m=2152,l=859,n1=968,n2=963,LogPval=-0.366728
# m=722,l=260,n1=354,n2=288,LogPval=-0.254518
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4367,l=802,n1=1958,n2=903,LogPval=-0.110936
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3607,l=1370,n1=1638,n2=1573,LogPval=-0.302238
# m=2462,l=893,n1=1142,n2=1031,LogPval=-0.258177
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3266,l=13,n1=1469,n2=14,LogPval=-0.002563
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=727,l=46,n1=313,n2=46,LogPval=-0.056108
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 48 m=7066,l=1401,n1=1727,n2=2064,LogPval=-0.202607
# m=726,l=187,n1=217,n2=251,LogPval=-0.262286
# m=6407,l=1343,n1=1505,n2=1800,LogPval=-0.276917
# m=8176,l=1238,n1=1809,n2=1809,LogPval=-0.155924
# m=6072,l=1396,n1=1635,n2=2561,LogPval=-0.148682
# m=8907,l=1054,n1=2290,n2=1339,LogPval=-0.114339
# m=339,l=6,n1=19,n2=17,LogPval=-0.026977
# m=1371,l=6,n1=37,n2=13,LogPval=-0.010798
# m=1022,l=192,n1=383,n2=274,LogPval=-0.084642
# m=4236,l=270,n1=1543,n2=327,LogPval=-0.038424
# m=2092,l=34,n1=53,n2=193,LogPval=-0.025322
# m=5359,l=152,n1=1378,n2=218,LogPval=-0.018648
# m=6472,l=583,n1=1750,n2=848,LogPval=-0.059068
# m=708,l=1,n1=7,n2=21,LogPval=-0.002464
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6047,l=387,n1=1353,n2=492,LogPval=-0.065500
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2077,l=22,n1=56,n2=140,LogPval=-0.013332
# m=5036,l=1557,n1=1694,n2=2049,LogPval=-0.304473
# m=6013,l=1210,n1=1477,n2=2734,LogPval=-0.091989
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=8184,l=970,n1=2152,n2=1258,LogPval=-0.107143
# m=3508,l=235,n1=291,n2=539,LogPval=-0.102221
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5293,l=864,n1=1066,n2=1047,LogPval=-0.257712
# m=1411,l=302,n1=411,n2=377,LogPval=-0.224877
# m=1716,l=10,n1=44,n2=82,LogPval=-0.006296
# m=346,l=3,n1=10,n2=6,LogPval=-0.023172
# m=6408,l=1112,n1=1629,n2=1417,LogPval=-0.192963
# m=3524,l=184,n1=1247,n2=251,LogPval=-0.023759
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=703,l=2,n1=26,n2=5,LogPval=-0.006308
# m=1428,l=104,n1=472,n2=115,LogPval=-0.065105
# m=3614,l=1197,n1=1331,n2=1582,LogPval=-0.279261
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4318,l=973,n1=1335,n2=1240,LogPval=-0.211411
# m=6729,l=10,n1=1716,n2=39,LogPval=-0.000287
# m=3163,l=1087,n1=1160,n2=1392,LogPval=-0.330400
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=346,l=1,n1=10,n2=10,LogPval=-0.004283
# m=2452,l=7,n1=63,n2=18,LogPval=-0.006466
# m=3190,l=456,n1=699,n2=580,LogPval=-0.178948
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3963,l=1235,n1=1429,n2=1599,LogPval=-0.268778
# m=3137,l=858,n1=1158,n2=1072,LogPval=-0.215811
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6052,l=406,n1=1405,n2=484,LogPval=-0.074145
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1434,l=6,n1=474,n2=6,LogPval=-0.004647
# 49 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=362,l=28,n1=33,n2=70,LogPval=-0.109188
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=364,l=31,n1=33,n2=94,LogPval=-0.110979
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=339,l=21,n1=33,n2=47,LogPval=-0.081204
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=364,l=31,n1=33,n2=97,LogPval=-0.107826
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 50 m=19247,l=2276,n1=3210,n2=4585,LogPval=-0.105261
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16480,l=703,n1=944,n2=2361,LogPval=-0.058360
# m=21058,l=2262,n1=3198,n2=4878,LogPval=-0.096352
# m=14705,l=718,n1=831,n2=7063,LogPval=-0.019582
# m=22660,l=1706,n1=3850,n2=4830,LogPval=-0.028392
# m=357,l=4,n1=5,n2=17,LogPval=-0.030726
# m=2110,l=5,n1=14,n2=15,LogPval=-0.008490
# m=3427,l=41,n1=531,n2=713,LogPval=-0.012226
# m=6968,l=122,n1=1250,n2=747,LogPval=-0.000564
# m=2881,l=14,n1=19,n2=212,LogPval=-0.009696
# m=16638,l=358,n1=908,n2=502,LogPval=-0.049684
# m=21242,l=2618,n1=3724,n2=3227,LogPval=-0.195069
# m=725,l=1,n1=4,n2=21,LogPval=-0.003089
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=17615,l=860,n1=1491,n2=2178,LogPval=-0.057615
# m=691,l=127,n1=282,n2=144,LogPval=-0.131631
# m=5649,l=19,n1=46,n2=344,LogPval=-0.004639
# m=15115,l=1244,n1=1487,n2=4212,LogPval=-0.075574
# m=13552,l=504,n1=564,n2=6561,LogPval=-0.016625
# m=365,l=32,n1=50,n2=60,LogPval=-0.103449
# m=21104,l=2188,n1=3779,n2=3150,LogPval=-0.123658
# m=8254,l=986,n1=1258,n2=1523,LogPval=-0.169474
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=14789,l=87,n1=232,n2=2720,LogPval=-0.001802
# m=9278,l=106,n1=123,n2=3257,LogPval=-0.007772
# m=2466,l=4,n1=15,n2=101,LogPval=-0.002459
# m=1082,l=1,n1=8,n2=8,LogPval=-0.002656
# m=19108,l=1455,n1=1798,n2=5372,LogPval=-0.063927
# m=7377,l=225,n1=1113,n2=445,LogPval=-0.023172
# m=325,l=1,n1=2,n2=32,LogPval=-0.005309
# m=730,l=1,n1=9,n2=5,LogPval=-0.003878
# m=1071,l=24,n1=60,n2=94,LogPval=-0.024054
# m=6850,l=440,n1=471,n2=3043,LogPval=-0.040948
# m=342,l=6,n1=17,n2=32,LogPval=-0.017968
# m=4318,l=165,n1=201,n2=1164,LogPval=-0.033218
# m=16783,l=20,n1=1160,n2=77,LogPval=-0.000940
# m=4961,l=191,n1=201,n2=2244,LogPval=-0.025012
# m=2880,l=66,n1=70,n2=1272,LogPval=-0.015074
# m=364,l=27,n1=50,n2=49,LogPval=-0.086358
# m=730,l=2,n1=6,n2=22,LogPval=-0.006100
# m=4342,l=6,n1=27,n2=23,LogPval=-0.004522
# m=11940,l=113,n1=283,n2=1532,LogPval=-0.005885
# m=1737,l=441,n1=685,n2=524,LogPval=-0.189801
# m=11886,l=422,n1=450,n2=5192,LogPval=-0.022911
# m=7443,l=378,n1=419,n2=2817,LogPval=-0.036270
# m=3266,l=13,n1=14,n2=1469,LogPval=-0.002563
# m=6052,l=406,n1=484,n2=1405,LogPval=-0.074145
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1074,l=0,n1=3,n2=2,LogPval=-0.000005
# m=1825,l=3,n1=8,n2=80,LogPval=-0.003073
# m=1086,l=3,n1=60,n2=5,LogPval=-0.006023
# 51 m=1046,l=0,n1=2,n2=18,LogPval=-0.000033
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1086,l=0,n1=2,n2=1,LogPval=-0.000002
# m=1086,l=0,n1=2,n2=114,LogPval=-0.000204
# m=1053,l=2,n1=2,n2=578,LogPval=-0.001140
# m=1081,l=0,n1=2,n2=30,LogPval=-0.000052
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=693,l=0,n1=2,n2=1,LogPval=-0.000004
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1086,l=1,n1=2,n2=2,LogPval=-0.005161
# m=1079,l=0,n1=2,n2=4,LogPval=-0.000007
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1085,l=0,n1=2,n2=6,LogPval=-0.000010
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1056,l=0,n1=2,n2=90,LogPval=-0.000169
# m=357,l=0,n1=1,n2=2,LogPval=-0.000016
# m=1086,l=2,n1=2,n2=602,LogPval=-0.001087
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=723,l=0,n1=1,n2=6,LogPval=-0.000012
# m=1080,l=1,n1=2,n2=71,LogPval=-0.001941
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1076,l=0,n1=2,n2=2,LogPval=-0.000003
# m=711,l=0,n1=2,n2=2,LogPval=-0.000008
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=720,l=0,n1=2,n2=2,LogPval=-0.000008
# m=1086,l=0,n1=2,n2=12,LogPval=-0.000020
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=331,l=0,n1=1,n2=32,LogPval=-0.000307
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1075,l=0,n1=2,n2=1,LogPval=-0.000002
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=363,l=0,n1=1,n2=9,LogPval=-0.000069
# m=1078,l=0,n1=2,n2=3,LogPval=-0.000005
# m=707,l=0,n1=2,n2=0,LogPval=0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=714,l=1,n1=1,n2=334,LogPval=-0.001064
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1074,l=0,n1=2,n2=3,LogPval=-0.000005
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 52 m=711,l=7,n1=29,n2=27,LogPval=-0.014203
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2168,l=31,n1=119,n2=97,LogPval=-0.017778
# m=1795,l=84,n1=92,n2=406,LogPval=-0.060470
# m=1812,l=77,n1=80,n2=867,LogPval=-0.027102
# m=2187,l=118,n1=119,n2=1027,LogPval=-0.040591
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1036,l=36,n1=37,n2=425,LogPval=-0.028831
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1824,l=2,n1=92,n2=10,LogPval=-0.001417
# m=1823,l=8,n1=92,n2=11,LogPval=-0.010546
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1459,l=39,n1=87,n2=206,LogPval=-0.019474
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=338,l=7,n1=18,n2=18,LogPval=-0.034956
# m=1448,l=19,n1=105,n2=39,LogPval=-0.019174
# m=1740,l=88,n1=90,n2=820,LogPval=-0.035453
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1808,l=18,n1=100,n2=50,LogPval=-0.013628
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2178,l=116,n1=119,n2=835,LogPval=-0.048322
# m=1427,l=57,n1=61,n2=636,LogPval=-0.025615
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1824,l=91,n1=92,n2=741,LogPval=-0.044629
# m=1083,l=4,n1=51,n2=13,LogPval=-0.005695
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1811,l=89,n1=91,n2=792,LogPval=-0.038257
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1413,l=7,n1=69,n2=9,LogPval=-0.012698
# m=1090,l=70,n1=71,n2=520,LogPval=-0.046540
# m=365,l=9,n1=9,n2=156,LogPval=-0.021332
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2188,l=5,n1=119,n2=6,LogPval=-0.005896
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1822,l=98,n1=100,n2=791,LogPval=-0.042759
# m=353,l=19,n1=19,n2=152,LogPval=-0.047280
# m=727,l=46,n1=46,n2=313,LogPval=-0.056108
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1825,l=3,n1=80,n2=8,LogPval=-0.003073
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 53 m=1432,l=7,n1=7,n2=658,LogPval=-0.003813
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1418,l=7,n1=7,n2=635,LogPval=-0.003979
# m=1054,l=5,n1=7,n2=453,LogPval=-0.002187
# m=1433,l=6,n1=7,n2=524,LogPval=-0.003182
# m=1431,l=4,n1=7,n2=197,LogPval=-0.003382
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=350,l=0,n1=0,n2=137,LogPval=0.000000
# m=1042,l=1,n1=6,n2=14,LogPval=-0.002477
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1091,l=1,n1=5,n2=17,LogPval=-0.002394
# m=363,l=0,n1=1,n2=7,LogPval=-0.000054
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1447,l=6,n1=7,n2=165,LogPval=-0.007796
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1433,l=5,n1=6,n2=633,LogPval=-0.002011
# m=1404,l=6,n1=7,n2=623,LogPval=-0.002511
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1422,l=4,n1=6,n2=504,LogPval=-0.001631
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1447,l=6,n1=7,n2=516,LogPval=-0.003246
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1436,l=7,n1=7,n2=459,LogPval=-0.005582
# m=1394,l=3,n1=6,n2=174,LogPval=-0.002623
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1430,l=5,n1=7,n2=115,LogPval=-0.006853
# m=1090,l=5,n1=5,n2=496,LogPval=-0.003622
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1079,l=3,n1=3,n2=372,LogPval=-0.002966
# m=1424,l=0,n1=7,n2=0,LogPval=0.000000
# m=1055,l=5,n1=5,n2=497,LogPval=-0.003577
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=714,l=3,n1=3,n2=235,LogPval=-0.004681
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1437,l=5,n1=7,n2=574,LogPval=-0.001787
# m=1415,l=6,n1=7,n2=400,LogPval=-0.004233
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1434,l=6,n1=6,n2=474,LogPval=-0.004647
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1086,l=3,n1=5,n2=60,LogPval=-0.006023
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan

# %%
print Pvals[:2,:2]
print Length[:2,:2]
print P_norm[:2,:2]
# Out:
# [[ 0.  0.]
#  [ 0.  0.]]
# [[   0.  693.]
#  [ 693.    0.]]
# [[-0.4        -0.22741126]
#  [-0.22741126 -0.4       ]]

# %%
A=P_norm.flatten();
B=A[~isnan(A)]
print A.shape,B.shape
hist(-B,bins=100);
xlabel('significance')
# Out:
# (2916,) (1692,)

# %%
def showmat(mat):
    fig,axes=plt.subplots(1,1,figsize=(10,10))
    axes.imshow(mat, cmap=plt.cm.gray)

# %%
showmat(P_norm)

# %% [markdown]
# ### Finding structure in the rependency matrix.
# The matrix above shows, for each pair of stations, the normalized log probability that the overlap in rain days is random.
#
# We see immediately the first 8 stations are highly correlatedwith each other.
#
# To find more correlations we use SVD (the term PCA is reserved for decomposition of the covariance matrix). As we shall see that the top 10 eigenvectors explain about 80% of the square magnitude of the matrix.

# %%
print 'A group of very correlated stations is:',All.keys()[:8]
# Out:
# A group of very correlated stations is: [u'USC00094238', u'USC00098351', u'USW00093845', u'USC00094255', u'USC00094429', u'USC00092839', u'USC00095858', u'USC00095811']

# %%
from sklearn.decomposition import PCA
P_norm0 = np.nan_to_num(P_norm)
n_comp=10
pca = PCA(n_components=n_comp, svd_solver='full')
pca.fit(P_norm0)     
#print(pca.explained_variance_)
Var_explained=pca.explained_variance_ratio_
plot(insert(cumsum(Var_explained),0,0))
grid()

# %%
# we will look only at the top 4 eigenvectors.
n_comp=4
pca = PCA(n_components=n_comp, svd_solver='full')
pca.fit(P_norm0)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=4, random_state=None,
#   svd_solver='full', tol=0.0, whiten=False)

# %%
fig,axes=plt.subplots(1,4,figsize=(20,5),sharey='row');
L=list(pca.components_.transpose())
for i in range(4):
    X=sorted(L,key=lambda x:x[i]) 
    axes[i].plot(X);

# %%
def re_order_matrix(M,order):
    M_reord=M[order,:]
    M_reord=M_reord[:,order]
    return M_reord

# %%
fig,axes=plt.subplots(2,2,figsize=(15,15),sharex='col',sharey='row');
i=0
for r in range(2):
    for c in range(2):
        order=np.argsort(pca.components_[i,:])
        P_norm_reord=re_order_matrix(P_norm0,order)
        axes[r,c].matshow(P_norm_reord)
        i+=1

# %% [markdown]
# ### Explanation and possibe extensions
# When we reorder the rows and columns of the matrix using one of the eigenvectors, the grouping of the
# stations becomes more evident. For example, consider the upper left corner of the scond matrix (The upper left one). The stations at positions 0-22 are clearly strongly correlated with each other. Even though there are some stations, in positions 15-18 or so, which are more related to each other than to the rest of this block.
#
# This type of organization is called **Block Diagonal** and it typically reveals important structure such as grouping or clustering.
#
# You might want to extract the sets of stations that form blocks for your region, and then plot them on the map to see their spatial relationship.

# %%
from pickle import dump
with open(data_dir+'/'+ meas+'_residuals_PCA.pickle','wb') as file:
    dump({'stations':All.keys(),
          'eigen-vecs':pca.components_},
        file)
