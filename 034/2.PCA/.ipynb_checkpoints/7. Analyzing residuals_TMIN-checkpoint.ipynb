# %%
#setup
data_dir='../../Data/Weather'
#file_index='BBBSBBBB'
file_index='BSBSSSBB'
meas='PRCP'

# %% [markdown]
# # Reconstruction using top eigen-vectors
# For measurement = {{meas}}

# %% [markdown]
# ## Load the required libraries

# %%
# Enable automiatic reload of libraries
#%load_ext autoreload
#%autoreload 2 # means that all modules are reloaded before every command

# %%
# %pylab inline
import numpy as np

import findspark
findspark.init()

import sys
sys.path.append('./lib')

from numpy_pack import packArray,unpackArray

from Eigen_decomp import Eigen_decomp
from YearPlotter import YearPlotter
from recon_plot import recon_plot

from import_modules import import_modules,modules
import_modules(modules)

from ipywidgets import interactive,widgets
# Out:
# Populating the interactive namespace from numpy and matplotlib
#     pandas as    pd 	version=0.19.2 	required version>=0.19.2
#      numpy as    np 	version=1.11.3 	required version>=1.12.0 ******* Update Version ******
#    sklearn as    sk 	version=0.18.1 	required version>=0.18.1
#     urllib as urllib 	version=1.17 	required version>=1.17
#    pyspark as pyspark 	version=2.1.0+hadoop2.7 	required version>=2.1.0
# ipywidgets as ipywidgets 	version=6.0.0 	required version>=6.0.0

# %%
from pyspark import SparkContext
#sc.stop()

sc = SparkContext(master="local[3]",pyFiles=['lib/numpy_pack.py','lib/spark_PCA.py','lib/computeStats.py','lib/recon_plot.py','lib/Eigen_decomp.py'])

from pyspark import SparkContext
from pyspark.sql import *
sqlContext = SQLContext(sc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-da1c4f2f274c> in <module>()
#       2 #sc.stop()
#       3
# ----> 4 sc = SparkContext(master="local[3]",pyFiles=['lib/numpy_pack.py','lib/spark_PCA.py','lib/computeStats.py','lib/recon_plot.py','lib/Eigen_decomp.py'])
#       5
#       6 from pyspark import SparkContext
#
# /lib/spark-2.1.0-bin-hadoop2.7/python/pyspark/context.py in __init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls)
#     113         """
#     114         self._callsite = first_spark_call() or CallSite(None, None, None)
# --> 115         SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     116         try:
#     117             self._do_init(master, appName, sparkHome, pyFiles, environment, batchSize, serializer,
#
# /lib/spark-2.1.0-bin-hadoop2.7/python/pyspark/context.py in _ensure_initialized(cls, instance, gateway, conf)
#     270                         " created by %s at %s:%s "
#     271                         % (currentAppName, currentMaster,
# --> 272                             callsite.function, callsite.file, callsite.linenum))
#     273                 else:
#     274                     SparkContext._active_spark_context = instance
#
# ValueError: Cannot run multiple SparkContexts at once; existing SparkContext(app=pyspark-shell, master=local[3]) created by __init__ at <ipython-input-4-da1c4f2f274c>:4

# %% [markdown]
# ## Read Statistics File

# %%
from pickle import load

#read statistics
filename=data_dir+'/STAT_%s.pickle'%file_index
STAT,STAT_Descriptions = load(open(filename,'rb'))
measurements=STAT.keys()
print 'keys from STAT=',measurements
# Out:
# keys from STAT= ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'SNWD', 'PRCP']

# %% [markdown]
# ## Read data file into a spark DataFrame
# We focus on the snow-depth records, because the eigen-vectors for them make sense.

# %%
#read data
filename=data_dir+'/decon_%s_%s.parquet'%(file_index,meas)
df_in=sqlContext.read.parquet(filename)
#filter in 
df=df_in.filter(df_in.measurement==meas)
df.show(5)
# Out:
# +------------------+-------------------+-------------------+---------+--------+--------+---------+-----------+------------------+------------------+------------------+------------------+-----------+---------+------+--------------------+------+
# |           coeff_1|            coeff_2|            coeff_3|elevation|   label|latitude|longitude|measurement|             res_1|             res_2|             res_3|          res_mean|    station|total_var|undefs|              vector|  year|
# +------------------+-------------------+-------------------+---------+--------+--------+---------+-----------+------------------+------------------+------------------+------------------+-----------+---------+------+--------------------+------+
# |-279.3962118945472|-196.28685745262968|-212.17025123929136|    112.2|BSBSSSBB| 33.0831| -83.2497|       PRCP| 0.964755026938693|0.9474794929736724|0.9257660494157849|  0.90367218705497|USC00095874|2551488.0|     7|[00 00 00 00 00 0...|1998.0|
# | 71.29630302902041|-57.656186202129135| 456.65684205822186|     85.3|BSBSSSBB| 32.8753| -82.2156|       PRCP|0.9973208867178498|0.9963221388088997|0.9255386555349213|0.8557706037939508|USC00095863|3403895.0|     8|[00 00 50 54 00 0...|1979.0|
# |104.79770219874675| 402.74693879548056| -181.9358298209131|     98.1|BSBSSSBB| 33.0125| -82.3914|       PRCP|0.9960350531201445|0.9374754197923321|0.9255253532277871|0.8451610634255463|USC00095314|3277379.0|     0|[00 00 00 00 00 0...|1975.0|
# | 299.4577893383979|-13.110401331242395|  456.4947480965791|     57.0|BSBSSSBB| 31.0767| -82.8003|       PRCP|0.9754714054512788|0.9754138199077499|0.9254386506083424|0.8524325732892272|USC00094429|4890939.0|     1|[00 42 90 55 00 4...|1991.0|
# |415.74798242895514|  43.88595733615932| 238.82875544333393|     36.6|BSBSSSBB| 30.2889|  -82.965|       PRCP|0.9448009754153044|0.9438460150273347| 0.925392281883825|0.8748863699865395|USC00085099|3690199.0|     7|[00 00 00 00 00 0...|1997.0|
# +------------------+-------------------+-------------------+---------+--------+--------+---------+-----------+------------------+------------------+------------------+------------------+-----------+---------+------+--------------------+------+
# only showing top 5 rows

# %% [markdown]
# ### Plot Mean and Eigenvecs

# %%
m=meas
fig,axes=plt.subplots(2,1, sharex='col', sharey='row',figsize=(10,6));
k=3
EigVec=np.matrix(STAT[m]['eigvec'][:,:k])
Mean=STAT[m]['Mean']
YearPlotter().plot(Mean,fig,axes[0],label='Mean',title=m+' Mean')
YearPlotter().plot(EigVec,fig,axes[1],title=m+' Eigs',labels=['eig'+str(i+1) for i in range(k)])

# %% [markdown]
# ### plot the percent of residual variance on average

# %%
#  x=0 in the graphs below correspond to the fraction of the variance explained by the mean alone
#  x=1,2,3,... are the residuals for eig1, eig1+eig2, eig1+eig2+eig3 ...
fig,ax=plt.subplots(1,1);
eigvals=STAT[m]['eigval']; eigvals/=sum(eigvals); cumvar=cumsum(eigvals); cumvar=100*np.insert(cumvar,0,0)
ax.plot(cumvar[:10]); 
ax.grid(); 
ax.set_ylabel('Percent of variance explained')
ax.set_xlabel('number of eigenvectors')
ax.set_title('Percent of variance explained');

# %% [markdown]
# ### How well-explained are the vectors in this collection?
#
# To answer this question we extract all of the values of `res_3` which is the residual variance after the Mean and the
# first two Eigen-vectors have been subtracted out. We rely here on the fact that `df3` is already sorted according to `res_3`

# %%
# A function for plotting the CDF of a given feature
def plot_CDF(df,feat):
    rows=df.select(feat).sort(feat).collect()
    vals=[r[feat] for r in rows]
    P=np.arange(0,1,1./(len(vals)))
    while len(vals)< len(P):
        vals=[vals[0]]+vals
    plot(vals,P)
    title('cumulative distribution of '+feat)
    ylabel('fraction of instances')
    xlabel(feat)
    grid()

# %%
plot_CDF(df,'res_3')

# %%
rows=df.rdd.map(lambda row:(row.station,row.year,unpackArray(row['vector'],np.float16))).collect()
rows[0][:2]
# Out:
# (u'USC00095874', 1998.0)

# %%
days=set([r[1] for r in rows])
miny=min(days)
maxy=max(days)
record_len=int((maxy-miny+1)*365)
record_len
# Out:
# 43800

# %%
## combine the measurements for each station into a single long array with an entry for each day of each day
All={}  # a dictionary with a numpy array for each day of each day
i=0
for station,day,vector in rows:
    i+=1; 
    # if i%1000==0: print i,len(All)
    if not station in All:
        a=np.zeros(record_len)
        a.fill(np.nan)
        All[station]=a
    loc = int((day-miny)*365)
    All[station][loc:loc+365]=vector

# %%
from datetime import date
d=datetime.date(int(miny), month=1, day=1)
start=d.toordinal()
dates=[date.fromordinal(i) for i in range(start,start+record_len)]

# %%
for station in All:
    print station, np.count_nonzero(~np.isnan(All[station]))
# Out:
# USC00094255 2452
# US1GAEM0001 727
# USC00096126 18355
# USW00013870 23261
# USC00098476 15949
# US1GACF0001 1435
# US1GACF0003 1423
# USC00095858 22714
# US1FLHM0002 1086
# US1GABD0001 1429
# USC00084393 6038
# US1FLSW0002 1747
# US1FLSW0001 711
# USC00094170 38233
# USC00093460 21176
# USC00099186 36148
# USC00093465 23272
# USW00013861 5366
# USC00096244 4883
# USC00097171 4355
# US1GALW0005 671
# USC00095492 1453
# USC00092996 7547
# USC00095314 34741
# USC00098351 22295
# USW00093845 8194
# USC00095401 3065
# USC00096255 1092
# US1FLBK0005 325
# US1FLMS0002 673
# US1FLBK0006 1024
# US1FLBK0003 1672
# USC00092783 24897
# US1GADG0003 693
# US1GALW0008 667
# US1GAAT0002 1409
# USC00098964 723
# US1GALW0001 988
# USC00099451 1737
# US1GABL0001 317
# USC00092966 36885
# USC00090053 11142
# USC00096838 13892
# USC00082391 1021
# USC00094204 12814
# USC00094110 5301
# USC00092532 13748
# USC00090190 1455
# USC00093840 363
# USC00094594 14741
# USC00095696 1458
# USC00094425 681
# USC00094429 19521
# USC00095811 12917
# US1GALN0001 688
# USC00095740 334
# USC00090670 2889
# US1GALW0004 1436
# USC00096879 364
# USC00097777 19395
# USC00096237 10002
# USC00098223 23688
# USC00092865 2548
# USC00094862 2881
# USC00093386 27615
# USC00090131 25325
# USC00094971 1089
# USC00098228 706
# USC00093312 3421
# USC00085275 34980
# USC00084394 22380
# US1GAPT0002 357
# USC00096650 1062
# US1GADG0002 695
# US1GADG0004 710
# USC00083470 28785
# USC00094238 1422
# USC00093695 20321
# USC00092839 35638
# USC00090006 700
# USW00013857 3598
# USC00093325 7407
# USC00095874 35924
# USC00099020 730
# USC00089640 2066
# US1GATG0001 1448
# USC00092844 1455
# US1GALR0004 688
# USC00090010 27251
# US1GALR0001 1007
# US1GALR0003 999
# US1FLBK0007 701
# USC00086515 699
# USC00095386 25527
# USC00084731 42879
# USC00098974 16545
# USC00090090 9397
# USC00095863 18897
# US1GAJN0003 1436
# USC00098972 5694
# US1FLBK0002 360
# USC00097055 1428
# USC00098496 15184
# USC00085099 23327
# US1GATF0006 1336
# USC00097720 6668

# %%
Stations=sorted(All.keys())
A=[]
for station in Stations:
    A.append(All[station])

day_station_table=np.hstack([A])
print shape(day_station_table)
# Out:
# (106, 43800)

# %%
def RMS(Mat):
    return np.sqrt(np.nanmean(Mat**2))

mean_by_day=np.nanmean(day_station_table,axis=0)
mean_by_station=np.nanmean(day_station_table,axis=1)
tbl_minus_day = day_station_table-mean_by_day
tbl_minus_station = (day_station_table.transpose()-mean_by_station).transpose()

print 'total RMS                   = ',RMS(day_station_table)
print 'RMS removing mean-by-station= ',RMS(tbl_minus_station)
print 'RMS removing mean-by-day   = ',RMS(tbl_minus_day)
# Out:
# total RMS                   =  91.4703129625
# RMS removing mean-by-station=  86.0669449859
# RMS removing mean-by-day   =  66.8640711071

# %%
RT=day_station_table
F=RT.flatten()
NN=F[~np.isnan(F)]

NN.sort()
P=np.arange(0.,1.,1./len(NN))
plot(NN,P)
grid()
title('CDF of daily rainfall')
xlabel('daily rainfall')
ylabel('cumulative probability')

# %% [markdown]
# ### Conclusions
# It is likely to be hard to find correlations between the **amount** of rain on the same day in different stations. Because amounts of rain vary a lot between even close locations. It is more reasonable to try to compare whether or not it rained on the same day in different stations. As we see from the graph above, in our region it rains in about one third of the days.
#
# ### measuring statistical significance
# We want to find a statistical test for rejecting the null hypothesis that says that the rainfall in the two locations is independent.
#
# Using the inner product is too noisy, because you multiply the rainfall on the same day in two locations and that product can be very large - leading to a large variance and poor ability to discriminate.
#
# An alternative is to ignore the amount of rain, and just ask whether it rained in both locations. We can then compute the probability associated with the number of overlaps under the null hypothesis.

# %% [markdown]
# Fix two stations. We restrict our attention to the days for which we have measurements for both stations, and define the following notation:
# * $m$ : the total number of days (for which we have measurements for both stations).
# * $n_1$ : the number of days that it rained on station 1
# * $n_2$ : the number of days that it rained on station 2
# * $l$ : the number of days that it rained on both stations.
#
# We want to calculate the probability that the number of overlap days is $l$ given $m,n_1,n_2$.
#
# The answer is:
# $$
# P = {m \choose l,n_1-l,n_2-l,m-n_1-n_2+l} /{m \choose n_1}{m \choose n_2}
# $$
#
# Where
# $$
# {m \choose l,n_1-l,n_2-l,m-n_1-n_2+l} = \frac{m!}{l! (n_1-l)! (n_2-l)! (m-n_1-n_2+l)!}
# $$
#
# We use the fact that $\Gamma(n+1) = n!$ and denote $G(n) \doteq \log \Gamma(n+1)$
# $$
# \log P = \left[G(m) - G(l) -G(n_1-l) -G(n_2-l) -G(m-n_1-n_2+l) \right] -
# \left[G(m)-G(n_1)-G(m-n_1)\right] - \left[G(m)-G(n_2)-G(m-n_2)\right]
# $$
# Which slightly simplifies to
# $$
# \log P = -G(l) -G(n_1-l) -G(n_2-l) -G(m-n_1-n_2+l) - G(m)+G(n_1)+G(m-n_1) +G(n_2)+G(m-n_2)
# $$
#
# The log probability scales with $m$ the length of the overlap. So to get a per-day significance we consider $
# \frac{1}{m} \log P $

# %%
from scipy.special import gammaln,factorial
#for i in range(10):
#    print exp(gammaln(i+1))-factorial(i)
def G(n):
    return gammaln(n+1)
def LogProb(m,l,n1,n2):
    logP=-G(l)-G(n1-l)-G(n2-l)-G(m-n1-n2+l)-G(m)+G(n1)+G(m-n1)+G(n2)+G(m-n2)
    return logP/m
exp(LogProb(1000,0,500,500))
# Out:
# 0.501843349103545

# %%
#USC00193270 21482
#USC00193702 28237
#USC00094238 1424
#USC00098351 3393
X=copy(All['USC00092783'])
Y=copy(All['USC00098351'])
print sum(~np.isnan(X))
print sum(~np.isnan(Y))
X[np.isnan(Y)]=np.nan
Y[np.isnan(X)]=np.nan
print sum(~np.isnan(X))
print sum(~np.isnan(Y))
# Out:
# 24897
# 22295
# 17166
# 17166

# %%
def computeLogProb(X,Y):
    X[np.isnan(Y)]=np.nan
    Y[np.isnan(X)]=np.nan
    G=~isnan(X)
    m=sum(G)
    XG=X[G]>0
    YG=Y[G]>0
    n1=sum(XG)
    n2=sum(YG)
    l=sum(XG*YG)
    logprob=LogProb(m,l,n1,n2)
    print 'm=%d,l=%d,n1=%d,n2=%d,LogPval=%f'%(m,l,n1,n2,logprob)
    return logprob,m
print computeLogProb(X,Y)
# Out:
# m=17166,l=2173,n1=3997,n2=3961,LogPval=-0.075179
# (-0.075178687337726938, 17166)

# %% [markdown]
# ### calculate the normalized log probability for each pair of stations.

# %%
L=len(Stations)
Pvals=np.zeros([L,L])
Length=np.zeros([L,L])
P_norm=np.zeros([L,L])
for i in range(L):
    print i,
    for j in range(L):
        if i==j: 
            P_norm[i,j]=-0.4
            continue
        X=copy(All[Stations[i]])
        Y=copy(All[Stations[j]])
        P_norm[i,j],Length[i,j]=computeLogProb(X,Y)
        if Length[i,j]<200:
            P_norm[i,j]=np.nan
# Out:
# 0 m=312,l=61,n1=93,n2=78,LogPval=-0.184619
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=337,l=70,n1=101,n2=104,LogPval=-0.150408
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=347,l=85,n1=103,n2=99,LogPval=-0.310022
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=62,n1=105,n2=88,LogPval=-0.130729
# m=360,l=87,n1=108,n2=136,LogPval=-0.175798
# m=356,l=36,n1=105,n2=65,LogPval=-0.039313
# m=327,l=37,n1=100,n2=54,LogPval=-0.067880
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=348,l=62,n1=101,n2=80,LogPval=-0.165643
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=58,n1=106,n2=96,LogPval=-0.084862
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=352,l=39,n1=103,n2=58,LogPval=-0.068346
# m=356,l=45,n1=107,n2=80,LogPval=-0.050488
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=351,l=32,n1=105,n2=56,LogPval=-0.036874
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=356,l=69,n1=106,n2=95,LogPval=-0.158627
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=358,l=24,n1=106,n2=47,LogPval=-0.021148
# m=329,l=69,n1=91,n2=111,LogPval=-0.155136
# m=359,l=47,n1=108,n2=90,LogPval=-0.043165
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=358,l=49,n1=108,n2=85,LogPval=-0.058598
# m=352,l=66,n1=107,n2=118,LogPval=-0.081993
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=339,l=71,n1=105,n2=107,LogPval=-0.138200
# m=358,l=42,n1=107,n2=82,LogPval=-0.036617
# m=344,l=47,n1=101,n2=87,LogPval=-0.053177
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=359,l=48,n1=108,n2=91,LogPval=-0.045516
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=328,l=31,n1=97,n2=50,LogPval=-0.047560
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=359,l=46,n1=107,n2=102,LogPval=-0.027722
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=327,l=40,n1=100,n2=73,LogPval=-0.043969
# m=358,l=46,n1=107,n2=89,LogPval=-0.041745
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=349,l=44,n1=103,n2=72,LogPval=-0.063837
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=356,l=55,n1=107,n2=96,LogPval=-0.068038
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=358,l=51,n1=107,n2=92,LogPval=-0.057113
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=317,l=50,n1=89,n2=71,LogPval=-0.124466
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=360,l=73,n1=108,n2=104,LogPval=-0.156729
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=358,l=39,n1=106,n2=91,LogPval=-0.020123
# m=354,l=34,n1=108,n2=78,LogPval=-0.017241
# 1 m=312,l=61,n1=78,n2=93,LogPval=-0.184619
# m=290,l=51,n1=64,n2=93,LogPval=-0.147999
# m=938,l=151,n1=203,n2=277,LogPval=-0.127299
# m=621,l=73,n1=126,n2=149,LogPval=-0.074928
# m=991,l=142,n1=219,n2=293,LogPval=-0.081466
# m=616,l=99,n1=144,n2=215,LogPval=-0.078276
# m=662,l=99,n1=150,n2=194,LogPval=-0.092219
# m=1614,l=255,n1=362,n2=501,LogPval=-0.100646
# m=1310,l=160,n1=292,n2=322,LogPval=-0.065763
# m=1330,l=152,n1=291,n2=409,LogPval=-0.030808
# m=310,l=28,n1=74,n2=65,LogPval=-0.031362
# m=1335,l=190,n1=297,n2=406,LogPval=-0.073355
# m=1323,l=181,n1=295,n2=397,LogPval=-0.064814
# m=620,l=64,n1=121,n2=157,LogPval=-0.047719
# m=611,l=70,n1=128,n2=161,LogPval=-0.053822
# m=668,l=71,n1=143,n2=174,LogPval=-0.039811
# m=647,l=67,n1=134,n2=155,LogPval=-0.047392
# m=1335,l=174,n1=295,n2=447,LogPval=-0.041657
# m=641,l=95,n1=148,n2=188,LogPval=-0.085767
# m=945,l=112,n1=220,n2=277,LogPval=-0.034981
# m=915,l=98,n1=205,n2=240,LogPval=-0.034988
# m=607,l=50,n1=129,n2=133,LogPval=-0.024373
# m=903,l=126,n1=187,n2=281,LogPval=-0.077867
# m=1336,l=181,n1=295,n2=389,LogPval=-0.068274
# m=617,l=103,n1=141,n2=220,LogPval=-0.091814
# m=599,l=83,n1=125,n2=190,LogPval=-0.072845
# m=344,l=38,n1=83,n2=115,LogPval=-0.017151
# m=1260,l=177,n1=276,n2=398,LogPval=-0.066966
# m=1345,l=149,n1=302,n2=361,LogPval=-0.036648
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1639,l=285,n1=373,n2=470,LogPval=-0.155228
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1665,l=238,n1=375,n2=465,LogPval=-0.085701
# m=1664,l=294,n1=373,n2=631,LogPval=-0.104152
# m=1609,l=136,n1=356,n2=309,LogPval=-0.031197
# m=1262,l=168,n1=280,n2=344,LogPval=-0.072778
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=926,l=123,n1=195,n2=229,LogPval=-0.096600
# m=618,l=63,n1=127,n2=150,LogPval=-0.044558
# m=641,l=54,n1=144,n2=120,LogPval=-0.033615
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1656,l=199,n1=372,n2=416,LogPval=-0.058009
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1307,l=112,n1=294,n2=213,LogPval=-0.045694
# m=643,l=67,n1=153,n2=151,LogPval=-0.036692
# m=682,l=78,n1=147,n2=200,LogPval=-0.038564
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1641,l=121,n1=371,n2=298,LogPval=-0.020290
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1652,l=258,n1=375,n2=496,LogPval=-0.100128
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=663,l=41,n1=161,n2=94,LogPval=-0.018674
# m=1607,l=259,n1=360,n2=496,LogPval=-0.109428
# m=1313,l=143,n1=297,n2=360,LogPval=-0.031574
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1633,l=167,n1=358,n2=391,LogPval=-0.037863
# m=1658,l=236,n1=377,n2=540,LogPval=-0.059178
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1627,l=245,n1=371,n2=493,LogPval=-0.085480
# m=315,l=31,n1=77,n2=72,LogPval=-0.032407
# m=1638,l=178,n1=374,n2=424,LogPval=-0.035337
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1293,l=152,n1=290,n2=349,LogPval=-0.045878
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=284,l=22,n1=68,n2=40,LogPval=-0.044334
# m=1351,l=196,n1=301,n2=420,LogPval=-0.074921
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1638,l=178,n1=369,n2=497,LogPval=-0.022728
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1637,l=175,n1=369,n2=379,LogPval=-0.045248
# m=1661,l=195,n1=376,n2=491,LogPval=-0.034611
# m=965,l=92,n1=215,n2=182,LogPval=-0.049590
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1659,l=174,n1=377,n2=336,LogPval=-0.055584
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1666,l=208,n1=377,n2=433,LogPval=-0.060812
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1668,l=193,n1=378,n2=455,LogPval=-0.040450
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1575,l=219,n1=346,n2=462,LogPval=-0.074515
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1618,l=223,n1=351,n2=439,LogPval=-0.086411
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1667,l=166,n1=376,n2=435,LogPval=-0.024690
# m=1602,l=170,n1=364,n2=447,LogPval=-0.026065
# 2 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=290,l=51,n1=93,n2=64,LogPval=-0.147999
# m=307,l=83,n1=93,n2=90,LogPval=-0.404128
# m=324,l=79,n1=96,n2=92,LogPval=-0.308751
# m=324,l=64,n1=96,n2=82,LogPval=-0.188310
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=314,l=68,n1=94,n2=86,LogPval=-0.217641
# m=302,l=62,n1=90,n2=80,LogPval=-0.195225
# m=325,l=58,n1=97,n2=66,LogPval=-0.201643
# m=322,l=56,n1=97,n2=93,LogPval=-0.090180
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=323,l=57,n1=97,n2=81,LogPval=-0.128965
# m=325,l=60,n1=97,n2=87,LogPval=-0.133490
# m=305,l=45,n1=84,n2=69,LogPval=-0.102048
# m=310,l=51,n1=93,n2=74,LogPval=-0.112831
# m=315,l=53,n1=94,n2=78,LogPval=-0.114016
# m=325,l=51,n1=97,n2=69,LogPval=-0.122679
# m=322,l=59,n1=96,n2=93,LogPval=-0.111547
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=308,l=41,n1=88,n2=58,LogPval=-0.098292
# m=318,l=39,n1=96,n2=67,LogPval=-0.053037
# m=296,l=58,n1=88,n2=79,LogPval=-0.165741
# m=318,l=60,n1=92,n2=85,LogPval=-0.152511
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=294,l=70,n1=92,n2=95,LogPval=-0.205972
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=312,l=59,n1=93,n2=86,LogPval=-0.137299
# m=325,l=51,n1=97,n2=80,LogPval=-0.090698
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=319,l=77,n1=95,n2=85,LogPval=-0.330791
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=325,l=68,n1=97,n2=85,LogPval=-0.211851
# m=320,l=77,n1=93,n2=111,LogPval=-0.217968
# m=310,l=42,n1=93,n2=55,LogPval=-0.108158
# m=315,l=61,n1=96,n2=81,LogPval=-0.163621
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=303,l=55,n1=85,n2=73,LogPval=-0.170913
# m=299,l=50,n1=87,n2=75,LogPval=-0.114252
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=321,l=51,n1=95,n2=74,LogPval=-0.110207
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=323,l=32,n1=96,n2=48,LogPval=-0.058008
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=324,l=56,n1=97,n2=90,LogPval=-0.097512
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=324,l=34,n1=97,n2=54,LogPval=-0.053990
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=315,l=64,n1=95,n2=81,LogPval=-0.195204
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=324,l=74,n1=96,n2=94,LogPval=-0.238840
# m=323,l=52,n1=97,n2=82,LogPval=-0.091656
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=314,l=43,n1=87,n2=73,LogPval=-0.074570
# m=325,l=59,n1=97,n2=94,LogPval=-0.107272
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=318,l=67,n1=96,n2=90,LogPval=-0.184261
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=318,l=50,n1=94,n2=69,LogPval=-0.120302
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=307,l=50,n1=86,n2=79,LogPval=-0.106571
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=324,l=68,n1=96,n2=90,LogPval=-0.194335
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=324,l=53,n1=97,n2=90,LogPval=-0.079730
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=325,l=50,n1=97,n2=73,LogPval=-0.102743
# m=322,l=57,n1=97,n2=94,LogPval=-0.093968
# m=324,l=32,n1=96,n2=48,LogPval=-0.058099
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=323,l=51,n1=96,n2=60,LogPval=-0.162451
# m=0,l=0,n1=0,n2=0,LogPval=nan
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in double_scalars
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=325,l=56,n1=97,n2=74,LogPval=-0.145230
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=325,l=56,n1=97,n2=84,LogPval=-0.113115
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=320,l=62,n1=93,n2=93,LogPval=-0.141122
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=305,l=41,n1=77,n2=62,LogPval=-0.106988
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=325,l=45,n1=97,n2=75,LogPval=-0.067456
# m=294,l=50,n1=91,n2=85,LogPval=-0.078108
# 3 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=938,l=151,n1=277,n2=203,LogPval=-0.127299
# m=307,l=83,n1=90,n2=93,LogPval=-0.404128
# m=650,l=123,n1=178,n2=156,LogPval=-0.200920
# m=669,l=136,n1=184,n2=183,LogPval=-0.201374
# m=304,l=67,n1=84,n2=105,LogPval=-0.178390
# m=332,l=68,n1=94,n2=88,LogPval=-0.209800
# m=991,l=211,n1=282,n2=295,LogPval=-0.190396
# m=1005,l=161,n1=289,n2=230,LogPval=-0.117100
# m=1011,l=156,n1=291,n2=293,LogPval=-0.059381
# m=303,l=38,n1=87,n2=63,LogPval=-0.065770
# m=1005,l=190,n1=289,n2=282,LogPval=-0.138000
# m=1021,l=182,n1=294,n2=285,LogPval=-0.112835
# m=642,l=98,n1=172,n2=158,LogPval=-0.099045
# m=641,l=102,n1=178,n2=167,LogPval=-0.094847
# m=672,l=106,n1=197,n2=175,LogPval=-0.081905
# m=672,l=105,n1=187,n2=156,LogPval=-0.111890
# m=1014,l=173,n1=293,n2=314,LogPval=-0.074597
# m=301,l=57,n1=89,n2=85,LogPval=-0.133725
# m=624,l=96,n1=186,n2=163,LogPval=-0.071521
# m=624,l=84,n1=173,n2=141,LogPval=-0.071905
# m=640,l=71,n1=179,n2=137,LogPval=-0.039503
# m=609,l=110,n1=160,n2=168,LogPval=-0.145807
# m=1009,l=195,n1=288,n2=277,LogPval=-0.157490
# m=301,l=66,n1=86,n2=88,LogPval=-0.219169
# m=617,l=130,n1=173,n2=194,LogPval=-0.172182
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=929,l=180,n1=275,n2=272,LogPval=-0.130610
# m=1020,l=142,n1=294,n2=254,LogPval=-0.058207
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1010,l=247,n1=291,n2=282,LogPval=-0.333088
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1020,l=200,n1=291,n2=286,LogPval=-0.159185
# m=1015,l=234,n1=286,n2=358,LogPval=-0.190324
# m=971,l=108,n1=275,n2=189,LogPval=-0.048071
# m=996,l=206,n1=286,n2=300,LogPval=-0.165514
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=649,l=132,n1=178,n2=167,LogPval=-0.224560
# m=646,l=101,n1=179,n2=154,LogPval=-0.107364
# m=326,l=41,n1=89,n2=58,LogPval=-0.098088
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1016,l=160,n1=290,n2=239,LogPval=-0.105915
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=673,l=78,n1=187,n2=106,LogPval=-0.090923
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=687,l=115,n1=201,n2=203,LogPval=-0.076307
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=998,l=100,n1=289,n2=175,LogPval=-0.040296
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1009,l=207,n1=290,n2=294,LogPval=-0.170855
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=990,l=209,n1=282,n2=298,LogPval=-0.180842
# m=673,l=108,n1=188,n2=178,LogPval=-0.093364
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=988,l=129,n1=268,n2=225,LogPval=-0.065218
# m=1021,l=191,n1=294,n2=312,LogPval=-0.111053
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=997,l=193,n1=287,n2=277,LogPval=-0.152459
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1005,l=150,n1=292,n2=243,LogPval=-0.079784
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=654,l=106,n1=179,n2=164,LogPval=-0.112223
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1020,l=209,n1=292,n2=299,LogPval=-0.169479
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=992,l=134,n1=285,n2=284,LogPval=-0.034641
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=993,l=138,n1=285,n2=214,LogPval=-0.081908
# m=1019,l=160,n1=293,n2=298,LogPval=-0.062435
# m=673,l=77,n1=187,n2=117,LogPval=-0.071821
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1014,l=141,n1=293,n2=195,LogPval=-0.102700
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1023,l=173,n1=294,n2=251,LogPval=-0.122566
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1023,l=160,n1=295,n2=268,LogPval=-0.080120
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=990,l=192,n1=284,n2=297,LogPval=-0.132916
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=971,l=148,n1=249,n2=231,LogPval=-0.112828
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1023,l=124,n1=295,n2=253,LogPval=-0.033444
# m=963,l=131,n1=274,n2=287,LogPval=-0.032408
# 4 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=621,l=73,n1=149,n2=126,LogPval=-0.074928
# m=324,l=79,n1=92,n2=96,LogPval=-0.308751
# m=650,l=123,n1=156,n2=178,LogPval=-0.200920
# m=697,l=108,n1=162,n2=185,LogPval=-0.117825
# m=306,l=43,n1=57,n2=99,LogPval=-0.098081
# m=351,l=69,n1=98,n2=91,LogPval=-0.194958
# m=667,l=101,n1=152,n2=189,LogPval=-0.101195
# m=692,l=90,n1=160,n2=150,LogPval=-0.096902
# m=691,l=87,n1=161,n2=189,LogPval=-0.053969
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=694,l=92,n1=161,n2=175,LogPval=-0.077624
# m=699,l=94,n1=163,n2=184,LogPval=-0.074033
# m=666,l=84,n1=151,n2=160,LogPval=-0.075673
# m=669,l=85,n1=155,n2=173,LogPval=-0.064027
# m=354,l=55,n1=96,n2=89,LogPval=-0.100656
# m=698,l=82,n1=162,n2=160,LogPval=-0.062437
# m=692,l=91,n1=162,n2=197,LogPval=-0.057212
# m=304,l=36,n1=60,n2=82,LogPval=-0.068280
# m=313,l=29,n1=54,n2=75,LogPval=-0.050926
# m=648,l=66,n1=151,n2=138,LogPval=-0.044657
# m=664,l=64,n1=162,n2=140,LogPval=-0.033708
# m=634,l=89,n1=136,n2=167,LogPval=-0.101035
# m=689,l=100,n1=156,n2=185,LogPval=-0.097981
# m=306,l=37,n1=55,n2=83,LogPval=-0.086474
# m=640,l=102,n1=145,n2=192,LogPval=-0.110050
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=641,l=96,n1=154,n2=173,LogPval=-0.096078
# m=700,l=79,n1=163,n2=163,LogPval=-0.052264
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=692,l=135,n1=160,n2=183,LogPval=-0.247190
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=700,l=106,n1=162,n2=184,LogPval=-0.112082
# m=695,l=125,n1=160,n2=238,LogPval=-0.128138
# m=667,l=63,n1=153,n2=119,LogPval=-0.051820
# m=682,l=100,n1=159,n2=185,LogPval=-0.093924
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=672,l=103,n1=152,n2=165,LogPval=-0.135807
# m=672,l=81,n1=155,n2=155,LogPval=-0.068143
# m=329,l=21,n1=61,n2=54,LogPval=-0.029268
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=693,l=81,n1=161,n2=148,LogPval=-0.070472
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=699,l=62,n1=162,n2=110,LogPval=-0.053131
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=362,l=56,n1=100,n2=98,LogPval=-0.081907
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=699,l=53,n1=163,n2=122,LogPval=-0.025011
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=689,l=107,n1=159,n2=181,LogPval=-0.122398
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=699,l=121,n1=162,n2=199,LogPval=-0.151102
# m=699,l=89,n1=163,n2=180,LogPval=-0.064040
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=676,l=76,n1=151,n2=151,LogPval=-0.061415
# m=699,l=99,n1=163,n2=202,LogPval=-0.073332
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=685,l=103,n1=158,n2=187,LogPval=-0.103146
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=687,l=88,n1=160,n2=167,LogPval=-0.073768
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=680,l=83,n1=155,n2=168,LogPval=-0.063397
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=699,l=107,n1=161,n2=198,LogPval=-0.102663
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=700,l=83,n1=163,n2=179,LogPval=-0.050558
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=701,l=79,n1=163,n2=144,LogPval=-0.067370
# m=697,l=90,n1=162,n2=196,LogPval=-0.055927
# m=699,l=61,n1=161,n2=118,LogPval=-0.044504
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=698,l=67,n1=161,n2=123,LogPval=-0.055168
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=701,l=86,n1=163,n2=160,LogPval=-0.072452
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=701,l=90,n1=163,n2=173,LogPval=-0.072328
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=678,l=94,n1=156,n2=182,LogPval=-0.081419
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=677,l=76,n1=144,n2=161,LogPval=-0.059582
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=701,l=72,n1=163,n2=158,LogPval=-0.040384
# m=669,l=83,n1=156,n2=182,LogPval=-0.051730
# 5 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=991,l=142,n1=293,n2=219,LogPval=-0.081466
# m=324,l=64,n1=82,n2=96,LogPval=-0.188310
# m=669,l=136,n1=183,n2=184,LogPval=-0.201374
# m=697,l=108,n1=185,n2=162,LogPval=-0.117825
# m=668,l=181,n1=210,n2=225,LogPval=-0.298587
# m=707,l=162,n1=202,n2=200,LogPval=-0.265519
# m=1035,l=260,n1=294,n2=322,LogPval=-0.314190
# m=1044,l=193,n1=302,n2=252,LogPval=-0.168521
# m=1059,l=181,n1=304,n2=314,LogPval=-0.084834
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1076,l=222,n1=308,n2=307,LogPval=-0.182328
# m=1051,l=204,n1=298,n2=302,LogPval=-0.148391
# m=692,l=112,n1=179,n2=169,LogPval=-0.129624
# m=688,l=115,n1=183,n2=175,LogPval=-0.127404
# m=354,l=59,n1=85,n2=88,LogPval=-0.158488
# m=721,l=111,n1=192,n2=164,LogPval=-0.119321
# m=1065,l=203,n1=306,n2=343,LogPval=-0.106685
# m=682,l=157,n1=218,n2=202,LogPval=-0.204700
# m=669,l=128,n1=206,n2=199,LogPval=-0.111532
# m=991,l=166,n1=290,n2=252,LogPval=-0.106552
# m=683,l=80,n1=187,n2=144,LogPval=-0.052514
# m=980,l=212,n1=268,n2=292,LogPval=-0.215969
# m=1070,l=255,n1=305,n2=304,LogPval=-0.301363
# m=666,l=177,n1=207,n2=234,LogPval=-0.264082
# m=661,l=152,n1=177,n2=199,LogPval=-0.272191
# m=354,l=59,n1=113,n2=116,LogPval=-0.045664
# m=1001,l=216,n1=289,n2=304,LogPval=-0.187165
# m=1078,l=169,n1=312,n2=281,LogPval=-0.080998
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1066,l=219,n1=305,n2=297,LogPval=-0.187765
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1083,l=243,n1=311,n2=300,LogPval=-0.253527
# m=1080,l=250,n1=310,n2=405,LogPval=-0.164803
# m=1044,l=129,n1=293,n2=192,LogPval=-0.079905
# m=705,l=157,n1=190,n2=194,LogPval=-0.277822
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=695,l=142,n1=186,n2=172,LogPval=-0.251820
# m=694,l=118,n1=185,n2=161,LogPval=-0.157983
# m=686,l=91,n1=211,n2=125,LogPval=-0.089377
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1072,l=182,n1=304,n2=254,LogPval=-0.135977
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1083,l=134,n1=311,n2=174,LogPval=-0.101415
# m=341,l=59,n1=110,n2=90,LogPval=-0.093518
# m=362,l=53,n1=89,n2=97,LogPval=-0.088156
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1082,l=115,n1=310,n2=208,LogPval=-0.040543
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1070,l=233,n1=307,n2=309,LogPval=-0.213606
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=358,l=37,n1=115,n2=55,LogPval=-0.053587
# m=1082,l=225,n1=309,n2=314,LogPval=-0.182382
# m=1083,l=188,n1=312,n2=297,LogPval=-0.106232
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1057,l=163,n1=289,n2=258,LogPval=-0.099051
# m=1084,l=227,n1=311,n2=350,LogPval=-0.151534
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1070,l=239,n1=306,n2=314,LogPval=-0.227841
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1072,l=178,n1=309,n2=282,LogPval=-0.098849
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1065,l=183,n1=304,n2=288,LogPval=-0.107552
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1083,l=251,n1=311,n2=332,LogPval=-0.238243
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1084,l=162,n1=312,n2=321,LogPval=-0.048665
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1084,l=164,n1=312,n2=246,LogPval=-0.097746
# m=1077,l=187,n1=310,n2=326,LogPval=-0.085297
# m=1052,l=133,n1=302,n2=192,LogPval=-0.084246
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1081,l=158,n1=311,n2=210,LogPval=-0.119169
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1085,l=197,n1=312,n2=273,LogPval=-0.148190
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1085,l=186,n1=313,n2=290,LogPval=-0.106947
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1038,l=221,n1=290,n2=300,LogPval=-0.207214
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1063,l=206,n1=291,n2=294,LogPval=-0.169004
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1084,l=154,n1=311,n2=274,LogPval=-0.061199
# m=1051,l=156,n1=302,n2=295,LogPval=-0.055320
# 6 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=616,l=99,n1=215,n2=144,LogPval=-0.078276
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=304,l=67,n1=105,n2=84,LogPval=-0.178390
# m=306,l=43,n1=99,n2=57,LogPval=-0.098081
# m=668,l=181,n1=225,n2=210,LogPval=-0.298587
# m=335,l=84,n1=114,n2=106,LogPval=-0.219659
# m=649,l=184,n1=220,n2=227,LogPval=-0.284025
# m=633,l=136,n1=218,n2=173,LogPval=-0.164938
# m=651,l=134,n1=217,n2=197,LogPval=-0.118875
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=668,l=161,n1=226,n2=209,LogPval=-0.194398
# m=639,l=146,n1=212,n2=198,LogPval=-0.169261
# m=321,l=69,n1=104,n2=86,LogPval=-0.194153
# m=318,l=69,n1=106,n2=88,LogPval=-0.178971
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=330,l=64,n1=109,n2=82,LogPval=-0.153480
# m=655,l=149,n1=222,n2=226,LogPval=-0.123952
# m=635,l=149,n1=222,n2=196,LogPval=-0.169697
# m=623,l=132,n1=210,n2=186,LogPval=-0.133955
# m=600,l=122,n1=211,n2=171,LogPval=-0.116635
# m=302,l=45,n1=103,n2=66,LogPval=-0.076013
# m=607,l=150,n1=193,n2=196,LogPval=-0.225905
# m=669,l=178,n1=226,n2=206,LogPval=-0.289496
# m=618,l=167,n1=212,n2=222,LogPval=-0.218547
# m=310,l=80,n1=104,n2=92,LogPval=-0.284150
# m=334,l=61,n1=111,n2=109,LogPval=-0.061824
# m=603,l=152,n1=208,n2=199,LogPval=-0.197869
# m=665,l=122,n1=226,n2=178,LogPval=-0.098118
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=660,l=151,n1=222,n2=197,LogPval=-0.179212
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=672,l=158,n1=228,n2=201,LogPval=-0.193999
# m=672,l=176,n1=227,n2=273,LogPval=-0.151827
# m=645,l=86,n1=209,n2=128,LogPval=-0.068204
# m=325,l=85,n1=109,n2=100,LogPval=-0.277728
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=331,l=70,n1=111,n2=88,LogPval=-0.175659
# m=332,l=59,n1=111,n2=73,LogPval=-0.144100
# m=638,l=89,n1=211,n2=115,LogPval=-0.096534
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=664,l=128,n1=223,n2=165,LogPval=-0.143594
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=672,l=98,n1=227,n2=118,LogPval=-0.115404
# m=320,l=57,n1=106,n2=87,LogPval=-0.092000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=671,l=85,n1=227,n2=142,LogPval=-0.042493
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=668,l=160,n1=226,n2=216,LogPval=-0.176997
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=337,l=36,n1=115,n2=53,LogPval=-0.050899
# m=671,l=153,n1=226,n2=206,LogPval=-0.166086
# m=672,l=141,n1=227,n2=194,LogPval=-0.138580
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=656,l=123,n1=216,n2=170,LogPval=-0.122788
# m=668,l=158,n1=224,n2=230,LogPval=-0.149519
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=664,l=164,n1=223,n2=208,LogPval=-0.215320
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=670,l=138,n1=228,n2=192,LogPval=-0.129436
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=673,l=135,n1=228,n2=189,LogPval=-0.123870
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=671,l=175,n1=227,n2=226,LogPval=-0.224129
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=673,l=120,n1=228,n2=209,LogPval=-0.058154
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=671,l=116,n1=227,n2=156,LogPval=-0.111024
# m=667,l=141,n1=224,n2=208,LogPval=-0.120652
# m=642,l=97,n1=218,n2=128,LogPval=-0.097000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=670,l=99,n1=225,n2=135,LogPval=-0.088999
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=672,l=146,n1=227,n2=184,LogPval=-0.177027
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=672,l=135,n1=228,n2=186,LogPval=-0.128459
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=638,l=145,n1=209,n2=193,LogPval=-0.179039
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=669,l=157,n1=224,n2=211,LogPval=-0.176643
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=672,l=115,n1=227,n2=179,LogPval=-0.076505
# m=670,l=106,n1=225,n2=182,LogPval=-0.052880
# 7 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=662,l=99,n1=194,n2=150,LogPval=-0.092219
# m=314,l=68,n1=86,n2=94,LogPval=-0.217641
# m=332,l=68,n1=88,n2=94,LogPval=-0.209800
# m=351,l=69,n1=91,n2=98,LogPval=-0.194958
# m=707,l=162,n1=200,n2=202,LogPval=-0.265519
# m=335,l=84,n1=106,n2=114,LogPval=-0.219659
# m=675,l=165,n1=191,n2=212,LogPval=-0.283995
# m=680,l=127,n1=198,n2=164,LogPval=-0.173679
# m=693,l=117,n1=194,n2=214,LogPval=-0.079083
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=702,l=145,n1=200,n2=206,LogPval=-0.176329
# m=677,l=136,n1=191,n2=203,LogPval=-0.156869
# m=334,l=49,n1=78,n2=74,LogPval=-0.135277
# m=335,l=58,n1=86,n2=77,LogPval=-0.182010
# m=342,l=58,n1=87,n2=85,LogPval=-0.152531
# m=352,l=51,n1=91,n2=71,LogPval=-0.130370
# m=696,l=132,n1=198,n2=236,LogPval=-0.096291
# m=351,l=80,n1=108,n2=111,LogPval=-0.189113
# m=332,l=65,n1=104,n2=115,LogPval=-0.083303
# m=650,l=109,n1=186,n2=169,LogPval=-0.107759
# m=345,l=42,n1=90,n2=75,LogPval=-0.064729
# m=650,l=142,n1=178,n2=205,LogPval=-0.203401
# m=696,l=155,n1=195,n2=198,LogPval=-0.247109
# m=334,l=88,n1=104,n2=138,LogPval=-0.189340
# m=319,l=71,n1=86,n2=100,LogPval=-0.227940
# m=351,l=54,n1=106,n2=114,LogPval=-0.039139
# m=673,l=137,n1=189,n2=213,LogPval=-0.149816
# m=703,l=120,n1=201,n2=197,LogPval=-0.097906
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=694,l=143,n1=195,n2=195,LogPval=-0.193770
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=708,l=149,n1=201,n2=194,LogPval=-0.213331
# m=705,l=164,n1=199,n2=270,LogPval=-0.169035
# m=688,l=89,n1=194,n2=123,LogPval=-0.098428
# m=342,l=69,n1=89,n2=89,LogPval=-0.234993
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=328,l=59,n1=80,n2=75,LogPval=-0.221318
# m=323,l=58,n1=84,n2=78,LogPval=-0.184544
# m=335,l=45,n1=104,n2=68,LogPval=-0.074800
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=703,l=123,n1=197,n2=181,LogPval=-0.131972
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=708,l=85,n1=201,n2=111,LogPval=-0.099160
# m=337,l=51,n1=101,n2=88,LogPval=-0.068816
# m=350,l=57,n1=90,n2=93,LogPval=-0.117071
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=708,l=69,n1=200,n2=138,LogPval=-0.029741
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=696,l=154,n1=197,n2=202,LogPval=-0.229817
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=355,l=34,n1=109,n2=57,LogPval=-0.040715
# m=708,l=150,n1=200,n2=206,LogPval=-0.198276
# m=708,l=114,n1=202,n2=199,LogPval=-0.078611
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=695,l=107,n1=189,n2=177,LogPval=-0.092193
# m=707,l=151,n1=199,n2=240,LogPval=-0.155056
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=703,l=155,n1=201,n2=214,LogPval=-0.205385
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=700,l=113,n1=200,n2=184,LogPval=-0.092088
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=691,l=114,n1=196,n2=198,LogPval=-0.083601
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=707,l=163,n1=200,n2=219,LogPval=-0.237195
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=709,l=113,n1=202,n2=223,LogPval=-0.056838
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=709,l=109,n1=202,n2=170,LogPval=-0.094837
# m=704,l=124,n1=201,n2=217,LogPval=-0.089179
# m=679,l=80,n1=196,n2=122,LogPval=-0.069049
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=706,l=101,n1=200,n2=143,LogPval=-0.105866
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=709,l=129,n1=201,n2=183,LogPval=-0.146711
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=710,l=122,n1=203,n2=196,LogPval=-0.103548
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=679,l=145,n1=193,n2=209,LogPval=-0.182347
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=691,l=125,n1=183,n2=192,LogPval=-0.142199
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=709,l=104,n1=201,n2=183,LogPval=-0.068658
# m=681,l=109,n1=195,n2=197,LogPval=-0.071164
# 8 m=337,l=70,n1=104,n2=101,LogPval=-0.150408
# m=1614,l=255,n1=501,n2=362,LogPval=-0.100646
# m=302,l=62,n1=80,n2=90,LogPval=-0.195225
# m=991,l=211,n1=295,n2=282,LogPval=-0.190396
# m=667,l=101,n1=189,n2=152,LogPval=-0.101195
# m=1035,l=260,n1=322,n2=294,LogPval=-0.314190
# m=649,l=184,n1=227,n2=220,LogPval=-0.284025
# m=675,l=165,n1=212,n2=191,LogPval=-0.283995
# m=1354,l=254,n1=425,n2=326,LogPval=-0.155269
# m=1375,l=239,n1=428,n2=406,LogPval=-0.074459
# m=314,l=45,n1=93,n2=67,LogPval=-0.091548
# m=1381,l=301,n1=430,n2=409,LogPval=-0.175562
# m=1369,l=287,n1=427,n2=407,LogPval=-0.150758
# m=665,l=114,n1=184,n2=164,LogPval=-0.136894
# m=661,l=113,n1=189,n2=167,LogPval=-0.122158
# m=683,l=119,n1=191,n2=176,LogPval=-0.130471
# m=693,l=110,n1=200,n2=158,LogPval=-0.114528
# m=1381,l=274,n1=433,n2=451,LogPval=-0.097182
# m=662,l=161,n1=233,n2=197,LogPval=-0.207657
# m=975,l=182,n1=326,n2=281,LogPval=-0.089510
# m=950,l=166,n1=301,n2=244,LogPval=-0.103600
# m=654,l=86,n1=191,n2=140,LogPval=-0.067054
# m=942,l=214,n1=284,n2=279,LogPval=-0.216469
# m=1386,l=326,n1=432,n2=397,LogPval=-0.244620
# m=647,l=179,n1=224,n2=226,LogPval=-0.248501
# m=638,l=150,n1=184,n2=192,LogPval=-0.257310
# m=341,l=60,n1=123,n2=111,LogPval=-0.040037
# m=1281,l=288,n1=404,n2=396,LogPval=-0.175879
# m=1393,l=222,n1=438,n2=365,LogPval=-0.069822
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1711,l=377,n1=532,n2=485,LogPval=-0.199116
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1743,l=399,n1=542,n2=482,LogPval=-0.238473
# m=1737,l=429,n1=538,n2=643,LogPval=-0.180730
# m=1686,l=209,n1=515,n2=321,LogPval=-0.063147
# m=1339,l=285,n1=400,n2=358,LogPval=-0.211635
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1000,l=207,n1=292,n2=241,LogPval=-0.241824
# m=669,l=112,n1=193,n2=153,LogPval=-0.136040
# m=667,l=92,n1=227,n2=123,LogPval=-0.083611
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1730,l=311,n1=534,n2=435,LogPval=-0.125525
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1374,l=175,n1=425,n2=222,LogPval=-0.098400
# m=665,l=104,n1=218,n2=159,LogPval=-0.076168
# m=699,l=120,n1=197,n2=204,LogPval=-0.094419
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1712,l=185,n1=533,n2=313,LogPval=-0.039788
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1725,l=398,n1=536,n2=506,LogPval=-0.219520
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=684,l=63,n1=228,n2=99,LogPval=-0.036317
# m=1684,l=372,n1=520,n2=519,LogPval=-0.172691
# m=1382,l=230,n1=433,n2=369,LogPval=-0.079724
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1705,l=271,n1=514,n2=409,LogPval=-0.093617
# m=1733,l=374,n1=536,n2=566,LogPval=-0.139732
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1700,l=395,n1=534,n2=507,LogPval=-0.213827
# m=340,l=42,n1=103,n2=79,LogPval=-0.041819
# m=1713,l=283,n1=531,n2=437,LogPval=-0.088401
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1368,l=236,n1=428,n2=367,LogPval=-0.090922
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=312,l=35,n1=93,n2=48,LogPval=-0.079833
# m=1399,l=325,n1=435,n2=424,LogPval=-0.211366
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1715,l=264,n1=536,n2=522,LogPval=-0.038509
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1694,l=255,n1=525,n2=386,LogPval=-0.081610
# m=1734,l=294,n1=539,n2=502,LogPval=-0.070693
# m=1013,l=130,n1=319,n2=186,LogPval=-0.074350
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1729,l=253,n1=537,n2=341,LogPval=-0.101756
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1740,l=333,n1=539,n2=452,LogPval=-0.145385
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1743,l=297,n1=543,n2=471,LogPval=-0.085631
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1651,l=358,n1=501,n2=477,LogPval=-0.189606
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1693,l=325,n1=500,n2=458,LogPval=-0.147847
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1742,l=241,n1=540,n2=453,LogPval=-0.040333
# m=1681,l=255,n1=523,n2=469,LogPval=-0.048554
# 9 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1310,l=160,n1=322,n2=292,LogPval=-0.065763
# m=325,l=58,n1=66,n2=97,LogPval=-0.201643
# m=1005,l=161,n1=230,n2=289,LogPval=-0.117100
# m=692,l=90,n1=150,n2=160,LogPval=-0.096902
# m=1044,l=193,n1=252,n2=302,LogPval=-0.168521
# m=633,l=136,n1=173,n2=218,LogPval=-0.164938
# m=680,l=127,n1=164,n2=198,LogPval=-0.173679
# m=1354,l=254,n1=326,n2=425,LogPval=-0.155269
# m=1378,l=228,n1=333,n2=417,LogPval=-0.105964
# m=312,l=43,n1=78,n2=65,LogPval=-0.112157
# m=1390,l=297,n1=341,n2=418,LogPval=-0.248912
# m=1379,l=281,n1=336,n2=413,LogPval=-0.216297
# m=683,l=103,n1=140,n2=169,LogPval=-0.150168
# m=683,l=113,n1=156,n2=178,LogPval=-0.154260
# m=701,l=118,n1=157,n2=184,LogPval=-0.166419
# m=715,l=100,n1=157,n2=165,LogPval=-0.118743
# m=1387,l=250,n1=341,n2=457,LogPval=-0.117982
# m=648,l=146,n1=179,n2=199,LogPval=-0.232559
# m=961,l=181,n1=261,n2=282,LogPval=-0.139852
# m=961,l=159,n1=234,n2=249,LogPval=-0.138694
# m=676,l=74,n1=152,n2=146,LogPval=-0.059358
# m=951,l=195,n1=224,n2=287,LogPval=-0.233470
# m=1389,l=262,n1=337,n2=404,LogPval=-0.176390
# m=632,l=148,n1=170,n2=222,LogPval=-0.226113
# m=656,l=124,n1=143,n2=200,LogPval=-0.204454
# m=328,l=59,n1=94,n2=109,LogPval=-0.083082
# m=1291,l=265,n1=314,n2=410,LogPval=-0.203735
# m=1400,l=216,n1=343,n2=371,LogPval=-0.103994
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1381,l=231,n1=334,n2=394,LogPval=-0.122570
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1402,l=242,n1=340,n2=402,LogPval=-0.134399
# m=1398,l=263,n1=339,n2=519,LogPval=-0.113543
# m=1348,l=149,n1=329,n2=263,LogPval=-0.062601
# m=1046,l=191,n1=243,n2=316,LogPval=-0.162363
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=690,l=107,n1=154,n2=172,LogPval=-0.140513
# m=688,l=109,n1=151,n2=165,LogPval=-0.163278
# m=656,l=94,n1=170,n2=126,LogPval=-0.134521
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1398,l=246,n1=341,n2=348,LogPval=-0.178722
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1050,l=138,n1=255,n2=171,LogPval=-0.148233
# m=313,l=57,n1=86,n2=83,LogPval=-0.150791
# m=717,l=119,n1=163,n2=210,LogPval=-0.130249
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1386,l=140,n1=338,n2=257,LogPval=-0.051499
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1387,l=273,n1=339,n2=422,LogPval=-0.186783
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=331,l=25,n1=95,n2=52,LogPval=-0.022132
# m=1380,l=256,n1=334,n2=422,LogPval=-0.154414
# m=1049,l=171,n1=255,n2=293,LogPval=-0.115992
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1372,l=204,n1=317,n2=336,LogPval=-0.118215
# m=1404,l=288,n1=345,n2=460,LogPval=-0.189472
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1383,l=286,n1=343,n2=410,LogPval=-0.223224
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1391,l=215,n1=343,n2=362,LogPval=-0.106909
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1031,l=167,n1=247,n2=284,LogPval=-0.119788
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1403,l=291,n1=342,n2=433,LogPval=-0.219344
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1382,l=193,n1=337,n2=424,LogPval=-0.052739
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1382,l=198,n1=335,n2=320,LogPval=-0.106428
# m=1398,l=228,n1=341,n2=425,LogPval=-0.097662
# m=1026,l=123,n1=247,n2=190,LogPval=-0.092137
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1398,l=198,n1=343,n2=283,LogPval=-0.127075
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1409,l=273,n1=346,n2=371,LogPval=-0.219604
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1407,l=229,n1=345,n2=384,LogPval=-0.117802
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1353,l=255,n1=327,n2=420,LogPval=-0.159496
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1353,l=242,n1=299,n2=360,LogPval=-0.200310
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1406,l=179,n1=344,n2=369,LogPval=-0.053448
# m=1344,l=184,n1=327,n2=393,LogPval=-0.055336
# 10 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1330,l=152,n1=409,n2=291,LogPval=-0.030808
# m=322,l=56,n1=93,n2=97,LogPval=-0.090180
# m=1011,l=156,n1=293,n2=291,LogPval=-0.059381
# m=691,l=87,n1=189,n2=161,LogPval=-0.053969
# m=1059,l=181,n1=314,n2=304,LogPval=-0.084834
# m=651,l=134,n1=197,n2=217,LogPval=-0.118875
# m=693,l=117,n1=214,n2=194,LogPval=-0.079083
# m=1375,l=239,n1=406,n2=428,LogPval=-0.074459
# m=1378,l=228,n1=417,n2=333,LogPval=-0.105964
# m=313,l=52,n1=97,n2=66,LogPval=-0.141301
# m=1405,l=272,n1=417,n2=415,LogPval=-0.126365
# m=1392,l=287,n1=410,n2=408,LogPval=-0.163546
# m=683,l=131,n1=181,n2=168,LogPval=-0.211311
# m=682,l=132,n1=186,n2=176,LogPval=-0.192031
# m=703,l=140,n1=206,n2=183,LogPval=-0.184605
# m=715,l=127,n1=200,n2=164,LogPval=-0.171903
# m=1406,l=365,n1=423,n2=450,LogPval=-0.302468
# m=669,l=127,n1=208,n2=195,LogPval=-0.110988
# m=980,l=229,n1=304,n2=279,LogPval=-0.244325
# m=973,l=198,n1=292,n2=248,LogPval=-0.197796
# m=676,l=94,n1=192,n2=145,LogPval=-0.085505
# m=963,l=187,n1=285,n2=287,LogPval=-0.126863
# m=1405,l=251,n1=416,n2=400,LogPval=-0.102127
# m=651,l=133,n1=202,n2=227,LogPval=-0.097331
# m=656,l=127,n1=187,n2=200,LogPval=-0.130542
# m=343,l=89,n1=113,n2=108,LogPval=-0.266289
# m=1310,l=264,n1=389,n2=409,LogPval=-0.130388
# m=1419,l=313,n1=428,n2=368,LogPval=-0.248728
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1401,l=215,n1=421,n2=396,LogPval=-0.054639
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1420,l=219,n1=422,n2=399,LogPval=-0.058470
# m=1417,l=254,n1=421,n2=525,LogPval=-0.050347
# m=1364,l=151,n1=410,n2=262,LogPval=-0.041989
# m=1049,l=181,n1=303,n2=316,LogPval=-0.083529
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=689,l=103,n1=194,n2=174,LogPval=-0.078696
# m=688,l=127,n1=188,n2=161,LogPval=-0.194382
# m=675,l=97,n1=202,n2=123,LogPval=-0.121595
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1413,l=246,n1=419,n2=344,LogPval=-0.129415
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1064,l=121,n1=318,n2=168,LogPval=-0.075094
# m=328,l=67,n1=103,n2=83,LogPval=-0.191938
# m=719,l=160,n1=210,n2=207,LogPval=-0.224920
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1403,l=175,n1=419,n2=263,LogPval=-0.070268
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1409,l=250,n1=421,n2=425,LogPval=-0.084993
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=346,l=27,n1=117,n2=54,LogPval=-0.016468
# m=1394,l=241,n1=414,n2=421,LogPval=-0.077511
# m=1066,l=236,n1=320,n2=290,LogPval=-0.232814
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1390,l=270,n1=399,n2=332,LogPval=-0.204036
# m=1422,l=301,n1=422,n2=461,LogPval=-0.144895
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1401,l=254,n1=421,n2=410,LogPval=-0.098097
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1409,l=283,n1=423,n2=355,LogPval=-0.192734
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1047,l=226,n1=310,n2=279,LogPval=-0.226904
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1423,l=268,n1=423,n2=434,LogPval=-0.105837
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1398,l=262,n1=418,n2=428,LogPval=-0.101584
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1398,l=247,n1=416,n2=314,LogPval=-0.158573
# m=1419,l=348,n1=423,n2=418,LogPval=-0.289930
# m=1034,l=145,n1=304,n2=189,LogPval=-0.113692
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1416,l=192,n1=421,n2=285,LogPval=-0.080991
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1426,l=262,n1=425,n2=366,LogPval=-0.138853
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1427,l=310,n1=427,n2=382,LogPval=-0.225597
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1372,l=254,n1=406,n2=420,LogPval=-0.099314
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1372,l=223,n1=384,n2=364,LogPval=-0.095088
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1426,l=223,n1=425,n2=366,LogPval=-0.077431
# m=1365,l=211,n1=410,n2=391,LogPval=-0.054370
# 11 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=310,l=28,n1=65,n2=74,LogPval=-0.031362
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=303,l=38,n1=63,n2=87,LogPval=-0.065770
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=314,l=45,n1=67,n2=93,LogPval=-0.091548
# m=312,l=43,n1=65,n2=78,LogPval=-0.112157
# m=313,l=52,n1=66,n2=97,LogPval=-0.141301
# m=312,l=53,n1=65,n2=106,LogPval=-0.135377
# m=316,l=54,n1=66,n2=102,LogPval=-0.148602
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=313,l=51,n1=65,n2=86,LogPval=-0.162878
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=315,l=56,n1=67,n2=106,LogPval=-0.153560
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=283,l=50,n1=62,n2=78,LogPval=-0.190141
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=310,l=46,n1=65,n2=89,LogPval=-0.111962
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=282,l=46,n1=60,n2=96,LogPval=-0.112404
# m=315,l=50,n1=67,n2=88,LogPval=-0.140602
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=309,l=43,n1=67,n2=88,LogPval=-0.086350
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=314,l=43,n1=66,n2=94,LogPval=-0.079589
# m=313,l=46,n1=67,n2=114,LogPval=-0.065950
# m=297,l=28,n1=64,n2=65,LogPval=-0.041347
# m=307,l=49,n1=64,n2=108,LogPval=-0.102561
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=316,l=48,n1=66,n2=86,LogPval=-0.131798
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=315,l=51,n1=67,n2=101,LogPval=-0.120751
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=294,l=22,n1=62,n2=46,LogPval=-0.040800
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=311,l=45,n1=67,n2=101,LogPval=-0.077966
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=286,l=40,n1=58,n2=90,LogPval=-0.084685
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=308,l=50,n1=61,n2=76,LogPval=-0.200553
# m=316,l=58,n1=67,n2=104,LogPval=-0.178057
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=306,l=52,n1=65,n2=95,LogPval=-0.149646
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=313,l=44,n1=67,n2=71,LogPval=-0.131780
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=316,l=48,n1=66,n2=98,LogPval=-0.107097
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=288,l=38,n1=59,n2=98,LogPval=-0.057598
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=288,l=41,n1=58,n2=67,LogPval=-0.144990
# m=315,l=47,n1=66,n2=98,LogPval=-0.099703
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=310,l=39,n1=65,n2=72,LogPval=-0.094877
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=316,l=52,n1=66,n2=89,LogPval=-0.160518
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=316,l=51,n1=67,n2=93,LogPval=-0.137730
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=306,l=51,n1=64,n2=114,LogPval=-0.107411
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=292,l=35,n1=51,n2=73,LogPval=-0.100363
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=316,l=38,n1=66,n2=96,LogPval=-0.049816
# m=291,l=36,n1=61,n2=96,LogPval=-0.045745
# 12 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1335,l=190,n1=406,n2=297,LogPval=-0.073355
# m=323,l=57,n1=81,n2=97,LogPval=-0.128965
# m=1005,l=190,n1=282,n2=289,LogPval=-0.138000
# m=694,l=92,n1=175,n2=161,LogPval=-0.077624
# m=1076,l=222,n1=307,n2=308,LogPval=-0.182328
# m=668,l=161,n1=209,n2=226,LogPval=-0.194398
# m=702,l=145,n1=206,n2=200,LogPval=-0.176329
# m=1381,l=301,n1=409,n2=430,LogPval=-0.175562
# m=1390,l=297,n1=418,n2=341,LogPval=-0.248912
# m=1405,l=272,n1=415,n2=417,LogPval=-0.126365
# m=312,l=53,n1=106,n2=65,LogPval=-0.135377
# m=1402,l=338,n1=416,n2=413,LogPval=-0.275417
# m=688,l=119,n1=166,n2=168,LogPval=-0.178949
# m=686,l=130,n1=175,n2=178,LogPval=-0.198112
# m=692,l=139,n1=203,n2=180,LogPval=-0.189937
# m=721,l=118,n1=183,n2=167,LogPval=-0.151628
# m=1412,l=299,n1=421,n2=458,LogPval=-0.143474
# m=683,l=163,n1=215,n2=202,LogPval=-0.239564
# m=988,l=207,n1=319,n2=286,LogPval=-0.149115
# m=988,l=190,n1=289,n2=251,LogPval=-0.171632
# m=681,l=77,n1=173,n2=144,LogPval=-0.054046
# ...
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3514,l=567,n1=983,n2=968,LogPval=-0.084172
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3539,l=565,n1=992,n2=864,LogPval=-0.104825
# m=3558,l=604,n1=991,n2=1068,LogPval=-0.084687
# m=3201,l=588,n1=909,n2=924,LogPval=-0.119124
# m=3221,l=708,n1=887,n2=1129,LogPval=-0.168220
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3189,l=444,n1=917,n2=780,LogPval=-0.059635
# m=3181,l=533,n1=905,n2=909,LogPval=-0.085973
# m=2477,l=353,n1=699,n2=628,LogPval=-0.062692
# m=3571,l=445,n1=997,n2=813,LogPval=-0.049705
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1772,l=264,n1=535,n2=394,LogPval=-0.087595
# m=1393,l=194,n1=381,n2=294,LogPval=-0.093500
# m=3217,l=507,n1=922,n2=897,LogPval=-0.070486
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3228,l=543,n1=901,n2=868,LogPval=-0.104113
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3587,l=647,n1=1005,n2=990,LogPval=-0.125575
# m=3173,l=445,n1=910,n2=815,LogPval=-0.054377
# m=3525,l=465,n1=962,n2=727,LogPval=-0.080932
# m=2135,l=275,n1=634,n2=500,LogPval=-0.045461
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3587,l=477,n1=1007,n2=869,LogPval=-0.053957
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1360,l=300,n1=422,n2=429,LogPval=-0.162561
# m=348,l=70,n1=112,n2=107,LogPval=-0.115730
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3582,l=520,n1=1003,n2=826,LogPval=-0.084767
# m=3222,l=488,n1=924,n2=919,LogPval=-0.056287
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=695,l=94,n1=212,n2=170,LogPval=-0.048042
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2099,l=395,n1=621,n2=637,LogPval=-0.107325
# m=3196,l=362,n1=920,n2=707,LogPval=-0.033551
# m=1404,l=207,n1=421,n2=333,LogPval=-0.073926
# m=3215,l=484,n1=920,n2=942,LogPval=-0.051119
# m=3583,l=444,n1=1002,n2=845,LogPval=-0.044019
# m=1735,l=370,n1=521,n2=540,LogPval=-0.157525
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1421,l=213,n1=420,n2=414,LogPval=-0.047303
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2062,l=304,n1=612,n2=491,LogPval=-0.074325
# m=3590,l=402,n1=1010,n2=812,LogPval=-0.031768
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2130,l=257,n1=630,n2=473,LogPval=-0.040734
# m=1423,l=290,n1=421,n2=466,LogPval=-0.123659
# m=2757,l=404,n1=785,n2=652,LogPval=-0.080352
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2498,l=528,n1=726,n2=735,LogPval=-0.181006
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3235,l=496,n1=893,n2=1037,LogPval=-0.047401
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3596,l=736,n1=1014,n2=1026,LogPval=-0.180869
# m=1407,l=296,n1=404,n2=475,LogPval=-0.140286
# 103 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3828,l=496,n1=1087,n2=982,LogPval=-0.039954
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5281,l=771,n1=1552,n2=1369,LogPval=-0.058340
# m=5342,l=882,n1=1581,n2=1723,LogPval=-0.052133
# m=5282,l=882,n1=1557,n2=1329,LogPval=-0.104271
# m=5341,l=973,n1=1570,n2=1509,LogPval=-0.112084
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4969,l=739,n1=1460,n2=1243,LogPval=-0.068970
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1396,l=228,n1=394,n2=350,LogPval=-0.107105
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5313,l=718,n1=1570,n2=1177,LogPval=-0.063584
# m=5313,l=785,n1=1574,n2=1234,LogPval=-0.078958
# m=5283,l=749,n1=1565,n2=1313,LogPval=-0.056777
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5312,l=788,n1=1567,n2=1307,LogPval=-0.070457
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1734,l=261,n1=515,n2=466,LogPval=-0.059458
# m=5266,l=791,n1=1560,n2=1353,LogPval=-0.065697
# m=5286,l=685,n1=1562,n2=1302,LogPval=-0.040034
# m=4902,l=896,n1=1438,n2=1486,LogPval=-0.097340
# m=5318,l=715,n1=1571,n2=1335,LogPval=-0.044473
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5276,l=767,n1=1555,n2=1303,LogPval=-0.064639
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5338,l=993,n1=1573,n2=1633,LogPval=-0.100941
# m=4888,l=689,n1=1428,n2=1138,LogPval=-0.067848
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5257,l=855,n1=1545,n2=1364,LogPval=-0.088889
# m=4116,l=584,n1=1188,n2=1081,LogPval=-0.052596
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3536,l=590,n1=1048,n2=865,LogPval=-0.109588
# m=4944,l=672,n1=1480,n2=1216,LogPval=-0.047734
# m=4843,l=677,n1=1430,n2=1227,LogPval=-0.051281
# m=4561,l=686,n1=1343,n2=1278,LogPval=-0.053087
# m=2797,l=216,n1=833,n2=352,LogPval=-0.032318
# m=2063,l=383,n1=625,n2=542,LogPval=-0.132709
# m=2143,l=269,n1=619,n2=476,LogPval=-0.050723
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4133,l=385,n1=1216,n2=600,LogPval=-0.045643
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5354,l=815,n1=1583,n2=1494,LogPval=-0.055826
# m=4942,l=694,n1=1469,n2=1250,LogPval=-0.051578
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5353,l=700,n1=1583,n2=1222,LogPval=-0.051622
# m=5319,l=989,n1=1573,n2=1471,LogPval=-0.124905
# m=4511,l=686,n1=1335,n2=1127,LogPval=-0.074244
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3415,l=580,n1=973,n2=877,LogPval=-0.113747
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5259,l=853,n1=1550,n2=1544,LogPval=-0.064111
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5347,l=1160,n1=1577,n2=1574,LogPval=-0.192217
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 104 m=358,l=39,n1=91,n2=106,LogPval=-0.020123
# m=1667,l=166,n1=435,n2=376,LogPval=-0.024690
# m=325,l=45,n1=75,n2=97,LogPval=-0.067456
# m=1023,l=124,n1=253,n2=295,LogPval=-0.033444
# m=701,l=72,n1=158,n2=163,LogPval=-0.040384
# m=1084,l=154,n1=274,n2=311,LogPval=-0.061199
# m=672,l=115,n1=179,n2=227,LogPval=-0.076505
# m=709,l=104,n1=183,n2=201,LogPval=-0.068658
# m=1742,l=241,n1=453,n2=540,LogPval=-0.040333
# m=1406,l=179,n1=369,n2=344,LogPval=-0.053448
# m=1426,l=223,n1=366,n2=425,LogPval=-0.077431
# m=316,l=38,n1=96,n2=66,LogPval=-0.049816
# m=1432,l=207,n1=377,n2=427,LogPval=-0.052932
# m=1421,l=214,n1=370,n2=423,LogPval=-0.064710
# m=695,l=92,n1=156,n2=171,LogPval=-0.086294
# m=693,l=93,n1=160,n2=180,LogPval=-0.077103
# m=709,l=104,n1=184,n2=186,LogPval=-0.080475
# m=727,l=84,n1=170,n2=168,LogPval=-0.057020
# m=1434,l=233,n1=380,n2=468,LogPval=-0.066741
# m=686,l=106,n1=184,n2=203,LogPval=-0.069036
# m=1004,l=157,n1=280,n2=290,LogPval=-0.068629
# m=998,l=145,n1=248,n2=256,LogPval=-0.088291
# m=688,l=93,n1=163,n2=147,LogPval=-0.107483
# m=986,l=142,n1=244,n2=296,LogPval=-0.061272
# m=1434,l=199,n1=372,n2=412,LogPval=-0.051406
# m=669,l=108,n1=179,n2=236,LogPval=-0.052601
# m=667,l=98,n1=157,n2=204,LogPval=-0.072830
# m=356,l=63,n1=102,n2=116,LogPval=-0.081358
# m=1333,l=203,n1=353,n2=418,LogPval=-0.056731
# m=1445,l=208,n1=383,n2=380,LogPval=-0.069883
# m=1018,l=159,n1=318,n2=256,LogPval=-0.073397
# m=19731,l=3022,n1=5619,n2=5552,LogPval=-0.061523
# m=357,l=51,n1=91,n2=88,LogPval=-0.089037
# m=22288,l=3420,n1=6359,n2=5865,LogPval=-0.073164
# m=22994,l=3967,n1=6620,n2=7479,LogPval=-0.066931
# m=21474,l=3472,n1=6120,n2=5553,LogPval=-0.093125
# m=19393,l=3600,n1=5510,n2=5746,LogPval=-0.116310
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2029,l=197,n1=496,n2=480,LogPval=-0.022991
# m=700,l=94,n1=164,n2=166,LogPval=-0.089235
# m=20798,l=3306,n1=6021,n2=5417,LogPval=-0.083079
# m=9020,l=1610,n1=2576,n2=2459,LogPval=-0.118910
# m=9054,l=1533,n1=2605,n2=2365,LogPval=-0.105951
# m=9022,l=1303,n1=2531,n2=2018,LogPval=-0.088066
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2880,l=356,n1=752,n2=697,LogPval=-0.048726
# m=13704,l=1960,n1=4011,n2=2964,LogPval=-0.084204
# m=20163,l=3008,n1=5802,n2=4557,LogPval=-0.091747
# m=21467,l=3424,n1=6258,n2=5577,LogPval=-0.083360
# m=1453,l=264,n1=447,n2=415,LogPval=-0.099189
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=22353,l=3594,n1=6460,n2=5678,LogPval=-0.092170
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=7354,l=1106,n1=2112,n2=2046,LogPval=-0.057745
# m=19691,l=3665,n1=5733,n2=5221,LogPval=-0.140404
# m=21083,l=2791,n1=6120,n2=4886,LogPval=-0.054073
# m=22490,l=3879,n1=6434,n2=6252,LogPval=-0.099999
# m=20228,l=3000,n1=5842,n2=5236,LogPval=-0.064734
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=22258,l=3463,n1=6430,n2=5623,LogPval=-0.082636
# m=5705,l=992,n1=1647,n2=1790,LogPval=-0.076073
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=19437,l=3796,n1=5630,n2=5922,LogPval=-0.127045
# m=14659,l=2266,n1=4224,n2=3714,LogPval=-0.080634
# m=2871,l=369,n1=749,n2=720,LogPval=-0.051999
# m=1086,l=209,n1=362,n2=292,LogPval=-0.120107
# m=22291,l=3638,n1=6424,n2=5622,LogPval=-0.099477
# m=13508,l=2239,n1=3920,n2=3780,LogPval=-0.081965
# m=3025,l=347,n1=857,n2=596,LogPval=-0.050559
# m=1451,l=210,n1=380,n2=444,LogPval=-0.050306
# m=1455,l=181,n1=417,n2=327,LogPval=-0.048923
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=12882,l=2428,n1=3664,n2=3540,LogPval=-0.142987
# m=17285,l=2508,n1=5072,n2=4186,LogPval=-0.067665
# m=18807,l=2994,n1=5375,n2=4713,LogPval=-0.093771
# m=21976,l=3559,n1=6348,n2=6330,LogPval=-0.070182
# m=14735,l=1681,n1=4165,n2=2735,LogPval=-0.056680
# m=9979,l=2051,n1=2923,n2=2833,LogPval=-0.172205
# m=4840,l=588,n1=1352,n2=962,LogPval=-0.062623
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1058,l=148,n1=350,n2=212,LogPval=-0.074978
# m=13825,l=1689,n1=3924,n2=2760,LogPval=-0.060792
# m=364,l=96,n1=138,n2=110,LogPval=-0.240274
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4341,l=608,n1=1218,n2=1115,LogPval=-0.056961
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=19332,l=3151,n1=5576,n2=5291,LogPval=-0.082062
# m=17609,l=2322,n1=5109,n2=4068,LogPval=-0.053778
# m=705,l=138,n1=248,n2=194,LogPval=-0.109126
# m=16217,l=2306,n1=4706,n2=3738,LogPval=-0.072432
# m=15874,l=3343,n1=4650,n2=4510,LogPval=-0.187074
# m=14781,l=2458,n1=4237,n2=3689,LogPval=-0.110052
# m=722,l=161,n1=252,n2=195,LogPval=-0.189078
# m=5676,l=1107,n1=1691,n2=1575,LogPval=-0.145132
# m=9287,l=1653,n1=2539,n2=2616,LogPval=-0.120303
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=21531,l=3524,n1=6173,n2=6167,LogPval=-0.075740
# m=1733,l=319,n1=526,n2=424,LogPval=-0.148695
# m=3596,l=736,n1=1026,n2=1014,LogPval=-0.180869
# m=5347,l=1160,n1=1574,n2=1577,LogPval=-0.192217
# m=7822,l=1549,n1=2248,n2=2424,LogPval=-0.131618
# 105 m=354,l=34,n1=78,n2=108,LogPval=-0.017241
# m=1602,l=170,n1=447,n2=364,LogPval=-0.026065
# m=294,l=50,n1=85,n2=91,LogPval=-0.078108
# m=963,l=131,n1=287,n2=274,LogPval=-0.032408
# m=669,l=83,n1=182,n2=156,LogPval=-0.051730
# m=1051,l=156,n1=295,n2=302,LogPval=-0.055320
# m=670,l=106,n1=182,n2=225,LogPval=-0.052880
# m=681,l=109,n1=197,n2=195,LogPval=-0.071164
# m=1681,l=255,n1=469,n2=523,LogPval=-0.048554
# m=1344,l=184,n1=393,n2=327,LogPval=-0.055336
# m=1365,l=211,n1=391,n2=410,LogPval=-0.054370
# m=291,l=36,n1=96,n2=61,LogPval=-0.045745
# m=1371,l=213,n1=398,n2=404,LogPval=-0.056440
# m=1359,l=219,n1=398,n2=402,LogPval=-0.063617
# m=664,l=93,n1=188,n2=165,LogPval=-0.063602
# m=660,l=87,n1=187,n2=173,LogPval=-0.043611
# m=650,l=105,n1=204,n2=171,LogPval=-0.075034
# m=694,l=82,n1=199,n2=163,LogPval=-0.036613
# m=1372,l=228,n1=403,n2=449,LogPval=-0.054086
# m=684,l=105,n1=181,n2=201,LogPval=-0.070767
# m=978,l=149,n1=286,n2=282,LogPval=-0.054746
# m=965,l=140,n1=271,n2=251,LogPval=-0.065316
# m=655,l=90,n1=189,n2=142,LogPval=-0.077936
# m=956,l=150,n1=256,n2=288,LogPval=-0.069612
# m=1374,l=210,n1=394,n2=394,LogPval=-0.058727
# m=667,l=114,n1=180,n2=234,LogPval=-0.066729
# m=636,l=101,n1=180,n2=195,LogPval=-0.061465
# m=356,l=54,n1=97,n2=116,LogPval=-0.050021
# m=1276,l=212,n1=370,n2=397,LogPval=-0.064962
# m=1383,l=198,n1=407,n2=365,LogPval=-0.052376
# m=1019,l=169,n1=277,n2=257,LogPval=-0.120343
# m=8007,l=1331,n1=2486,n2=2322,LogPval=-0.063683
# m=356,l=54,n1=94,n2=87,LogPval=-0.103185
# m=7045,l=1123,n1=2192,n2=1950,LogPval=-0.060364
# m=8102,l=1563,n1=2512,n2=2885,LogPval=-0.068643
# m=6232,l=934,n1=1948,n2=1499,LogPval=-0.067805
# m=7006,l=1292,n1=2178,n2=2077,LogPval=-0.092373
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1681,l=166,n1=396,n2=384,LogPval=-0.030875
# m=667,l=92,n1=188,n2=157,LogPval=-0.068931
# m=6713,l=1044,n1=2101,n2=1724,LogPval=-0.065967
# m=3519,l=573,n1=1073,n2=956,LogPval=-0.073574
# m=3017,l=444,n1=968,n2=800,LogPval=-0.044576
# m=3894,l=632,n1=1196,n2=920,LogPval=-0.099839
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2809,l=348,n1=750,n2=679,LogPval=-0.046631
# m=1766,l=221,n1=563,n2=395,LogPval=-0.038125
# m=7077,l=996,n1=2138,n2=1548,LogPval=-0.072722
# m=7040,l=1113,n1=2201,n2=1892,LogPval=-0.062521
# m=1395,l=247,n1=423,n2=403,LogPval=-0.090384
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=7794,l=1158,n1=2426,n2=1901,LogPval=-0.063664
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4174,l=645,n1=1289,n2=1238,LogPval=-0.043619
# m=4852,l=861,n1=1636,n2=1310,LogPval=-0.082763
# m=6310,l=791,n1=1966,n2=1215,LogPval=-0.060325
# m=8018,l=1305,n1=2462,n2=2199,LogPval=-0.069928
# m=5664,l=797,n1=1768,n2=1447,LogPval=-0.043948
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=7755,l=1172,n1=2431,n2=1972,LogPval=-0.059882
# m=4891,l=825,n1=1502,n2=1552,LogPval=-0.053964
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5949,l=1013,n1=1866,n2=1762,LogPval=-0.064855
# m=2803,l=390,n1=886,n2=721,LogPval=-0.039815
# m=2799,l=350,n1=742,n2=705,LogPval=-0.044194
# m=1077,l=225,n1=434,n2=288,LogPval=-0.112624
# m=7783,l=1135,n1=2407,n2=2028,LogPval=-0.049672
# m=3913,l=643,n1=1217,n2=1065,LogPval=-0.072263
# m=2647,l=282,n1=815,n2=504,LogPval=-0.033855
# m=1389,l=218,n1=403,n2=425,LogPval=-0.053035
# m=1440,l=205,n1=472,n2=319,LogPval=-0.062797
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3809,l=646,n1=1102,n2=1153,LogPval=-0.075065
# m=3574,l=491,n1=1109,n2=815,LogPval=-0.056406
# m=5604,l=815,n1=1722,n2=1407,LogPval=-0.055791
# m=8113,l=1309,n1=2519,n2=2373,LogPval=-0.054404
# m=5631,l=729,n1=1714,n2=1217,LogPval=-0.053487
# m=1752,l=308,n1=551,n2=469,LogPval=-0.096718
# m=624,l=72,n1=256,n2=113,LogPval=-0.027097
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1049,l=140,n1=382,n2=204,LogPval=-0.054898
# m=3496,l=555,n1=1044,n2=837,LogPval=-0.094644
# m=364,l=78,n1=111,n2=110,LogPval=-0.168733
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4223,l=608,n1=1311,n2=1083,LogPval=-0.049048
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5544,l=788,n1=1703,n2=1449,LogPval=-0.044930
# m=3932,l=552,n1=1227,n2=948,LogPval=-0.052014
# m=706,l=122,n1=211,n2=195,LogPval=-0.096073
# m=2086,l=313,n1=687,n2=479,LogPval=-0.069014
# m=2785,l=533,n1=990,n2=838,LogPval=-0.073698
# m=2765,l=413,n1=857,n2=717,LogPval=-0.056245
# m=723,l=177,n1=210,n2=196,LogPval=-0.347782
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4822,l=777,n1=1377,n2=1377,LogPval=-0.072908
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=8120,l=1313,n1=2506,n2=2309,LogPval=-0.060740
# m=1687,l=310,n1=621,n2=412,LogPval=-0.103063
# m=1407,l=296,n1=475,n2=404,LogPval=-0.140286
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=7822,l=1549,n1=2424,n2=2248,LogPval=-0.131618

# %%
print Pvals[:2,:2]
print Length[:2,:2]
print P_norm[:2,:2]
# Out:
# [[ 0.  0.]
#  [ 0.  0.]]
# [[   0.  312.]
#  [ 312.    0.]]
# [[-0.4        -0.18461905]
#  [-0.18461905 -0.4       ]]

# %%
A=P_norm.flatten();
B=A[~isnan(A)]
print A.shape,B.shape
hist(-B,bins=100);
xlabel('significance')
# Out:
# (11236,) (6260,)

# %%
def showmat(mat):
    fig,axes=plt.subplots(1,1,figsize=(10,10))
    axes.imshow(mat, cmap=plt.cm.gray)

# %%
showmat(P_norm)

# %% [markdown]
# ### Finding structure in the rependency matrix.
# The matrix above shows, for each pair of stations, the normalized log probability that the overlap in rain days is random.
#
# We see immediately the first 8 stations are highly correlatedwith each other.
#
# To find more correlations we use SVD (the term PCA is reserved for decomposition of the covariance matrix). As we shall see that the top 10 eigenvectors explain about 80% of the square magnitude of the matrix.

# %%
print 'A group of very correlated stations is:',All.keys()[:8]
# Out:
# A group of very correlated stations is: [u'USC00094255', u'US1GAEM0001', u'USC00096126', u'USW00013870', u'USC00098476', u'US1GACF0001', u'US1GACF0003', u'USC00095858']

# %%
from sklearn.decomposition import PCA
P_norm0 = np.nan_to_num(P_norm)
n_comp=10
pca = PCA(n_components=n_comp, svd_solver='full')
pca.fit(P_norm0)     
#print(pca.explained_variance_)
Var_explained=pca.explained_variance_ratio_
plot(insert(cumsum(Var_explained),0,0))
grid()

# %%
# we will look only at the top 4 eigenvectors.
n_comp=4
pca = PCA(n_components=n_comp, svd_solver='full')
pca.fit(P_norm0)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=4, random_state=None,
#   svd_solver='full', tol=0.0, whiten=False)

# %%
fig,axes=plt.subplots(1,4,figsize=(20,5),sharey='row');
L=list(pca.components_.transpose())
for i in range(4):
    X=sorted(L,key=lambda x:x[i]) 
    axes[i].plot(X);

# %%
def re_order_matrix(M,order):
    M_reord=M[order,:]
    M_reord=M_reord[:,order]
    return M_reord

# %%
fig,axes=plt.subplots(2,2,figsize=(15,15),sharex='col',sharey='row');
i=0
for r in range(2):
    for c in range(2):
        order=np.argsort(pca.components_[i,:])
        P_norm_reord=re_order_matrix(P_norm0,order)
        axes[r,c].matshow(P_norm_reord)
        i+=1

# %% [markdown]
# ### Explanation and possibe extensions
# When we reorder the rows and columns of the matrix using one of the eigenvectors, the grouping of the
# stations becomes more evident. For example, consider the upper left corner of the scond matrix (The upper left one). The stations at positions 0-22 are clearly strongly correlated with each other. Even though there are some stations, in positions 15-18 or so, which are more related to each other than to the rest of this block.
#
# This type of organization is called **Block Diagonal** and it typically reveals important structure such as grouping or clustering.
#
# You might want to extract the sets of stations that form blocks for your region, and then plot them on the map to see their spatial relationship.

# %%
from pickle import dump
with open(data_dir+'/PRCP_residuals_PCA.pickle','wb') as file:
    dump({'stations':All.keys(),
          'eigen-vecs':pca.components_},
        file)
