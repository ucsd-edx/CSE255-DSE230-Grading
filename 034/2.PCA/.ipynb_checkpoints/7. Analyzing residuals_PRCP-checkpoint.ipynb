# %%
#setup
data_dir='../../Data/Weather'
#file_index='BBBSBBBB'
file_index='BSBSSSBB'
meas='TOBS'

# %% [markdown]
# # Reconstruction using top eigen-vectors
# For measurement = {{meas}}

# %% [markdown]
# ## Load the required libraries

# %%
# Enable automiatic reload of libraries
#%load_ext autoreload
#%autoreload 2 # means that all modules are reloaded before every command

# %%
# %pylab inline
import numpy as np

import findspark
findspark.init()

import sys
sys.path.append('./lib')

from numpy_pack import packArray,unpackArray

from Eigen_decomp import Eigen_decomp
from YearPlotter import YearPlotter
from recon_plot import recon_plot

from import_modules import import_modules,modules
import_modules(modules)

from ipywidgets import interactive,widgets
# Out:
# Populating the interactive namespace from numpy and matplotlib
#     pandas as    pd 	version=0.19.2 	required version>=0.19.2
#      numpy as    np 	version=1.11.3 	required version>=1.12.0 ******* Update Version ******
#    sklearn as    sk 	version=0.18.1 	required version>=0.18.1
#     urllib as urllib 	version=1.17 	required version>=1.17
#    pyspark as pyspark 	version=2.1.0+hadoop2.7 	required version>=2.1.0
# ipywidgets as ipywidgets 	version=6.0.0 	required version>=6.0.0

# %%
from pyspark import SparkContext
#sc.stop()

sc = SparkContext(master="local[3]",pyFiles=['lib/numpy_pack.py','lib/spark_PCA.py','lib/computeStats.py','lib/recon_plot.py','lib/Eigen_decomp.py'])

from pyspark import SparkContext
from pyspark.sql import *
sqlContext = SQLContext(sc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-da1c4f2f274c> in <module>()
#       2 #sc.stop()
#       3
# ----> 4 sc = SparkContext(master="local[3]",pyFiles=['lib/numpy_pack.py','lib/spark_PCA.py','lib/computeStats.py','lib/recon_plot.py','lib/Eigen_decomp.py'])
#       5
#       6 from pyspark import SparkContext
#
# /lib/spark-2.1.0-bin-hadoop2.7/python/pyspark/context.py in __init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls)
#     113         """
#     114         self._callsite = first_spark_call() or CallSite(None, None, None)
# --> 115         SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     116         try:
#     117             self._do_init(master, appName, sparkHome, pyFiles, environment, batchSize, serializer,
#
# /lib/spark-2.1.0-bin-hadoop2.7/python/pyspark/context.py in _ensure_initialized(cls, instance, gateway, conf)
#     270                         " created by %s at %s:%s "
#     271                         % (currentAppName, currentMaster,
# --> 272                             callsite.function, callsite.file, callsite.linenum))
#     273                 else:
#     274                     SparkContext._active_spark_context = instance
#
# ValueError: Cannot run multiple SparkContexts at once; existing SparkContext(app=pyspark-shell, master=local[3]) created by __init__ at <ipython-input-4-da1c4f2f274c>:4

# %% [markdown]
# ## Read Statistics File

# %%
from pickle import load

#read statistics
filename=data_dir+'/STAT_%s.pickle'%file_index
STAT,STAT_Descriptions = load(open(filename,'rb'))
measurements=STAT.keys()
print 'keys from STAT=',measurements
# Out:
# keys from STAT= ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'SNWD', 'PRCP']

# %% [markdown]
# ## Read data file into a spark DataFrame
# We focus on the snow-depth records, because the eigen-vectors for them make sense.

# %%
#read data
filename=data_dir+'/decon_%s_%s.parquet'%(file_index,meas)
df_in=sqlContext.read.parquet(filename)
#filter in 
df=df_in.filter(df_in.measurement==meas)
df.show(5)
# Out:
# +------------------+------------------+-------------------+---------+--------+--------+---------+-----------+-------------------+-------------------+-------------------+-------------------+-----------+-----------+------+--------------------+------+
# |           coeff_1|           coeff_2|            coeff_3|elevation|   label|latitude|longitude|measurement|              res_1|              res_2|              res_3|           res_mean|    station|  total_var|undefs|              vector|  year|
# +------------------+------------------+-------------------+---------+--------+--------+---------+-----------+-------------------+-------------------+-------------------+-------------------+-----------+-----------+------+--------------------+------+
# | 951.3156042742843|-36.86447687289478|-232.83629691576016|     46.9|BSBSSSBB| 31.0833| -82.5653|       TOBS| 0.4872809225033287| 0.4865110011103735| 0.4557973389173408|0.19826879475154144|USC00095492|  8902570.0|     0|[80 54 38 59 40 C...|2011.0|
# | 862.3642009136354|336.05427233388633|  -203.480607470735|     36.6|BSBSSSBB| 31.9297| -82.6792|       TOBS| 0.5494314798449891| 0.4810090884690779|  0.455923432746413| 0.1889860649917068|USC00095386|  8733550.0|     0|[A0 53 E0 58 A0 5...|1972.0|
# |-921.4317214854921|  84.7870923280904| -62.35786054988607|     61.0|BSBSSSBB| 31.7078| -82.1969|       TOBS| 0.4641490541750649| 0.4586976354158956| 0.4559973146614423|0.07569118036401214|USC00098476|2.1236624E7|     1|[98 5A 58 58 28 5...|1967.0|
# |-683.0455129943923|-264.4610271548915|-229.68698929039638|     36.6|BSBSSSBB|   30.74| -82.1278|       TOBS| 0.5419061090538881|0.49384305287358654|0.45605636254155096|0.07042153652897415|USC00093465|2.0221562E7|    15|[50 57 30 54 F0 5...|1978.0|
# |1131.0255047268342| 40.88850526749031| 15.923265261165586|    112.2|BSBSSSBB| 33.0831| -83.2497|       TOBS|0.45667900862829386| 0.4568872650481287|0.45683285989123884|0.26161013126913374|USC00095874|  8278040.0|     6|[30 54 00 53 E0 5...|1991.0|
# +------------------+------------------+-------------------+---------+--------+--------+---------+-----------+-------------------+-------------------+-------------------+-------------------+-----------+-----------+------+--------------------+------+
# only showing top 5 rows

# %% [markdown]
# ### Plot Mean and Eigenvecs

# %%
m=meas
fig,axes=plt.subplots(2,1, sharex='col', sharey='row',figsize=(10,6));
k=3
EigVec=np.matrix(STAT[m]['eigvec'][:,:k])
Mean=STAT[m]['Mean']
YearPlotter().plot(Mean,fig,axes[0],label='Mean',title=m+' Mean')
YearPlotter().plot(EigVec,fig,axes[1],title=m+' Eigs',labels=['eig'+str(i+1) for i in range(k)])

# %% [markdown]
# ### plot the percent of residual variance on average

# %%
#  x=0 in the graphs below correspond to the fraction of the variance explained by the mean alone
#  x=1,2,3,... are the residuals for eig1, eig1+eig2, eig1+eig2+eig3 ...
fig,ax=plt.subplots(1,1);
eigvals=STAT[m]['eigval']; eigvals/=sum(eigvals); cumvar=cumsum(eigvals); cumvar=100*np.insert(cumvar,0,0)
ax.plot(cumvar[:10]); 
ax.grid(); 
ax.set_ylabel('Percent of variance explained')
ax.set_xlabel('number of eigenvectors')
ax.set_title('Percent of variance explained');

# %% [markdown]
# ### How well-explained are the vectors in this collection?
#
# To answer this question we extract all of the values of `res_3` which is the residual variance after the Mean and the
# first two Eigen-vectors have been subtracted out. We rely here on the fact that `df3` is already sorted according to `res_3`

# %%
# A function for plotting the CDF of a given feature
def plot_CDF(df,feat):
    rows=df.select(feat).sort(feat).collect()
    vals=[r[feat] for r in rows]
    P=np.arange(0,1,1./(len(vals)))
    while len(vals)< len(P):
        vals=[vals[0]]+vals
    plot(vals,P)
    title('cumulative distribution of '+feat)
    ylabel('fraction of instances')
    xlabel(feat)
    grid()

# %%
plot_CDF(df,'res_3')

# %%
rows=df.rdd.map(lambda row:(row.station,row.year,unpackArray(row['vector'],np.float16))).collect()
rows[0][:2]
# Out:
# (u'USC00095492', 2011.0)

# %%
days=set([r[1] for r in rows])
miny=min(days)
maxy=max(days)
record_len=int((maxy-miny+1)*365)
record_len
# Out:
# 40880

# %%
## combine the measurements for each station into a single long array with an entry for each day of each day
All={}  # a dictionary with a numpy array for each day of each day
i=0
for station,day,vector in rows:
    i+=1; 
    # if i%1000==0: print i,len(All)
    if not station in All:
        a=np.zeros(record_len)
        a.fill(np.nan)
        All[station]=a
    loc = int((day-miny)*365)
    All[station][loc:loc+365]=vector

# %%
from datetime import date
d=datetime.date(int(miny), month=1, day=1)
start=d.toordinal()
dates=[date.fromordinal(i) for i in range(start,start+record_len)]

# %%
for station in All:
    print station, np.count_nonzero(~np.isnan(All[station]))
# Out:
# USC00094238 1095
# USC00098351 1762
# USW00093845 1448
# USC00094255 364
# USC00094429 18465
# USC00092839 29409
# USC00095858 342
# USC00095811 9764
# USC00090670 2885
# USC00096255 728
# USC00098476 14860
# USC00095696 1442
# USC00093325 6005
# USC00094110 3619
# USC00095401 336
# USC00095874 20730
# USC00097777 15617
# USC00093312 707
# USC00096237 7167
# USC00099020 365
# USC00092865 2186
# USC00089640 357
# USC00094862 2470
# USC00084393 2542
# USC00099451 1086
# USC00093386 20622
# USC00090131 8468
# USC00092966 21720
# USC00092844 726
# USC00097171 4358
# USC00094170 28119
# USC00090010 2125
# USC00099186 27541
# USC00093465 16820
# USC00094971 1094
# USC00094594 12141
# USC00094204 9380
# USC00095386 9976
# USC00096244 3243
# USC00084731 29542
# USC00098974 10452
# USC00090090 3460
# USC00095863 6518
# USC00085275 28957
# USC00098972 4371
# USC00084394 19786
# USC00092783 20352
# USC00095492 730
# USC00098496 9222
# USC00085099 19453
# USC00096650 730
# USW00013861 2189
# USC00083470 22256
# USC00095314 23227

# %%
Stations=sorted(All.keys())
A=[]
for station in Stations:
    A.append(All[station])

day_station_table=np.hstack([A])
print shape(day_station_table)
# Out:
# (54, 40880)

# %%
def RMS(Mat):
    return np.sqrt(np.nanmean(Mat**2))

mean_by_day=np.nanmean(day_station_table,axis=0)
mean_by_station=np.nanmean(day_station_table,axis=1)
tbl_minus_day = day_station_table-mean_by_day
tbl_minus_station = (day_station_table.transpose()-mean_by_station).transpose()

print 'total RMS                   = ',RMS(day_station_table)
print 'RMS removing mean-by-station= ',RMS(tbl_minus_station)
print 'RMS removing mean-by-day   = ',RMS(tbl_minus_day)
# Out:
# total RMS                   =  203.171356213
# RMS removing mean-by-station=  81.5408358551
# RMS removing mean-by-day   =  45.6835640248

# %%
RT=day_station_table
F=RT.flatten()
NN=F[~np.isnan(F)]

NN.sort()
P=np.arange(0.,1.,1./len(NN))
plot(NN,P)
grid()
title('CDF of daily rainfall')
xlabel('daily rainfall')
ylabel('cumulative probability')

# %% [markdown]
# ### Conclusions
# It is likely to be hard to find correlations between the **amount** of rain on the same day in different stations. Because amounts of rain vary a lot between even close locations. It is more reasonable to try to compare whether or not it rained on the same day in different stations. As we see from the graph above, in our region it rains in about one third of the days.
#
# ### measuring statistical significance
# We want to find a statistical test for rejecting the null hypothesis that says that the rainfall in the two locations is independent.
#
# Using the inner product is too noisy, because you multiply the rainfall on the same day in two locations and that product can be very large - leading to a large variance and poor ability to discriminate.
#
# An alternative is to ignore the amount of rain, and just ask whether it rained in both locations. We can then compute the probability associated with the number of overlaps under the null hypothesis.

# %% [markdown]
# Fix two stations. We restrict our attention to the days for which we have measurements for both stations, and define the following notation:
# * $m$ : the total number of days (for which we have measurements for both stations).
# * $n_1$ : the number of days that it rained on station 1
# * $n_2$ : the number of days that it rained on station 2
# * $l$ : the number of days that it rained on both stations.
#
# We want to calculate the probability that the number of overlap days is $l$ given $m,n_1,n_2$.
#
# The answer is:
# $$
# P = {m \choose l,n_1-l,n_2-l,m-n_1-n_2+l} /{m \choose n_1}{m \choose n_2}
# $$
#
# Where
# $$
# {m \choose l,n_1-l,n_2-l,m-n_1-n_2+l} = \frac{m!}{l! (n_1-l)! (n_2-l)! (m-n_1-n_2+l)!}
# $$
#
# We use the fact that $\Gamma(n+1) = n!$ and denote $G(n) \doteq \log \Gamma(n+1)$
# $$
# \log P = \left[G(m) - G(l) -G(n_1-l) -G(n_2-l) -G(m-n_1-n_2+l) \right] -
# \left[G(m)-G(n_1)-G(m-n_1)\right] - \left[G(m)-G(n_2)-G(m-n_2)\right]
# $$
# Which slightly simplifies to
# $$
# \log P = -G(l) -G(n_1-l) -G(n_2-l) -G(m-n_1-n_2+l) - G(m)+G(n_1)+G(m-n_1) +G(n_2)+G(m-n_2)
# $$
#
# The log probability scales with $m$ the length of the overlap. So to get a per-day significance we consider $
# \frac{1}{m} \log P $

# %%
from scipy.special import gammaln,factorial
#for i in range(10):
#    print exp(gammaln(i+1))-factorial(i)
def G(n):
    return gammaln(n+1)
def LogProb(m,l,n1,n2):
    logP=-G(l)-G(n1-l)-G(n2-l)-G(m-n1-n2+l)-G(m)+G(n1)+G(m-n1)+G(n2)+G(m-n2)
    return logP/m
exp(LogProb(1000,0,500,500))
# Out:
# 0.501843349103545

# %%
#USC00193270 21482
#USC00193702 28237
#USC00094238 1424
#USC00098351 3393
X=copy(All['USC00092783'])
Y=copy(All['USC00098351'])
print sum(~np.isnan(X))
print sum(~np.isnan(Y))
X[np.isnan(Y)]=np.nan
Y[np.isnan(X)]=np.nan
print sum(~np.isnan(X))
print sum(~np.isnan(Y))
# Out:
# 20352
# 1762
# 365
# 365

# %%
def computeLogProb(X,Y):
    X[np.isnan(Y)]=np.nan
    Y[np.isnan(X)]=np.nan
    G=~isnan(X)
    m=sum(G)
    XG=X[G]>250.0
    YG=Y[G]>250.0
    
    XG = XG1 + XG2
    YG = YG1 + YG2
    n1=sum(XG)
    n2=sum(YG)
    l=sum(XG*YG)
    logprob=LogProb(m,l,n1,n2)
    print 'm=%d,l=%d,n1=%d,n2=%d,LogPval=%f'%(m,l,n1,n2,logprob)
    return logprob,m
print computeLogProb(X,Y)
# Out:
# m=365,l=80,n1=129,n2=160,LogPval=-0.043293
# (-0.043293213889284109, 365)

# %% [markdown]
# ### calculate the normalized log probability for each pair of stations.

# %%
L=len(Stations)
Pvals=np.zeros([L,L])
Length=np.zeros([L,L])
P_norm=np.zeros([L,L])
for i in range(L):
    print i,
    for j in range(L):
        if i==j:
            P_norm[i,j]=-0.4
            continue
        X=copy(All[Stations[i]])
        Y=copy(All[Stations[j]])
        P_norm[i,j],Length[i,j]=computeLogProb(X,Y)
        if Length[i,j]<200:
            P_norm[i,j]=np.nan
# Out:
# 0 m=693,l=212,n1=286,n2=272,LogPval=-0.191656
# m=12667,l=3556,n1=4351,n2=4324,LogPval=-0.276710
# m=18385,l=4388,n1=6563,n2=6227,LogPval=-0.135718
# m=11940,l=2102,n1=4049,n2=5945,LogPval=-0.000812
# m=18913,l=3008,n1=7261,n2=5710,LogPval=-0.018622
# m=355,l=92,n1=120,n2=110,LogPval=-0.261154
# m=1713,l=378,n1=419,n2=573,LogPval=-0.240090
# m=2740,l=342,n1=1208,n2=1011,LogPval=-0.013888
# m=5975,l=459,n1=2879,n2=1843,LogPval=-0.050824
# m=2462,l=537,n1=652,n2=844,LogPval=-0.185946
# m=12457,l=2194,n1=4218,n2=4151,LogPval=-0.039754
# m=17134,l=3758,n1=6391,n2=6767,LogPval=-0.046589
# m=708,l=146,n1=176,n2=253,LogPval=-0.164307
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=14541,l=2845,n1=5106,n2=4992,LogPval=-0.054410
# m=696,l=121,n1=298,n2=241,LogPval=-0.009826
# m=4848,l=928,n1=1220,n2=1337,LogPval=-0.187520
# m=11009,l=3212,n1=4227,n2=4410,LogPval=-0.174702
# m=11612,l=1966,n1=3822,n2=6037,LogPval=-0.000387
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=19148,l=4290,n1=7310,n2=7047,LogPval=-0.063747
# m=6733,l=1199,n1=1775,n2=2407,LogPval=-0.077490
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=10586,l=2604,n1=3303,n2=3794,LogPval=-0.185472
# m=5944,l=837,n1=1574,n2=2714,LogPval=-0.004721
# m=2058,l=465,n1=543,n2=776,LogPval=-0.181636
# m=1051,l=209,n1=251,n2=272,LogPval=-0.256055
# m=15340,l=3665,n1=5618,n2=6714,LogPval=-0.054877
# m=5273,l=672,n1=2533,n2=1770,LogPval=-0.011054
# m=326,l=64,n1=74,n2=110,LogPval=-0.187206
# m=718,l=204,n1=226,n2=260,LogPval=-0.313810
# m=1426,l=173,n1=706,n2=622,LogPval=-0.077014
# m=4993,l=1442,n1=1999,n2=2542,LogPval=-0.062531
# m=329,l=48,n1=84,n2=104,LogPval=-0.055886
# m=3964,l=1135,n1=1654,n2=1754,LogPval=-0.089114
# m=13387,l=2162,n1=4669,n2=5314,LogPval=-0.005172
# m=2454,l=897,n1=1140,n2=1226,LogPval=-0.152392
# m=2816,l=231,n1=688,n2=1440,LogPval=-0.021377
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=703,l=135,n1=172,n2=195,LogPval=-0.199663
# m=3878,l=862,n1=988,n2=1158,LogPval=-0.266939
# m=8147,l=1814,n1=2411,n2=3132,LogPval=-0.121512
# m=1040,l=173,n1=372,n2=385,LogPval=-0.013455
# m=8528,l=1682,n1=2921,n2=4243,LogPval=-0.006873
# m=5608,l=1255,n1=2146,n2=2771,LogPval=-0.010914
# m=350,l=20,n1=71,n2=188,LogPval=-0.040064
# m=7066,l=2014,n1=2839,n2=2659,LogPval=-0.165038
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=19247,l=4322,n1=7107,n2=6741,LogPval=-0.085592
# m=1046,l=185,n1=239,n2=305,LogPval=-0.159407
# m=711,l=116,n1=197,n2=178,LogPval=-0.112293
# m=1432,l=69,n1=712,n2=410,LogPval=-0.094692
# 1 m=693,l=212,n1=272,n2=286,LogPval=-0.191656
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1441,l=229,n1=542,n2=306,LogPval=-0.080393
# m=362,l=99,n1=136,n2=114,LogPval=-0.255396
# m=721,l=177,n1=284,n2=212,LogPval=-0.178814
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1084,l=229,n1=358,n2=434,LogPval=-0.061307
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=723,l=216,n1=314,n2=320,LogPval=-0.099806
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=358,l=105,n1=154,n2=132,LogPval=-0.172199
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1426,l=369,n1=583,n2=600,LogPval=-0.066745
# m=1079,l=246,n1=447,n2=452,LogPval=-0.027871
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=726,l=119,n1=324,n2=253,LogPval=-0.004448
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=726,l=210,n1=285,n2=259,LogPval=-0.216493
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 2 m=12667,l=3556,n1=4324,n2=4351,LogPval=-0.276710
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=15703,l=2935,n1=4830,n2=4843,LogPval=-0.090462
# m=15286,l=2226,n1=4870,n2=7838,LogPval=-0.003181
# m=15366,l=2304,n1=5280,n2=5534,LogPval=-0.006805
# m=357,l=95,n1=124,n2=110,LogPval=-0.277354
# m=2125,l=542,n1=588,n2=713,LogPval=-0.310612
# m=2398,l=358,n1=928,n2=1022,LogPval=-0.003525
# m=5551,l=498,n1=2523,n2=1905,LogPval=-0.041262
# m=2884,l=673,n1=839,n2=968,LogPval=-0.201827
# m=16584,l=3112,n1=5369,n2=5313,LogPval=-0.072258
# m=14330,l=2974,n1=4633,n2=5202,LogPval=-0.079792
# m=726,l=181,n1=194,n2=258,LogPval=-0.284390
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=17533,l=3492,n1=5663,n2=6503,LogPval=-0.061255
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5990,l=1197,n1=1640,n2=1647,LogPval=-0.187417
# m=14940,l=3923,n1=5107,n2=6191,LogPval=-0.138132
# m=15192,l=2139,n1=4840,n2=7826,LogPval=-0.005301
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=14494,l=3264,n1=4986,n2=5201,LogPval=-0.099685
# m=5080,l=1102,n1=1423,n2=1644,LogPval=-0.178602
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16805,l=3827,n1=5219,n2=6812,LogPval=-0.101876
# m=10203,l=1521,n1=2908,n2=5055,LogPval=-0.001004
# m=2469,l=619,n1=719,n2=925,LogPval=-0.216518
# m=1094,l=245,n1=301,n2=280,LogPval=-0.307227
# m=17184,l=3692,n1=5743,n2=7801,LogPval=-0.036619
# m=8385,l=1244,n1=3074,n2=2620,LogPval=-0.011754
# m=336,l=69,n1=88,n2=116,LogPval=-0.155202
# m=730,l=228,n1=240,n2=262,LogPval=-0.420129
# m=1407,l=168,n1=676,n2=593,LogPval=-0.060300
# m=8601,l=1862,n1=2944,n2=4418,LogPval=-0.015303
# m=339,l=49,n1=79,n2=109,LogPval=-0.065320
# m=5731,l=1479,n1=2265,n2=2564,LogPval=-0.057225
# m=17304,l=3200,n1=5766,n2=6750,LogPval=-0.028524
# m=6399,l=1527,n1=2269,n2=3267,LogPval=-0.030063
# m=2781,l=204,n1=712,n2=1402,LogPval=-0.034568
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=730,l=157,n1=207,n2=200,LogPval=-0.229684
# m=4357,l=1107,n1=1228,n2=1297,LogPval=-0.354316
# m=13621,l=3123,n1=4063,n2=5649,LogPval=-0.112244
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=12888,l=2273,n1=4233,n2=6446,LogPval=-0.001653
# m=7310,l=1385,n1=2690,n2=3577,LogPval=-0.001299
# m=2875,l=273,n1=746,n2=1475,LogPval=-0.016456
# m=6407,l=2012,n1=2617,n2=2414,LogPval=-0.242052
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16480,l=3617,n1=5479,n2=5481,LogPval=-0.119427
# m=1086,l=211,n1=285,n2=313,LogPval=-0.171286
# m=2168,l=382,n1=595,n2=573,LogPval=-0.131569
# m=1418,l=56,n1=682,n2=390,LogPval=-0.095991
# 3 m=18385,l=4388,n1=6227,n2=6563,LogPval=-0.135718
# m=1441,l=229,n1=306,n2=542,LogPval=-0.080393
# m=15703,l=2935,n1=4843,n2=4830,LogPval=-0.090462
# m=15350,l=3161,n1=4768,n2=7746,LogPval=-0.023190
# m=22092,l=4121,n1=7523,n2=7358,LogPval=-0.052749
# m=344,l=79,n1=152,n2=103,LogPval=-0.100325
# m=2113,l=304,n1=555,n2=711,LogPval=-0.035825
# m=3058,l=441,n1=1231,n2=1117,LogPval=-0.001212
# m=5909,l=603,n1=2373,n2=2083,LogPval=-0.015189
# m=2845,l=560,n1=797,n2=959,LogPval=-0.114692
# m=15857,l=2199,n1=4905,n2=5104,LogPval=-0.016252
# m=22962,l=4403,n1=7587,n2=8960,LogPval=-0.037334
# m=711,l=129,n1=136,n2=255,LogPval=-0.190896
# m=1093,l=148,n1=199,n2=476,LogPval=-0.045960
# m=16882,l=2968,n1=5276,n2=6139,LogPval=-0.038402
# m=351,l=79,n1=141,n2=119,LogPval=-0.079975
# m=5274,l=903,n1=1449,n2=1460,LogPval=-0.107564
# m=14347,l=3121,n1=4700,n2=5872,LogPval=-0.065833
# m=13882,l=2750,n1=4269,n2=7284,LogPval=-0.013162
# m=1443,l=197,n1=287,n2=557,LogPval=-0.048309
# m=21355,l=4025,n1=7152,n2=7606,LogPval=-0.046340
# m=7809,l=1680,n1=2324,n2=2821,LogPval=-0.119802
# m=364,l=31,n1=48,n2=165,LogPval=-0.016995
# m=364,l=54,n1=100,n2=103,LogPval=-0.064311
# m=14358,l=2779,n1=4314,n2=5672,LogPval=-0.055654
# m=9230,l=1771,n1=2541,n2=4571,LogPval=-0.031974
# m=2440,l=424,n1=694,n2=916,LogPval=-0.047505
# m=1093,l=162,n1=281,n2=279,LogPval=-0.088990
# m=17614,l=4109,n1=5738,n2=8086,LogPval=-0.065803
# m=7759,l=1013,n1=2789,n2=2540,LogPval=-0.002131
# m=336,l=60,n1=84,n2=116,LogPval=-0.103752
# m=707,l=155,n1=232,n2=250,LogPval=-0.108468
# m=1060,l=139,n1=508,n2=458,LogPval=-0.050777
# m=7142,l=1862,n1=2422,n2=3759,LogPval=-0.063621
# m=341,l=43,n1=89,n2=109,LogPval=-0.027522
# m=5029,l=1198,n1=1702,n2=2273,LogPval=-0.067374
# m=15610,l=1994,n1=4925,n2=6106,LogPval=-0.000455
# m=4993,l=1247,n1=1682,n2=2582,LogPval=-0.053580
# m=2861,l=429,n1=723,n2=1484,LogPval=-0.004969
# m=361,l=59,n1=103,n2=108,LogPval=-0.074143
# m=729,l=118,n1=191,n2=200,LogPval=-0.101606
# m=4316,l=677,n1=1158,n2=1284,LogPval=-0.069312
# m=12974,l=2239,n1=3875,n2=5336,LogPval=-0.024501
# m=1017,l=218,n1=348,n2=371,LogPval=-0.079026
# m=10443,l=2291,n1=3249,n2=5270,LogPval=-0.037530
# m=7028,l=1691,n1=2375,n2=3625,LogPval=-0.040867
# m=2177,l=432,n1=632,n2=1139,LogPval=-0.022974
# m=8176,l=1985,n1=2686,n2=2942,LogPval=-0.154495
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=21058,l=4161,n1=7136,n2=7500,LogPval=-0.056986
# m=1086,l=142,n1=273,n2=313,LogPval=-0.043978
# m=1795,l=286,n1=625,n2=458,LogPval=-0.057394
# m=1054,l=53,n1=505,n2=283,LogPval=-0.069189
# 4 m=11940,l=2102,n1=5945,n2=4049,LogPval=-0.000812
# m=362,l=99,n1=114,n2=136,LogPval=-0.255396
# m=15286,l=2226,n1=7838,n2=4870,LogPval=-0.003181
# m=15350,l=3161,n1=7746,n2=4768,LogPval=-0.023190
# m=13963,l=3774,n1=6938,n2=5098,LogPval=-0.070596
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1733,l=117,n1=1007,n2=572,LogPval=-0.150327
# m=2741,l=699,n1=1286,n2=1124,LogPval=-0.034073
# m=5632,l=1038,n1=2590,n2=2093,LogPval=-0.002224
# m=1393,l=180,n1=849,n2=466,LogPval=-0.054446
# m=15092,l=973,n1=7892,n2=4821,LogPval=-0.101887
# m=14000,l=1405,n1=7073,n2=5150,LogPval=-0.064919
# m=350,l=56,n1=231,n2=143,LogPval=-0.119005
# m=361,l=67,n1=127,n2=175,LogPval=-0.008720
# m=15428,l=2337,n1=7923,n2=5796,LogPval=-0.015009
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4474,l=427,n1=2546,n2=1232,LogPval=-0.039147
# m=14746,l=3933,n1=7333,n2=6235,LogPval=-0.026654
# m=13765,l=6031,n1=7181,n2=7127,LogPval=-0.247936
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=12751,l=1836,n1=6300,n2=4672,LogPval=-0.012222
# m=3903,l=486,n1=2233,n2=1231,LogPval=-0.030425
# m=362,l=65,n1=127,n2=164,LogPval=-0.010462
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=15374,l=3989,n1=8025,n2=6322,LogPval=-0.017043
# m=10933,l=3887,n1=5829,n2=5441,LogPval=-0.067285
# m=1015,l=93,n1=586,n2=364,LogPval=-0.124534
# m=1066,l=54,n1=613,n2=274,LogPval=-0.106548
# m=15778,l=4883,n1=8095,n2=7394,LogPval=-0.039132
# m=7481,l=621,n1=3585,n2=2417,LogPval=-0.049386
# m=317,l=40,n1=185,n2=108,LogPval=-0.055503
# m=352,l=39,n1=233,n2=113,LogPval=-0.110578
# m=1427,l=177,n1=595,n2=612,LogPval=-0.027813
# m=8233,l=3342,n1=3977,n2=4286,LogPval=-0.207053
# m=341,l=39,n1=199,n2=110,LogPval=-0.058084
# m=5365,l=1639,n1=2634,n2=2442,LogPval=-0.055993
# m=15548,l=1289,n1=7930,n2=6150,LogPval=-0.124350
# m=5706,l=2367,n1=2821,n2=2866,LogPval=-0.242715
# m=2796,l=1210,n1=1428,n2=1438,LogPval=-0.255088
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=722,l=47,n1=411,n2=200,LogPval=-0.092634
# m=2820,l=158,n1=1665,n2=836,LogPval=-0.146015
# m=13595,l=2518,n1=7104,n2=5755,LogPval=-0.010972
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=13237,l=5421,n1=6714,n2=6639,LogPval=-0.207676
# m=8421,l=3122,n1=4181,n2=4187,LogPval=-0.128814
# m=3613,l=1623,n1=1957,n2=1852,LogPval=-0.261965
# m=6072,l=1653,n1=2809,n2=2368,LogPval=-0.073416
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=14705,l=1611,n1=7613,n2=4900,LogPval=-0.036509
# m=1053,l=51,n1=606,n2=306,LogPval=-0.148840
# m=1812,l=156,n1=946,n2=486,LogPval=-0.031810
# m=1433,l=74,n1=596,n2=402,LogPval=-0.048305
# 5 m=18913,l=3008,n1=5710,n2=7261,LogPval=-0.018622
# m=721,l=177,n1=212,n2=284,LogPval=-0.178814
# m=15366,l=2304,n1=5534,n2=5280,LogPval=-0.006805
# m=22092,l=4121,n1=7358,n2=7523,LogPval=-0.052749
# m=13963,l=3774,n1=5098,n2=6938,LogPval=-0.070596
# m=350,l=87,n1=158,n2=110,LogPval=-0.116839
# m=1384,l=272,n1=361,n2=466,LogPval=-0.136078
# m=3459,l=701,n1=1130,n2=1287,LogPval=-0.064336
# m=7399,l=1020,n1=2014,n2=2354,LogPval=-0.029890
# m=1761,l=391,n1=535,n2=611,LogPval=-0.142627
# m=15538,l=1917,n1=5771,n2=5111,LogPval=-0.000288
# m=22011,l=3822,n1=7313,n2=8753,LogPval=-0.016275
# m=712,l=124,n1=204,n2=258,LogPval=-0.054883
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=17254,l=3274,n1=5930,n2=6424,LogPval=-0.036047
# m=340,l=84,n1=116,n2=118,LogPval=-0.170023
# m=4515,l=728,n1=1605,n2=1258,LogPval=-0.041675
# m=14801,l=2827,n1=5377,n2=6220,LogPval=-0.013275
# m=12775,l=3170,n1=4652,n2=6601,LogPval=-0.031987
# m=348,l=49,n1=71,n2=134,LogPval=-0.055507
# m=23271,l=3916,n1=7316,n2=8453,LogPval=-0.028988
# m=7455,l=1606,n1=2070,n2=2775,LogPval=-0.134938
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=13318,l=3447,n1=5266,n2=5458,LogPval=-0.082415
# m=8549,l=2923,n1=3700,n2=4315,LogPval=-0.131060
# m=1383,l=287,n1=407,n2=525,LogPval=-0.095454
# m=724,l=140,n1=196,n2=173,LogPval=-0.220226
# m=17701,l=4609,n1=5975,n2=8037,LogPval=-0.107405
# m=8853,l=981,n1=3167,n2=2931,LogPval=-0.001022
# m=332,l=72,n1=94,n2=115,LogPval=-0.158363
# m=716,l=158,n1=282,n2=262,LogPval=-0.056572
# m=1425,l=234,n1=377,n2=618,LogPval=-0.027625
# m=8297,l=2693,n1=3386,n2=4288,LogPval=-0.113061
# m=342,l=52,n1=77,n2=110,LogPval=-0.085117
# m=4707,l=1157,n1=1449,n2=2182,LogPval=-0.105485
# m=16008,l=2135,n1=5648,n2=6349,LogPval=-0.000664
# m=5719,l=1820,n1=2203,n2=2931,LogPval=-0.131988
# m=2524,l=951,n1=1252,n2=1263,LogPval=-0.140044
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=364,l=68,n1=94,n2=97,LogPval=-0.179639
# m=2855,l=552,n1=818,n2=853,LogPval=-0.131377
# m=11203,l=2047,n1=4750,n2=4657,LogPval=-0.000725
# m=1397,l=296,n1=412,n2=546,LogPval=-0.096438
# m=11921,l=3456,n1=4665,n2=6019,LogPval=-0.074242
# m=6691,l=2065,n1=2656,n2=3296,LogPval=-0.112230
# m=2912,l=1369,n1=1560,n2=1560,LogPval=-0.303294
# m=8907,l=1915,n1=2436,n2=3376,LogPval=-0.133993
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=22660,l=3803,n1=7387,n2=8265,LogPval=-0.023330
# m=1081,l=197,n1=277,n2=313,LogPval=-0.143155
# m=2187,l=212,n1=1123,n2=583,LogPval=-0.017938
# m=1431,l=167,n1=374,n2=409,LogPval=-0.023375
# 6 m=355,l=92,n1=110,n2=120,LogPval=-0.261154
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=95,n1=110,n2=124,LogPval=-0.277354
# m=344,l=79,n1=103,n2=152,LogPval=-0.100325
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=350,l=87,n1=110,n2=158,LogPval=-0.116839
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=355,l=94,n1=110,n2=166,LogPval=-0.150105
# m=357,l=98,n1=110,n2=144,LogPval=-0.240323
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=92,n1=110,n2=146,LogPval=-0.181203
# m=0,l=0,n1=0,n2=0,LogPval=nan
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in double_scalars
# m=357,l=91,n1=110,n2=125,LogPval=-0.233543
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=47,n1=110,n2=231,LogPval=-0.052499
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=97,n1=110,n2=153,LogPval=-0.205648
# m=355,l=93,n1=110,n2=159,LogPval=-0.157712
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=350,l=93,n1=110,n2=132,LogPval=-0.228162
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=351,l=92,n1=106,n2=160,LogPval=-0.164489
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=98,n1=110,n2=166,LogPval=-0.182456
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=94,n1=110,n2=138,LogPval=-0.220270
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=99,n1=110,n2=160,LogPval=-0.205753
# m=357,l=94,n1=110,n2=165,LogPval=-0.152936
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=92,n1=110,n2=127,LogPval=-0.236288
# m=353,l=93,n1=110,n2=154,LogPval=-0.168452
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=339,l=85,n1=105,n2=119,LogPval=-0.216571
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=97,n1=110,n2=133,LogPval=-0.265665
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 7 m=1713,l=378,n1=573,n2=419,LogPval=-0.240090
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2125,l=542,n1=713,n2=588,LogPval=-0.310612
# m=2113,l=304,n1=711,n2=555,LogPval=-0.035825
# m=1733,l=117,n1=572,n2=1007,LogPval=-0.150327
# m=1384,l=272,n1=466,n2=361,LogPval=-0.136078
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1052,l=249,n1=369,n2=336,LogPval=-0.160011
# m=1765,l=450,n1=586,n2=536,LogPval=-0.261007
# m=1404,l=404,n1=464,n2=482,LogPval=-0.326006
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2122,l=578,n1=711,n2=667,LogPval=-0.305686
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1743,l=360,n1=580,n2=471,LogPval=-0.154056
# m=681,l=170,n1=217,n2=188,LogPval=-0.313374
# m=2113,l=146,n1=711,n2=1228,LogPval=-0.154054
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=703,l=207,n1=226,n2=224,LogPval=-0.430445
# m=2117,l=499,n1=710,n2=663,LogPval=-0.179628
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2104,l=608,n1=706,n2=673,LogPval=-0.367668
# m=1044,l=291,n1=334,n2=333,LogPval=-0.352253
# m=1042,l=312,n1=371,n2=388,LogPval=-0.278873
# m=1054,l=247,n1=338,n2=266,LogPval=-0.296664
# m=1767,l=521,n1=592,n2=590,LogPval=-0.366621
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=333,l=83,n1=107,n2=116,LogPval=-0.198912
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1754,l=524,n1=581,n2=643,LogPval=-0.332563
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=693,l=159,n1=224,n2=187,LogPval=-0.238275
# m=2112,l=601,n1=710,n2=630,LogPval=-0.399288
# m=1377,l=416,n1=447,n2=465,LogPval=-0.419537
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=353,l=21,n1=115,n2=187,LogPval=-0.129088
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1371,l=297,n1=472,n2=338,LogPval=-0.211648
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2110,l=581,n1=704,n2=640,LogPval=-0.344082
# m=693,l=160,n1=226,n2=202,LogPval=-0.205890
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 8 m=2740,l=342,n1=1011,n2=1208,LogPval=-0.013888
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2398,l=358,n1=1022,n2=928,LogPval=-0.003525
# m=3058,l=441,n1=1117,n2=1231,LogPval=-0.001212
# m=2741,l=699,n1=1124,n2=1286,LogPval=-0.034073
# m=3459,l=701,n1=1287,n2=1130,LogPval=-0.064336
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1672,l=363,n1=533,n2=470,LogPval=-0.183763
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2404,l=196,n1=998,n2=799,LogPval=-0.032082
# m=3100,l=370,n1=1128,n2=1250,LogPval=-0.007923
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3096,l=464,n1=1111,n2=1297,LogPval=-0.001131
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=312,l=35,n1=145,n2=84,LogPval=-0.009012
# m=3093,l=439,n1=1104,n2=1370,LogPval=-0.003446
# m=1671,l=577,n1=809,n2=761,LogPval=-0.133342
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3079,l=438,n1=1110,n2=1141,LogPval=-0.001824
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1714,l=584,n1=826,n2=772,LogPval=-0.131046
# m=682,l=311,n1=346,n2=371,LogPval=-0.294869
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3448,l=798,n1=1280,n2=1568,LogPval=-0.035107
# m=2023,l=337,n1=743,n2=577,LogPval=-0.041046
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=342,l=42,n1=155,n2=137,LogPval=-0.036413
# m=2058,l=735,n1=927,n2=1017,LogPval=-0.156119
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=687,l=230,n1=326,n2=318,LogPval=-0.114655
# m=2363,l=417,n1=958,n2=950,LogPval=-0.002995
# m=674,l=270,n1=324,n2=361,LogPval=-0.179951
# m=349,l=156,n1=180,n2=197,LogPval=-0.219526
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1379,l=134,n1=604,n2=559,LogPval=-0.058558
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1383,l=539,n1=675,n2=670,LogPval=-0.204189
# m=1330,l=368,n1=572,n2=607,LogPval=-0.056200
# m=336,l=127,n1=158,n2=171,LogPval=-0.170067
# m=1022,l=252,n1=421,n2=480,LogPval=-0.026374
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3427,l=367,n1=1280,n2=1258,LogPval=-0.009449
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1036,l=114,n1=507,n2=272,LogPval=-0.006295
# m=350,l=19,n1=156,n2=102,LogPval=-0.065947
# 9 m=5975,l=459,n1=1843,n2=2879,LogPval=-0.050824
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5551,l=498,n1=1905,n2=2523,LogPval=-0.041262
# m=5909,l=603,n1=2083,n2=2373,LogPval=-0.015189
# m=5632,l=1038,n1=2093,n2=2590,LogPval=-0.002224
# m=7399,l=1020,n1=2354,n2=2014,LogPval=-0.029890
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1672,l=363,n1=470,n2=533,LogPval=-0.183763
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5570,l=928,n1=2054,n2=1804,LogPval=-0.022162
# m=7030,l=1109,n1=2482,n2=2705,LogPval=-0.004960
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6634,l=1052,n1=2261,n2=2543,LogPval=-0.007860
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=7361,l=1355,n1=2597,n2=3701,LogPval=-0.000928
# m=4496,l=754,n1=1665,n2=2066,LogPval=-0.000876
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=7654,l=1074,n1=2537,n2=2889,LogPval=-0.002718
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3841,l=899,n1=1489,n2=1837,LogPval=-0.021025
# m=2085,l=771,n1=937,n2=1039,LogPval=-0.185439
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=8024,l=1483,n1=2728,n2=3664,LogPval=-0.008340
# m=5168,l=978,n1=1838,n2=1754,LogPval=-0.045728
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1044,l=315,n1=348,n2=466,LogPval=-0.236312
# m=3900,l=595,n1=1303,n2=1992,LogPval=-0.003867
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4214,l=1036,n1=1619,n2=2021,LogPval=-0.033302
# m=6925,l=1549,n1=2494,n2=2757,LogPval=-0.058964
# m=3421,l=672,n1=1274,n2=1685,LogPval=-0.002491
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3511,l=1020,n1=1466,n2=1706,LogPval=-0.065603
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4545,l=843,n1=1612,n2=2201,LogPval=-0.002460
# m=3747,l=799,n1=1401,n2=1803,LogPval=-0.010481
# m=679,l=296,n1=358,n2=326,LogPval=-0.305486
# m=4236,l=629,n1=1386,n2=1948,LogPval=-0.000895
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6968,l=930,n1=2291,n2=2492,LogPval=-0.003020
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1042,l=284,n1=344,n2=296,LogPval=-0.387127
# 10 m=2462,l=537,n1=844,n2=652,LogPval=-0.185946
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2884,l=673,n1=968,n2=839,LogPval=-0.201827
# m=2845,l=560,n1=959,n2=797,LogPval=-0.114692
# m=1393,l=180,n1=466,n2=849,LogPval=-0.054446
# m=1761,l=391,n1=611,n2=535,LogPval=-0.142627
# m=355,l=94,n1=166,n2=110,LogPval=-0.150105
# m=1052,l=249,n1=336,n2=369,LogPval=-0.160011
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2146,l=562,n1=738,n2=715,LogPval=-0.223262
# m=700,l=184,n1=244,n2=258,LogPval=-0.178246
# m=721,l=189,n1=240,n2=258,LogPval=-0.208800
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2485,l=585,n1=837,n2=775,LogPval=-0.178665
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2484,l=569,n1=854,n2=707,LogPval=-0.189180
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2154,l=287,n1=764,n2=1250,LogPval=-0.048869
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1804,l=516,n1=628,n2=663,LogPval=-0.250224
# m=2866,l=763,n1=962,n2=953,LogPval=-0.250156
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2827,l=705,n1=962,n2=937,LogPval=-0.190961
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2440,l=645,n1=798,n2=919,LogPval=-0.200309
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2501,l=702,n1=852,n2=935,LogPval=-0.235002
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=722,l=210,n1=321,n2=262,LogPval=-0.157461
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1081,l=325,n1=424,n2=412,LogPval=-0.216129
# m=2161,l=566,n1=731,n2=832,LogPval=-0.169268
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2874,l=715,n1=964,n2=862,LogPval=-0.239864
# m=1411,l=400,n1=520,n2=536,LogPval=-0.197000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2092,l=478,n1=730,n2=545,LogPval=-0.222253
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2881,l=703,n1=969,n2=904,LogPval=-0.202321
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 11 m=12457,l=2194,n1=4151,n2=4218,LogPval=-0.039754
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16584,l=3112,n1=5313,n2=5369,LogPval=-0.072258
# m=15857,l=2199,n1=5104,n2=4905,LogPval=-0.016252
# m=15092,l=973,n1=4821,n2=7892,LogPval=-0.101887
# m=15538,l=1917,n1=5111,n2=5771,LogPval=-0.000288
# m=357,l=98,n1=144,n2=110,LogPval=-0.240323
# m=1765,l=450,n1=536,n2=586,LogPval=-0.261007
# m=2404,l=196,n1=799,n2=998,LogPval=-0.032082
# m=5570,l=928,n1=1804,n2=2054,LogPval=-0.022162
# m=2146,l=562,n1=715,n2=738,LogPval=-0.223262
# m=15173,l=4118,n1=4807,n2=5482,LogPval=-0.258174
# m=354,l=111,n1=129,n2=147,LogPval=-0.257008
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=17403,l=3981,n1=5566,n2=6435,LogPval=-0.120854
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5270,l=1051,n1=1724,n2=1452,LogPval=-0.133026
# m=14851,l=2336,n1=4739,n2=6180,LogPval=-0.005939
# m=14687,l=968,n1=4676,n2=7645,LogPval=-0.096491
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=13969,l=3470,n1=4594,n2=4981,LogPval=-0.172335
# m=4675,l=1072,n1=1506,n2=1545,LogPval=-0.156114
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16632,l=2710,n1=5282,n2=6762,LogPval=-0.011105
# m=11435,l=1399,n1=3583,n2=5700,LogPval=-0.011073
# m=1751,l=504,n1=581,n2=683,LogPval=-0.254526
# m=1094,l=220,n1=337,n2=280,LogPval=-0.180443
# m=17005,l=2753,n1=5391,n2=7910,LogPval=-0.002184
# m=6709,l=1629,n1=2175,n2=2273,LogPval=-0.181908
# m=336,l=68,n1=105,n2=116,LogPval=-0.096784
# m=721,l=227,n1=279,n2=261,LogPval=-0.304927
# m=1076,l=320,n1=344,n2=474,LogPval=-0.257109
# m=8659,l=734,n1=2734,n2=4539,LogPval=-0.062505
# m=342,l=53,n1=80,n2=110,LogPval=-0.083430
# m=5430,l=884,n1=1760,n2=2484,LogPval=-0.002630
# m=16789,l=4703,n1=5409,n2=6646,LogPval=-0.236906
# m=6075,l=440,n1=1823,n2=3114,LogPval=-0.065956
# m=3243,l=235,n1=1075,n2=1648,LogPval=-0.087851
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=730,l=155,n1=226,n2=200,LogPval=-0.189811
# m=3618,l=940,n1=1160,n2=1096,LogPval=-0.297730
# m=14141,l=3155,n1=4510,n2=5933,LogPval=-0.076340
# m=365,l=80,n1=129,n2=160,LogPval=-0.043293
# m=13038,l=1015,n1=4078,n2=6581,LogPval=-0.061953
# m=8521,l=1078,n1=2807,n2=4196,LogPval=-0.012093
# m=3999,l=313,n1=1252,n2=2076,LogPval=-0.069081
# m=5359,l=896,n1=1807,n2=2159,LogPval=-0.009772
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16638,l=4088,n1=5326,n2=5434,LogPval=-0.210310
# m=1086,l=297,n1=331,n2=313,LogPval=-0.429500
# m=1824,l=366,n1=589,n2=466,LogPval=-0.165202
# m=1091,l=299,n1=349,n2=326,LogPval=-0.373703
# 12 m=17134,l=3758,n1=6767,n2=6391,LogPval=-0.046589
# m=1084,l=229,n1=434,n2=358,LogPval=-0.061307
# m=14330,l=2974,n1=5202,n2=4633,LogPval=-0.079792
# m=22962,l=4403,n1=8960,n2=7587,LogPval=-0.037334
# m=14000,l=1405,n1=5150,n2=7073,LogPval=-0.064919
# m=22011,l=3822,n1=8753,n2=7313,LogPval=-0.016275
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1404,l=404,n1=482,n2=464,LogPval=-0.326006
# m=3100,l=370,n1=1250,n2=1128,LogPval=-0.007923
# m=7030,l=1109,n1=2705,n2=2482,LogPval=-0.004960
# m=700,l=184,n1=258,n2=244,LogPval=-0.178246
# m=15173,l=4118,n1=5482,n2=4807,LogPval=-0.258174
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16934,l=4331,n1=6271,n2=6283,LogPval=-0.130934
# m=704,l=163,n1=310,n2=239,LogPval=-0.065333
# m=3824,l=760,n1=1377,n2=1024,LogPval=-0.115343
# m=14800,l=3044,n1=5474,n2=6264,LogPval=-0.021462
# m=11746,l=1030,n1=4164,n2=5946,LogPval=-0.076525
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=21168,l=6258,n1=8311,n2=7548,LogPval=-0.234220
# m=6456,l=1831,n1=2524,n2=2419,LogPval=-0.175196
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=12976,l=2139,n1=4587,n2=5406,LogPval=-0.003093
# m=10311,l=1361,n1=3606,n2=5120,LogPval=-0.015779
# m=691,l=227,n1=259,n2=267,LogPval=-0.336740
# m=1082,l=238,n1=368,n2=276,LogPval=-0.211877
# m=16621,l=3481,n1=6163,n2=7751,LogPval=-0.011760
# m=7819,l=2010,n1=2977,n2=2546,LogPval=-0.175958
# m=335,l=73,n1=112,n2=115,LogPval=-0.111440
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=363,l=125,n1=143,n2=162,LogPval=-0.268602
# m=7552,l=778,n1=2670,n2=3896,LogPval=-0.056926
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4308,l=566,n1=1507,n2=2042,LogPval=-0.011382
# m=14915,l=4444,n1=5461,n2=5776,LogPval=-0.234034
# m=5727,l=455,n1=1978,n2=2905,LogPval=-0.085008
# m=2856,l=280,n1=1006,n2=1465,LogPval=-0.062612
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=719,l=161,n1=248,n2=197,LogPval=-0.189919
# m=2144,l=567,n1=749,n2=641,LogPval=-0.282484
# m=11953,l=2986,n1=4245,n2=5084,LogPval=-0.088870
# m=1392,l=415,n1=599,n2=523,LogPval=-0.171724
# m=10852,l=949,n1=3804,n2=5475,LogPval=-0.072999
# m=6722,l=957,n1=2436,n2=3391,LogPval=-0.014817
# m=3263,l=293,n1=1167,n2=1691,LogPval=-0.083242
# m=6472,l=1265,n1=2467,n2=2462,LogPval=-0.023342
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=21242,l=6172,n1=8366,n2=7651,LogPval=-0.210957
# m=1079,l=297,n1=364,n2=313,LogPval=-0.371618
# m=1823,l=363,n1=662,n2=465,LogPval=-0.129879
# m=363,l=106,n1=143,n2=107,LogPval=-0.364886
# 13 m=708,l=146,n1=253,n2=176,LogPval=-0.164307
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=726,l=181,n1=258,n2=194,LogPval=-0.284390
# m=711,l=129,n1=255,n2=136,LogPval=-0.190896
# m=350,l=56,n1=143,n2=231,LogPval=-0.119005
# m=712,l=124,n1=258,n2=204,LogPval=-0.054883
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=721,l=189,n1=258,n2=240,LogPval=-0.208800
# m=354,l=111,n1=147,n2=129,LogPval=-0.257008
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=691,l=150,n1=244,n2=169,LogPval=-0.210041
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=696,l=144,n1=254,n2=208,LogPval=-0.101151
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=363,l=48,n1=149,n2=217,LogPval=-0.118812
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=724,l=223,n1=256,n2=246,LogPval=-0.380525
# m=724,l=184,n1=258,n2=236,LogPval=-0.195725
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=711,l=188,n1=256,n2=208,LogPval=-0.283214
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=352,l=82,n1=103,n2=108,LogPval=-0.236766
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=705,l=221,n1=245,n2=246,LogPval=-0.399762
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=363,l=109,n1=149,n2=118,LogPval=-0.293175
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=363,l=122,n1=149,n2=139,LogPval=-0.312172
# m=722,l=219,n1=258,n2=257,LogPval=-0.319794
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=720,l=191,n1=255,n2=199,LogPval=-0.335775
# m=363,l=132,n1=149,n2=140,LogPval=-0.429994
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=708,l=151,n1=247,n2=162,LogPval=-0.233807
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=725,l=188,n1=258,n2=205,LogPval=-0.289286
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 14 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=723,l=216,n1=320,n2=314,LogPval=-0.099806
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1093,l=148,n1=476,n2=199,LogPval=-0.045960
# m=361,l=67,n1=175,n2=127,LogPval=-0.008720
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=703,l=169,n1=297,n2=235,LogPval=-0.095631
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1820,l=565,n1=786,n2=731,LogPval=-0.168404
# m=1065,l=276,n1=468,n2=468,LogPval=-0.038995
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1094,l=411,n1=491,n2=480,LogPval=-0.292171
# m=364,l=83,n1=149,n2=103,LogPval=-0.137436
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=727,l=220,n1=322,n2=289,LogPval=-0.144560
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 15 m=14541,l=2845,n1=4992,n2=5106,LogPval=-0.054410
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=17533,l=3492,n1=6503,n2=5663,LogPval=-0.061255
# m=16882,l=2968,n1=6139,n2=5276,LogPval=-0.038402
# m=15428,l=2337,n1=5796,n2=7923,LogPval=-0.015009
# m=17254,l=3274,n1=6424,n2=5930,LogPval=-0.036047
# m=357,l=92,n1=146,n2=110,LogPval=-0.181203
# m=2122,l=578,n1=667,n2=711,LogPval=-0.305686
# m=3096,l=464,n1=1297,n2=1111,LogPval=-0.001131
# m=6634,l=1052,n1=2543,n2=2261,LogPval=-0.007860
# m=2485,l=585,n1=775,n2=837,LogPval=-0.178665
# m=17403,l=3981,n1=6435,n2=5566,LogPval=-0.120854
# m=16934,l=4331,n1=6283,n2=6271,LogPval=-0.130934
# m=691,l=150,n1=169,n2=244,LogPval=-0.210041
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5601,l=1056,n1=1879,n2=1544,LogPval=-0.101325
# m=16563,l=3883,n1=6295,n2=6861,LogPval=-0.052342
# m=15000,l=1758,n1=5243,n2=7716,LogPval=-0.035244
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16009,l=4138,n1=5618,n2=5750,LogPval=-0.170750
# m=4684,l=1069,n1=1452,n2=1494,LogPval=-0.179349
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16236,l=3886,n1=5859,n2=6415,LogPval=-0.085770
# m=11049,l=2369,n1=4052,n2=5431,LogPval=-0.010453
# m=2095,l=558,n1=659,n2=779,LogPval=-0.232126
# m=1092,l=246,n1=347,n2=278,LogPval=-0.256685
# m=18763,l=4484,n1=6705,n2=8490,LogPval=-0.053355
# m=8129,l=1497,n1=3503,n2=2709,LogPval=-0.015518
# m=336,l=83,n1=108,n2=116,LogPval=-0.195644
# m=717,l=211,n1=258,n2=260,LogPval=-0.269565
# m=1441,l=469,n1=565,n2=623,LogPval=-0.224416
# m=7931,l=1642,n1=3074,n2=4084,LogPval=-0.000972
# m=342,l=62,n1=109,n2=110,LogPval=-0.070212
# m=5427,l=1092,n1=1909,n2=2435,LogPval=-0.017379
# m=17430,l=4238,n1=6339,n2=6860,LogPval=-0.091546
# m=5348,l=1203,n1=2149,n2=2725,LogPval=-0.004111
# m=3237,l=273,n1=1011,n2=1646,LogPval=-0.054141
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=728,l=162,n1=231,n2=198,LogPval=-0.217235
# m=3954,l=1001,n1=1233,n2=1178,LogPval=-0.293402
# m=14129,l=3637,n1=5249,n2=5931,LogPval=-0.092313
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=12328,l=1995,n1=4485,n2=6170,LogPval=-0.003890
# m=8157,l=1640,n1=3069,n2=3986,LogPval=-0.003014
# m=3269,l=932,n1=1450,n2=1691,LogPval=-0.026465
# m=6047,l=1220,n1=2192,n2=2259,LogPval=-0.040988
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=17615,l=4089,n1=6331,n2=5871,LogPval=-0.123684
# m=1085,l=234,n1=324,n2=312,LogPval=-0.193923
# m=1459,l=262,n1=566,n2=388,LogPval=-0.064261
# m=1447,l=342,n1=560,n2=411,LogPval=-0.172281
# 16 m=696,l=121,n1=241,n2=298,LogPval=-0.009826
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=351,l=79,n1=119,n2=141,LogPval=-0.079975
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=340,l=84,n1=118,n2=116,LogPval=-0.170023
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=704,l=163,n1=239,n2=310,LogPval=-0.065333
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=707,l=145,n1=242,n2=261,LogPval=-0.062290
# m=350,l=97,n1=118,n2=161,LogPval=-0.147447
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=678,l=150,n1=226,n2=274,LogPval=-0.073931
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=691,l=156,n1=241,n2=317,LogPval=-0.042534
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 17 m=4848,l=928,n1=1337,n2=1220,LogPval=-0.187520
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5990,l=1197,n1=1647,n2=1640,LogPval=-0.187417
# m=5274,l=903,n1=1460,n2=1449,LogPval=-0.107564
# m=4474,l=427,n1=1232,n2=2546,LogPval=-0.039147
# m=4515,l=728,n1=1258,n2=1605,LogPval=-0.041675
# m=357,l=91,n1=125,n2=110,LogPval=-0.233543
# m=1743,l=360,n1=471,n2=580,LogPval=-0.154056
# m=312,l=35,n1=84,n2=145,LogPval=-0.009012
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2484,l=569,n1=707,n2=854,LogPval=-0.189180
# m=5270,l=1051,n1=1452,n2=1724,LogPval=-0.133026
# m=3824,l=760,n1=1024,n2=1377,LogPval=-0.115343
# m=696,l=144,n1=208,n2=254,LogPval=-0.101151
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5601,l=1056,n1=1544,n2=1879,LogPval=-0.101325
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2431,l=482,n1=644,n2=700,LogPval=-0.179426
# m=4916,l=502,n1=1363,n2=2842,LogPval=-0.035204
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4199,l=893,n1=1165,n2=1440,LogPval=-0.152030
# m=4584,l=972,n1=1284,n2=1490,LogPval=-0.163126
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5589,l=1137,n1=1555,n2=1881,LogPval=-0.132345
# m=2759,l=438,n1=729,n2=1093,LogPval=-0.032184
# m=2083,l=448,n1=570,n2=785,LogPval=-0.136580
# m=1066,l=216,n1=299,n2=275,LogPval=-0.212293
# m=4929,l=994,n1=1376,n2=1872,LogPval=-0.096713
# m=678,l=134,n1=193,n2=237,LogPval=-0.105665
# m=323,l=75,n1=97,n2=114,LogPval=-0.172625
# m=710,l=188,n1=251,n2=260,LogPval=-0.180175
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1369,l=133,n1=348,n2=700,LogPval=-0.013615
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1071,l=273,n1=355,n2=407,LogPval=-0.165052
# m=4561,l=941,n1=1227,n2=1760,LogPval=-0.114002
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=702,l=62,n1=161,n2=325,LogPval=-0.007384
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=716,l=143,n1=198,n2=197,LogPval=-0.186152
# m=3912,l=830,n1=1107,n2=1174,LogPval=-0.185703
# m=4172,l=895,n1=1160,n2=1528,LogPval=-0.137083
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2431,l=269,n1=646,n2=1266,LogPval=-0.009265
# m=362,l=21,n1=83,n2=200,LogPval=-0.060937
# m=689,l=71,n1=174,n2=357,LogPval=-0.012054
# m=2077,l=418,n1=588,n2=540,LogPval=-0.200875
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5649,l=1165,n1=1539,n2=1795,LogPval=-0.163018
# m=1056,l=184,n1=312,n2=306,LogPval=-0.090126
# m=338,l=69,n1=93,n2=107,LogPval=-0.160173
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 18 m=11009,l=3212,n1=4410,n2=4227,LogPval=-0.174702
# m=358,l=105,n1=132,n2=154,LogPval=-0.172199
# m=14940,l=3923,n1=6191,n2=5107,LogPval=-0.138132
# m=14347,l=3121,n1=5872,n2=4700,LogPval=-0.065833
# m=14746,l=3933,n1=6235,n2=7333,LogPval=-0.026654
# m=14801,l=2827,n1=6220,n2=5377,LogPval=-0.013275
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=681,l=170,n1=188,n2=217,LogPval=-0.313374
# m=3093,l=439,n1=1370,n2=1104,LogPval=-0.003446
# m=7361,l=1355,n1=3701,n2=2597,LogPval=-0.000928
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=14851,l=2336,n1=6180,n2=4739,LogPval=-0.005939
# m=14800,l=3044,n1=6264,n2=5474,LogPval=-0.021462
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=703,l=169,n1=235,n2=297,LogPval=-0.095631
# m=16563,l=3883,n1=6861,n2=6295,LogPval=-0.052342
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2431,l=482,n1=700,n2=644,LogPval=-0.179426
# m=12752,l=3107,n1=5318,n2=6308,LogPval=-0.011857
# m=1749,l=473,n1=679,n2=721,LogPval=-0.109900
# m=14564,l=3610,n1=5922,n2=5350,LogPval=-0.087779
# m=1074,l=241,n1=313,n2=339,LogPval=-0.196498
# m=352,l=120,n1=129,n2=158,LogPval=-0.310173
# m=350,l=54,n1=105,n2=101,LogPval=-0.057224
# m=14076,l=4457,n1=5734,n2=5964,LogPval=-0.185752
# m=10646,l=2926,n1=4247,n2=5431,LogPval=-0.043655
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=716,l=157,n1=201,n2=187,LogPval=-0.269631
# m=16932,l=5002,n1=7140,n2=8007,LogPval=-0.077954
# m=9223,l=1180,n1=4364,n2=2986,LogPval=-0.006311
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1427,l=204,n1=723,n2=618,LogPval=-0.050585
# m=9020,l=2924,n1=3875,n2=4661,LogPval=-0.088888
# m=340,l=54,n1=79,n2=110,LogPval=-0.091464
# m=5407,l=2144,n1=2814,n2=2530,LogPval=-0.204281
# m=16314,l=2525,n1=7134,n2=6467,LogPval=-0.003207
# m=6790,l=2681,n1=3263,n2=3420,LogPval=-0.201652
# m=2841,l=171,n1=791,n2=1416,LogPval=-0.065508
# m=714,l=188,n1=316,n2=265,LogPval=-0.090639
# m=717,l=160,n1=202,n2=191,LogPval=-0.274845
# m=707,l=181,n1=202,n2=211,LogPval=-0.355460
# m=12662,l=4191,n1=5149,n2=5514,LogPval=-0.213558
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=12971,l=3597,n1=5363,n2=6460,LogPval=-0.043035
# m=9170,l=2814,n1=4216,n2=4543,LogPval=-0.051704
# m=4358,l=1316,n1=1884,n2=2253,LogPval=-0.052141
# m=5036,l=1904,n1=2474,n2=2215,LogPval=-0.233292
# m=362,l=107,n1=162,n2=122,LogPval=-0.210221
# m=15115,l=3248,n1=6462,n2=5232,LogPval=-0.040749
# m=357,l=72,n1=93,n2=100,LogPval=-0.208829
# m=1448,l=277,n1=442,n2=418,LogPval=-0.119663
# m=1433,l=92,n1=726,n2=409,LogPval=-0.068071
# 19 m=11612,l=1966,n1=6037,n2=3822,LogPval=-0.000387
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=15192,l=2139,n1=7826,n2=4840,LogPval=-0.005301
# m=13882,l=2750,n1=7284,n2=4269,LogPval=-0.013162
# m=13765,l=6031,n1=7127,n2=7181,LogPval=-0.247936
# m=12775,l=3170,n1=6601,n2=4652,LogPval=-0.031987
# m=357,l=47,n1=231,n2=110,LogPval=-0.052499
# m=2113,l=146,n1=1228,n2=711,LogPval=-0.154054
# m=1671,l=577,n1=761,n2=809,LogPval=-0.133342
# m=4496,l=754,n1=2066,n2=1665,LogPval=-0.000876
# m=2154,l=287,n1=1250,n2=764,LogPval=-0.048869
# m=14687,l=968,n1=7645,n2=4676,LogPval=-0.096491
# m=11746,l=1030,n1=5946,n2=4164,LogPval=-0.076525
# m=363,l=48,n1=217,n2=149,LogPval=-0.118812
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=15000,l=1758,n1=7716,n2=5243,LogPval=-0.035244
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4916,l=502,n1=2842,n2=1363,LogPval=-0.035204
# m=12752,l=3107,n1=6308,n2=5318,LogPval=-0.011857
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=12370,l=1592,n1=6319,n2=4464,LogPval=-0.027477
# m=4352,l=522,n1=2545,n2=1410,LogPval=-0.046193
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=14591,l=3109,n1=7612,n2=5755,LogPval=-0.000743
# m=9133,l=3011,n1=4774,n2=4489,LogPval=-0.043532
# m=1762,l=190,n1=1001,n2=683,LogPval=-0.113103
# m=1086,l=62,n1=657,n2=278,LogPval=-0.108341
# m=14976,l=4304,n1=7770,n2=6933,LogPval=-0.018363
# m=5545,l=539,n1=2632,n2=1740,LogPval=-0.026119
# m=336,l=43,n1=197,n2=116,LogPval=-0.057387
# m=730,l=82,n1=453,n2=262,LogPval=-0.117063
# m=1398,l=192,n1=692,n2=600,LogPval=-0.049060
# m=8101,l=3297,n1=3985,n2=4309,LogPval=-0.181859
# m=340,l=41,n1=209,n2=109,LogPval=-0.062867
# m=6086,l=1771,n1=2927,n2=2727,LogPval=-0.047479
# m=15459,l=1329,n1=7924,n2=6117,LogPval=-0.119927
# m=4910,l=1977,n1=2339,n2=2514,LogPval=-0.219922
# m=3185,l=1354,n1=1727,n2=1617,LogPval=-0.195026
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=722,l=54,n1=443,n2=198,LogPval=-0.095783
# m=3625,l=206,n1=2129,n2=1102,LogPval=-0.150455
# m=12084,l=1994,n1=6327,n2=4968,LogPval=-0.021366
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=11702,l=4862,n1=5958,n2=5929,LogPval=-0.214724
# m=7283,l=2724,n1=3569,n2=3683,LogPval=-0.134102
# m=2424,l=1070,n1=1264,n2=1291,LogPval=-0.235616
# m=6013,l=1490,n1=3019,n2=2376,LogPval=-0.021232
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=13552,l=1351,n1=7145,n2=4370,LogPval=-0.046450
# m=1086,l=57,n1=641,n2=313,LogPval=-0.146423
# m=1740,l=152,n1=896,n2=444,LogPval=-0.022422
# m=1404,l=82,n1=695,n2=393,LogPval=-0.069026
# 20 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1426,l=369,n1=600,n2=583,LogPval=-0.066745
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1443,l=197,n1=557,n2=287,LogPval=-0.048309
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=348,l=49,n1=134,n2=71,LogPval=-0.055507
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1820,l=565,n1=731,n2=786,LogPval=-0.168404
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1749,l=473,n1=721,n2=679,LogPval=-0.109900
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1423,l=369,n1=556,n2=610,LogPval=-0.075430
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=729,l=198,n1=274,n2=314,LogPval=-0.110776
# m=363,l=82,n1=145,n2=103,LogPval=-0.138275
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1424,l=397,n1=601,n2=542,LogPval=-0.126911
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=338,l=88,n1=139,n2=142,LogPval=-0.072610
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=727,l=191,n1=287,n2=268,LogPval=-0.129424
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=364,l=85,n1=155,n2=122,LogPval=-0.082750
# m=365,l=87,n1=133,n2=144,LogPval=-0.087588
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 21 m=19148,l=4290,n1=7047,n2=7310,LogPval=-0.063747
# m=1079,l=246,n1=452,n2=447,LogPval=-0.027871
# m=14494,l=3264,n1=5201,n2=4986,LogPval=-0.099685
# m=21355,l=4025,n1=7606,n2=7152,LogPval=-0.046340
# m=12751,l=1836,n1=4672,n2=6300,LogPval=-0.012222
# m=23271,l=3916,n1=8453,n2=7316,LogPval=-0.028988
# m=357,l=97,n1=153,n2=110,LogPval=-0.205648
# m=703,l=207,n1=224,n2=226,LogPval=-0.430445
# m=3079,l=438,n1=1141,n2=1110,LogPval=-0.001824
# m=7654,l=1074,n1=2889,n2=2537,LogPval=-0.002718
# m=1804,l=516,n1=663,n2=628,LogPval=-0.250224
# m=13969,l=3470,n1=4981,n2=4594,LogPval=-0.172335
# m=21168,l=6258,n1=7548,n2=8311,LogPval=-0.234220
# m=724,l=223,n1=246,n2=256,LogPval=-0.380525
# m=1065,l=276,n1=468,n2=468,LogPval=-0.038995
# m=16009,l=4138,n1=5750,n2=5618,LogPval=-0.170750
# m=707,l=145,n1=261,n2=242,LogPval=-0.062290
# m=4199,l=893,n1=1440,n2=1165,LogPval=-0.152030
# m=14564,l=3610,n1=5350,n2=5922,LogPval=-0.087779
# m=12370,l=1592,n1=4464,n2=6319,LogPval=-0.027477
# m=1423,l=369,n1=610,n2=556,LogPval=-0.075430
# m=6463,l=1592,n1=2213,n2=2442,LogPval=-0.131259
# m=347,l=72,n1=140,n2=141,LogPval=-0.023215
# m=359,l=59,n1=125,n2=101,LogPval=-0.052980
# m=12490,l=2844,n1=4470,n2=4879,LogPval=-0.071044
# m=8103,l=1148,n1=2755,n2=4024,LogPval=-0.007092
# m=1399,l=432,n1=498,n2=527,LogPval=-0.307847
# m=716,l=170,n1=233,n2=191,LogPval=-0.272043
# m=17187,l=4175,n1=6293,n2=7747,LogPval=-0.053645
# m=7682,l=1590,n1=2950,n2=2549,LogPval=-0.060442
# m=336,l=86,n1=108,n2=116,LogPval=-0.223170
# m=730,l=244,n1=309,n2=262,LogPval=-0.335589
# m=1417,l=240,n1=649,n2=615,LogPval=-0.009334
# m=7506,l=1359,n1=2719,n2=3836,LogPval=-0.000670
# m=334,l=66,n1=104,n2=110,LogPval=-0.099619
# m=5730,l=1399,n1=2226,n2=2571,LogPval=-0.042500
# m=15167,l=3870,n1=5539,n2=6014,LogPval=-0.111724
# m=4562,l=850,n1=1698,n2=2277,LogPval=-0.000816
# m=2836,l=286,n1=973,n2=1448,LogPval=-0.051297
# m=356,l=76,n1=140,n2=106,LogPval=-0.099416
# m=351,l=84,n1=117,n2=103,LogPval=-0.224239
# m=2890,l=820,n1=1008,n2=864,LogPval=-0.370675
# m=10053,l=2867,n1=3570,n2=4053,LogPval=-0.191611
# m=1762,l=451,n1=650,n2=688,LogPval=-0.116452
# m=11073,l=1688,n1=3985,n2=5525,LogPval=-0.006780
# m=6278,l=1334,n1=2452,n2=3070,LogPval=-0.004505
# m=1080,l=101,n1=381,n2=570,LogPval=-0.080161
# m=8184,l=1887,n1=3027,n2=3152,LogPval=-0.070949
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=21104,l=5383,n1=7741,n2=7675,LogPval=-0.140033
# m=723,l=163,n1=228,n2=209,LogPval=-0.204150
# m=1808,l=362,n1=631,n2=469,LogPval=-0.137558
# m=1422,l=124,n1=646,n2=407,LogPval=-0.020638
# 22 m=6733,l=1199,n1=2407,n2=1775,LogPval=-0.077490
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5080,l=1102,n1=1644,n2=1423,LogPval=-0.178602
# m=7809,l=1680,n1=2821,n2=2324,LogPval=-0.119802
# m=3903,l=486,n1=1231,n2=2233,LogPval=-0.030425
# m=7455,l=1606,n1=2775,n2=2070,LogPval=-0.134938
# m=355,l=93,n1=159,n2=110,LogPval=-0.157712
# m=2117,l=499,n1=663,n2=710,LogPval=-0.179628
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2866,l=763,n1=953,n2=962,LogPval=-0.250156
# m=4675,l=1072,n1=1545,n2=1506,LogPval=-0.156114
# m=6456,l=1831,n1=2419,n2=2524,LogPval=-0.175196
# m=724,l=184,n1=236,n2=258,LogPval=-0.195725
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4684,l=1069,n1=1494,n2=1452,LogPval=-0.179349
# m=350,l=97,n1=161,n2=118,LogPval=-0.147447
# m=4584,l=972,n1=1490,n2=1284,LogPval=-0.163126
# ...
# m=3747,l=799,n1=1803,n2=1401,LogPval=-0.010481
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=8521,l=1078,n1=4196,n2=2807,LogPval=-0.012093
# m=6722,l=957,n1=3391,n2=2436,LogPval=-0.014817
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=8157,l=1640,n1=3986,n2=3069,LogPval=-0.003014
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=362,l=21,n1=200,n2=83,LogPval=-0.060937
# m=9170,l=2814,n1=4543,n2=4216,LogPval=-0.051704
# m=7283,l=2724,n1=3683,n2=3569,LogPval=-0.134102
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6278,l=1334,n1=3070,n2=2452,LogPval=-0.004505
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=8175,l=2294,n1=4023,n2=3527,LogPval=-0.039028
# m=6269,l=2695,n1=3221,n2=3340,LogPval=-0.211921
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=8462,l=3517,n1=4190,n2=4246,LogPval=-0.244668
# m=4422,l=664,n1=2139,n2=1423,LogPval=-0.001106
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1404,l=272,n1=581,n2=601,LogPval=-0.004544
# m=5606,l=2455,n1=2792,n2=3014,LogPval=-0.257203
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3513,l=1370,n1=1642,n2=1688,LogPval=-0.240649
# m=9041,l=1219,n1=4478,n2=3644,LogPval=-0.035863
# m=3094,l=1153,n1=1436,n2=1630,LogPval=-0.140828
# m=2489,l=1052,n1=1291,n2=1266,LogPval=-0.219794
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=7097,l=2069,n1=3573,n2=3227,LogPval=-0.032534
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=7739,l=3088,n1=3773,n2=3891,LogPval=-0.204438
# m=2462,l=1031,n1=1261,n2=1302,LogPval=-0.188937
# m=3137,l=1118,n1=1462,n2=1484,LogPval=-0.158112
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=7443,l=1178,n1=3648,n2=2474,LogPval=-0.000723
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=353,l=47,n1=185,n2=91,LogPval=-0.006653
# m=1415,l=159,n1=580,n2=401,LogPval=-0.002293
# 47 m=350,l=20,n1=188,n2=71,LogPval=-0.040064
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2875,l=273,n1=1475,n2=746,LogPval=-0.016456
# m=2177,l=432,n1=1139,n2=632,LogPval=-0.022974
# m=3613,l=1623,n1=1852,n2=1957,LogPval=-0.261965
# m=2912,l=1369,n1=1560,n2=1560,LogPval=-0.303294
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=336,l=127,n1=171,n2=158,LogPval=-0.170067
# m=679,l=296,n1=326,n2=358,LogPval=-0.305486
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3999,l=313,n1=2076,n2=1252,LogPval=-0.069081
# m=3263,l=293,n1=1691,n2=1167,LogPval=-0.083242
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3269,l=932,n1=1691,n2=1450,LogPval=-0.026465
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=689,l=71,n1=357,n2=174,LogPval=-0.012054
# m=4358,l=1316,n1=2253,n2=1884,LogPval=-0.052141
# m=2424,l=1070,n1=1291,n2=1264,LogPval=-0.235616
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1080,l=101,n1=570,n2=381,LogPval=-0.080161
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4361,l=1636,n1=2253,n2=1993,LogPval=-0.167050
# m=3547,l=1543,n1=1863,n2=1933,LogPval=-0.192140
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2880,l=1231,n1=1519,n2=1502,LogPval=-0.201240
# m=1769,l=167,n1=926,n2=555,LogPval=-0.047963
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2516,l=1120,n1=1330,n2=1338,LogPval=-0.236797
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=341,l=136,n1=169,n2=164,LogPval=-0.229246
# m=3184,l=347,n1=1644,n2=1274,LogPval=-0.082887
# m=2152,l=980,n1=1113,n2=1114,LogPval=-0.318848
# m=722,l=291,n1=388,n2=349,LogPval=-0.180173
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4367,l=1140,n1=2256,n2=1969,LogPval=-0.007262
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3607,l=1559,n1=1866,n2=1837,LogPval=-0.250558
# m=2462,l=1031,n1=1302,n2=1261,LogPval=-0.188937
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3266,l=344,n1=1715,n2=1116,LogPval=-0.050847
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=727,l=97,n1=365,n2=227,LogPval=-0.008855
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 48 m=7066,l=2014,n1=2659,n2=2839,LogPval=-0.165038
# m=726,l=210,n1=259,n2=285,LogPval=-0.216493
# m=6407,l=2012,n1=2414,n2=2617,LogPval=-0.242052
# m=8176,l=1985,n1=2942,n2=2686,LogPval=-0.154495
# m=6072,l=1653,n1=2368,n2=2809,LogPval=-0.073416
# m=8907,l=1915,n1=3376,n2=2436,LogPval=-0.133993
# m=339,l=85,n1=119,n2=105,LogPval=-0.216571
# m=1371,l=297,n1=338,n2=472,LogPval=-0.211648
# m=1022,l=252,n1=480,n2=421,LogPval=-0.026374
# m=4236,l=629,n1=1948,n2=1386,LogPval=-0.000895
# m=2092,l=478,n1=545,n2=730,LogPval=-0.222253
# m=5359,l=896,n1=2159,n2=1807,LogPval=-0.009772
# m=6472,l=1265,n1=2462,n2=2467,LogPval=-0.023342
# m=708,l=151,n1=162,n2=247,LogPval=-0.233807
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6047,l=1220,n1=2259,n2=2192,LogPval=-0.040988
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2077,l=418,n1=540,n2=588,LogPval=-0.200875
# m=5036,l=1904,n1=2215,n2=2474,LogPval=-0.233292
# m=6013,l=1490,n1=2376,n2=3019,LogPval=-0.021232
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=8184,l=1887,n1=3152,n2=3027,LogPval=-0.070949
# m=3508,l=756,n1=919,n2=1201,LogPval=-0.182352
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5293,l=1627,n1=1911,n2=2091,LogPval=-0.264310
# m=1411,l=450,n1=605,n2=607,LogPval=-0.159688
# m=1716,l=376,n1=441,n2=646,LogPval=-0.172756
# m=346,l=75,n1=86,n2=103,LogPval=-0.261522
# m=6408,l=1915,n1=2516,n2=2676,LogPval=-0.164070
# m=3524,l=489,n1=1597,n2=1162,LogPval=-0.002048
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=703,l=192,n1=219,n2=250,LogPval=-0.284879
# m=1428,l=246,n1=611,n2=619,LogPval=-0.003652
# m=3614,l=1406,n1=1667,n2=1849,LogPval=-0.204674
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4318,l=1455,n1=1885,n2=1953,LogPval=-0.169362
# m=6729,l=984,n1=2657,n2=2706,LogPval=-0.001955
# m=3163,l=1253,n1=1444,n2=1574,LogPval=-0.254044
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=346,l=71,n1=86,n2=96,LogPval=-0.242324
# m=2452,l=563,n1=633,n2=746,LogPval=-0.283484
# m=3190,l=956,n1=1216,n2=1391,LogPval=-0.161769
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3963,l=1473,n1=1793,n2=1890,LogPval=-0.212707
# m=3137,l=1118,n1=1484,n2=1462,LogPval=-0.158112
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6052,l=1275,n1=2308,n2=2048,LogPval=-0.063309
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1434,l=135,n1=609,n2=407,LogPval=-0.009232
# 49 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=362,l=107,n1=122,n2=162,LogPval=-0.210221
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=364,l=85,n1=122,n2=155,LogPval=-0.082750
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=339,l=86,n1=101,n2=142,LogPval=-0.177235
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=364,l=85,n1=121,n2=160,LogPval=-0.077110
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 50 m=19247,l=4322,n1=6741,n2=7107,LogPval=-0.085592
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16480,l=3617,n1=5481,n2=5479,LogPval=-0.119427
# m=21058,l=4161,n1=7500,n2=7136,LogPval=-0.056986
# m=14705,l=1611,n1=4900,n2=7613,LogPval=-0.036509
# m=22660,l=3803,n1=8265,n2=7387,LogPval=-0.023330
# m=357,l=97,n1=133,n2=110,LogPval=-0.265665
# m=2110,l=581,n1=640,n2=704,LogPval=-0.344082
# m=3427,l=367,n1=1258,n2=1280,LogPval=-0.009449
# m=6968,l=930,n1=2492,n2=2291,LogPval=-0.003020
# m=2881,l=703,n1=904,n2=969,LogPval=-0.202321
# m=16638,l=4088,n1=5434,n2=5326,LogPval=-0.210310
# m=21242,l=6172,n1=7651,n2=8366,LogPval=-0.210957
# m=725,l=188,n1=205,n2=258,LogPval=-0.289286
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=17615,l=4089,n1=5871,n2=6331,LogPval=-0.123684
# m=691,l=156,n1=317,n2=241,LogPval=-0.042534
# m=5649,l=1165,n1=1795,n2=1539,LogPval=-0.163018
# m=15115,l=3248,n1=5232,n2=6462,LogPval=-0.040749
# m=13552,l=1351,n1=4370,n2=7145,LogPval=-0.046450
# m=365,l=87,n1=144,n2=133,LogPval=-0.087588
# m=21104,l=5383,n1=7675,n2=7741,LogPval=-0.140033
# m=8254,l=2240,n1=2929,n2=2970,LogPval=-0.202331
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=14789,l=2869,n1=4728,n2=5839,LogPval=-0.044123
# m=9278,l=1375,n1=2964,n2=4610,LogPval=-0.001456
# m=2466,l=652,n1=771,n2=926,LogPval=-0.224366
# m=1082,l=247,n1=320,n2=272,LogPval=-0.305093
# m=19108,l=4102,n1=6373,n2=8631,LogPval=-0.037694
# m=7377,l=1552,n1=2792,n2=2447,LogPval=-0.069089
# m=325,l=69,n1=91,n2=108,LogPval=-0.162477
# m=730,l=231,n1=256,n2=262,LogPval=-0.385938
# m=1071,l=295,n1=355,n2=469,LogPval=-0.166462
# m=6850,l=1001,n1=2299,n2=3575,LogPval=-0.008148
# m=342,l=54,n1=101,n2=110,LogPval=-0.048690
# m=4318,l=847,n1=1438,n2=1942,LogPval=-0.020414
# m=16783,l=4223,n1=5598,n2=6581,LogPval=-0.140734
# m=4961,l=562,n1=1649,n2=2551,LogPval=-0.031066
# m=2880,l=278,n1=882,n2=1459,LogPval=-0.034075
# m=364,l=77,n1=143,n2=108,LogPval=-0.096732
# m=730,l=169,n1=223,n2=200,LogPval=-0.260966
# m=4342,l=1151,n1=1329,n2=1289,LogPval=-0.359180
# m=11940,l=2861,n1=3894,n2=4985,LogPval=-0.102189
# m=1737,l=506,n1=773,n2=685,LogPval=-0.119194
# m=11886,l=1369,n1=3816,n2=6033,LogPval=-0.021500
# m=7443,l=1178,n1=2474,n2=3648,LogPval=-0.000723
# m=3266,l=344,n1=1116,n2=1715,LogPval=-0.050847
# m=6052,l=1275,n1=2048,n2=2308,LogPval=-0.063309
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1074,l=223,n1=304,n2=303,LogPval=-0.193960
# m=1825,l=376,n1=673,n2=488,LogPval=-0.127825
# m=1086,l=271,n1=359,n2=323,LogPval=-0.254206
# 51 m=1046,l=185,n1=305,n2=239,LogPval=-0.159407
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1086,l=211,n1=313,n2=285,LogPval=-0.171286
# m=1086,l=142,n1=313,n2=273,LogPval=-0.043978
# m=1053,l=51,n1=306,n2=606,LogPval=-0.148840
# m=1081,l=197,n1=313,n2=277,LogPval=-0.143155
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=693,l=160,n1=202,n2=226,LogPval=-0.205890
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1086,l=297,n1=313,n2=331,LogPval=-0.429500
# m=1079,l=297,n1=313,n2=364,LogPval=-0.371618
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1085,l=234,n1=312,n2=324,LogPval=-0.193923
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1056,l=184,n1=306,n2=312,LogPval=-0.090126
# m=357,l=72,n1=100,n2=93,LogPval=-0.208829
# m=1086,l=57,n1=313,n2=641,LogPval=-0.146423
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=723,l=163,n1=209,n2=228,LogPval=-0.204150
# m=1080,l=198,n1=312,n2=330,LogPval=-0.102057
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1076,l=227,n1=312,n2=324,LogPval=-0.174079
# m=711,l=170,n1=203,n2=228,LogPval=-0.249744
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=720,l=134,n1=208,n2=173,LogPval=-0.174899
# m=1086,l=246,n1=313,n2=357,LogPval=-0.193001
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=331,l=65,n1=97,n2=116,LogPval=-0.097706
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1075,l=266,n1=309,n2=406,LogPval=-0.210252
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=363,l=72,n1=104,n2=97,LogPval=-0.182415
# m=1078,l=228,n1=313,n2=313,LogPval=-0.187386
# m=707,l=171,n1=205,n2=243,LogPval=-0.224274
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=714,l=44,n1=209,n2=368,LogPval=-0.083996
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1074,l=223,n1=303,n2=304,LogPval=-0.193960
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 52 m=711,l=116,n1=178,n2=197,LogPval=-0.112293
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2168,l=382,n1=573,n2=595,LogPval=-0.131569
# m=1795,l=286,n1=458,n2=625,LogPval=-0.057394
# m=1812,l=156,n1=486,n2=946,LogPval=-0.031810
# m=2187,l=212,n1=583,n2=1123,LogPval=-0.017938
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1036,l=114,n1=272,n2=507,LogPval=-0.006295
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1824,l=366,n1=466,n2=589,LogPval=-0.165202
# m=1823,l=363,n1=465,n2=662,LogPval=-0.129879
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1459,l=262,n1=388,n2=566,LogPval=-0.064261
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=338,l=69,n1=107,n2=93,LogPval=-0.160173
# m=1448,l=277,n1=418,n2=442,LogPval=-0.119663
# m=1740,l=152,n1=444,n2=896,LogPval=-0.022422
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1808,l=362,n1=469,n2=631,LogPval=-0.137558
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2178,l=295,n1=582,n2=1041,LogPval=-0.002104
# m=1427,l=193,n1=367,n2=793,LogPval=-0.002743
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1824,l=292,n1=466,n2=965,LogPval=-0.008330
# m=1083,l=232,n1=305,n2=350,LogPval=-0.170825
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1811,l=232,n1=463,n2=944,LogPval=-0.002018
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1413,l=270,n1=340,n2=543,LogPval=-0.115000
# m=1090,l=127,n1=288,n2=578,LogPval=-0.008399
# m=365,l=50,n1=86,n2=206,LogPval=-0.006510
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2188,l=451,n1=582,n2=834,LogPval=-0.120927
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1822,l=225,n1=470,n2=925,LogPval=-0.002313
# m=353,l=47,n1=91,n2=185,LogPval=-0.006653
# m=727,l=97,n1=227,n2=365,LogPval=-0.008855
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1825,l=376,n1=488,n2=673,LogPval=-0.127825
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 53 m=1432,l=69,n1=410,n2=712,LogPval=-0.094692
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1418,l=56,n1=390,n2=682,LogPval=-0.095991
# m=1054,l=53,n1=283,n2=505,LogPval=-0.069189
# m=1433,l=74,n1=402,n2=596,LogPval=-0.048305
# m=1431,l=167,n1=409,n2=374,LogPval=-0.023375
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=350,l=19,n1=102,n2=156,LogPval=-0.065947
# m=1042,l=284,n1=296,n2=344,LogPval=-0.387127
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1091,l=299,n1=326,n2=349,LogPval=-0.373703
# m=363,l=106,n1=107,n2=143,LogPval=-0.364886
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1447,l=342,n1=411,n2=560,LogPval=-0.172281
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1433,l=92,n1=409,n2=726,LogPval=-0.068071
# m=1404,l=82,n1=393,n2=695,LogPval=-0.069026
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1422,l=124,n1=407,n2=646,LogPval=-0.020638
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1447,l=117,n1=410,n2=632,LogPval=-0.021027
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1436,l=155,n1=409,n2=636,LogPval=-0.005442
# m=1394,l=249,n1=405,n2=454,LogPval=-0.077432
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1430,l=381,n1=406,n2=611,LogPval=-0.236935
# m=1090,l=85,n1=325,n2=582,LogPval=-0.067495
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1079,l=103,n1=298,n2=490,LogPval=-0.011851
# m=1424,l=394,n1=404,n2=612,LogPval=-0.279894
# m=1055,l=73,n1=313,n2=562,LogPval=-0.081127
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=714,l=91,n1=190,n2=346,LogPval=-0.003798
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1437,l=111,n1=406,n2=688,LogPval=-0.036365
# m=1415,l=159,n1=401,n2=580,LogPval=-0.002293
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1434,l=135,n1=407,n2=609,LogPval=-0.009232
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1086,l=271,n1=323,n2=359,LogPval=-0.254206
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan

# %%
print Pvals[:2,:2]
print Length[:2,:2]
print P_norm[:2,:2]
# Out:
# [[ 0.  0.]
#  [ 0.  0.]]
# [[   0.  693.]
#  [ 693.    0.]]
# [[-0.4        -0.19165559]
#  [-0.19165559 -0.4       ]]

# %%
A=P_norm.flatten();
B=A[~isnan(A)]
print A.shape,B.shape
hist(-B,bins=100);
xlabel('significance')
# Out:
# (2916,) (1692,)

# %%
def showmat(mat):
    fig,axes=plt.subplots(1,1,figsize=(10,10))
    axes.imshow(mat, cmap=plt.cm.gray)

# %%
showmat(P_norm)

# %% [markdown]
# ### Finding structure in the rependency matrix.
# The matrix above shows, for each pair of stations, the normalized log probability that the overlap in rain days is random.
#
# We see immediately the first 8 stations are highly correlatedwith each other.
#
# To find more correlations we use SVD (the term PCA is reserved for decomposition of the covariance matrix). As we shall see that the top 10 eigenvectors explain about 80% of the square magnitude of the matrix.

# %%
print 'A group of very correlated stations is:',All.keys()[:8]
# Out:
# A group of very correlated stations is: [u'USC00094238', u'USC00098351', u'USW00093845', u'USC00094255', u'USC00094429', u'USC00092839', u'USC00095858', u'USC00095811']

# %%
from sklearn.decomposition import PCA
P_norm0 = np.nan_to_num(P_norm)
n_comp=10
pca = PCA(n_components=n_comp, svd_solver='full')
pca.fit(P_norm0)     
#print(pca.explained_variance_)
Var_explained=pca.explained_variance_ratio_
plot(insert(cumsum(Var_explained),0,0))
grid()

# %%
# we will look only at the top 4 eigenvectors.
n_comp=4
pca = PCA(n_components=n_comp, svd_solver='full')
pca.fit(P_norm0)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=4, random_state=None,
#   svd_solver='full', tol=0.0, whiten=False)

# %%
fig,axes=plt.subplots(1,4,figsize=(20,5),sharey='row');
L=list(pca.components_.transpose())
for i in range(4):
    X=sorted(L,key=lambda x:x[i]) 
    axes[i].plot(X);

# %%
def re_order_matrix(M,order):
    M_reord=M[order,:]
    M_reord=M_reord[:,order]
    return M_reord

# %%
fig,axes=plt.subplots(2,2,figsize=(15,15),sharex='col',sharey='row');
i=0
for r in range(2):
    for c in range(2):
        order=np.argsort(pca.components_[i,:])
        P_norm_reord=re_order_matrix(P_norm0,order)
        axes[r,c].matshow(P_norm_reord)
        i+=1

# %% [markdown]
# ### Explanation and possibe extensions
# When we reorder the rows and columns of the matrix using one of the eigenvectors, the grouping of the
# stations becomes more evident. For example, consider the upper left corner of the scond matrix (The upper left one). The stations at positions 0-22 are clearly strongly correlated with each other. Even though there are some stations, in positions 15-18 or so, which are more related to each other than to the rest of this block.
#
# This type of organization is called **Block Diagonal** and it typically reveals important structure such as grouping or clustering.
#
# You might want to extract the sets of stations that form blocks for your region, and then plot them on the map to see their spatial relationship.

# %%
from pickle import dump
with open(data_dir+'/'+ meas+'_residuals_PCA.pickle','wb') as file:
    dump({'stations':All.keys(),
          'eigen-vecs':pca.components_},
        file)
