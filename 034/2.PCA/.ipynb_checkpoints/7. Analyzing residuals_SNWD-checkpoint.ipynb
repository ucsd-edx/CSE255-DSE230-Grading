# %%
#setup
data_dir='../../Data/Weather'
#file_index='BBBSBBBB'
file_index='BSBSSSBB'
meas='TOBS'

# %% [markdown]
# # Reconstruction using top eigen-vectors
# For measurement = {{meas}}

# %% [markdown]
# ## Load the required libraries

# %%
# Enable automiatic reload of libraries
#%load_ext autoreload
#%autoreload 2 # means that all modules are reloaded before every command

# %%
# %pylab inline
import numpy as np

import findspark
findspark.init()

import sys
sys.path.append('./lib')

from numpy_pack import packArray,unpackArray

from Eigen_decomp import Eigen_decomp
from YearPlotter import YearPlotter
from recon_plot import recon_plot

from import_modules import import_modules,modules
import_modules(modules)

from ipywidgets import interactive,widgets
# Out:
# Populating the interactive namespace from numpy and matplotlib
#     pandas as    pd 	version=0.19.2 	required version>=0.19.2
#      numpy as    np 	version=1.11.3 	required version>=1.12.0 ******* Update Version ******
#    sklearn as    sk 	version=0.18.1 	required version>=0.18.1
#     urllib as urllib 	version=1.17 	required version>=1.17
#    pyspark as pyspark 	version=2.1.0+hadoop2.7 	required version>=2.1.0
# ipywidgets as ipywidgets 	version=6.0.0 	required version>=6.0.0

# %%
from pyspark import SparkContext
#sc.stop()

sc = SparkContext(master="local[3]",pyFiles=['lib/numpy_pack.py','lib/spark_PCA.py','lib/computeStats.py','lib/recon_plot.py','lib/Eigen_decomp.py'])

from pyspark import SparkContext
from pyspark.sql import *
sqlContext = SQLContext(sc)

# %% [markdown]
# ## Read Statistics File

# %%
from pickle import load

#read statistics
filename=data_dir+'/STAT_%s.pickle'%file_index
STAT,STAT_Descriptions = load(open(filename,'rb'))
measurements=STAT.keys()
print 'keys from STAT=',measurements
# Out:
# keys from STAT= ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'SNWD', 'PRCP']

# %% [markdown]
# ## Read data file into a spark DataFrame
# We focus on the snow-depth records, because the eigen-vectors for them make sense.

# %%
#read data
filename=data_dir+'/decon_%s_%s.parquet'%(file_index,meas)
df_in=sqlContext.read.parquet(filename)
#filter in 
df=df_in.filter(df_in.measurement==meas)
df.show(5)
# Out:
# +------------------+-------------------+-------------------+---------+--------+--------+---------+-----------+-------------------+-------------------+-------------------+-------------------+-----------+-----------+------+--------------------+------+
# |           coeff_1|            coeff_2|            coeff_3|elevation|   label|latitude|longitude|measurement|              res_1|              res_2|              res_3|           res_mean|    station|  total_var|undefs|              vector|  year|
# +------------------+-------------------+-------------------+---------+--------+--------+---------+-----------+-------------------+-------------------+-------------------+-------------------+-----------+-----------+------+--------------------+------+
# |1040.1244553796432|-191.20163471726025| -140.2129681165104|     70.1|BSBSSSBB| 32.5575| -82.9036|       TOBS| 0.4199179798796949|0.39986009272794115| 0.3886385581013815|0.19446504616202012|USC00092839|  8795496.0|     6|[20 50 30 55 50 5...|2004.0|
# | -863.802870343999| 359.57595160625505|  169.0912751832646|     59.4|BSBSSSBB| 30.1853| -82.5942|       TOBS|0.48118853450681065|0.41039884843880414|0.38871317958301516|0.07633707603215133|USC00084731|2.0622752E7|     3|[10 5A B8 59 40 5...|1950.0|
# |1154.0100770712713| -81.40820316940207|-125.37899719359444|     44.2|BSBSSSBB| 31.2514| -82.3128|       TOBS|0.39893908110270154|0.39594794877318085| 0.3888530063982292|0.26827982956357094|USC00099186|  8258719.0|     0|[50 57 58 58 E0 D...|1979.0|
# |   907.85765144536| -318.6837396947819| 222.26572720841537|    121.9|BSBSSSBB| 32.2003| -83.2058|       TOBS| 0.4834681244766722|0.41982061407464294| 0.3888602105450109|0.16371225524677074|USC00092966|  9746691.0|     0|[E0 54 80 51 A0 5...|1968.0|
# |-976.7609170907085|-112.36771078180286| 167.33524342877266|     44.8|BSBSSSBB| 30.5228| -82.9447|       TOBS|  0.414243273634738| 0.4064910944409528| 0.3892995230079739|0.07391207323663573|USC00084394|2.2036564E7|     0|[A0 56 A0 56 28 5...|1963.0|
# +------------------+-------------------+-------------------+---------+--------+--------+---------+-----------+-------------------+-------------------+-------------------+-------------------+-----------+-----------+------+--------------------+------+
# only showing top 5 rows

# %% [markdown]
# ### Plot Mean and Eigenvecs

# %%
m=meas
fig,axes=plt.subplots(2,1, sharex='col', sharey='row',figsize=(10,6));
k=3
EigVec=np.matrix(STAT[m]['eigvec'][:,:k])
Mean=STAT[m]['Mean']
YearPlotter().plot(Mean,fig,axes[0],label='Mean',title=m+' Mean')
YearPlotter().plot(EigVec,fig,axes[1],title=m+' Eigs',labels=['eig'+str(i+1) for i in range(k)])

# %% [markdown]
# ### plot the percent of residual variance on average

# %%
#  x=0 in the graphs below correspond to the fraction of the variance explained by the mean alone
#  x=1,2,3,... are the residuals for eig1, eig1+eig2, eig1+eig2+eig3 ...
fig,ax=plt.subplots(1,1);
eigvals=STAT[m]['eigval']; eigvals/=sum(eigvals); cumvar=cumsum(eigvals); cumvar=100*np.insert(cumvar,0,0)
ax.plot(cumvar[:10]); 
ax.grid(); 
ax.set_ylabel('Percent of variance explained')
ax.set_xlabel('number of eigenvectors')
ax.set_title('Percent of variance explained');

# %% [markdown]
# ### How well-explained are the vectors in this collection?
#
# To answer this question we extract all of the values of `res_3` which is the residual variance after the Mean and the
# first two Eigen-vectors have been subtracted out. We rely here on the fact that `df3` is already sorted according to `res_3`

# %%
# A function for plotting the CDF of a given feature
def plot_CDF(df,feat):
    rows=df.select(feat).sort(feat).collect()
    vals=[r[feat] for r in rows]
    P=np.arange(0,1,1./(len(vals)))
    while len(vals)< len(P):
        vals=[vals[0]]+vals
    plot(vals,P)
    title('cumulative distribution of '+feat)
    ylabel('fraction of instances')
    xlabel(feat)
    grid()

# %%
plot_CDF(df,'res_3')

# %%
rows=df.rdd.map(lambda row:(row.station,row.year,unpackArray(row['vector'],np.float16))).collect()
rows[0][:2]
# Out:
# (u'USC00092839', 2004.0)

# %%
days=set([r[1] for r in rows])
miny=min(days)
maxy=max(days)
record_len=int((maxy-miny+1)*365)
record_len
# Out:
# 40880

# %%
## combine the measurements for each station into a single long array with an entry for each day of each day
All={}  # a dictionary with a numpy array for each day of each day
i=0
for station,day,vector in rows:
    i+=1; 
    # if i%1000==0: print i,len(All)
    if not station in All:
        a=np.zeros(record_len)
        a.fill(np.nan)
        All[station]=a
    loc = int((day-miny)*365)
    All[station][loc:loc+365]=vector

# %%
from datetime import date
d=datetime.date(int(miny), month=1, day=1)
start=d.toordinal()
dates=[date.fromordinal(i) for i in range(start,start+record_len)]

# %%
for station in All:
    print station, np.count_nonzero(~np.isnan(All[station]))
# Out:
# USC00094238 1424
# USC00098351 3393
# USW00093845 1782
# USC00093312 3657
# USC00094255 697
# USC00094429 19114
# USC00092839 33997
# USC00095811 10756
# USC00092844 726
# USC00090670 2885
# USC00096255 1062
# USC00098476 15526
# USC00095696 1442
# USC00093325 6670
# USC00094110 4286
# USC00095874 21388
# USC00097777 18256
# USC00095858 342
# USC00096237 9461
# USC00099020 687
# USC00092865 2518
# USC00089640 357
# USC00094862 2798
# USC00084393 3525
# USC00084394 22110
# USC00093386 22594
# USC00090131 10433
# USC00092966 23709
# USC00095401 1301
# USC00097171 4358
# USC00094170 34705
# USC00090010 2450
# USC00099186 29869
# USC00093465 20743
# USC00094971 1094
# USC00094594 13125
# USC00094204 10041
# USC00095386 12604
# USC00096244 3578
# USC00084731 33519
# USC00098974 11436
# USC00090090 6716
# USC00095863 7510
# USC00085275 31270
# USC00098972 5699
# USC00099451 1421
# USC00092783 21673
# USC00095492 1057
# USC00098496 11820
# USC00085099 22732
# USC00096650 1064
# USW00013861 3526
# USC00083470 26527
# USC00097720 323
# USC00095314 25224

# %%
Stations=sorted(All.keys())
A=[]
for station in Stations:
    A.append(All[station])

day_station_table=np.hstack([A])
print shape(day_station_table)
# Out:
# (55, 40880)

# %%
def RMS(Mat):
    return np.sqrt(np.nanmean(Mat**2))

mean_by_day=np.nanmean(day_station_table,axis=0)
mean_by_station=np.nanmean(day_station_table,axis=1)
tbl_minus_day = day_station_table-mean_by_day
tbl_minus_station = (day_station_table.transpose()-mean_by_station).transpose()

print 'total RMS                   = ',RMS(day_station_table)
print 'RMS removing mean-by-station= ',RMS(tbl_minus_station)
print 'RMS removing mean-by-day   = ',RMS(tbl_minus_day)
# Out:
# total RMS                   =  203.097925058
# RMS removing mean-by-station=  81.5607352788
# RMS removing mean-by-day   =  45.8154406543

# %%
RT=day_station_table
F=RT.flatten()
NN=F[~np.isnan(F)]

NN.sort()
P=np.arange(0.,1.,1./len(NN))
plot(NN,P)
grid()
title('CDF of daily rainfall')
xlabel('daily rainfall')
ylabel('cumulative probability')

# %% [markdown]
# ### Conclusions
# It is likely to be hard to find correlations between the **amount** of rain on the same day in different stations. Because amounts of rain vary a lot between even close locations. It is more reasonable to try to compare whether or not it rained on the same day in different stations. As we see from the graph above, in our region it rains in about one third of the days.
#
# ### measuring statistical significance
# We want to find a statistical test for rejecting the null hypothesis that says that the rainfall in the two locations is independent.
#
# Using the inner product is too noisy, because you multiply the rainfall on the same day in two locations and that product can be very large - leading to a large variance and poor ability to discriminate.
#
# An alternative is to ignore the amount of rain, and just ask whether it rained in both locations. We can then compute the probability associated with the number of overlaps under the null hypothesis.

# %% [markdown]
# Fix two stations. We restrict our attention to the days for which we have measurements for both stations, and define the following notation:
# * $m$ : the total number of days (for which we have measurements for both stations).
# * $n_1$ : the number of days that it rained on station 1
# * $n_2$ : the number of days that it rained on station 2
# * $l$ : the number of days that it rained on both stations.
#
# We want to calculate the probability that the number of overlap days is $l$ given $m,n_1,n_2$.
#
# The answer is:
# $$
# P = {m \choose l,n_1-l,n_2-l,m-n_1-n_2+l} /{m \choose n_1}{m \choose n_2}
# $$
#
# Where
# $$
# {m \choose l,n_1-l,n_2-l,m-n_1-n_2+l} = \frac{m!}{l! (n_1-l)! (n_2-l)! (m-n_1-n_2+l)!}
# $$
#
# We use the fact that $\Gamma(n+1) = n!$ and denote $G(n) \doteq \log \Gamma(n+1)$
# $$
# \log P = \left[G(m) - G(l) -G(n_1-l) -G(n_2-l) -G(m-n_1-n_2+l) \right] -
# \left[G(m)-G(n_1)-G(m-n_1)\right] - \left[G(m)-G(n_2)-G(m-n_2)\right]
# $$
# Which slightly simplifies to
# $$
# \log P = -G(l) -G(n_1-l) -G(n_2-l) -G(m-n_1-n_2+l) - G(m)+G(n_1)+G(m-n_1) +G(n_2)+G(m-n_2)
# $$
#
# The log probability scales with $m$ the length of the overlap. So to get a per-day significance we consider $
# \frac{1}{m} \log P $

# %%
from scipy.special import gammaln,factorial
#for i in range(10):
#    print exp(gammaln(i+1))-factorial(i)
def G(n):
    return gammaln(n+1)
def LogProb(m,l,n1,n2):
    logP=-G(l)-G(n1-l)-G(n2-l)-G(m-n1-n2+l)-G(m)+G(n1)+G(m-n1)+G(n2)+G(m-n2)
    return logP/m
exp(LogProb(1000,0,500,500))
# Out:
# 0.501843349103545

# %%
#USC00193270 21482
#USC00193702 28237
#USC00094238 1424
#USC00098351 3393
X=copy(All['USC00092783'])
Y=copy(All['USC00098351'])
print sum(~np.isnan(X))
print sum(~np.isnan(Y))
X[np.isnan(Y)]=np.nan
Y[np.isnan(X)]=np.nan
print sum(~np.isnan(X))
print sum(~np.isnan(Y))
# Out:
# 21673
# 3393
# 670
# 670

# %%
def computeLogProb(X,Y):
    X[np.isnan(Y)]=np.nan
    Y[np.isnan(X)]=np.nan
    G=~isnan(X)
    m=sum(G)
    XG=X[G]>0
    YG=Y[G]>0
    n1=sum(XG)
    n2=sum(YG)
    l=sum(XG*YG)
    logprob=LogProb(m,l,n1,n2)
    print 'm=%d,l=%d,n1=%d,n2=%d,LogPval=%f'%(m,l,n1,n2,logprob)
    return logprob,m
print computeLogProb(X,Y)
# Out:
# m=670,l=657,n1=658,n2=669,LogPval=-0.000027
# (-2.6974300089253786e-05, 670)

# %% [markdown]
# ### calculate the normalized log probability for each pair of stations.

# %%
L=len(Stations)
Pvals=np.zeros([L,L])
Length=np.zeros([L,L])
P_norm=np.zeros([L,L])
for i in range(L):
    print i,
    for j in range(L):
        if i==j: 
            P_norm[i,j]=-0.4
            continue
        X=copy(All[Stations[i]])
        Y=copy(All[Stations[j]])
        P_norm[i,j],Length[i,j]=computeLogProb(X,Y)
        if Length[i,j]<200:
            P_norm[i,j]=np.nan
# Out:
# 0 m=693,l=693,n1=693,n2=693,LogPval=0.000000
# m=16857,l=16269,n1=16480,n2=16332,LogPval=-0.061764
# m=22906,l=22422,n1=22475,n2=22762,LogPval=-0.012239
# m=16081,l=15734,n1=15741,n2=16071,LogPval=-0.000431
# m=23777,l=23296,n1=23399,n2=23550,LogPval=-0.016139
# m=355,l=323,n1=325,n2=333,LogPval=-0.146371
# m=2351,l=2142,n1=2262,n2=2151,LogPval=-0.079770
# m=5562,l=5409,n1=5535,n2=5431,LogPval=-0.001443
# m=8199,l=7764,n1=8175,n2=7784,LogPval=-0.000452
# m=2790,l=2624,n1=2664,n2=2676,LogPval=-0.066392
# m=16061,l=15040,n1=15704,n2=15174,LogPval=-0.027867
# m=24215,l=23090,n1=23835,n2=23211,LogPval=-0.025967
# m=708,l=651,n1=684,n2=654,LogPval=-0.071725
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=18443,l=17578,n1=18066,n2=17708,LogPval=-0.032808
# m=3287,l=3198,n1=3237,n2=3230,LogPval=-0.013937
# m=6114,l=5817,n1=5865,n2=5929,LogPval=-0.062449
# m=15227,l=14849,n1=14973,n2=14946,LogPval=-0.033889
# m=16986,l=16610,n1=16614,n2=16980,LogPval=-0.000296
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=24622,l=23625,n1=24206,n2=23748,LogPval=-0.031902
# m=8366,l=8021,n1=8077,n2=8193,LogPval=-0.037704
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=13826,l=13166,n1=13480,n2=13218,LogPval=-0.062140
# m=8796,l=8467,n1=8555,n2=8637,LogPval=-0.018396
# m=2708,l=2463,n1=2586,n2=2490,LogPval=-0.074324
# m=1051,l=995,n1=1008,n2=1011,LogPval=-0.070076
# m=18589,l=17980,n1=18218,n2=18145,LogPval=-0.030981
# m=8448,l=7986,n1=8372,n2=7997,LogPval=-0.019674
# m=1271,l=1189,n1=1214,n2=1208,LogPval=-0.074231
# m=1038,l=944,n1=985,n2=945,LogPval=-0.133172
# m=1426,l=1259,n1=1424,n2=1259,LogPval=-0.003012
# m=7597,l=7505,n1=7520,n2=7578,LogPval=-0.001359
# m=329,l=321,n1=325,n2=322,LogPval=-0.032395
# m=5587,l=5408,n1=5477,n2=5452,LogPval=-0.034681
# m=16580,l=14657,n1=16218,n2=14696,LogPval=-0.036885
# m=5298,l=5254,n1=5261,n2=5290,LogPval=-0.000554
# m=3475,l=3352,n1=3363,n2=3452,LogPval=-0.008062
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1020,l=968,n1=979,n2=992,LogPval=-0.040951
# m=4211,l=3937,n1=4026,n2=3970,LogPval=-0.097711
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=12997,l=12207,n1=12691,n2=12271,LogPval=-0.045386
# m=2949,l=2906,n1=2917,n2=2938,LogPval=-0.000041
# m=10823,l=10605,n1=10621,n2=10801,LogPval=-0.001204
# m=9036,l=8841,n1=8900,n2=8962,LogPval=-0.003253
# m=2612,l=2556,n1=2560,n2=2608,LogPval=-0.000031
# m=8000,l=7854,n1=7876,n2=7916,LogPval=-0.028872
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=23738,l=22699,n1=23309,n2=22805,LogPval=-0.036768
# m=1371,l=1249,n1=1313,n2=1276,LogPval=-0.037536
# m=1332,l=1291,n1=1300,n2=1315,LogPval=-0.015636
# m=1766,l=1663,n1=1764,n2=1663,LogPval=-0.003223
# 1 m=693,l=693,n1=693,n2=693,LogPval=0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2071,l=2071,n1=2071,n2=2071,LogPval=0.000000
# m=362,l=362,n1=362,n2=362,LogPval=0.000000
# m=721,l=721,n1=721,n2=721,LogPval=0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1406,l=1353,n1=1406,n2=1353,LogPval=-0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1383,l=1371,n1=1381,n2=1372,LogPval=-0.002999
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1324,l=1302,n1=1324,n2=1302,LogPval=0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2376,l=2340,n1=2374,n2=2341,LogPval=-0.001490
# m=1723,l=1646,n1=1721,n2=1646,LogPval=-0.003615
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=660,l=660,n1=660,n2=660,LogPval=0.000000
# m=327,l=326,n1=327,n2=326,LogPval=0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1053,l=1034,n1=1051,n2=1035,LogPval=-0.003221
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=296,l=294,n1=296,n2=294,LogPval=0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=726,l=726,n1=726,n2=726,LogPval=0.000000
# m=322,l=315,n1=321,n2=315,LogPval=-0.011890
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 2 m=16857,l=16269,n1=16332,n2=16480,LogPval=-0.061764
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=18647,l=17959,n1=17980,n2=18500,LogPval=-0.020087
# m=20509,l=19803,n1=19812,n2=20491,LogPval=-0.000975
# m=18329,l=17679,n1=17737,n2=18120,LogPval=-0.022887
# m=357,l=316,n1=316,n2=335,LogPval=-0.151136
# m=2449,l=2221,n1=2319,n2=2242,LogPval=-0.101261
# m=5854,l=5611,n1=5725,n2=5713,LogPval=-0.007091
# m=8099,l=7675,n1=8037,n2=7731,LogPval=-0.000398
# m=2884,l=2701,n1=2723,n2=2769,LogPval=-0.085850
# m=19170,l=17675,n1=18439,n2=17896,LogPval=-0.055279
# m=19472,l=17972,n1=18864,n2=18062,LogPval=-0.062391
# m=726,l=669,n1=693,n2=672,LogPval=-0.108794
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=21082,l=19854,n1=20332,n2=20229,LogPval=-0.037465
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6655,l=6282,n1=6303,n2=6456,LogPval=-0.076902
# m=18900,l=18209,n1=18316,n2=18542,LogPval=-0.038168
# m=19295,l=18643,n1=18647,n2=19281,LogPval=-0.001411
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=19671,l=18374,n1=19042,n2=18484,LogPval=-0.066113
# m=5080,l=4759,n1=4790,n2=4909,LogPval=-0.071310
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=18777,l=17791,n1=18034,n2=18138,LogPval=-0.052716
# m=12800,l=12183,n1=12271,n2=12606,LogPval=-0.017251
# m=2797,l=2538,n1=2639,n2=2575,LogPval=-0.094040
# m=1094,l=1024,n1=1028,n2=1052,LogPval=-0.098810
# m=20769,l=19842,n1=20063,n2=20283,LogPval=-0.030090
# m=11301,l=10564,n1=11037,n2=10609,LogPval=-0.047124
# m=1301,l=1203,n1=1217,n2=1236,LogPval=-0.097685
# m=1057,l=957,n1=984,n2=963,LogPval=-0.164529
# m=1407,l=1253,n1=1404,n2=1253,LogPval=-0.004729
# m=10555,l=10261,n1=10281,n2=10522,LogPval=-0.002661
# m=339,l=330,n1=334,n2=332,LogPval=-0.029037
# m=7375,l=7152,n1=7211,n2=7229,LogPval=-0.035776
# m=20213,l=17783,n1=19540,n2=17853,LogPval=-0.057158
# m=9239,l=8987,n1=8998,n2=9223,LogPval=-0.001101
# m=3446,l=3283,n1=3291,n2=3421,LogPval=-0.011617
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1064,l=1007,n1=1012,n2=1036,LogPval=-0.059782
# m=4357,l=4060,n1=4111,n2=4109,LogPval=-0.127660
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=17872,l=16677,n1=17207,n2=16914,LogPval=-0.052533
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=15174,l=14642,n1=14664,n2=15134,LogPval=-0.002415
# m=11135,l=10756,n1=10817,n2=11045,LogPval=-0.004657
# m=5526,l=5239,n1=5248,n2=5505,LogPval=-0.004336
# m=8031,l=7851,n1=7867,n2=7945,LogPval=-0.031200
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=20087,l=18633,n1=19391,n2=18707,LogPval=-0.079341
# m=1421,l=1279,n1=1337,n2=1322,LogPval=-0.045378
# m=3500,l=3320,n1=3350,n2=3426,LogPval=-0.028197
# m=1752,l=1652,n1=1749,n2=1653,LogPval=-0.002691
# 3 m=22906,l=22422,n1=22762,n2=22475,LogPval=-0.012239
# m=2071,l=2071,n1=2071,n2=2071,LogPval=0.000000
# m=18647,l=17959,n1=18500,n2=17980,LogPval=-0.020087
# m=19925,l=19769,n1=19783,n2=19903,LogPval=-0.001364
# m=26369,l=26016,n1=26185,n2=26111,LogPval=-0.011565
# m=344,l=321,n1=334,n2=322,LogPval=-0.070576
# m=2438,l=2231,n1=2421,n2=2231,LogPval=-0.017451
# m=5316,l=5163,n1=5291,n2=5175,LogPval=-0.006127
# m=7866,l=7536,n1=7839,n2=7552,LogPval=-0.002523
# m=2845,l=2724,n1=2810,n2=2730,LogPval=-0.029051
# m=18431,l=17273,n1=18274,n2=17304,LogPval=-0.015474
# m=29078,l=27547,n1=28885,n2=27588,LogPval=-0.012518
# m=711,l=654,n1=697,n2=657,LogPval=-0.033280
# m=1428,l=1423,n1=1428,n2=1423,LogPval=-0.000000
# m=20123,l=19277,n1=19970,n2=19324,LogPval=-0.012868
# m=3164,l=3088,n1=3150,n2=3095,LogPval=-0.006032
# m=6211,l=6018,n1=6152,n2=6028,LogPval=-0.024949
# m=18590,l=18137,n1=18476,n2=18190,LogPval=-0.008808
# m=17060,l=16934,n1=16936,n2=17051,LogPval=-0.001821
# m=2441,l=2408,n1=2441,n2=2408,LogPval=0.000000
# m=29113,l=27746,n1=28921,n2=27790,LogPval=-0.012601
# m=9088,l=8889,n1=9019,n2=8911,LogPval=-0.016629
# m=1028,l=1028,n1=1028,n2=1028,LogPval=0.000000
# m=662,l=657,n1=662,n2=657,LogPval=-0.000000
# m=16327,l=15642,n1=16180,n2=15708,LogPval=-0.010667
# m=11495,l=11245,n1=11397,n2=11310,LogPval=-0.006958
# m=2759,l=2530,n1=2727,n2=2537,LogPval=-0.018046
# m=1093,l=1050,n1=1085,n2=1051,LogPval=-0.019465
# m=20512,l=19941,n1=20367,n2=20016,LogPval=-0.008260
# m=10369,l=9687,n1=10300,n2=9694,LogPval=-0.014631
# m=1256,l=1191,n1=1245,n2=1191,LogPval=-0.026613
# m=1028,l=936,n1=1004,n2=938,LogPval=-0.049295
# m=1060,l=948,n1=1057,n2=948,LogPval=-0.006384
# m=8432,l=8359,n1=8375,n2=8405,LogPval=-0.004707
# m=341,l=334,n1=341,n2=334,LogPval=0.000000
# m=6652,l=6480,n1=6593,n2=6507,LogPval=-0.013244
# m=17854,l=15787,n1=17714,n2=15795,LogPval=-0.014625
# m=7548,l=7471,n1=7481,n2=7529,LogPval=-0.004202
# m=3149,l=3110,n1=3126,n2=3128,LogPval=-0.004837
# m=1024,l=1018,n1=1024,n2=1018,LogPval=-0.000000
# m=1063,l=1034,n1=1057,n2=1035,LogPval=-0.015787
# m=4316,l=4066,n1=4269,n2=4069,LogPval=-0.027845
# m=322,l=319,n1=322,n2=319,LogPval=-0.000000
# m=15875,l=14918,n1=15745,n2=14960,LogPval=-0.011229
# m=2883,l=2853,n1=2862,n2=2874,LogPval=-0.000023
# m=12750,l=12627,n1=12648,n2=12717,LogPval=-0.003064
# m=10223,l=10086,n1=10155,n2=10134,LogPval=-0.005727
# m=4146,l=4099,n1=4106,n2=4133,LogPval=-0.005028
# m=9793,l=9632,n1=9709,n2=9664,LogPval=-0.018775
# m=330,l=312,n1=330,n2=312,LogPval=-0.000000
# m=25673,l=24381,n1=25503,n2=24422,LogPval=-0.011953
# m=1421,l=1320,n1=1409,n2=1322,LogPval=-0.016199
# m=3457,l=3377,n1=3434,n2=3384,LogPval=-0.014802
# m=1388,l=1307,n1=1385,n2=1307,LogPval=-0.006166
# 4 m=16081,l=15734,n1=16071,n2=15741,LogPval=-0.000431
# m=362,l=362,n1=362,n2=362,LogPval=0.000000
# m=20509,l=19803,n1=20491,n2=19812,LogPval=-0.000975
# m=19925,l=19769,n1=19903,n2=19783,LogPval=-0.001364
# m=17862,l=17668,n1=17845,n2=17676,LogPval=-0.001750
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2356,l=2157,n1=2355,n2=2158,LogPval=-0.000037
# m=5626,l=5484,n1=5616,n2=5485,LogPval=-0.005537
# m=7564,l=7233,n1=7555,n2=7233,LogPval=-0.003737
# m=2370,l=2289,n1=2369,n2=2290,LogPval=-0.000014
# m=18059,l=16844,n1=18044,n2=16847,LogPval=-0.001470
# m=20111,l=18635,n1=20094,n2=18644,LogPval=-0.000574
# m=672,l=625,n1=672,n2=625,LogPval=-0.000000
# m=361,l=353,n1=354,n2=360,LogPval=-0.000054
# m=19979,l=19170,n1=19960,n2=19176,LogPval=-0.001597
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6052,l=5884,n1=6047,n2=5887,LogPval=-0.000824
# m=18298,l=17938,n1=18282,n2=17945,LogPval=-0.001444
# m=18256,l=18231,n1=18238,n2=18240,LogPval=-0.003033
# m=331,l=314,n1=324,n2=320,LogPval=-0.004968
# m=19243,l=18110,n1=19229,n2=18117,LogPval=-0.000632
# m=4878,l=4738,n1=4877,n2=4739,LogPval=-0.000006
# m=362,l=355,n1=355,n2=362,LogPval=0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=18260,l=17693,n1=18244,n2=17699,LogPval=-0.001429
# m=12818,l=12625,n1=12809,n2=12627,LogPval=-0.002028
# m=2291,l=2123,n1=2290,n2=2124,LogPval=-0.000033
# m=1066,l=1027,n1=1066,n2=1027,LogPval=-0.000000
# m=19647,l=19215,n1=19629,n2=19222,LogPval=-0.001633
# m=10631,l=9936,n1=10615,n2=9943,LogPval=-0.001487
# m=1275,l=1212,n1=1274,n2=1213,LogPval=-0.000039
# m=639,l=607,n1=639,n2=607,LogPval=0.000000
# m=1427,l=1263,n1=1423,n2=1263,LogPval=-0.006087
# m=10527,l=10486,n1=10513,n2=10492,LogPval=-0.003659
# m=341,l=334,n1=341,n2=334,LogPval=0.000000
# m=6960,l=6853,n1=6953,n2=6856,LogPval=-0.001920
# m=19091,l=16833,n1=19075,n2=16835,LogPval=-0.001330
# m=9297,l=9272,n1=9287,n2=9276,LogPval=-0.003442
# m=3445,l=3418,n1=3442,n2=3421,LogPval=-0.000006
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1054,l=1026,n1=1054,n2=1026,LogPval=0.000000
# m=3801,l=3608,n1=3800,n2=3609,LogPval=-0.000014
# m=320,l=313,n1=315,n2=317,LogPval=-0.009642
# m=17447,l=16551,n1=17433,n2=16555,LogPval=-0.001323
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=15185,l=15142,n1=15169,n2=15145,LogPval=-0.004812
# m=11277,l=11178,n1=11269,n2=11178,LogPval=-0.003385
# m=5576,l=5555,n1=5568,n2=5557,LogPval=-0.005674
# m=8340,l=8277,n1=8333,n2=8280,LogPval=-0.001955
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=18934,l=17613,n1=18915,n2=17619,LogPval=-0.001318
# m=1383,l=1287,n1=1383,n2=1287,LogPval=-0.000000
# m=3446,l=3372,n1=3443,n2=3372,LogPval=-0.003355
# m=1767,l=1664,n1=1763,n2=1664,LogPval=-0.006466
# 5 m=23777,l=23296,n1=23550,n2=23399,LogPval=-0.016139
# m=721,l=721,n1=721,n2=721,LogPval=0.000000
# m=18329,l=17679,n1=18120,n2=17737,LogPval=-0.022887
# m=26369,l=26016,n1=26111,n2=26185,LogPval=-0.011565
# m=17862,l=17668,n1=17676,n2=17845,LogPval=-0.001750
# m=350,l=327,n1=335,n2=328,LogPval=-0.117706
# m=1384,l=1256,n1=1335,n2=1267,LogPval=-0.055433
# m=6004,l=5866,n1=5982,n2=5878,LogPval=-0.004306
# m=8711,l=8279,n1=8678,n2=8286,LogPval=-0.007385
# m=2089,l=1986,n1=2033,n2=2009,LogPval=-0.038289
# m=18159,l=16954,n1=17943,n2=17038,LogPval=-0.013132
# m=28472,l=27108,n1=28233,n2=27177,LogPval=-0.013997
# m=712,l=658,n1=704,n2=658,LogPval=-0.029688
# m=331,l=328,n1=331,n2=328,LogPval=-0.000000
# m=19858,l=19059,n1=19647,n2=19132,LogPval=-0.017074
# m=3229,l=3164,n1=3215,n2=3171,LogPval=-0.006342
# m=5504,l=5270,n1=5360,n2=5333,LogPval=-0.037899
# m=17414,l=17019,n1=17260,n2=17083,LogPval=-0.015441
# m=16957,l=16743,n1=16749,n2=16944,LogPval=-0.001388
# m=348,l=346,n1=348,n2=346,LogPval=0.000000
# m=28805,l=27595,n1=28572,n2=27653,LogPval=-0.015651
# m=8745,l=8525,n1=8580,n2=8603,LogPval=-0.032197
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=15258,l=14692,n1=15067,n2=14726,LogPval=-0.030527
# m=10189,l=9994,n1=10086,n2=10047,LogPval=-0.015220
# m=2021,l=1856,n1=1966,n2=1867,LogPval=-0.046880
# m=724,l=681,n1=689,n2=696,LogPval=-0.072400
# m=20335,l=19869,n1=20119,n2=19941,LogPval=-0.022804
# m=11153,l=10479,n1=11113,n2=10498,LogPval=-0.003170
# m=1276,l=1191,n1=1220,n2=1212,LogPval=-0.063938
# m=1036,l=942,n1=1013,n2=942,LogPval=-0.055875
# m=1425,l=1255,n1=1414,n2=1258,LogPval=-0.008809
# m=9264,l=9212,n1=9227,n2=9232,LogPval=-0.008435
# m=342,l=334,n1=340,n2=335,LogPval=-0.009396
# m=5652,l=5521,n1=5595,n2=5536,LogPval=-0.024956
# m=17616,l=15508,n1=17412,n2=15541,LogPval=-0.016362
# m=7305,l=7267,n1=7274,n2=7288,LogPval=-0.006350
# m=3183,l=3130,n1=3145,n2=3158,LogPval=-0.009644
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=364,l=344,n1=345,n2=357,LogPval=-0.045728
# m=3185,l=2970,n1=3072,n2=3001,LogPval=-0.060098
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=14772,l=13892,n1=14634,n2=13924,LogPval=-0.016168
# m=3020,l=3001,n1=3007,n2=3012,LogPval=-0.002538
# m=13567,l=13413,n1=13433,n2=13529,LogPval=-0.004440
# m=9579,l=9461,n1=9525,n2=9496,LogPval=-0.006246
# m=4562,l=4538,n1=4550,n2=4542,LogPval=-0.008517
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in double_scalars
# m=9899,l=9763,n1=9813,n2=9794,LogPval=-0.021596
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=26262,l=24975,n1=26023,n2=25038,LogPval=-0.015986
# m=1081,l=969,n1=1024,n2=999,LogPval=-0.035697
# m=3522,l=3445,n1=3514,n2=3448,LogPval=-0.004396
# m=1765,l=1659,n1=1753,n2=1662,LogPval=-0.011717
# 6 m=355,l=323,n1=333,n2=325,LogPval=-0.146371
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=316,n1=335,n2=316,LogPval=-0.151136
# m=344,l=321,n1=322,n2=334,LogPval=-0.070576
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=350,l=327,n1=328,n2=335,LogPval=-0.117706
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=355,l=322,n1=333,n2=326,LogPval=-0.120397
# m=357,l=311,n1=335,n2=311,LogPval=-0.141406
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=310,n1=335,n2=311,LogPval=-0.125686
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=330,n1=335,n2=334,LogPval=-0.139233
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=335,n1=335,n2=357,LogPval=-0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=300,n1=335,n2=300,LogPval=-0.124342
# m=355,l=324,n1=333,n2=329,LogPval=-0.115307
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=350,l=297,n1=328,n2=297,LogPval=-0.131319
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=351,l=306,n1=329,n2=308,LogPval=-0.118061
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=309,n1=335,n2=311,LogPval=-0.112157
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=304,n1=335,n2=304,LogPval=-0.130002
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=312,n1=335,n2=313,LogPval=-0.129137
# m=357,l=297,n1=335,n2=298,LogPval=-0.107272
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=314,n1=335,n2=314,LogPval=-0.147050
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=353,l=300,n1=331,n2=300,LogPval=-0.130752
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=339,l=307,n1=317,n2=311,LogPval=-0.126410
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=357,l=305,n1=335,n2=305,LogPval=-0.131505
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 7 m=2351,l=2142,n1=2151,n2=2262,LogPval=-0.079770
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2449,l=2221,n1=2242,n2=2319,LogPval=-0.101261
# m=2438,l=2231,n1=2231,n2=2421,LogPval=-0.017451
# m=2356,l=2157,n1=2158,n2=2355,LogPval=-0.000037
# m=1384,l=1256,n1=1267,n2=1335,LogPval=-0.055433
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1375,l=1276,n1=1277,n2=1338,LogPval=-0.071596
# m=2090,l=1887,n1=1913,n2=1977,LogPval=-0.086810
# m=2032,l=1805,n1=1849,n2=1870,LogPval=-0.118231
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2447,l=2216,n1=2242,n2=2323,LogPval=-0.085457
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2384,l=2181,n1=2184,n2=2327,LogPval=-0.054960
# m=994,l=887,n1=889,n2=950,LogPval=-0.096958
# m=2438,l=2232,n1=2232,n2=2438,LogPval=0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1678,l=1535,n1=1542,n2=1581,LogPval=-0.143169
# m=2441,l=2233,n1=2236,n2=2373,LogPval=-0.065929
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2429,l=2185,n1=2223,n2=2238,LogPval=-0.148711
# m=1365,l=1214,n1=1231,n2=1273,LogPval=-0.115175
# m=1343,l=1207,n1=1244,n2=1233,LogPval=-0.118378
# m=1054,l=943,n1=946,n2=1014,LogPval=-0.077498
# m=2420,l=2186,n1=2216,n2=2241,LogPval=-0.149789
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=948,l=857,n1=859,n2=906,LogPval=-0.102959
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=324,l=298,n1=300,n2=308,LogPval=-0.111862
# m=2048,l=1810,n1=1874,n2=1844,LogPval=-0.147009
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1022,l=933,n1=938,n2=996,LogPval=-0.043278
# m=2436,l=2225,n1=2230,n2=2308,LogPval=-0.134890
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1997,l=1784,n1=1823,n2=1818,LogPval=-0.165177
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=353,l=313,n1=313,n2=352,LogPval=-0.006169
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1371,l=1265,n1=1266,n2=1343,LogPval=-0.050699
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2435,l=2189,n1=2232,n2=2251,LogPval=-0.130131
# m=1017,l=887,n1=913,n2=949,LogPval=-0.062332
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 8 m=5562,l=5409,n1=5431,n2=5535,LogPval=-0.001443
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5854,l=5611,n1=5713,n2=5725,LogPval=-0.007091
# m=5316,l=5163,n1=5175,n2=5291,LogPval=-0.006127
# m=5626,l=5484,n1=5485,n2=5616,LogPval=-0.005537
# m=6004,l=5866,n1=5878,n2=5982,LogPval=-0.004306
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4786,l=4493,n1=4645,n2=4541,LogPval=-0.043779
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4982,l=4634,n1=4879,n2=4678,LogPval=-0.021111
# m=6225,l=5828,n1=6067,n2=5931,LogPval=-0.012492
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6304,l=5967,n1=6142,n2=6072,LogPval=-0.015253
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=631,l=609,n1=628,n2=611,LogPval=-0.003826
# m=6630,l=6417,n1=6467,n2=6567,LogPval=-0.002990
# m=5418,l=5308,n1=5308,n2=5409,LogPval=-0.006534
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6216,l=5863,n1=6057,n2=5969,LogPval=-0.013138
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4289,l=4216,n1=4227,n2=4265,LogPval=-0.009748
# m=2268,l=2212,n1=2218,n2=2252,LogPval=-0.013320
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6373,l=6201,n1=6212,n2=6340,LogPval=-0.009973
# m=5182,l=4887,n1=5060,n2=4928,LogPval=-0.035530
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1323,l=1187,n1=1316,n2=1187,LogPval=-0.012144
# m=4627,l=4543,n1=4545,n2=4612,LogPval=-0.010545
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2601,l=2540,n1=2549,n2=2576,LogPval=-0.019503
# m=5539,l=4832,n1=5389,n2=4842,LogPval=-0.048711
# m=2805,l=2752,n1=2753,n2=2798,LogPval=-0.007947
# m=349,l=343,n1=347,n2=344,LogPval=-0.010212
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4294,l=4084,n1=4212,n2=4144,LogPval=-0.007411
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3634,l=3607,n1=3610,n2=3621,LogPval=-0.012859
# m=4173,l=4076,n1=4090,n2=4139,LogPval=-0.014368
# m=1615,l=1601,n1=1605,n2=1606,LogPval=-0.013491
# m=2901,l=2828,n1=2830,n2=2891,LogPval=-0.009072
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5957,l=5614,n1=5831,n2=5716,LogPval=-0.003862
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1036,l=1016,n1=1033,n2=1017,LogPval=-0.006726
# m=1652,l=1570,n1=1644,n2=1571,LogPval=-0.011699
# 9 m=8199,l=7764,n1=7784,n2=8175,LogPval=-0.000452
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=8099,l=7675,n1=7731,n2=8037,LogPval=-0.000398
# m=7866,l=7536,n1=7552,n2=7839,LogPval=-0.002523
# m=7564,l=7233,n1=7233,n2=7555,LogPval=-0.003737
# m=8711,l=8279,n1=8286,n2=8678,LogPval=-0.007385
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4786,l=4493,n1=4541,n2=4645,LogPval=-0.043779
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6800,l=6289,n1=6528,n2=6416,LogPval=-0.039177
# m=9859,l=9131,n1=9457,n2=9411,LogPval=-0.016297
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=9192,l=8598,n1=8821,n2=8835,LogPval=-0.024978
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=9310,l=8898,n1=8903,n2=9294,LogPval=-0.002835
# m=8275,l=7954,n1=7956,n2=8267,LogPval=-0.001973
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=9852,l=9130,n1=9425,n2=9471,LogPval=-0.009028
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5428,l=5241,n1=5244,n2=5416,LogPval=-0.004671
# m=2717,l=2700,n1=2709,n2=2703,LogPval=-0.008512
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=9970,l=9529,n1=9549,n2=9930,LogPval=-0.003902
# m=8008,l=7390,n1=7654,n2=7595,LogPval=-0.030010
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1357,l=1186,n1=1257,n2=1198,LogPval=-0.134312
# m=5468,l=5206,n1=5211,n2=5453,LogPval=-0.004201
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5491,l=5248,n1=5271,n2=5449,LogPval=-0.006544
# m=8209,l=7144,n1=7833,n2=7172,LogPval=-0.083333
# m=5958,l=5729,n1=5731,n2=5945,LogPval=-0.005354
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5729,l=5553,n1=5580,n2=5682,LogPval=-0.007854
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5198,l=4965,n1=4968,n2=5184,LogPval=-0.005533
# m=5598,l=5342,n1=5372,n2=5545,LogPval=-0.007500
# m=679,l=678,n1=678,n2=678,LogPval=-0.009603
# m=5473,l=5211,n1=5215,n2=5456,LogPval=-0.005922
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=8580,l=8016,n1=8183,n2=8312,LogPval=-0.018088
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1691,l=1563,n1=1569,n2=1595,LogPval=-0.153865
# 10 m=2790,l=2624,n1=2676,n2=2664,LogPval=-0.066392
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2884,l=2701,n1=2769,n2=2723,LogPval=-0.085850
# m=2845,l=2724,n1=2730,n2=2810,LogPval=-0.029051
# m=2370,l=2289,n1=2290,n2=2369,LogPval=-0.000014
# m=2089,l=1986,n1=2009,n2=2033,LogPval=-0.038289
# m=355,l=322,n1=326,n2=333,LogPval=-0.120397
# m=1375,l=1276,n1=1338,n2=1277,LogPval=-0.071596
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2146,l=1995,n1=2049,n2=2007,LogPval=-0.107428
# m=1337,l=1245,n1=1305,n2=1245,LogPval=-0.068370
# m=721,l=667,n1=691,n2=667,LogPval=-0.121043
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2802,l=2615,n1=2694,n2=2646,LogPval=-0.065272
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2808,l=2674,n1=2696,n2=2725,LogPval=-0.060928
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2820,l=2709,n1=2709,n2=2820,LogPval=0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2463,l=2269,n1=2353,n2=2273,LogPval=-0.118108
# m=2866,l=2729,n1=2751,n2=2773,LogPval=-0.072399
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2827,l=2582,n1=2712,n2=2592,LogPval=-0.090380
# m=317,l=292,n1=311,n2=292,LogPval=-0.049975
# m=2763,l=2526,n1=2652,n2=2542,LogPval=-0.079435
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2833,l=2608,n1=2722,n2=2613,LogPval=-0.099244
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=315,l=299,n1=311,n2=299,LogPval=-0.039068
# m=1049,l=950,n1=991,n2=955,LogPval=-0.123886
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1745,l=1624,n1=1659,n2=1638,LogPval=-0.112374
# m=2492,l=2248,n1=2385,n2=2254,LogPval=-0.096008
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=327,l=318,n1=321,n2=319,LogPval=-0.056036
# m=2874,l=2694,n1=2759,n2=2706,LogPval=-0.102766
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2388,l=2176,n1=2283,n2=2181,LogPval=-0.106098
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2092,l=2002,n1=2016,n2=2029,LogPval=-0.072348
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2881,l=2642,n1=2766,n2=2653,LogPval=-0.088995
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 11 m=16061,l=15040,n1=15174,n2=15704,LogPval=-0.027867
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=19170,l=17675,n1=17896,n2=18439,LogPval=-0.055279
# m=18431,l=17273,n1=17304,n2=18274,LogPval=-0.015474
# m=18059,l=16844,n1=16847,n2=18044,LogPval=-0.001470
# m=18159,l=16954,n1=17038,n2=17943,LogPval=-0.013132
# m=357,l=311,n1=311,n2=335,LogPval=-0.141406
# m=2090,l=1887,n1=1977,n2=1913,LogPval=-0.086810
# m=4982,l=4634,n1=4678,n2=4879,LogPval=-0.021111
# m=6800,l=6289,n1=6416,n2=6528,LogPval=-0.039177
# m=2146,l=1995,n1=2007,n2=2049,LogPval=-0.107428
# m=19736,l=17966,n1=18573,n2=18297,LogPval=-0.090616
# m=354,l=322,n1=339,n2=322,LogPval=-0.112107
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=19983,l=18436,n1=18716,n2=19116,LogPval=-0.062158
# m=650,l=625,n1=639,n2=626,LogPval=-0.050355
# m=5935,l=5490,n1=5538,n2=5750,LogPval=-0.049656
# m=17473,l=16187,n1=16328,n2=17113,LogPval=-0.022189
# m=17262,l=16117,n1=16119,n2=17246,LogPval=-0.001937
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=19211,l=17563,n1=18057,n2=17991,LogPval=-0.079166
# m=4998,l=4684,n1=4724,n2=4839,LogPval=-0.057776
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=17628,l=16107,n1=16396,n2=17024,LogPval=-0.027264
# m=12724,l=11756,n1=11824,n2=12552,LogPval=-0.013600
# m=2073,l=1860,n1=1936,n2=1888,LogPval=-0.113676
# m=1094,l=1012,n1=1033,n2=1052,LogPval=-0.034855
# m=18959,l=17542,n1=17729,n2=18515,LogPval=-0.023268
# m=9970,l=9031,n1=9274,n2=9314,LogPval=-0.082952
# m=1300,l=1193,n1=1219,n2=1235,LogPval=-0.060157
# m=721,l=643,n1=658,n2=645,LogPval=-0.226011
# m=1076,l=945,n1=1014,n2=948,LogPval=-0.120553
# m=9325,l=8633,n1=8638,n2=9292,LogPval=-0.006599
# m=342,l=330,n1=334,n2=335,LogPval=-0.023927
# m=6396,l=5896,n1=5934,n2=6258,LogPval=-0.030833
# m=18098,l=15728,n1=16910,n2=15957,LogPval=-0.094780
# m=8385,l=7750,n1=7754,n2=8368,LogPval=-0.003134
# m=3577,l=3314,n1=3321,n2=3552,LogPval=-0.009907
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=730,l=685,n1=693,n2=710,LogPval=-0.035945
# m=3618,l=3344,n1=3402,n2=3402,LogPval=-0.110843
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16436,l=14830,n1=15312,n2=15483,LogPval=-0.044804
# m=670,l=657,n1=658,n2=669,LogPval=-0.000027
# m=14365,l=13355,n1=13359,n2=14328,LogPval=-0.005389
# m=10771,l=9995,n1=10028,n2=10681,LogPval=-0.009280
# m=5655,l=5211,n1=5212,n2=5634,LogPval=-0.008553
# m=6343,l=5911,n1=5920,n2=6269,LogPval=-0.024588
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=19286,l=17531,n1=18107,n2=17932,LogPval=-0.082788
# m=1421,l=1316,n1=1345,n2=1322,LogPval=-0.140366
# m=3490,l=3235,n1=3243,n2=3416,LogPval=-0.046057
# m=1425,l=1324,n1=1342,n2=1337,LogPval=-0.140432
# 12 m=24215,l=23090,n1=23211,n2=23835,LogPval=-0.025967
# m=1406,l=1353,n1=1353,n2=1406,LogPval=-0.000000
# m=19472,l=17972,n1=18062,n2=18864,LogPval=-0.062391
# m=29078,l=27547,n1=27588,n2=28885,LogPval=-0.012518
# m=20111,l=18635,n1=18644,n2=20094,LogPval=-0.000574
# m=28472,l=27108,n1=27177,n2=28233,LogPval=-0.013997
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2032,l=1805,n1=1870,n2=1849,LogPval=-0.118231
# m=6225,l=5828,n1=5931,n2=6067,LogPval=-0.012492
# m=9859,l=9131,n1=9411,n2=9457,LogPval=-0.016297
# m=1337,l=1245,n1=1245,n2=1305,LogPval=-0.068370
# m=19736,l=17966,n1=18297,n2=18573,LogPval=-0.090616
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=21446,l=19847,n1=20034,n2=20648,LogPval=-0.064645
# m=3627,l=3538,n1=3614,n2=3545,LogPval=-0.004307
# m=5084,l=4627,n1=4656,n2=4939,LogPval=-0.046180
# m=19346,l=17957,n1=17996,n2=18989,LogPval=-0.039616
# m=18181,l=16946,n1=16948,n2=18170,LogPval=-0.001121
# m=332,l=294,n1=297,n2=323,LogPval=-0.029385
# m=29606,l=28016,n1=28261,n2=28427,LogPval=-0.091988
# m=8362,l=8041,n1=8059,n2=8239,LogPval=-0.038241
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16555,l=15011,n1=15183,n2=16048,LogPval=-0.034154
# m=12562,l=11416,n1=11468,n2=12371,LogPval=-0.019324
# m=1316,l=1182,n1=1224,n2=1200,LogPval=-0.126039
# m=1082,l=964,n1=978,n2=1040,LogPval=-0.042142
# m=20787,l=19327,n1=19427,n2=20426,LogPval=-0.025609
# m=12011,l=10951,n1=11182,n2=11257,LogPval=-0.095690
# m=1231,l=1097,n1=1114,n2=1166,LogPval=-0.072462
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1304,l=1151,n1=1248,n2=1157,LogPval=-0.077333
# m=9817,l=9057,n1=9065,n2=9787,LogPval=-0.004262
# m=312,l=296,n1=299,n2=305,LogPval=-0.031206
# m=5873,l=5410,n1=5422,n2=5820,LogPval=-0.013883
# m=18447,l=16163,n1=17157,n2=16300,LogPval=-0.130378
# m=8847,l=8055,n1=8059,n2=8828,LogPval=-0.003222
# m=3493,l=3230,n1=3236,n2=3468,LogPval=-0.011037
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1053,l=965,n1=971,n2=1025,LogPval=-0.044218
# m=2789,l=2537,n1=2572,n2=2644,LogPval=-0.084820
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=15723,l=14285,n1=14491,n2=14909,LogPval=-0.080855
# m=3347,l=3330,n1=3338,n2=3336,LogPval=-0.003894
# m=14453,l=13277,n1=13284,n2=14417,LogPval=-0.004005
# m=11165,l=10330,n1=10361,n2=11071,LogPval=-0.010126
# m=5258,l=4756,n1=4758,n2=5241,LogPval=-0.005851
# m=9670,l=9117,n1=9125,n2=9585,LogPval=-0.020950
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=26822,l=25162,n1=25511,n2=25591,LogPval=-0.086697
# m=1408,l=1270,n1=1283,n2=1309,LogPval=-0.148887
# m=3495,l=3169,n1=3182,n2=3422,LogPval=-0.034113
# m=1645,l=1517,n1=1562,n2=1551,LogPval=-0.062156
# 13 m=708,l=651,n1=654,n2=684,LogPval=-0.071725
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=726,l=669,n1=672,n2=693,LogPval=-0.108794
# m=711,l=654,n1=657,n2=697,LogPval=-0.033280
# m=672,l=625,n1=625,n2=672,LogPval=0.000000
# m=712,l=658,n1=658,n2=704,LogPval=-0.029688
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=721,l=667,n1=667,n2=691,LogPval=-0.121043
# m=354,l=322,n1=322,n2=339,LogPval=-0.112107
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=691,l=642,n1=643,n2=672,LogPval=-0.070259
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=696,l=641,n1=642,n2=676,LogPval=-0.070384
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=697,l=649,n1=649,n2=697,LogPval=0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=724,l=667,n1=670,n2=676,LogPval=-0.184645
# m=724,l=670,n1=670,n2=707,LogPval=-0.064589
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=711,l=651,n1=657,n2=670,LogPval=-0.124973
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=678,l=626,n1=629,n2=649,LogPval=-0.100232
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=705,l=651,n1=657,n2=660,LogPval=-0.157441
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=688,l=633,n1=639,n2=649,LogPval=-0.125134
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=697,l=646,n1=649,n2=665,LogPval=-0.114074
# m=722,l=660,n1=668,n2=671,LogPval=-0.158993
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=720,l=665,n1=666,n2=684,LogPval=-0.140136
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=696,l=641,n1=648,n2=650,LogPval=-0.156053
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=708,l=658,n1=658,n2=693,LogPval=-0.059245
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=725,l=669,n1=671,n2=687,LogPval=-0.140402
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 14 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1383,l=1371,n1=1372,n2=1381,LogPval=-0.002999
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1428,l=1423,n1=1423,n2=1428,LogPval=-0.000000
# m=361,l=353,n1=360,n2=354,LogPval=-0.000054
# m=331,l=328,n1=328,n2=331,LogPval=-0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1036,l=1013,n1=1033,n2=1014,LogPval=-0.006439
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2485,l=2450,n1=2467,n2=2452,LogPval=-0.027555
# m=1365,l=1269,n1=1348,n2=1275,LogPval=-0.015710
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1423,l=1417,n1=1417,n2=1421,LogPval=-0.007814
# m=364,l=360,n1=361,n2=363,LogPval=-0.000023
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1052,l=1027,n1=1039,n2=1032,LogPval=-0.024896
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=334,l=330,n1=332,n2=332,LogPval=-0.000036
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=322,l=319,n1=322,n2=319,LogPval=-0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=320,l=311,n1=315,n2=313,LogPval=-0.030223
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 15 m=18443,l=17578,n1=17708,n2=18066,LogPval=-0.032808
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=21082,l=19854,n1=20229,n2=20332,LogPval=-0.037465
# m=20123,l=19277,n1=19324,n2=19970,LogPval=-0.012868
# m=19979,l=19170,n1=19176,n2=19960,LogPval=-0.001597
# m=19858,l=19059,n1=19132,n2=19647,LogPval=-0.017074
# m=357,l=310,n1=311,n2=335,LogPval=-0.125686
# m=2447,l=2216,n1=2323,n2=2242,LogPval=-0.085457
# m=6304,l=5967,n1=6072,n2=6142,LogPval=-0.015253
# m=9192,l=8598,n1=8835,n2=8821,LogPval=-0.024978
# m=2802,l=2615,n1=2646,n2=2694,LogPval=-0.065272
# m=19983,l=18436,n1=19116,n2=18716,LogPval=-0.062158
# m=21446,l=19847,n1=20648,n2=20034,LogPval=-0.064645
# m=691,l=642,n1=672,n2=643,LogPval=-0.070259
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6578,l=6182,n1=6233,n2=6384,LogPval=-0.052785
# m=19498,l=18618,n1=18757,n2=19139,LogPval=-0.026763
# m=19469,l=18617,n1=18619,n2=19453,LogPval=-0.002016
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=21211,l=19773,n1=20374,n2=20003,LogPval=-0.067697
# m=4994,l=4690,n1=4718,n2=4832,LogPval=-0.070936
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=18213,l=17091,n1=17399,n2=17584,LogPval=-0.035393
# m=13019,l=12401,n1=12478,n2=12824,LogPval=-0.020216
# m=2719,l=2473,n1=2568,n2=2504,LogPval=-0.099613
# m=1092,l=1016,n1=1035,n2=1050,LogPval=-0.042718
# m=22051,l=20969,n1=21167,n2=21568,LogPval=-0.029410
# m=11707,l=10807,n1=11264,n2=10959,LogPval=-0.050136
# m=1298,l=1200,n1=1221,n2=1235,LogPval=-0.072975
# m=1020,l=918,n1=954,n2=933,LogPval=-0.108251
# m=1441,l=1272,n1=1367,n2=1274,LogPval=-0.113625
# m=9917,l=9474,n1=9478,n2=9883,LogPval=-0.008462
# m=342,l=330,n1=334,n2=335,LogPval=-0.023927
# m=7036,l=6565,n1=6612,n2=6884,LogPval=-0.031145
# m=19705,l=17319,n1=18863,n2=17390,LogPval=-0.078497
# m=8606,l=8227,n1=8230,n2=8585,LogPval=-0.005773
# m=3570,l=3381,n1=3386,n2=3547,LogPval=-0.012327
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1062,l=1010,n1=1019,n2=1034,LogPval=-0.047027
# m=4273,l=3960,n1=4039,n2=4034,LogPval=-0.090959
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=17666,l=16360,n1=16925,n2=16703,LogPval=-0.042644
# m=320,l=315,n1=317,n2=318,LogPval=-0.000059
# m=14624,l=14022,n1=14028,n2=14583,LogPval=-0.006694
# m=11378,l=10847,n1=10884,n2=11280,LogPval=-0.011780
# m=5596,l=5414,n1=5417,n2=5575,LogPval=-0.009956
# m=7359,l=6936,n1=6952,n2=7273,LogPval=-0.023137
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=21602,l=19964,n1=20804,n2=20241,LogPval=-0.048563
# m=1419,l=1291,n1=1341,n2=1321,LogPval=-0.065569
# m=3462,l=3338,n1=3386,n2=3388,LogPval=-0.017078
# m=1447,l=1348,n1=1379,n2=1365,LogPval=-0.089985
# 16 m=3287,l=3198,n1=3230,n2=3237,LogPval=-0.013937
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3164,l=3088,n1=3095,n2=3150,LogPval=-0.006032
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3229,l=3164,n1=3171,n2=3215,LogPval=-0.006342
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=650,l=625,n1=626,n2=639,LogPval=-0.050355
# m=3627,l=3538,n1=3545,n2=3614,LogPval=-0.004307
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3608,l=3507,n1=3525,n2=3578,LogPval=-0.007806
# m=1951,l=1910,n1=1910,n2=1948,LogPval=-0.005977
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2157,l=2087,n1=2092,n2=2149,LogPval=-0.003093
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3619,l=3538,n1=3538,n2=3618,LogPval=-0.001050
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 17 m=6114,l=5817,n1=5929,n2=5865,LogPval=-0.062449
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6655,l=6282,n1=6456,n2=6303,LogPval=-0.076902
# m=6211,l=6018,n1=6028,n2=6152,LogPval=-0.024949
# m=6052,l=5884,n1=5887,n2=6047,LogPval=-0.000824
# m=5504,l=5270,n1=5333,n2=5360,LogPval=-0.037899
# m=357,l=330,n1=334,n2=335,LogPval=-0.139233
# m=2384,l=2181,n1=2327,n2=2184,LogPval=-0.054960
# m=631,l=609,n1=611,n2=628,LogPval=-0.003826
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2808,l=2674,n1=2725,n2=2696,LogPval=-0.060928
# m=5935,l=5490,n1=5750,n2=5538,LogPval=-0.049656
# m=5084,l=4627,n1=4939,n2=4656,LogPval=-0.046180
# m=696,l=641,n1=676,n2=642,LogPval=-0.070384
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6578,l=6182,n1=6384,n2=6233,LogPval=-0.052785
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3658,l=3462,n1=3543,n2=3485,LogPval=-0.069735
# m=6509,l=6316,n1=6318,n2=6505,LogPval=-0.000819
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5782,l=5343,n1=5606,n2=5359,LogPval=-0.069249
# m=4914,l=4707,n1=4769,n2=4753,LogPval=-0.058902
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6246,l=5795,n1=6054,n2=5823,LogPval=-0.064050
# m=3415,l=3220,n1=3313,n2=3273,LogPval=-0.028791
# m=2723,l=2497,n1=2642,n2=2506,LogPval=-0.061970
# m=1066,l=1017,n1=1038,n2=1026,LogPval=-0.048588
# m=6247,l=5798,n1=6056,n2=5852,LogPval=-0.047222
# m=1296,l=1168,n1=1253,n2=1176,LogPval=-0.054093
# m=1258,l=1186,n1=1222,n2=1195,LogPval=-0.054884
# m=1026,l=933,n1=985,n2=933,LogPval=-0.105364
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1701,l=1644,n1=1649,n2=1692,LogPval=-0.005510
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1721,l=1609,n1=1667,n2=1616,LogPval=-0.072252
# m=5549,l=4947,n1=5374,n2=4961,LogPval=-0.060884
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1354,l=1289,n1=1299,n2=1331,LogPval=-0.021785
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1049,l=1009,n1=1021,n2=1022,LogPval=-0.040398
# m=4243,l=3987,n1=4120,n2=4003,LogPval=-0.068210
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5442,l=4920,n1=5281,n2=4934,LogPval=-0.059857
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3074,l=2976,n1=2981,n2=3065,LogPval=-0.003047
# m=658,l=628,n1=633,n2=653,LogPval=-0.000295
# m=1329,l=1284,n1=1288,n2=1321,LogPval=-0.007468
# m=2389,l=2293,n1=2314,n2=2319,LogPval=-0.062692
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6626,l=6081,n1=6429,n2=6088,LogPval=-0.073128
# m=1385,l=1270,n1=1345,n2=1289,LogPval=-0.024363
# m=984,l=943,n1=956,n2=960,LogPval=-0.027304
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 18 m=15227,l=14849,n1=14946,n2=14973,LogPval=-0.033889
# m=1324,l=1302,n1=1302,n2=1324,LogPval=0.000000
# m=18900,l=18209,n1=18542,n2=18316,LogPval=-0.038168
# m=18590,l=18137,n1=18190,n2=18476,LogPval=-0.008808
# m=18298,l=17938,n1=17945,n2=18282,LogPval=-0.001444
# m=17414,l=17019,n1=17083,n2=17260,LogPval=-0.015441
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=994,l=887,n1=950,n2=889,LogPval=-0.096958
# m=6630,l=6417,n1=6567,n2=6467,LogPval=-0.002990
# m=9310,l=8898,n1=9294,n2=8903,LogPval=-0.002835
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=17473,l=16187,n1=17113,n2=16328,LogPval=-0.022189
# m=19346,l=17957,n1=18989,n2=17996,LogPval=-0.039616
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1036,l=1013,n1=1014,n2=1033,LogPval=-0.006439
# m=19498,l=18618,n1=19139,n2=18757,LogPval=-0.026763
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3658,l=3462,n1=3485,n2=3543,LogPval=-0.069735
# m=16952,l=16619,n1=16624,n2=16937,LogPval=-0.001868
# m=2082,l=2011,n1=2017,n2=2063,LogPval=-0.017416
# m=19773,l=18594,n1=19381,n2=18641,LogPval=-0.045694
# m=2049,l=1934,n1=1950,n2=1972,LogPval=-0.083562
# m=649,l=648,n1=648,n2=649,LogPval=0.000000
# m=680,l=638,n1=639,n2=675,LogPval=-0.014445
# m=16014,l=15478,n1=15667,n2=15616,LogPval=-0.038111
# m=12586,l=12201,n1=12285,n2=12418,LogPval=-0.017000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1032,l=974,n1=985,n2=992,LogPval=-0.076621
# m=20219,l=19676,n1=19826,n2=19927,LogPval=-0.019337
# m=12131,l=11356,n1=11987,n2=11389,LogPval=-0.020207
# m=926,l=864,n1=879,n2=878,LogPval=-0.092602
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1427,l=1260,n1=1423,n2=1260,LogPval=-0.006036
# m=10658,l=10477,n1=10488,n2=10623,LogPval=-0.007628
# m=340,l=330,n1=333,n2=333,LogPval=-0.038342
# m=5731,l=5685,n1=5718,n2=5685,LogPval=-0.011270
# m=18244,l=16037,n1=17917,n2=16065,LogPval=-0.030937
# m=9401,l=9326,n1=9333,n2=9382,LogPval=-0.005253
# m=3505,l=3349,n1=3359,n2=3480,LogPval=-0.009636
# m=1038,l=978,n1=978,n2=1032,LogPval=-0.016713
# m=717,l=682,n1=686,n2=698,LogPval=-0.059816
# m=1348,l=1260,n1=1284,n2=1270,LogPval=-0.113038
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=15612,l=14855,n1=15316,n2=14864,LogPval=-0.057327
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=15267,l=14926,n1=14939,n2=15228,LogPval=-0.005128
# m=11722,l=11483,n1=11552,n2=11622,LogPval=-0.006439
# m=5650,l=5536,n1=5543,n2=5629,LogPval=-0.007939
# m=6020,l=5984,n1=5992,n2=5993,LogPval=-0.015886
# m=362,l=338,n1=341,n2=342,LogPval=-0.139698
# m=18728,l=17510,n1=18349,n2=17565,LogPval=-0.042498
# m=1321,l=1202,n1=1257,n2=1228,LogPval=-0.052504
# m=3447,l=3301,n1=3335,n2=3379,LogPval=-0.022611
# m=1767,l=1663,n1=1762,n2=1664,LogPval=-0.005588
# 19 m=16986,l=16610,n1=16980,n2=16614,LogPval=-0.000296
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=19295,l=18643,n1=19281,n2=18647,LogPval=-0.001411
# m=17060,l=16934,n1=17051,n2=16936,LogPval=-0.001821
# m=18256,l=18231,n1=18240,n2=18238,LogPval=-0.003033
# m=16957,l=16743,n1=16944,n2=16749,LogPval=-0.001388
# m=357,l=335,n1=357,n2=335,LogPval=-0.000000
# m=2438,l=2232,n1=2438,n2=2232,LogPval=0.000000
# m=5418,l=5308,n1=5409,n2=5308,LogPval=-0.006534
# m=8275,l=7954,n1=8267,n2=7956,LogPval=-0.001973
# m=2820,l=2709,n1=2820,n2=2709,LogPval=0.000000
# m=17262,l=16117,n1=17246,n2=16119,LogPval=-0.001937
# m=18181,l=16946,n1=18170,n2=16948,LogPval=-0.001121
# m=697,l=649,n1=697,n2=649,LogPval=0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=19469,l=18617,n1=19453,n2=18619,LogPval=-0.002016
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6509,l=6316,n1=6505,n2=6318,LogPval=-0.000819
# m=16952,l=16619,n1=16937,n2=16624,LogPval=-0.001868
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=18472,l=17420,n1=18462,n2=17423,LogPval=-0.000838
# m=5010,l=4842,n1=5010,n2=4842,LogPval=-0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=17121,l=16489,n1=17105,n2=16494,LogPval=-0.001651
# m=11386,l=11199,n1=11376,n2=11202,LogPval=-0.002130
# m=2748,l=2528,n1=2748,n2=2528,LogPval=-0.000000
# m=1086,l=1044,n1=1086,n2=1044,LogPval=0.000000
# m=19541,l=19062,n1=19527,n2=19066,LogPval=-0.001558
# m=9351,l=8756,n1=9339,n2=8761,LogPval=-0.001393
# m=1300,l=1235,n1=1300,n2=1235,LogPval=0.000000
# m=1026,l=939,n1=1026,n2=939,LogPval=0.000000
# m=1398,l=1241,n1=1394,n2=1241,LogPval=-0.006281
# m=9678,l=9642,n1=9664,n2=9646,LogPval=-0.005351
# m=340,l=333,n1=340,n2=333,LogPval=0.000000
# m=7363,l=7208,n1=7356,n2=7209,LogPval=-0.002903
# m=18367,l=16216,n1=18354,n2=16217,LogPval=-0.001270
# m=7738,l=7719,n1=7729,n2=7722,LogPval=-0.004359
# m=3520,l=3494,n1=3518,n2=3496,LogPval=-0.000004
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1054,l=1026,n1=1054,n2=1026,LogPval=0.000000
# m=4288,l=4045,n1=4288,n2=4045,LogPval=0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=15897,l=15073,n1=15884,n2=15077,LogPval=-0.001281
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=13638,l=13597,n1=13623,n2=13601,LogPval=-0.004359
# m=10486,l=10387,n1=10476,n2=10389,LogPval=-0.003239
# m=3993,l=3979,n1=3985,n2=3981,LogPval=-0.008268
# m=7613,l=7524,n1=7608,n2=7525,LogPval=-0.002143
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=18699,l=17521,n1=18684,n2=17524,LogPval=-0.001462
# m=1413,l=1314,n1=1413,n2=1314,LogPval=-0.000000
# m=2056,l=2017,n1=2053,n2=2018,LogPval=-0.003369
# m=1738,l=1638,n1=1734,n2=1639,LogPval=-0.004198
# 20 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2376,l=2340,n1=2341,n2=2374,LogPval=-0.001490
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2441,l=2408,n1=2408,n2=2441,LogPval=0.000000
# m=331,l=314,n1=320,n2=324,LogPval=-0.004968
# m=348,l=346,n1=346,n2=348,LogPval=0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=332,l=294,n1=323,n2=297,LogPval=-0.029385
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2485,l=2450,n1=2452,n2=2467,LogPval=-0.027555
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2082,l=2011,n1=2063,n2=2017,LogPval=-0.017416
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2369,l=2202,n1=2336,n2=2212,LogPval=-0.019525
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1392,l=1375,n1=1375,n2=1390,LogPval=-0.006372
# m=695,l=686,n1=689,n2=690,LogPval=-0.010647
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1754,l=1705,n1=1732,n2=1713,LogPval=-0.024228
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=338,l=316,n1=336,n2=316,LogPval=-0.016295
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1060,l=1044,n1=1047,n2=1054,LogPval=-0.009887
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=292,l=282,n1=285,n2=289,LogPval=-0.000250
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=686,l=656,n1=677,n2=659,LogPval=-0.022812
# m=365,l=348,n1=357,n2=351,LogPval=-0.035982
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 21 m=24622,l=23625,n1=23748,n2=24206,LogPval=-0.031902
# m=1723,l=1646,n1=1646,n2=1721,LogPval=-0.003615
# m=19671,l=18374,n1=18484,n2=19042,LogPval=-0.066113
# m=29113,l=27746,n1=27790,n2=28921,LogPval=-0.012601
# m=19243,l=18110,n1=18117,n2=19229,LogPval=-0.000632
# m=28805,l=27595,n1=27653,n2=28572,LogPval=-0.015651
# m=357,l=300,n1=300,n2=335,LogPval=-0.124342
# m=1678,l=1535,n1=1581,n2=1542,LogPval=-0.143169
# m=6216,l=5863,n1=5969,n2=6057,LogPval=-0.013138
# m=9852,l=9130,n1=9471,n2=9425,LogPval=-0.009028
# m=2463,l=2269,n1=2273,n2=2353,LogPval=-0.118108
# m=19211,l=17563,n1=17991,n2=18057,LogPval=-0.079166
# m=29606,l=28016,n1=28427,n2=28261,LogPval=-0.091988
# m=724,l=667,n1=676,n2=670,LogPval=-0.184645
# m=1365,l=1269,n1=1275,n2=1348,LogPval=-0.015710
# ...
# m=6598,l=6144,n1=6538,n2=6158,LogPval=-0.014735
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1404,l=1240,n1=1390,n2=1241,LogPval=-0.018450
# m=7490,l=7429,n1=7431,n2=7468,LogPval=-0.012693
# m=314,l=299,n1=303,n2=307,LogPval=-0.021944
# m=4794,l=4732,n1=4742,n2=4754,LogPval=-0.026233
# m=11250,l=9808,n1=11152,n2=9823,LogPval=-0.012061
# m=6588,l=6531,n1=6532,n2=6575,LogPval=-0.008487
# m=2811,l=2788,n1=2792,n2=2805,LogPval=-0.002620
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=10286,l=9893,n1=10197,n2=9927,LogPval=-0.012934
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=10013,l=9929,n1=9933,n2=9990,LogPval=-0.008490
# m=3079,l=3061,n1=3063,n2=3071,LogPval=-0.009515
# m=4732,l=4678,n1=4682,n2=4716,LogPval=-0.010259
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=10295,l=9592,n1=10215,n2=9624,LogPval=-0.008087
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1328,l=1304,n1=1321,n2=1308,LogPval=-0.006956
# m=1740,l=1635,n1=1727,n2=1640,LogPval=-0.009331
# 48 m=2612,l=2556,n1=2608,n2=2560,LogPval=-0.000031
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5526,l=5239,n1=5505,n2=5248,LogPval=-0.004336
# m=4146,l=4099,n1=4133,n2=4106,LogPval=-0.005028
# m=5576,l=5555,n1=5557,n2=5568,LogPval=-0.005674
# m=4562,l=4538,n1=4542,n2=4550,LogPval=-0.008517
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1615,l=1601,n1=1606,n2=1605,LogPval=-0.013491
# m=679,l=678,n1=678,n2=678,LogPval=-0.009603
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5655,l=5211,n1=5634,n2=5212,LogPval=-0.008553
# m=5258,l=4756,n1=5241,n2=4758,LogPval=-0.005851
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5596,l=5414,n1=5575,n2=5417,LogPval=-0.009956
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1329,l=1284,n1=1321,n2=1288,LogPval=-0.007468
# m=5650,l=5536,n1=5629,n2=5543,LogPval=-0.007939
# m=3993,l=3979,n1=3981,n2=3985,LogPval=-0.008268
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4331,l=3969,n1=4317,n2=3974,LogPval=-0.003550
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5677,l=5624,n1=5656,n2=5633,LogPval=-0.008353
# m=4842,l=4803,n1=4827,n2=4806,LogPval=-0.011311
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4875,l=4835,n1=4855,n2=4837,LogPval=-0.017836
# m=3989,l=3684,n1=3972,n2=3688,LogPval=-0.006609
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3505,l=3487,n1=3490,n2=3491,LogPval=-0.016876
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=341,l=337,n1=340,n2=338,LogPval=-0.000026
# m=4486,l=3944,n1=4470,n2=3945,LogPval=-0.006521
# m=3146,l=3137,n1=3138,n2=3140,LogPval=-0.009429
# m=1055,l=1043,n1=1049,n2=1046,LogPval=-0.011071
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5695,l=5374,n1=5674,n2=5376,LogPval=-0.008786
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5595,l=5570,n1=5574,n2=5576,LogPval=-0.014721
# m=3079,l=3061,n1=3071,n2=3063,LogPval=-0.009515
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5560,l=5013,n1=5539,n2=5016,LogPval=-0.006331
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2661,l=2603,n1=2654,n2=2604,LogPval=-0.008042
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 49 m=8000,l=7854,n1=7916,n2=7876,LogPval=-0.028872
# m=726,l=726,n1=726,n2=726,LogPval=0.000000
# m=8031,l=7851,n1=7945,n2=7867,LogPval=-0.031200
# m=9793,l=9632,n1=9664,n2=9709,LogPval=-0.018775
# m=8340,l=8277,n1=8280,n2=8333,LogPval=-0.001955
# m=9899,l=9763,n1=9794,n2=9813,LogPval=-0.021596
# m=339,l=307,n1=311,n2=317,LogPval=-0.126410
# m=1371,l=1265,n1=1343,n2=1266,LogPval=-0.050699
# m=2901,l=2828,n1=2891,n2=2830,LogPval=-0.009072
# m=5473,l=5211,n1=5456,n2=5215,LogPval=-0.005922
# m=2092,l=2002,n1=2029,n2=2016,LogPval=-0.072348
# m=6343,l=5911,n1=6269,n2=5920,LogPval=-0.024588
# m=9670,l=9117,n1=9585,n2=9125,LogPval=-0.020950
# m=708,l=658,n1=693,n2=658,LogPval=-0.059245
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=7359,l=6936,n1=7273,n2=6952,LogPval=-0.023137
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2389,l=2293,n1=2319,n2=2314,LogPval=-0.062692
# m=6020,l=5984,n1=5993,n2=5992,LogPval=-0.015886
# m=7613,l=7524,n1=7525,n2=7608,LogPval=-0.002143
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=10427,l=9908,n1=10315,n2=9918,LogPval=-0.027536
# m=3508,l=3404,n1=3435,n2=3428,LogPval=-0.045712
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6910,l=6701,n1=6823,n2=6711,LogPval=-0.037764
# m=2693,l=2633,n1=2672,n2=2635,LogPval=-0.026314
# m=2037,l=1875,n1=1977,n2=1885,LogPval=-0.055845
# m=346,l=332,n1=336,n2=333,LogPval=-0.089157
# m=8040,l=7823,n1=7953,n2=7831,LogPval=-0.034867
# m=5156,l=4848,n1=5140,n2=4853,LogPval=-0.004511
# m=316,l=299,n1=309,n2=300,LogPval=-0.053817
# m=1020,l=933,n1=977,n2=933,LogPval=-0.115311
# m=1428,l=1262,n1=1421,n2=1262,LogPval=-0.010629
# m=4920,l=4898,n1=4903,n2=4906,LogPval=-0.009351
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=5951,l=5829,n1=5892,n2=5835,LogPval=-0.034472
# m=7692,l=6709,n1=7608,n2=6715,LogPval=-0.018805
# m=5052,l=5035,n1=5036,n2=5041,LogPval=-0.011634
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=673,l=652,n1=659,n2=654,LogPval=-0.063504
# m=2452,l=2313,n1=2380,n2=2313,LogPval=-0.093124
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6442,l=6219,n1=6367,n2=6222,LogPval=-0.038005
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=4296,l=4275,n1=4282,n2=4283,LogPval=-0.006557
# m=4732,l=4678,n1=4716,n2=4682,LogPval=-0.010259
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=6718,l=6307,n1=6632,n2=6311,LogPval=-0.033315
# m=317,l=297,n1=307,n2=301,LogPval=-0.043289
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1768,l=1664,n1=1761,n2=1665,LogPval=-0.008658
# 50 m=0,l=0,n1=0,n2=0,LogPval=nan
# m=322,l=315,n1=315,n2=321,LogPval=-0.011890
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=330,l=312,n1=312,n2=330,LogPval=0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=320,l=311,n1=313,n2=315,LogPval=-0.030223
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=362,l=338,n1=342,n2=341,LogPval=-0.139698
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=686,l=656,n1=659,n2=677,LogPval=-0.022812
# m=638,l=595,n1=613,n2=598,LogPval=-0.094264
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=333,l=313,n1=314,n2=329,LogPval=-0.022255
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=653,l=619,n1=626,n2=633,LogPval=-0.051564
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=339,l=313,n1=327,n2=317,LogPval=-0.050779
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=364,l=344,n1=344,n2=364,LogPval=0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 51 m=23738,l=22699,n1=22805,n2=23309,LogPval=-0.036768
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=20087,l=18633,n1=18707,n2=19391,LogPval=-0.079341
# m=25673,l=24381,n1=24422,n2=25503,LogPval=-0.011953
# m=18934,l=17613,n1=17619,n2=18915,LogPval=-0.001318
# m=26262,l=24975,n1=25038,n2=26023,LogPval=-0.015986
# m=357,l=305,n1=305,n2=335,LogPval=-0.131505
# m=2435,l=2189,n1=2251,n2=2232,LogPval=-0.130131
# m=5957,l=5614,n1=5716,n2=5831,LogPval=-0.003862
# m=8580,l=8016,n1=8312,n2=8183,LogPval=-0.018088
# m=2881,l=2642,n1=2653,n2=2766,LogPval=-0.088995
# m=19286,l=17531,n1=17932,n2=18107,LogPval=-0.082788
# m=26822,l=25162,n1=25591,n2=25511,LogPval=-0.086697
# m=725,l=669,n1=687,n2=671,LogPval=-0.140402
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=21602,l=19964,n1=20241,n2=20804,LogPval=-0.048563
# m=3619,l=3538,n1=3618,n2=3538,LogPval=-0.001050
# m=6626,l=6081,n1=6088,n2=6429,LogPval=-0.073128
# m=18728,l=17510,n1=17565,n2=18349,LogPval=-0.042498
# m=18699,l=17521,n1=17524,n2=18684,LogPval=-0.001462
# m=365,l=348,n1=351,n2=357,LogPval=-0.035982
# m=27304,l=25722,n1=26087,n2=26148,LogPval=-0.076216
# m=8579,l=8171,n1=8188,n2=8406,LogPval=-0.054046
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=17421,l=15897,n1=16055,n2=16785,LogPval=-0.055160
# m=11533,l=10523,n1=10579,n2=11348,LogPval=-0.019370
# m=2794,l=2501,n1=2571,n2=2572,LogPval=-0.113339
# m=1082,l=992,n1=996,n2=1041,LogPval=-0.084004
# m=21772,l=20292,n1=20438,n2=21292,LogPval=-0.031744
# m=10631,l=9717,n1=9955,n2=10004,LogPval=-0.075379
# m=1289,l=1176,n1=1182,n2=1225,LogPval=-0.112103
# m=1056,l=950,n1=968,n2=962,LogPval=-0.183492
# m=1401,l=1231,n1=1342,n2=1235,LogPval=-0.081143
# m=9132,l=8465,n1=8471,n2=9100,LogPval=-0.006072
# m=342,l=331,n1=334,n2=335,LogPval=-0.036186
# m=5638,l=5221,n1=5258,n2=5501,LogPval=-0.036848
# m=19005,l=16602,n1=17764,n2=16814,LogPval=-0.101907
# m=7525,l=6914,n1=6918,n2=7508,LogPval=-0.003376
# m=3543,l=3281,n1=3285,n2=3518,LogPval=-0.013160
# m=364,l=350,n1=350,n2=360,LogPval=-0.037047
# m=1062,l=989,n1=995,n2=1034,LogPval=-0.048859
# m=4342,l=3977,n1=4006,n2=4098,LogPval=-0.126702
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=16565,l=15034,n1=15341,n2=15627,LogPval=-0.075756
# m=3352,l=3341,n1=3351,n2=3341,LogPval=-0.001706
# m=14547,l=13452,n1=13461,n2=14505,LogPval=-0.004595
# m=10295,l=9592,n1=9624,n2=10215,LogPval=-0.008087
# m=5560,l=5013,n1=5016,n2=5539,LogPval=-0.006331
# m=6718,l=6307,n1=6311,n2=6632,LogPval=-0.033315
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1409,l=1254,n1=1303,n2=1312,LogPval=-0.052207
# m=3461,l=3093,n1=3107,n2=3387,LogPval=-0.031525
# m=1736,l=1629,n1=1661,n2=1635,LogPval=-0.119542
# 52 m=1371,l=1249,n1=1276,n2=1313,LogPval=-0.037536
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1421,l=1279,n1=1322,n2=1337,LogPval=-0.045378
# m=1421,l=1320,n1=1322,n2=1409,LogPval=-0.016199
# m=1383,l=1287,n1=1287,n2=1383,LogPval=-0.000000
# m=1081,l=969,n1=999,n2=1024,LogPval=-0.035697
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1017,l=887,n1=949,n2=913,LogPval=-0.062332
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1421,l=1316,n1=1322,n2=1345,LogPval=-0.140366
# m=1408,l=1270,n1=1309,n2=1283,LogPval=-0.148887
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1419,l=1291,n1=1321,n2=1341,LogPval=-0.065569
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1385,l=1270,n1=1289,n2=1345,LogPval=-0.024363
# m=1321,l=1202,n1=1228,n2=1257,LogPval=-0.052504
# m=1413,l=1314,n1=1314,n2=1413,LogPval=-0.000000
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1044,l=939,n1=971,n2=980,LogPval=-0.049812
# m=1414,l=1296,n1=1315,n2=1366,LogPval=-0.036989
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1411,l=1243,n1=1312,n2=1290,LogPval=-0.054047
# m=1045,l=939,n1=976,n2=972,LogPval=-0.058902
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1055,l=964,n1=984,n2=1014,LogPval=-0.032649
# m=1421,l=1264,n1=1322,n2=1310,LogPval=-0.060065
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=647,l=588,n1=600,n2=620,LogPval=-0.039621
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1410,l=1210,n1=1313,n2=1247,LogPval=-0.057912
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=698,l=646,n1=655,n2=679,LogPval=-0.025717
# m=1410,l=1275,n1=1311,n2=1331,LogPval=-0.052388
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1037,l=905,n1=967,n2=931,LogPval=-0.065326
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=714,l=658,n1=658,n2=713,LogPval=-0.003565
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=317,l=297,n1=301,n2=307,LogPval=-0.043289
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1409,l=1254,n1=1312,n2=1303,LogPval=-0.052207
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 53 m=1332,l=1291,n1=1315,n2=1300,LogPval=-0.015636
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3500,l=3320,n1=3426,n2=3350,LogPval=-0.028197
# m=3457,l=3377,n1=3384,n2=3434,LogPval=-0.014802
# m=3446,l=3372,n1=3372,n2=3443,LogPval=-0.003355
# m=3522,l=3445,n1=3448,n2=3514,LogPval=-0.004396
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1036,l=1016,n1=1017,n2=1033,LogPval=-0.006726
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3490,l=3235,n1=3416,n2=3243,LogPval=-0.046057
# m=3495,l=3169,n1=3422,n2=3182,LogPval=-0.034113
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3462,l=3338,n1=3388,n2=3386,LogPval=-0.017078
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=984,l=943,n1=960,n2=956,LogPval=-0.027304
# m=3447,l=3301,n1=3379,n2=3335,LogPval=-0.022611
# m=2056,l=2017,n1=2018,n2=2053,LogPval=-0.003369
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3387,l=3087,n1=3318,n2=3103,LogPval=-0.030148
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3512,l=3432,n1=3438,n2=3496,LogPval=-0.008640
# m=3033,l=2967,n1=2972,n2=3018,LogPval=-0.010520
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3129,l=3054,n1=3061,n2=3111,LogPval=-0.010456
# m=3055,l=2815,n1=2984,n2=2836,LogPval=-0.032018
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2450,l=2405,n1=2407,n2=2441,LogPval=-0.010307
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=2371,l=2123,n1=2336,n2=2126,LogPval=-0.027854
# m=2089,l=2043,n1=2044,n2=2084,LogPval=-0.006652
# m=365,l=352,n1=356,n2=360,LogPval=-0.005979
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3525,l=3215,n1=3452,n2=3230,LogPval=-0.032785
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3454,l=3380,n1=3381,n2=3444,LogPval=-0.009534
# m=1328,l=1304,n1=1308,n2=1321,LogPval=-0.006956
# m=2661,l=2603,n1=2604,n2=2654,LogPval=-0.008042
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=3461,l=3093,n1=3387,n2=3107,LogPval=-0.031525
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# 54 m=1766,l=1663,n1=1663,n2=1764,LogPval=-0.003223
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1752,l=1652,n1=1653,n2=1749,LogPval=-0.002691
# m=1388,l=1307,n1=1307,n2=1385,LogPval=-0.006166
# m=1767,l=1664,n1=1664,n2=1763,LogPval=-0.006466
# m=1765,l=1659,n1=1662,n2=1753,LogPval=-0.011717
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1652,l=1570,n1=1571,n2=1644,LogPval=-0.011699
# m=1691,l=1563,n1=1595,n2=1569,LogPval=-0.153865
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1425,l=1324,n1=1337,n2=1342,LogPval=-0.140432
# m=1645,l=1517,n1=1551,n2=1562,LogPval=-0.062156
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1447,l=1348,n1=1365,n2=1379,LogPval=-0.089985
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1767,l=1663,n1=1664,n2=1762,LogPval=-0.005588
# m=1738,l=1638,n1=1639,n2=1734,LogPval=-0.004198
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1747,l=1639,n1=1644,n2=1733,LogPval=-0.010586
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1781,l=1677,n1=1678,n2=1774,LogPval=-0.008620
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1767,l=1663,n1=1665,n2=1758,LogPval=-0.009446
# m=1723,l=1614,n1=1621,n2=1698,LogPval=-0.023018
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1430,l=1265,n1=1348,n2=1269,LogPval=-0.123616
# m=1737,l=1633,n1=1634,n2=1734,LogPval=-0.002660
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1737,l=1625,n1=1634,n2=1720,LogPval=-0.007643
# m=1753,l=1516,n1=1650,n2=1518,LogPval=-0.123828
# m=1702,l=1604,n1=1605,n2=1700,LogPval=-0.001310
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1378,l=1314,n1=1321,n2=1362,LogPval=-0.014668
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1768,l=1664,n1=1665,n2=1762,LogPval=-0.007111
# m=1740,l=1635,n1=1640,n2=1727,LogPval=-0.009331
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1768,l=1664,n1=1665,n2=1761,LogPval=-0.008658
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=1736,l=1629,n1=1635,n2=1661,LogPval=-0.119542
# m=0,l=0,n1=0,n2=0,LogPval=nan
# m=0,l=0,n1=0,n2=0,LogPval=nan

# %%
print Pvals[:2,:2]
print Length[:2,:2]
print P_norm[:2,:2]
# Out:
# [[ 0.  0.]
#  [ 0.  0.]]
# [[   0.  693.]
#  [ 693.    0.]]
# [[-0.4  0. ]
#  [ 0.  -0.4]]

# %%
A=P_norm.flatten();
B=A[~isnan(A)]
print A.shape,B.shape
hist(-B,bins=100);
xlabel('significance')
# Out:
# (3025,) (1771,)

# %%
def showmat(mat):
    fig,axes=plt.subplots(1,1,figsize=(10,10))
    axes.imshow(mat, cmap=plt.cm.gray)

# %%
showmat(P_norm)

# %% [markdown]
# ### Finding structure in the rependency matrix.
# The matrix above shows, for each pair of stations, the normalized log probability that the overlap in rain days is random.
#
# We see immediately the first 8 stations are highly correlatedwith each other.
#
# To find more correlations we use SVD (the term PCA is reserved for decomposition of the covariance matrix). As we shall see that the top 10 eigenvectors explain about 80% of the square magnitude of the matrix.

# %%
print 'A group of very correlated stations is:',All.keys()[:8]
# Out:
# A group of very correlated stations is: [u'USC00094238', u'USC00098351', u'USW00093845', u'USC00093312', u'USC00094255', u'USC00094429', u'USC00092839', u'USC00095811']

# %%
from sklearn.decomposition import PCA
P_norm0 = np.nan_to_num(P_norm)
n_comp=10
pca = PCA(n_components=n_comp, svd_solver='full')
pca.fit(P_norm0)     
#print(pca.explained_variance_)
Var_explained=pca.explained_variance_ratio_
plot(insert(cumsum(Var_explained),0,0))
grid()

# %%
# we will look only at the top 4 eigenvectors.
n_comp=4
pca = PCA(n_components=n_comp, svd_solver='full')
pca.fit(P_norm0)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=4, random_state=None,
#   svd_solver='full', tol=0.0, whiten=False)

# %%
fig,axes=plt.subplots(1,4,figsize=(20,5),sharey='row');
L=list(pca.components_.transpose())
for i in range(4):
    X=sorted(L,key=lambda x:x[i]) 
    axes[i].plot(X);

# %%
def re_order_matrix(M,order):
    M_reord=M[order,:]
    M_reord=M_reord[:,order]
    return M_reord

# %%
fig,axes=plt.subplots(2,2,figsize=(15,15),sharex='col',sharey='row');
i=0
for r in range(2):
    for c in range(2):
        order=np.argsort(pca.components_[i,:])
        P_norm_reord=re_order_matrix(P_norm0,order)
        axes[r,c].matshow(P_norm_reord)
        i+=1

# %% [markdown]
# ### Explanation and possibe extensions
# When we reorder the rows and columns of the matrix using one of the eigenvectors, the grouping of the
# stations becomes more evident. For example, consider the upper left corner of the scond matrix (The upper left one). The stations at positions 0-22 are clearly strongly correlated with each other. Even though there are some stations, in positions 15-18 or so, which are more related to each other than to the rest of this block.
#
# This type of organization is called **Block Diagonal** and it typically reveals important structure such as grouping or clustering.
#
# You might want to extract the sets of stations that form blocks for your region, and then plot them on the map to see their spatial relationship.

# %%
from pickle import dump
with open(data_dir+'/PRCP_residuals_PCA.pickle','wb') as file:
    dump({'stations':All.keys(),
          'eigen-vecs':pca.components_},
        file)
