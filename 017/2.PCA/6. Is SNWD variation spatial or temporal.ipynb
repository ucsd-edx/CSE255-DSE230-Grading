# %%
import pandas as pd
import numpy as np
import urllib
import math

# %%
import findspark
findspark.init()

from pyspark import SparkContext
#sc.stop()
sc = SparkContext(master="local[3]",pyFiles=['lib/numpy_pack.py','lib/spark_PCA.py','lib/computeStats.py'])

from pyspark import SparkContext
from pyspark.sql import *
sqlContext = SQLContext(sc)

# %%
import sys
sys.path.append('./lib')

import numpy as np
from numpy_pack import packArray,unpackArray
from spark_PCA import computeCov
from computeStats import computeOverAllDist, STAT_Descriptions

# %%
### Read the data frame from pickle file

data_dir='../../Data/Weather'
file_index='BBBBBSBS'
meas='SNWD'

from pickle import load

#read statistics
filename=data_dir+'/STAT_%s.pickle'%file_index
STAT,STAT_Descriptions = load(open(filename,'rb'))
print('keys from STAT=',STAT.keys())

#!ls -ld $data_dir/*.parquet

#read data
filename=data_dir+'/decon_%s_%s.parquet'%(file_index,meas)

df=sqlContext.read.parquet(filename)
print(df.count())
df.show(2)
# Out:
# ('keys from STAT=', ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'SNWD', 'PRCP'])
# 942
# +------------------+------------------+-------------------+---------+--------+--------+---------+-----------+-------------------+-------------------+-------------------+-------------------+-----------+-----------+------+--------------------+------+
# |           coeff_1|           coeff_2|            coeff_3|elevation|   label|latitude|longitude|measurement|              res_1|              res_2|              res_3|           res_mean|    station|  total_var|undefs|              vector|  year|
# +------------------+------------------+-------------------+---------+--------+--------+---------+-----------+-------------------+-------------------+-------------------+-------------------+-----------+-----------+------+--------------------+------+
# |3255.9381788602113|-563.8355681800143|-189.58171068737818|    240.8|BBBBBSBS|    43.9|    -71.3|       SNWD|0.11881505172944894|0.09238976506184808|0.08940226690972031|  0.401594911279398|USC00278612|2.9956911E7|     0|[28 5B F0 5B 24 5...|1987.0|
# |3592.8010358972265| 445.0986680148509|  322.1319634557009|    170.7|BBBBBSBS|   43.55| -71.4667|       SNWD|0.11050954014927128| 0.0968578145866564| 0.0897072126970522|0.44486949738671505|USC00274475|3.2620635E7|     0|[5C 5C 5C 5C 90 5...|1952.0|
# +------------------+------------------+-------------------+---------+--------+--------+---------+-----------+-------------------+-------------------+-------------------+-------------------+-----------+-----------+------+--------------------+------+
# only showing top 2 rows

# %%
print df.columns
# Out:
# ['coeff_1', 'coeff_2', 'coeff_3', 'elevation', 'label', 'latitude', 'longitude', 'measurement', 'res_1', 'res_2', 'res_3', 'res_mean', 'station', 'total_var', 'undefs', 'vector', 'year']

# %%
#extract longitude and latitude for each station
#feature='coeff_1'
sqlContext.registerDataFrameAsTable(df,'weather')
#Features=', '.join(['coeff_1', 'coeff_2', 'coeff_3', 'elevation', 'latitude', 'longitude',\
#          'res_1', 'res_2', 'res_3', 'res_mean', 'year'])
Features='station, year, coeff_1'
Query="SELECT %s FROM weather"%Features
print(Query)
pdf = sqlContext.sql(Query).toPandas()
pdf.head()
# Out:
# SELECT station, year, coeff_1 FROM weather
#        station    year      coeff_1
# 0  USC00278612  1987.0  3255.938179
# 1  USC00274475  1952.0  3592.801036
# 2  USC00172238  2008.0  5527.301734
# 3  US1MECM0020  2011.0  2261.738234
# 4  USW00014611  1977.0  2183.016009

# %%
year_station_table=pdf.pivot(index='year', columns='station', values='coeff_1')
year_station_table.head(10)
# Out:
# station  US1MECM0007  US1MECM0018  US1MECM0020  US1MECM0023  US1NHBK0002  \
# year
# 1893.0           NaN          NaN          NaN          NaN          NaN
# 1894.0           NaN          NaN          NaN          NaN          NaN
# 1895.0           NaN          NaN          NaN          NaN          NaN
# 1896.0           NaN          NaN          NaN          NaN          NaN
# 1898.0           NaN          NaN          NaN          NaN          NaN
# 1901.0           NaN          NaN          NaN          NaN          NaN
# 1904.0           NaN          NaN          NaN          NaN          NaN
# 1905.0           NaN          NaN          NaN          NaN          NaN
# 1907.0           NaN          NaN          NaN          NaN          NaN
# 1909.0           NaN          NaN          NaN          NaN          NaN
#
# station  US1NHCR0001  US1NHMR0025  US1NHRC0018  USC00170409  USC00171131  \
# year
# 1893.0           NaN          NaN          NaN          NaN          NaN
# 1894.0           NaN          NaN          NaN          NaN          NaN
# 1895.0           NaN          NaN          NaN          NaN          NaN
# 1896.0           NaN          NaN          NaN          NaN          NaN
# 1898.0           NaN          NaN          NaN          NaN          NaN
# 1901.0           NaN          NaN          NaN          NaN          NaN
# 1904.0           NaN          NaN          NaN          NaN          NaN
# 1905.0           NaN          NaN          NaN          NaN          NaN
# 1907.0           NaN          NaN          NaN          NaN          NaN
# 1909.0           NaN          NaN          NaN          NaN          NaN
#
# station     ...       USC00279278  USC00279740  USC00279865  USC00279866  \
# year        ...
# 1893.0      ...               NaN          NaN          NaN          NaN
# 1894.0      ...               NaN          NaN          NaN          NaN
# 1895.0      ...               NaN          NaN          NaN          NaN
# 1896.0      ...               NaN          NaN          NaN          NaN
# 1898.0      ...               NaN          NaN          NaN          NaN
# 1901.0      ...               NaN          NaN          NaN          NaN
# 1904.0      ...               NaN          NaN          NaN          NaN
# 1905.0      ...               NaN          NaN          NaN          NaN
# 1907.0      ...               NaN          NaN          NaN          NaN
# 1909.0      ...               NaN          NaN          NaN          NaN
#
# station  USC00279903  USW00004743  USW00014611  USW00014710  USW00014745  \
# year
# 1893.0           NaN          NaN          NaN          NaN          NaN
# 1894.0           NaN          NaN          NaN          NaN          NaN
# 1895.0           NaN          NaN          NaN          NaN          NaN
# 1896.0           NaN          NaN          NaN          NaN          NaN
# 1898.0           NaN          NaN          NaN          NaN          NaN
# 1901.0           NaN          NaN          NaN          NaN          NaN
# 1904.0           NaN          NaN          NaN          NaN          NaN
# 1905.0           NaN          NaN          NaN          NaN          NaN
# 1907.0           NaN          NaN          NaN          NaN          NaN
# 1909.0           NaN          NaN          NaN          NaN          NaN
#
# station  USW00014764
# year
# 1893.0           NaN
# 1894.0           NaN
# 1895.0           NaN
# 1896.0           NaN
# 1898.0           NaN
# 1901.0           NaN
# 1904.0           NaN
# 1905.0           NaN
# 1907.0           NaN
# 1909.0           NaN
#
# [10 rows x 86 columns]

# %%
def RMS(Mat):
    return np.sqrt(np.nanmean(Mat**2))

mean_by_year=np.nanmean(year_station_table,axis=1)
mean_by_station=np.nanmean(year_station_table,axis=0)
tbl_minus_year = (year_station_table.transpose()-mean_by_year).transpose()
tbl_minus_station = year_station_table-mean_by_station

print 'total RMS                   = ',RMS(year_station_table)
print 'RMS removing mean-by-station= ',RMS(tbl_minus_station)
print 'RMS removing mean-by-year   = ',RMS(tbl_minus_year)
# Out:
# total RMS                   =  1857.21540069
# RMS removing mean-by-station=  1394.96185094
# RMS removing mean-by-year   =  1340.12426857

# %%
#extract longitude and latitude for each station
#feature='coeff_1'
sqlContext.registerDataFrameAsTable(df,'weather')
#Features=', '.join(['coeff_1', 'coeff_2', 'coeff_3', 'elevation', 'latitude', 'longitude',\
#          'res_1', 'res_2', 'res_3', 'res_mean', 'year'])
Features='station, year, coeff_2'
Query="SELECT %s FROM weather"%Features
print(Query)
pdf = sqlContext.sql(Query).toPandas()
pdf.head()
# Out:
# SELECT station, year, coeff_2 FROM weather
#        station    year      coeff_2
# 0  USC00278612  1987.0  -563.835568
# 1  USC00274475  1952.0   445.098668
# 2  USC00172238  2008.0   747.125849
# 3  US1MECM0020  2011.0  -356.664645
# 4  USW00014611  1977.0 -3251.645166

# %%
year_station_table=pdf.pivot(index='year', columns='station', values='coeff_2')
year_station_table.head(10)
# Out:
# station  US1MECM0007  US1MECM0018  US1MECM0020  US1MECM0023  US1NHBK0002  \
# year
# 1893.0           NaN          NaN          NaN          NaN          NaN
# 1894.0           NaN          NaN          NaN          NaN          NaN
# 1895.0           NaN          NaN          NaN          NaN          NaN
# 1896.0           NaN          NaN          NaN          NaN          NaN
# 1898.0           NaN          NaN          NaN          NaN          NaN
# 1901.0           NaN          NaN          NaN          NaN          NaN
# 1904.0           NaN          NaN          NaN          NaN          NaN
# 1905.0           NaN          NaN          NaN          NaN          NaN
# 1907.0           NaN          NaN          NaN          NaN          NaN
# 1909.0           NaN          NaN          NaN          NaN          NaN
#
# station  US1NHCR0001  US1NHMR0025  US1NHRC0018  USC00170409  USC00171131  \
# year
# 1893.0           NaN          NaN          NaN          NaN          NaN
# 1894.0           NaN          NaN          NaN          NaN          NaN
# 1895.0           NaN          NaN          NaN          NaN          NaN
# 1896.0           NaN          NaN          NaN          NaN          NaN
# 1898.0           NaN          NaN          NaN          NaN          NaN
# 1901.0           NaN          NaN          NaN          NaN          NaN
# 1904.0           NaN          NaN          NaN          NaN          NaN
# 1905.0           NaN          NaN          NaN          NaN          NaN
# 1907.0           NaN          NaN          NaN          NaN          NaN
# 1909.0           NaN          NaN          NaN          NaN          NaN
#
# station     ...       USC00279278  USC00279740  USC00279865  USC00279866  \
# year        ...
# 1893.0      ...               NaN          NaN          NaN          NaN
# 1894.0      ...               NaN          NaN          NaN          NaN
# 1895.0      ...               NaN          NaN          NaN          NaN
# 1896.0      ...               NaN          NaN          NaN          NaN
# 1898.0      ...               NaN          NaN          NaN          NaN
# 1901.0      ...               NaN          NaN          NaN          NaN
# 1904.0      ...               NaN          NaN          NaN          NaN
# 1905.0      ...               NaN          NaN          NaN          NaN
# 1907.0      ...               NaN          NaN          NaN          NaN
# 1909.0      ...               NaN          NaN          NaN          NaN
#
# station  USC00279903  USW00004743  USW00014611  USW00014710  USW00014745  \
# year
# 1893.0           NaN          NaN          NaN          NaN          NaN
# 1894.0           NaN          NaN          NaN          NaN          NaN
# 1895.0           NaN          NaN          NaN          NaN          NaN
# 1896.0           NaN          NaN          NaN          NaN          NaN
# 1898.0           NaN          NaN          NaN          NaN          NaN
# 1901.0           NaN          NaN          NaN          NaN          NaN
# 1904.0           NaN          NaN          NaN          NaN          NaN
# 1905.0           NaN          NaN          NaN          NaN          NaN
# 1907.0           NaN          NaN          NaN          NaN          NaN
# 1909.0           NaN          NaN          NaN          NaN          NaN
#
# station  USW00014764
# year
# 1893.0           NaN
# 1894.0           NaN
# 1895.0           NaN
# 1896.0           NaN
# 1898.0           NaN
# 1901.0           NaN
# 1904.0           NaN
# 1905.0           NaN
# 1907.0           NaN
# 1909.0           NaN
#
# [10 rows x 86 columns]

# %%
def RMS(Mat):
    return np.sqrt(np.nanmean(Mat**2))

mean_by_year=np.nanmean(year_station_table,axis=1)
mean_by_station=np.nanmean(year_station_table,axis=0)
tbl_minus_year = (year_station_table.transpose()-mean_by_year).transpose()
tbl_minus_station = year_station_table-mean_by_station

print 'total RMS                   = ',RMS(year_station_table)
print 'RMS removing mean-by-station= ',RMS(tbl_minus_station)
print 'RMS removing mean-by-year   = ',RMS(tbl_minus_year)
# Out:
# total RMS                   =  978.569620587
# RMS removing mean-by-station=  930.754194373
# RMS removing mean-by-year   =  493.268247967

# %%
#extract longitude and latitude for each station
#feature='coeff_1'
sqlContext.registerDataFrameAsTable(df,'weather')
#Features=', '.join(['coeff_1', 'coeff_2', 'coeff_3', 'elevation', 'latitude', 'longitude',\
#          'res_1', 'res_2', 'res_3', 'res_mean', 'year'])
Features='station, year, coeff_3'
Query="SELECT %s FROM weather"%Features
print(Query)
pdf = sqlContext.sql(Query).toPandas()
pdf.head()
# Out:
# SELECT station, year, coeff_3 FROM weather
#        station    year     coeff_3
# 0  USC00278612  1987.0 -189.581711
# 1  USC00274475  1952.0  322.131963
# 2  USC00172238  2008.0  626.165623
# 3  US1MECM0020  2011.0 -918.521359
# 4  USW00014611  1977.0  811.238039

# %%
year_station_table=pdf.pivot(index='year', columns='station', values='coeff_3')
year_station_table.head(10)
# Out:
# station  US1MECM0007  US1MECM0018  US1MECM0020  US1MECM0023  US1NHBK0002  \
# year
# 1893.0           NaN          NaN          NaN          NaN          NaN
# 1894.0           NaN          NaN          NaN          NaN          NaN
# 1895.0           NaN          NaN          NaN          NaN          NaN
# 1896.0           NaN          NaN          NaN          NaN          NaN
# 1898.0           NaN          NaN          NaN          NaN          NaN
# 1901.0           NaN          NaN          NaN          NaN          NaN
# 1904.0           NaN          NaN          NaN          NaN          NaN
# 1905.0           NaN          NaN          NaN          NaN          NaN
# 1907.0           NaN          NaN          NaN          NaN          NaN
# 1909.0           NaN          NaN          NaN          NaN          NaN
#
# station  US1NHCR0001  US1NHMR0025  US1NHRC0018  USC00170409  USC00171131  \
# year
# 1893.0           NaN          NaN          NaN          NaN          NaN
# 1894.0           NaN          NaN          NaN          NaN          NaN
# 1895.0           NaN          NaN          NaN          NaN          NaN
# 1896.0           NaN          NaN          NaN          NaN          NaN
# 1898.0           NaN          NaN          NaN          NaN          NaN
# 1901.0           NaN          NaN          NaN          NaN          NaN
# 1904.0           NaN          NaN          NaN          NaN          NaN
# 1905.0           NaN          NaN          NaN          NaN          NaN
# 1907.0           NaN          NaN          NaN          NaN          NaN
# 1909.0           NaN          NaN          NaN          NaN          NaN
#
# station     ...       USC00279278  USC00279740  USC00279865  USC00279866  \
# year        ...
# 1893.0      ...               NaN          NaN          NaN          NaN
# 1894.0      ...               NaN          NaN          NaN          NaN
# 1895.0      ...               NaN          NaN          NaN          NaN
# 1896.0      ...               NaN          NaN          NaN          NaN
# 1898.0      ...               NaN          NaN          NaN          NaN
# 1901.0      ...               NaN          NaN          NaN          NaN
# 1904.0      ...               NaN          NaN          NaN          NaN
# 1905.0      ...               NaN          NaN          NaN          NaN
# 1907.0      ...               NaN          NaN          NaN          NaN
# 1909.0      ...               NaN          NaN          NaN          NaN
#
# station  USC00279903  USW00004743  USW00014611  USW00014710  USW00014745  \
# year
# 1893.0           NaN          NaN          NaN          NaN          NaN
# 1894.0           NaN          NaN          NaN          NaN          NaN
# 1895.0           NaN          NaN          NaN          NaN          NaN
# 1896.0           NaN          NaN          NaN          NaN          NaN
# 1898.0           NaN          NaN          NaN          NaN          NaN
# 1901.0           NaN          NaN          NaN          NaN          NaN
# 1904.0           NaN          NaN          NaN          NaN          NaN
# 1905.0           NaN          NaN          NaN          NaN          NaN
# 1907.0           NaN          NaN          NaN          NaN          NaN
# 1909.0           NaN          NaN          NaN          NaN          NaN
#
# station  USW00014764
# year
# 1893.0           NaN
# 1894.0           NaN
# 1895.0           NaN
# 1896.0           NaN
# 1898.0           NaN
# 1901.0           NaN
# 1904.0           NaN
# 1905.0           NaN
# 1907.0           NaN
# 1909.0           NaN
#
# [10 rows x 86 columns]

# %%
def RMS(Mat):
    return np.sqrt(np.nanmean(Mat**2))

mean_by_year=np.nanmean(year_station_table,axis=1)
mean_by_station=np.nanmean(year_station_table,axis=0)
tbl_minus_year = (year_station_table.transpose()-mean_by_year).transpose()
tbl_minus_station = year_station_table-mean_by_station

print 'total RMS                   = ',RMS(year_station_table)
print 'RMS removing mean-by-station= ',RMS(tbl_minus_station)
print 'RMS removing mean-by-year   = ',RMS(tbl_minus_year)
# Out:
# total RMS                   =  634.164702073
# RMS removing mean-by-station=  594.297547809
# RMS removing mean-by-year   =  301.323808032

# %%
T=year_station_table
print 'initial RMS=',RMS(T)
for i in range(5):
    mean_by_station=np.nanmean(T,axis=0)
    T=T-mean_by_station
    print i,'after removing mean by stations=',RMS(T)
    
    mean_by_year=np.nanmean(T,axis=1)
    T=(T.transpose()-mean_by_year).transpose()
    print i,'after removing mean by year    =',RMS(T)
# Out:
# initial RMS= 634.164702073
# 0 after removing mean by stations= 594.297547809
# 0 after removing mean by year    = 312.847530295
# 1 after removing mean by stations= 287.614364575
# 1 after removing mean by year    = 283.053073485
# 2 after removing mean by stations= 281.543864886
# 2 after removing mean by year    = 280.799613567
# 3 after removing mean by stations= 280.357624452
# 3 after removing mean by year    = 280.072015968
# 4 after removing mean by stations= 279.878457484
# 4 after removing mean by year    = 279.74277643
