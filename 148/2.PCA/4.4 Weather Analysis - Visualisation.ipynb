0|SSSSBSBB|
# |   1478.3| 33.2367|-107.2681|       TMAX|USW00093045|     4|[00 58 50 57 00 5...|2012.0|SSSSBSBB|
# |   2114.4|   33.35|-105.6667|       TMAX|USC00297651|     0|[00 4F A0 53 40 5...|1988.0|SSSSBSBB|
# |   2114.4|   33.35|-105.6667|       TMAX|USC00297651|     0|[50 57 A0 56 50 5...|1989.0|SSSSBSBB|
# |   2114.4|   33.35|-105.6667|       TMAX|USC00297651|     0|[30 55 00 53 20 5...|1990.0|SSSSBSBB|
# |   2114.4|   33.35|-105.6667|       TMAX|USC00297651|     0|[E0 58 E0 58 58 5...|1991.0|SSSSBSBB|
# |   2114.4|   33.35|-105.6667|       TMAX|USC00297651|     0|[00 53 F0 56 30 5...|1992.0|SSSSBSBB|
# |   1250.9| 32.6242|-107.0418|       PRCP|US1NMDA0041|     1|[00 00 00 00 00 0...|2006.0|SSSSBSBB|
# |   1250.9| 32.6242|-107.0418|       PRCP|US1NMDA0041|     0|[00 00 00 00 00 0...|2007.0|SSSSBSBB|
# |   1250.9| 32.6242|-107.0418|       PRCP|US1NMDA0041|     9|[00 00 00 00 00 0...|2008.0|SSSSBSBB|
# |   1250.9| 32.6242|-107.0418|       PRCP|US1NMDA0041|     7|[00 00 00 00 00 0...|2009.0|SSSSBSBB|
# |   1250.9| 32.6242|-107.0418|       PRCP|US1NMDA0041|     0|[00 00 00 00 00 0...|2010.0|SSSSBSBB|
# |   1250.9| 32.6242|-107.0418|       PRCP|US1NMDA0041|     1|[00 00 00 00 00 0...|2011.0|SSSSBSBB|
# |   1250.9| 32.6242|-107.0418|       PRCP|US1NMDA0041|     2|[00 00 00 00 00 0...|2012.0|SSSSBSBB|
# |   1935.5|    33.0|-108.0833|       TMIN|USC00293615|    24|[30 D4 30 D4 00 D...|1915.0|SSSSBSBB|
# |   1478.3| 33.2367|-107.2681|       TMIN|USW00093045|     0|[00 C6 20 D0 00 D...|1951.0|SSSSBSBB|
# |   1478.3| 33.2367|-107.2681|       TMIN|USW00093045|     0|[80 C9 80 D1 80 D...|1952.0|SSSSBSBB|
# |   1478.3| 33.2367|-107.2681|       TMIN|USW00093045|     0|[80 C9 40 CC 00 D...|1953.0|SSSSBSBB|
# |   1478.3| 33.2367|-107.2681|       TMIN|USW00093045|     0|[E0 D5 80 D4 00 D...|1954.0|SSSSBSBB|
# |   1478.3| 33.2367|-107.2681|       TMIN|USW00093045|     0|[00 D3 80 CD 40 5...|1955.0|SSSSBSBB|
# |   1478.3| 33.2367|-107.2681|       TMIN|USW00093045|     0|[00 CF 80 CD E0 D...|1956.0|SSSSBSBB|
# |   1478.3| 33.2367|-107.2681|       TMIN|USW00093045|     1|[40 4C 00 46 00 4...|1957.0|SSSSBSBB|
# |   1478.3| 33.2367|-107.2681|       TMIN|USW00093045|     0|[30 D5 30 D4 40 D...|1958.0|SSSSBSBB|
# |   1478.3| 33.2367|-107.2681|       TMIN|USW00093045|     0|[E0 D5 80 D1 80 C...|1959.0|SSSSBSBB|
# +---------+--------+---------+-----------+-----------+------+--------------------+------+--------+
# only showing top 100 rows

# %% [markdown]
# ### Select data for a particular station and measurement type

# %%
sqlContext.registerDataFrameAsTable(df,'weather')
Query="SELECT * FROM weather\n\tWHERE measurement='%s' and station='%s'"%('PRCP','USC00293533')
#USC00198301
print Query
df1 = sqlContext.sql(Query)
print df1.count(),'rows'
df1.show(2)
rows=df1.rdd.map(lambda row:unpackArray(row['vector'],np.float16)).collect()
T=np.vstack(rows)
T=T/10.  # scaling to make the temperature be in centingrates
shape(T)
# Out:
# SELECT * FROM weather
# 	WHERE measurement='PRCP' and station='USC00293533'
# 8 rows
# +---------+--------+---------+-----------+-----------+------+--------------------+------+--------+
# |elevation|latitude|longitude|measurement|    station|undefs|              vector|  year|   label|
# +---------+--------+---------+-----------+-----------+------+--------------------+------+--------+
# |   1972.1| 32.8333|-108.1333|       PRCP|USC00293533|     1|[00 00 00 00 00 0...|1911.0|SSSSBSBB|
# |   1972.1| 32.8333|-108.1333|       PRCP|USC00293533|     5|[00 00 00 00 00 0...|1912.0|SSSSBSBB|
# +---------+--------+---------+-----------+-----------+------+--------------------+------+--------+
# only showing top 2 rows
# (8, 365)

# %% [markdown]
# ### Script for plotting yearly plots

# %%
from YearPlotter import YearPlotter
fig, ax = plt.subplots(figsize=(10,7));
YP=YearPlotter()
YP.plot(T[:2,:].transpose(),fig,ax,title='PRCP')
#title('A sample of graphs');

# %% [markdown]
# ### Distribution of missing observations
# The distribution of missing observations is not uniform throughout the year. We visualize it below.

# %%
#import pandas.rpy.common as com
import seaborn as sns
# %matplotlib inline

measurements = STAT.keys()
dict_mean = {}
for meas in measurements:
    dict_mean[meas]=STAT[meas]['Mean']
corr_df = pd.DataFrame(dict_mean)

correlation_mat = corr_df.corr('kendall')

#plot the heatmap
sns.heatmap(correlation_mat, 
        xticklabels=['TMIN', 'TOBS', 'TMAX', 'SNOW', 'SNWD', 'PRCP'],
        yticklabels=['TMIN', 'TOBS', 'TMAX', 'SNOW', 'SNWD', 'PRCP'])

# %%
STAT_Descriptions
# Out:
# [('SortedVals',
#   'Sample of values',
#   'vector whose length varies between measurements'),
#  ('UnDef',
#   'sample of number of undefs per row',
#   'vector whose length varies between measurements'),
#  ('mean', 'mean value', ()),
#  ('std', 'std', ()),
#  ('low100', 'bottom 1%', ()),
#  ('high100', 'top 1%', ()),
#  ('low1000', 'bottom 0.1%', ()),
#  ('high1000', 'top 0.1%', ()),
#  ('E', 'Sum of values per day', (365,)),
#  ('NE', 'count of values per day', (365,)),
#  ('Mean', 'E/NE', (365,)),
#  ('O', 'Sum of outer products', (365, 365)),
#  ('NO', 'counts for outer products', (365, 365)),
#  ('Cov', 'O/NO', (365, 365)),
#  ('Var', 'The variance per day = diagonal of Cov', (365,)),
#  ('eigval', 'PCA eigen-values', (365,)),
#  ('eigvec', 'PCA eigen-vectors', (365, 365))]

# %%
def plot_pair(pair,func):
    j=0
    fig,X=subplots(1,3,figsize=(16,6))
    axes=X.reshape(3)
    for m in pair:
        axis = axes[j]
        j+=1
        func(m,fig,axis)
        
def plot_valid(m,fig,axis):
    valid_m=STAT[m]['NE']
    YP.plot(valid_m,fig,axis,title='valid-counts '+m)

# %%
plot_pair(['TMIN','TMAX','TOBS'],plot_valid)

# %%
plot_pair(['SNOW','SNWD','PRCP'],plot_valid)

# %%
plot_pair(['SNOW', 'SNWD'],plot_valid)

# %% [markdown]
# ### Plots of mean and std of observations

# %%
#Manually Divide by 10 for TMIN,TMAX,TOBS,PRCP 
def plot_mean_std(m,fig,axis):
    mean=STAT[m]['Mean']#/10.0
    std=np.sqrt(STAT[m]['Var'])#/10.0  
    graphs=np.vstack([mean-std,mean,mean+std]).transpose()
    YP.plot(graphs,fig,axis,title='Mean+-std '+m+' in mm')

# %%
plot_pair(['TMIN','TMAX'],plot_mean_std)

# %%
plot_pair(['TOBS','PRCP'],plot_mean_std)

# %%
plot_pair(['SNOW', 'SNWD'],plot_mean_std)

# %% [markdown]
# ### plotting top 3 eigenvectors

# %%
def plot_eigen(m,fig,axis):
    EV=STAT[m]['eigvec']
    YP.plot(EV[:,:3],fig,axis,title='Top Eigenvectors '+m)

# %%
plot_pair(['TMIN','TMAX'],plot_eigen)

# %%
plot_pair(['TOBS','PRCP'],plot_eigen)

# %%
plot_pair(['SNOW', 'SNWD'],plot_eigen)

# %% [markdown]
# ### Script for plotting percentage of variance explained

# %%
def pltVarExplained(j):
    subplot(1,3,j)
    EV=STAT[m]['eigval']
    k=10
    plot(([0,]+list(cumsum(EV[:k])))/sum(EV))
    title('Percentage of Variance Explained for '+ m)
    ylabel('Percentage of Variance')
    xlabel('# Eigenvector')
    grid()

# %%
f=plt.figure(figsize=(15,4))
j=1
for m in ['TMIN', 'TMAX', 'TOBS']: #,
    pltVarExplained(j)
    j+=1

# %%
f=plt.figure(figsize=(15,4))
j=1
for m in ['SNOW', 'SNWD', 'PRCP']:
    pltVarExplained(j)
    j+=1
