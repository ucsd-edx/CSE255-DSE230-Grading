# %%
import pickle

# %%
f = open("hw3.pkl",'r')
thePickle = pickle.load(f)
datasets = thePickle["pca"]
answers  = thePickle["pca_correct"]
f.close()

# %%
answers
# Out:
# [{'Cov': array([[  7.91839805e-01,  -1.56895646e-02,  -3.94775805e-01,
#             4.51249590e-01,  -5.60284020e-01,  -6.30514812e-02,
#            -1.68899783e-01,  -2.91810336e-01,  -5.64239542e-01,
#             1.05594273e+00],
#          [ -1.56895646e-02,   3.10874037e-04,   4.89021944e-03,
#             1.34167502e-01,  -5.12897658e-03,  -3.17390134e-01,
#             6.56611101e-03,   6.75567824e-03,  -2.85890101e-01,
#             1.43786709e-01],
#          [ -3.94775805e-01,   4.89021944e-03,   1.29514086e-01,
#            -8.27040078e-02,   1.80407303e-01,  -5.13288358e-02,
#             5.66731359e-02,   9.66203363e-02,   7.70841528e-02,
#            -2.24940912e-01],
#          [  4.51249590e-01,   1.34167502e-01,  -8.27040078e-02,
#             4.46724353e-02,  -1.25950151e-01,  -9.94657259e-02,
#            -3.22060779e-02,  -5.89021614e-02,  -3.66669765e-01,
#             2.67964568e-02],
#          [ -5.60284020e-01,  -5.12897658e-03,   1.80407303e-01,
# ...
