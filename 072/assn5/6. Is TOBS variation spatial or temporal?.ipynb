# %% [markdown]
# ## Analyze whether TOBS varies more from year to year or from place to place.

# %%
import pandas as pd
import numpy as np
import urllib
import math

# %%
import findspark
findspark.init()

from pyspark import SparkContext
#sc.stop()
sc = SparkContext(master="local[3]",pyFiles=['lib/numpy_pack.py','lib/computeStats.py'])

from pyspark import SparkContext
from pyspark.sql import *
sqlContext = SQLContext(sc)

# %%
import sys
sys.path.append('./lib')

import numpy as np
from numpy_pack import packArray,unpackArray
from spark_PCA import computeCov
from computeStats import computeOverAllDist, STAT_Descriptions

# %%
### Read the data frame from pickle file

data_dir='../../Data/Weather'
file_index='SSSBSBBS'
meas='TOBS'

from pickle import load

#read statistics
filename=data_dir+'/STAT_%s.pickle'%file_index
STAT,STAT_Descriptions = load(open(filename,'rb'))
print('keys from STAT=',STAT.keys())

#!ls -ld $data_dir/*.parquet

#read data
filename=data_dir+'/decon_%s_%s.parquet'%(file_index,meas)

df=sqlContext.read.parquet(filename)
print(df.count())
df.show(2)
# Out:
# ('keys from STAT=', ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'SNWD', 'PRCP'])
# 1153
# +-----------------+-------------------+------------------+------------------+---------+--------+--------+---------+-----------+------------------+------------------+------------------+------------------+-------------------+-----------+---------+------+--------------------+------+
# |          coeff_1|            coeff_2|           coeff_3|           coeff_4|elevation|   label|latitude|longitude|measurement|             res_1|             res_2|             res_3|             res_4|           res_mean|    station|total_var|undefs|              vector|  year|
# +-----------------+-------------------+------------------+------------------+---------+--------+--------+---------+-----------+------------------+------------------+------------------+------------------+-------------------+-----------+---------+------+--------------------+------+
# | 342.831876618672|-26.442661519346114|226.25557198334317|274.79466664829454|   1958.0|SSSBSBBS| 38.3167|-119.2167|       TOBS|0.8602356816724522|0.8594042161405948|0.7985301256655747|0.7087354641578999|0.14799106735601994|USC00041075|5682384.0|     0|[80 CD 30 D4 30 D...|1932.0|
# |175.4212323342672| 113.09888712816002| 310.7630547094186|276.02865593520744|   1958.0|SSSBSBBS| 38.3167|-119.2167|       TOBS|0.9620865547728319|0.9463269399472365|0.8273431771062385|0.7334709163678639|0.12835631786866133|USC00041075|6323446.0|     0|[80 C9 20 50 E0 5...|1933.0|
# +-----------------+-------------------+------------------+------------------+---------+--------+--------+---------+-----------+------------------+------------------+------------------+------------------+-------------------+-----------+---------+------+--------------------+------+
# only showing top 2 rows

# %%
print df.columns
# Out:
# ['coeff_1', 'coeff_2', 'coeff_3', 'coeff_4', 'elevation', 'label', 'latitude', 'longitude', 'measurement', 'res_1', 'res_2', 'res_3', 'res_4', 'res_mean', 'station', 'total_var', 'undefs', 'vector', 'year']

# %%
def getPDF(coeff_index):
    #extract longitude and latitude for each station
    sqlContext.registerDataFrameAsTable(df,'weather')
    #Features=', '.join(['coeff_1', 'coeff_2', 'coeff_3', 'elevation', 'latitude', 'longitude',\
    #          'res_1', 'res_2', 'res_3', 'res_mean', 'year'])
    Features='station, year, coeff_%d'%coeff_index
    Query="SELECT %s FROM weather"%Features
    print(Query)
    pdf = sqlContext.sql(Query).toPandas()
    return pdf
pdf = getPDF(1)
# Out:
# SELECT station, year, coeff_1 FROM weather

# %%
def getYearStationTable(coeff_index):
    pdf = getPDF(coeff_index)
    year_station_table=pdf.pivot(index='year', columns='station', values='coeff_%d'%coeff_index)
    return year_station_table
year_station_table = getYearStationTable(1)
year_station_table.head(10)
# Out:
# SELECT station, year, coeff_1 FROM weather
# station  USC00040943  USC00041072  USC00041075  USC00041277  USC00041428  \
# year
# 1901.0    974.119573          NaN          NaN          NaN          NaN
# 1902.0    970.617070          NaN          NaN          NaN          NaN
# 1903.0           NaN          NaN          NaN          NaN          NaN
# 1904.0           NaN          NaN          NaN          NaN          NaN
# 1905.0           NaN          NaN          NaN          NaN          NaN
# 1907.0           NaN          NaN          NaN          NaN          NaN
# 1908.0           NaN          NaN          NaN          NaN          NaN
# 1909.0           NaN          NaN          NaN          NaN          NaN
# 1910.0           NaN          NaN          NaN          NaN          NaN
# 1911.0           NaN          NaN          NaN          NaN          NaN
#
# station  USC00041909  USC00041911  USC00042671  USC00042728  USC00043381  \
# year
# 1901.0           NaN          NaN          NaN          NaN          NaN
# 1902.0           NaN          NaN          NaN          NaN  -557.470773
# 1903.0           NaN          NaN          NaN          NaN  -632.832147
# 1904.0           NaN          NaN          NaN          NaN  -728.389708
# 1905.0           NaN          NaN          NaN          NaN  -536.745885
# 1907.0           NaN          NaN          NaN          NaN          NaN
# 1908.0           NaN          NaN          NaN          NaN          NaN
# 1909.0           NaN          NaN          NaN          NaN          NaN
# 1910.0           NaN          NaN          NaN          NaN          NaN
# 1911.0           NaN          NaN          NaN          NaN  -510.745833
#
# station     ...       USC00268202  USC00268475  USC00268822  USC00268977  \
# year        ...
# 1901.0      ...               NaN  -137.680515          NaN          NaN
# 1902.0      ...               NaN          NaN          NaN          NaN
# 1903.0      ...               NaN          NaN          NaN          NaN
# 1904.0      ...               NaN          NaN          NaN          NaN
# 1905.0      ...               NaN          NaN          NaN          NaN
# 1907.0      ...               NaN          NaN          NaN          NaN
# 1908.0      ...               NaN          NaN          NaN          NaN
# 1909.0      ...               NaN          NaN          NaN          NaN
# 1910.0      ...               NaN          NaN          NaN          NaN
# 1911.0      ...               NaN          NaN          NaN          NaN
#
# station  USC00269137  USC00269229  USS0019L39S  USS0020L02S  USS0020L06S  \
# year
# 1901.0           NaN          NaN          NaN          NaN          NaN
# 1902.0           NaN          NaN          NaN          NaN          NaN
# 1903.0           NaN          NaN          NaN          NaN          NaN
# 1904.0           NaN          NaN          NaN          NaN          NaN
# 1905.0           NaN          NaN          NaN          NaN          NaN
# 1907.0           NaN          NaN          NaN          NaN          NaN
# 1908.0           NaN          NaN          NaN          NaN          NaN
# 1909.0           NaN          NaN          NaN          NaN          NaN
# 1910.0           NaN          NaN          NaN          NaN          NaN
# 1911.0           NaN          NaN          NaN          NaN          NaN
#
# station  USW00093230
# year
# 1901.0           NaN
# 1902.0           NaN
# 1903.0           NaN
# 1904.0           NaN
# 1905.0           NaN
# 1907.0           NaN
# 1908.0           NaN
# 1909.0           NaN
# 1910.0           NaN
# 1911.0           NaN
#
# [10 rows x 57 columns]

# %% [markdown]
# ### Estimating the effect of the year vs the effect of the station
#
# To estimate the effect of time vs. location on the first eigenvector coefficient we
# compute:
#
# * The average row: `mean-by-station`
# * The average column: `mean-by-year`
#
# We then compute the RMS before and after subtracting either  the row or the column vector.

# %%
def estimateEffect(coeff_index):
    year_station_table = getYearStationTable(coeff_index)
    def RMS(Mat):
        return np.sqrt(np.nanmean(Mat**2))

    def MS(Mat):
        return np.nanmean(Mat**2)
    
    mean_by_year=np.nanmean(year_station_table,axis=1)
    mean_by_station=np.nanmean(year_station_table,axis=0)
    
    tbl_minus_year = year_station_table
    tbl_minus_station = year_station_table
    #for i in range(coeff_index):
    #    print "Minus %d"%i
    tbl_minus_year = (tbl_minus_year.transpose()-mean_by_year).transpose()
    tbl_minus_station = tbl_minus_station-mean_by_station

    print 'total RMS                   = %.2f'%RMS(year_station_table)
    print 'RMS removing mean-by-station= %.2f'%RMS(tbl_minus_station)
    print 'RMS removing mean-by-year   = %.2f'%RMS(tbl_minus_year)
    print '----------------------------------------------------'
    print 'total MS                   = %.2f'%MS(year_station_table)
    ms0 = MS(year_station_table)
    print 'MS removing mean-by-station= %.2f'%MS(tbl_minus_station)
    ms1 = MS(tbl_minus_station)
    print 'fraction explained = %.1f'%(100.-100.*ms1/ms0)
    print 'MS removing mean-by-year   = %.2f'%MS(tbl_minus_year)
    ms2 = MS(tbl_minus_year)
    print 'fraction explained = %.1f'%(100.-100.*ms2/ms0)
    print '----------------------------------------------------'

# %%
top_num_coeff = 4
for i in range(top_num_coeff):
    estimateEffect(i+1)
# Out:
# SELECT station, year, coeff_1 FROM weather
# total RMS                   = 926.86
# RMS removing mean-by-station= 353.94
# RMS removing mean-by-year   = 826.90
# ----------------------------------------------------
# total MS                   = 859066.97
# MS removing mean-by-station= 125272.32
# fraction explained = 85.4
# MS removing mean-by-year   = 683771.38
# fraction explained = 20.4
# ----------------------------------------------------
# SELECT station, year, coeff_2 FROM weather
# total RMS                   = 260.27
# RMS removing mean-by-station= 171.03
# RMS removing mean-by-year   = 219.71
# ----------------------------------------------------
# total MS                   = 67742.33
# MS removing mean-by-station= 29251.84
# fraction explained = 56.8
# MS removing mean-by-year   = 48273.36
# fraction explained = 28.7
# ----------------------------------------------------
# SELECT station, year, coeff_3 FROM weather
# total RMS                   = 199.75
# RMS removing mean-by-station= 162.84
# RMS removing mean-by-year   = 153.25
# ----------------------------------------------------
# total MS                   = 39900.90
# MS removing mean-by-station= 26517.29
# fraction explained = 33.5
# MS removing mean-by-year   = 23484.10
# fraction explained = 41.1
# ----------------------------------------------------
# SELECT station, year, coeff_4 FROM weather
# total RMS                   = 162.59
# RMS removing mean-by-station= 157.29
# RMS removing mean-by-year   = 84.68
# ----------------------------------------------------
# total MS                   = 26434.85
# MS removing mean-by-station= 24739.02
# fraction explained = 6.4
# MS removing mean-by-year   = 7169.97
# fraction explained = 72.9
# ----------------------------------------------------
