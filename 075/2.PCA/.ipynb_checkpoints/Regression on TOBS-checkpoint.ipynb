# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

Location =r'/Users/mengtingwang/Documents/DSE/CSE255-DSE230/Data/reg_data'
df = pd.read_csv(Location,sep=' ')
df
# Out:
#       Unnamed: 0  Elevation      Station   Avg_TOBS
# 0              0      402.9  USR0000CPNN  25.296875
# 1              1      402.9  USR0000CPNN  25.437500
# 2              2      402.9  USR0000CPNN  25.406250
# 3              3      402.9  USR0000CPNN  25.406250
# 4              4      402.9  USR0000CPNN  24.953125
# 5              5      402.9  USR0000CPNN  25.921875
# 6              6      402.9  USR0000CPNN  26.156250
# 7              7      402.9  USR0000CPNN  26.171875
# 8              8      402.9  USR0000CPNN  25.718750
# 9              9      111.3  USC00045123  19.015625
# 10            10      111.3  USC00045123  19.843750
# 11            11      111.3  USC00045123  19.468750
# 12            12      111.3  USC00045123  19.906250
# 13            13      111.3  USC00045123  19.125000
# 14            14      111.3  USC00045123  19.343750
# 15            15      111.3  USC00045123  21.781250
# 16            16      111.3  USC00045123  21.203125
# 17            17      111.3  USC00045123  20.828125
# 18            18      111.3  USC00045123  20.640625
# 19            19      111.3  USC00045123  21.515625
# 20            20      111.3  USC00045123  20.937500
# 21            21      111.3  USC00045123  20.500000
# 22            22      111.3  USC00045123  21.437500
# 23            23      111.3  USC00045123  21.046875
# 24            24      111.3  USC00045123  22.140625
# 25            25      111.3  USC00045123  20.843750
# 26            26      111.3  USC00045123  21.265625
# 27            27      111.3  USC00045123  21.921875
# 28            28      111.3  USC00045123  21.625000
# 29            29      111.3  USC00045123  21.234375
# ...          ...        ...          ...        ...
# 2149        2149       36.6  USC00045118  25.000000
# 2150        2150       36.6  USC00045118  24.812500
# 2151        2151       36.6  USC00045118  23.843750
# 2152        2152       36.6  USC00045118  23.515625
# 2153        2153       36.6  USC00045118  26.015625
# 2154        2154      137.2  USR0000CBSR  21.156250
# 2155        2155      137.2  USR0000CBSR  22.250000
# 2156        2156      137.2  USR0000CBSR  21.593750
# 2157        2157      137.2  USR0000CBSR  21.406250
# 2158        2158      137.2  USR0000CBSR  21.375000
# 2159        2159      137.2  USR0000CBSR  22.109375
# 2160        2160      137.2  USR0000CBSR  22.046875
# 2161        2161      137.2  USR0000CBSR  21.812500
# 2162        2162      137.2  USR0000CBSR  20.625000
# 2163        2163      149.4  USR0000CFO2  17.937500
# 2164        2164      149.4  USR0000CFO2  18.593750
# 2165        2165      149.4  USR0000CFO2  18.093750
# 2166        2166      149.4  USR0000CFO2  17.453125
# 2167        2167      149.4  USR0000CFO2  17.359375
# 2168        2168      149.4  USR0000CFO2  17.656250
# 2169        2169      149.4  USR0000CFO2  17.687500
# 2170        2170      149.4  USR0000CFO2  17.125000
# 2171        2171       23.8  USW00093243  23.843750
# 2172        2172       23.8  USW00093243  23.843750
# 2173        2173       23.8  USW00093243  24.703125
# 2174        2174       23.8  USW00093243  24.375000
# 2175        2175       23.8  USW00093243  25.000000
# 2176        2176       23.8  USW00093243  23.281250
# 2177        2177       23.8  USW00093243  23.062500
# 2178        2178       23.8  USW00093243  24.906250
#
# [2179 rows x 4 columns]

# %%
import statsmodels.api as sm
from pandas.stats.api import ols

ols_test=ols(y=df['Avg_TOBS'], x=df['Elevation'])
# Out:
# /Users/mengtingwang/anaconda2/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2881: FutureWarning: The pandas.stats.ols module is deprecated and will be removed in a future version. We refer to external packages like statsmodels, see some examples here: http://www.statsmodels.org/stable/regression.html
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
fig.clf() #clears the fig!
sm.graphics.plot_partregress_grid(ols_test, fig=fig)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-9832334fa942> in <module>()
#       1 fig.clf() #clears the fig!
# ----> 2 sm.graphics.plot_partregress_grid(ols_test, fig=fig)
#
# /Users/mengtingwang/anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/graphics/regressionplots.py in plot_partregress_grid(results, exog_idx, grid, fig)
#     448     fig = utils.create_mpl_fig(fig)
#     449
# --> 450     exog_name, exog_idx = utils.maybe_name_or_idx(exog_idx, results.model)
#     451
#     452     #maybe add option for using wendog, wexog instead
#
# AttributeError: 'OLS' object has no attribute 'model'
