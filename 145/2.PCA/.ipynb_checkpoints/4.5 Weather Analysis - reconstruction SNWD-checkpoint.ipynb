# %%
#setup
data_dir='../../Data/Weather'
file_index='SBBSSBSB' # my file
#file_index='BBBSBBBB'
m='SNWD'

# %% [markdown]
# ## Reconstruction using top eigen-vectors
# For measurement = {{m}}

# %% [markdown]
# ## Load the required libraries

# %%
# Enable automiatic reload of libraries
#%load_ext autoreload
#%autoreload 2 # means that all modules are reloaded before every command

# %%
#%matplotlib inline
# %pylab inline
import numpy as np

import findspark
findspark.init()

import sys
sys.path.append('./lib')

from numpy_pack import packArray,unpackArray

from Eigen_decomp import Eigen_decomp
from YearPlotter import YearPlotter
from recon_plot import recon_plot

from import_modules import import_modules,modules
import_modules(modules)

from ipywidgets import interactive,widgets
# Out:
# Populating the interactive namespace from numpy and matplotlib
#     pandas as    pd 	version=0.19.2 	required version>=0.19.2
#      numpy as    np 	version=1.12.1 	required version>=1.12.0
#    sklearn as    sk 	version=0.18.1 	required version>=0.18.1
#     urllib as urllib 	version=1.17 	required version>=1.17
#    pyspark as pyspark 	version=2.1.0+hadoop2.7 	required version>=2.1.0
# ipywidgets as ipywidgets 	version=6.0.0 	required version>=6.0.0

# %%
from pyspark import SparkContext
#sc.stop()

sc = SparkContext(master="local[3]",pyFiles=['lib/numpy_pack.py','lib/spark_PCA.py','lib/computeStats.py','lib/recon_plot.py','lib/Eigen_decomp.py'])

from pyspark import SparkContext
from pyspark.sql import *
sqlContext = SQLContext(sc)

# %% [markdown]
# ## Read Statistics File

# %%
from pickle import load

#read statistics
filename=data_dir+'/STAT_%s.pickle'%file_index
STAT,STAT_Descriptions = load(open(filename,'rb'))
measurements=STAT.keys()
print 'keys from STAT=',measurements
# Out:
# keys from STAT= ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'SNWD', 'PRCP']

# %% [markdown]
# ## Read data file into a spark DataFrame
# We focus on the snow-depth records, because the eigen-vectors for them make sense.

# %%
#read data
filename=data_dir+'/US_Weather_%s.parquet'%file_index
df_in=sqlContext.read.parquet(filename)
#filter in 
df=df_in.filter(df_in.measurement==m)
df.show(5)
# Out:
# +---------+--------+---------+-----------+-----------+------+--------------------+------+--------+
# |elevation|latitude|longitude|measurement|    station|undefs|              vector|  year|   label|
# +---------+--------+---------+-----------+-----------+------+--------------------+------+--------+
# |   1627.0| 42.8975|-106.4636|       SNWD|USW00024089|     0|[00 00 00 00 C0 5...|1949.0|SBBSSBSB|
# |   1627.0| 42.8975|-106.4636|       SNWD|USW00024089|     0|[00 00 00 00 C0 5...|1950.0|SBBSSBSB|
# |   1627.0| 42.8975|-106.4636|       SNWD|USW00024089|     0|[00 00 00 00 00 0...|1951.0|SBBSSBSB|
# |   1627.0| 42.8975|-106.4636|       SNWD|USW00024089|     0|[60 52 40 4E 40 4...|1952.0|SBBSSBSB|
# |   1627.0| 42.8975|-106.4636|       SNWD|USW00024089|     0|[00 00 00 00 00 0...|1953.0|SBBSSBSB|
# +---------+--------+---------+-----------+-----------+------+--------------------+------+--------+
# only showing top 5 rows

# %% [markdown]
# ### Plot Reconstructions
#
# Construct approximations of a time series using the mean and the $k$ top eigen-vectors
# First, we plot the mean and the top $k$ eigenvectors

# %%
import pylab as plt
fig,axes=plt.subplots(2,1, sharex='col', sharey='row',figsize=(8,6));
axes[0].set_ylabel('millimeters');
k=3
EigVec=np.matrix(STAT[m]['eigvec'][:,:k])
Mean=STAT[m]['Mean']
YearPlotter().plot(Mean,fig,axes[0],label='Mean',title=m+' Mean')
YearPlotter().plot(EigVec,fig,axes[1],title=m+' Eigs',labels=['eig'+str(i+1) for i in range(k)])

# %%
v=[np.array(EigVec[:,i]).flatten() for i in range(np.shape(EigVec)[1])]

# %% [markdown]
# ### plot the percent of residual variance on average

# %%
#  x=0 in the graphs below correspond to the fraction of the variance explained by the mean alone
#  x=1,2,3,... are the residuals for eig1, eig1+eig2, eig1+eig2+eig3 ...
fig,ax=plt.subplots(1,1);
eigvals=STAT[m]['eigval']; eigvals/=sum(eigvals); cumvar=np.cumsum(eigvals); cumvar=100*np.insert(cumvar,0,0)
ax.plot(cumvar[:5]); 
ax.grid(); 
ax.set_ylabel('Percent of variance explained')
ax.set_xlabel('number of eigenvectors')
ax.set_title('Percent of variance explained');

# %% [markdown]
# ## Process whole dataframe to find best and worse residuals

# %% [markdown]
# ### Add to each row in the dataframe a residual values
# Residuals are after subtracting in sequence: the mean, the projection on the first eigen-vector the projection on the second eigen-vector etc.
#
# `decompose(row)` axtracts the series from the row, computes the residuals and constructs a new row that is reassembled into a dataframe.

# %%
def decompose(row):
    """compute residual and coefficients for decomposition           

    :param row: SparkSQL Row that contains the measurements for a particular station, year and measurement. 
    :returns: the input row with additional information from the eigen-decomposition.
    :rtype: SparkSQL Row 

    Note that Decompose is designed to run inside a spark "map()" command.
    Mean and v are sent to the workers as local variables of "Decompose"

    """
    Series=np.array(unpackArray(row.vector,np.float16),dtype=np.float64)
    recon=Eigen_decomp(None,Series,Mean,v);
    total_var,residuals,reductions,coeff=recon.compute_var_explained()
    #print coeff
    residuals=[float(r) for r in residuals[1]]
    coeff=[float(r) for r in coeff[1]]
    D=row.asDict()
    D['total_var']=float(total_var[1])
    D['res_mean']=residuals[0]
    for i in range(1,len(residuals)):
        D['res_'+str(i)]=residuals[i]
        D['coeff_'+str(i)]=coeff[i-1]
    return Row(**D)

# %%
rdd2=df.rdd.map(decompose)
df2=sqlContext.createDataFrame(rdd2)
row,=df2.take(1)

#filter out vectors for which the mean is a worse approximation than zero.
print 'before filter',df2.count()
df3=df2.filter(df2.res_mean<1)
print 'after filter',df3.count()
# Out:
# before filter 1335
# after filter 497

# %%
def plot_decomp(row,Mean,v,fig=None,ax=None,Title=None,interactive=False,coef=None):
    """Plot a single reconstruction with an informative title

    :param row: SparkSQL Row that contains the measurements for a particular station, year and measurement. 
    :param Mean: The mean vector of all measurements of a given type
    :param v: eigen-vectors for the distribution of measurements.
    :param fig: a matplotlib figure in which to place the plot
    :param ax: a matplotlib axis in which to place the plot
    :param Title: A plot title over-ride.
    :param interactive: A flag that indicates whether or not this is an interactive plot (widget-driven)
    :returns: a plotter returned by recon_plot initialization
    :rtype: recon_plot

    """
    target=np.array(unpackArray(row.vector,np.float16),dtype=np.float64)
    if Title is None:
        Title='%s %s = %.1f'%(row['measurement'],coef,row[coef])
    eigen_decomp=Eigen_decomp(range(1,366),target,Mean,v)
    plotter=recon_plot(eigen_decomp,year_axis=True,fig=fig,ax=ax,interactive=interactive,Title=Title)
    return plotter

def plot_recon_grid(rows,column_n=3, row_n=1, figsize=(14,3.5), coef=None):
    """plot a grid of reconstruction plots

    :param rows: Data rows (as extracted from the measurements data-frame
    :param column_n: number of columns
    :param row_n:  number of rows
    :param figsize: Size of figure
    :returns: None
    :rtype: 

    """
    fig,axes=plt.subplots(row_n,column_n, sharex='col', sharey='row',figsize=figsize);
    k=0
    for i in range(row_n):
        for j in range(column_n):
            row=rows[k]
            k+=1
            #_title='%3.2f,r1=%3.2f,r2=%3.2f,r3=%3.2f'\
            #        %(row['res_mean'],row['res_1'],row['res_2'],row['res_3'])
            #print i,j,_title,axes[i,j]
            plot_decomp(row,Mean,v,fig=fig,ax=axes[j],interactive=False, coef=coef)
    return None

# %% [markdown]
# #### Different things to try
# The best/worst rows in terms of res_mean,res_1, res_2, res_3
#
# The rows with the highest lowest levels of coeff1, coeff2, coeff3, when the corresponding residue is small.

# %%
# top coeff 1
rows=df3.sort(df3.coeff_1,ascending=False).take(3)
plot_recon_grid(rows,coef='coeff_1')
# Out:
# /Users/joshwilson/anaconda3/envs/py27/lib/python2.7/site-packages/matplotlib/figure.py:402: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
# bottom coeff 1
rows=df3.sort(df3.coeff_1,ascending=True).take(3)
plot_recon_grid(rows,coef='coeff_1')

# %%
# top coeff 2
rows=df3.sort(df3.coeff_2,ascending=False).take(3)
plot_recon_grid(rows,coef='coeff_2')

# %%
# bottom coeff 2
rows=df3.sort(df3.coeff_2,ascending=True).take(3)
plot_recon_grid(rows,coef='coeff_2')

# %%
# top coeff 3
rows=df3.sort(df3.coeff_3,ascending=False).take(3)
plot_recon_grid(rows,coef='coeff_3')

# %%
# bottom coeff 3
rows=df3.sort(df3.coeff_3,ascending=True).take(3)
plot_recon_grid(rows,coef='coeff_3')

# %%
# Sort entries by increasing values of res_1
df3=df3.sort(df3.res_1,ascending=True)

# %%
# get rows where first eigenvector coefficient is below 0 - SNWD lower than mean
df_below_mean=df3.filter(df3.coeff_1<0).sort(df3.coeff_1)
#df_below_mean=df3.filter(df3.res_1<0.5).filter(df3.coeff_1<0).sort(df3.coeff_1)

rows=df_below_mean.sort(df_below_mean.coeff_1,ascending=True).collect()
print len(rows)

df_below_mean.select('res_mean','res_1','coeff_1','latitude','longitude').show(4)

rows=df3.sort(df3.coeff_3,ascending=False).take(3)
plot_recon_grid(rows,coef='coeff_3')
# Out:
# 100
# +------------------+-------------------+-------------------+--------+---------+
# |          res_mean|              res_1|            coeff_1|latitude|longitude|
# +------------------+-------------------+-------------------+--------+---------+
# |0.9685246818899741| 0.6507802244155114|-1352.6342906358404| 43.6561|-107.7375|
# |0.9729008464663114| 0.6430811047066815|-1337.1941630503775| 43.7536|-108.1436|
# |0.9292713632539623|0.42009851323271774|-1298.3850784138583| 42.9589|-109.9958|
# |0.8899945643921889| 0.4793397293699914|-1277.3657673085943| 43.8111|-107.3653|
# +------------------+-------------------+-------------------+--------+---------+
# only showing top 4 rows

# %%
# get rows where first eigenvector above 0 - SNWD larger than mean
#df_above_mean=df3.filter(df3.res_1<0.8).sort(df3.coeff_1,ascending=False)
df_above_mean=df3.sort(df3.coeff_1,ascending=False)


#df_above_mean=df3.filter(df3.res_1<0.1).sort(df3.coeff_1,ascending=False)
rows=df_above_mean.sort(df_above_mean.coeff_1,ascending=False).collect()
print len(rows)

df_above_mean.select('res_mean','res_1','coeff_1','latitude','longitude').show(4)


rows = df3.sort(df3.coeff_3,ascending=True).take(3)
plot_recon_grid(rows,coef='coeff_3')
# Out:
# 497
# +------------------+--------------------+------------------+--------+---------+
# |          res_mean|               res_1|           coeff_1|latitude|longitude|
# +------------------+--------------------+------------------+--------+---------+
# |0.7063323941660536| 0.04404244752919988| 12240.79050778375|    43.7|-110.7333|
# |0.6991924419145029|  0.0819143141112878|11441.540023779547|    43.7|-110.7333|
# |0.6798715796057824|0.023200338372240826|11219.505250617865| 43.8567|-110.5889|
# |0.6852508680342544| 0.05412848411913181| 11158.30235998614|    43.7|-110.7333|
# +------------------+--------------------+------------------+--------+---------+
# only showing top 4 rows

# %%
alldata = df3.toPandas()
fig,ax=plt.subplots(1,2, figsize=(10,4));
ax[0].scatter(alldata.loc[:,'longitude'],alldata.loc[:,'coeff_1']);
ax[0].set_ylabel(m+' coeff_1')
ax[0].set_xlabel('longitude')
ax[0].set_title(m+' Eigenvector 1 Coefficient vs. Longitude')

ax[1].scatter(alldata.loc[:,'longitude'],alldata.loc[:,'elevation'],label='_nolegend_');
ax[1].set_ylabel('elevation')
ax[1].set_xlabel('longitude')
ax[1].set_title('Elevation vs. Longitude')
ax[1].axhline(y=1800,label='1800 ft. elevation',color='grey');
ax[1].axvline(x=-109.5,label='-109.5 degrees longitude',color='black');
ax[1].legend();

#ax[2].scatter(alldata.loc[:,'elevation'],alldata.loc[:,'coeff_1']);
#ax[2].set_ylabel(m+' coeff_1')
#ax[2].set_xlabel('elevation')
#ax[2].set_title(m+' Eigenvector 1 Coefficient vs. Elevation')

plt.tight_layout();
plt.show();

# %%
# longitude and elevation are correlated:  higher elevations are in the west
plt.scatter(alldata.loc[:,'longitude'],alldata.loc[:,'elevation']);

# %%
# SNOW coeff_1 is not equal if data split based on elevation @ 1800 (or lon of -109 degrees)
high = alldata.loc[alldata['elevation']>1800,'coeff_1']
low = alldata.loc[alldata['elevation']<1800,'coeff_1']
from scipy import stats
print 'p-value for equal means above and below 1800 elevation =',str(stats.ttest_ind(high,low).pvalue)

# plot histogram of year values for data points with highest and lowest coeff 1
fig,axes=plt.subplots(2,1,figsize=(5,5),sharex=True);

axes[0].hist(high);
axes[1].hist(low);
# Out:
# p-value for equal means above and below 1800 elevation = 1.88171989989e-36

# %%
# coeff_1 is not equal if data split based on longitude @ -109
west = alldata.loc[alldata['longitude']<-109.5,'coeff_1']
east = alldata.loc[alldata['longitude']>=-109.5,'coeff_1']
from scipy import stats
print 'p-value for equal means east and west of -109.5 degrees longitude =',str(stats.ttest_ind(west,east).pvalue)

high_alt = alldata.loc[alldata['elevation']>1800,'coeff_1']
low_alt = alldata.loc[alldata['elevation']<=1800,'coeff_1']
print 'p-value for equal means above and below 1800 ft elevation =',str(stats.ttest_ind(high_alt,low_alt).pvalue)

# plot histogram of year values for data points with highest and lowest coeff 1
fig,axes=plt.subplots(2,1,figsize=(5,5),sharex=True);

axes[0].hist(west);
#axes[0].set
axes[1].hist(east);
# Out:
# p-value for equal means east and west of -109.5 degrees longitude = 1.88171989989e-36
# p-value for equal means above and below 1800 ft elevation = 1.88171989989e-36

# %%
e1high_pdf = df_above_mean.select(['station','year','latitude','longitude','elevation','coeff_1','res_1','vector']).toPandas()
print e1high_pdf.shape
e1high_pdf.head(10)
# Out:
# (497, 8)
#        station    year  latitude  longitude  elevation       coeff_1  \
# 0  USC00486430  1952.0   43.7000  -110.7333     2022.0  12240.790508
# 1  USC00486430  1958.0   43.7000  -110.7333     2022.0  11441.540024
# 2  USC00486440  1956.0   43.8567  -110.5889     2072.0  11219.505251
# 3  USC00486430  1957.0   43.7000  -110.7333     2022.0  11158.302360
# 4  USC00486440  1976.0   43.8567  -110.5889     2072.0  11091.781474
# 5  USC00486430  1951.0   43.7000  -110.7333     2022.0  10890.863299
# 6  USC00486440  1978.0   43.8567  -110.5889     2072.0  10699.843246
# 7  USC00486440  1971.0   43.8567  -110.5889     2072.0  10563.644968
# 8  USC00480865  1978.0   43.2278  -110.4358     1991.9  10382.035970
# 9  USC00486440  1975.0   43.8567  -110.5889     2072.0  10190.479148
#
#       res_1                                             vector
# 0  0.044042  [144, 100, 94, 100, 68, 100, 68, 100, 43, 100,...
# 1  0.081914  [170, 100, 119, 100, 68, 100, 68, 100, 43, 100...
# ...

# %%
e1low_pdf = df_below_mean.select(['station','year','latitude','longitude','elevation','coeff_1','res_1','vector']).toPandas()
print e1low_pdf.shape
e1low_pdf.head(10)
# Out:
# (100, 8)
#        station    year  latitude  longitude  elevation      coeff_1     res_1  \
# 0  USC00480778  1978.0   43.6561  -107.7375     1717.5 -1352.634291  0.650780
# 1  USC00488884  1992.0   43.7536  -108.1436     1304.8 -1337.194163  0.643081
# 2  USC00482054  1991.0   42.9589  -109.9958     2239.4 -1298.385078  0.420099
# 3  USC00488858  1982.0   43.8111  -107.3653     1426.5 -1277.365767  0.479340
# 4  USC00485055  1949.0   43.7144  -106.6375     1420.4 -1276.809230  0.503294
# 5  USC00488858  1992.0   43.8111  -107.3653     1426.5 -1266.928675  0.436526
# 6  USC00480778  1993.0   43.6561  -107.7375     1717.5 -1259.894640  0.350938
# 7  USC00480727  1953.0   43.3667  -105.2000     1382.0 -1254.029634  0.471182
# 8  USC00482242  1992.0   42.9281  -110.1272     2235.7 -1251.267545  0.274197
# 9  USC00488858  1987.0   43.8111  -107.3653     1426.5 -1243.506980  0.323610
#
#                                               vector
# ...

# %%
# get rows where second eigenvector coeff is largest = late snowfall
#df_late_winter = df3.filter(df3.res_2 < 0.1).sort(df3.coeff_2,ascending=False)
df_late_winter = df3.sort(df3.coeff_2,ascending=False)

rows=df_late_winter.collect()
print len(rows)
df_late_winter.select('res_mean','res_1','coeff_1','res_2','coeff_2','latitude','longitude').show(4)

# plot
plot_recon_grid(rows, coef='coeff_2')
# Out:
# 497
# +------------------+-------------------+-----------------+-------------------+------------------+--------+---------+
# |          res_mean|              res_1|          coeff_1|              res_2|           coeff_2|latitude|longitude|
# +------------------+-------------------+-----------------+-------------------+------------------+--------+---------+
# |0.6343459165857764|0.47128090696750163|5107.209478719536|0.16251974608535857|3902.8558127826263| 43.1667|-109.9833|
# | 0.671871573904535|0.23462635645570268|8375.974285070177|0.08448565712958954| 3709.776972973261| 43.4136|-110.1631|
# |0.6290219011986812| 0.1982415826999638|7404.571070388773|0.03701912968201988| 3320.403815388005|   42.95|-110.3667|
# |0.6156627397304093| 0.4720531430224414|4887.202197655397|0.26328656844066717| 3073.234399797956| 43.1667|-109.9833|
# +------------------+-------------------+-----------------+-------------------+------------------+--------+---------+
# only showing top 4 rows

# %%
# get rows where second eigenvector coeff is smallest = early snowfall?
df_early_winter = df3.filter(df3.res_2<0.1).sort(df3.coeff_2,ascending=True)
rows=df_early_winter.collect()
print len(rows)
df_early_winter.select('res_mean','res_1','coeff_1','res_2','coeff_2','latitude','longitude').show(4)

# plot
plot_recon_grid(rows, coef='coeff_2')
# Out:
# 149
# +-------------------+-------------------+-----------------+--------------------+-------------------+--------+---------+
# |           res_mean|              res_1|          coeff_1|               res_2|            coeff_2|latitude|longitude|
# +-------------------+-------------------+-----------------+--------------------+-------------------+--------+---------+
# |0.47389623927712754| 0.3218785384885771|4131.853219144827| 0.05673367765484172| -2583.644448128497| 43.6536|-110.7169|
# | 0.5185572994972597| 0.2211862755613829|5321.397159745977|0.055216883215095894| -2456.534554023852| 42.8733|-110.9075|
# | 0.6803435644418023|0.13825247420293876|10382.03597037824| 0.09358406929015488|-2363.7020334030362| 43.2278|-110.4358|
# |0.43858908731542146| 0.3508229586859695|3558.700317651003| 0.08091743761767725| -2294.646156781118| 43.8567|-110.5889|
# +-------------------+-------------------+-----------------+--------------------+-------------------+--------+---------+
# ...

# %%
e2high_pdf = df_late_winter.select(['station','year','latitude','longitude','elevation','coeff_2','res_2','vector']).toPandas()
print e2high_pdf.shape
e2high_pdf.head(10)
# Out:
# (497, 8)
#        station    year  latitude  longitude  elevation      coeff_2     res_2  \
# 0  USC00485115  1904.0   43.1667  -109.9833     2332.9  3902.855813  0.162520
# 1  USC00482375  1976.0   43.4136  -110.1631     2487.2  3709.776973  0.084486
# 2  USC00486165  1976.0   42.9500  -110.3667     2346.4  3320.403815  0.037019
# 3  USC00485115  1907.0   43.1667  -109.9833     2332.9  3073.234400  0.263287
# 4  USC00482375  1975.0   43.4136  -110.1631     2487.2  2893.144528  0.270389
# 5  USC00486440  1976.0   43.8567  -110.5889     2072.0  2850.038449  0.025258
# 6  USC00482375  1982.0   43.4136  -110.1631     2487.2  2806.872960  0.135072
# 7  USC00482375  2011.0   43.4136  -110.1631     2487.2  2744.915018  0.258437
# 8  USC00485115  1962.0   43.1667  -109.9833     2332.9  2367.101261  0.033299
# 9  USC00486440  2008.0   43.8567  -110.5889     2072.0  2365.925484  0.046704
#
#                                               vector
# ...

# %%
e2low_pdf = df_early_winter.select(['station','year','latitude','longitude','elevation','coeff_2','res_2','vector']).toPandas()
print e2low_pdf.shape
e2low_pdf.head(10)
# Out:
# (149, 8)
#        station    year  latitude  longitude  elevation      coeff_2     res_2  \
# 0  USC00486428  1961.0   43.6536  -110.7169     1964.1 -2583.644448  0.056734
# 1  USC00480603  1978.0   42.8733  -110.9075     1958.3 -2456.534554  0.055217
# 2  USC00480865  1978.0   43.2278  -110.4358     1991.9 -2363.702033  0.093584
# 3  USC00486440  1992.0   43.8567  -110.5889     2072.0 -2294.646157  0.080917
# 4  USC00486428  2001.0   43.6536  -110.7169     1964.1 -2281.273679  0.090777
# 5  USC00486428  1978.0   43.6536  -110.7169     1964.1 -2118.286657  0.015064
# 6  USC00480865  2001.0   43.2278  -110.4358     1991.9 -2046.605426  0.099169
# 7  USC00486440  1994.0   43.8567  -110.5889     2072.0 -1895.554424  0.076533
# 8  USC00486440  2001.0   43.8567  -110.5889     2072.0 -1689.366667  0.069568
# 9  USC00480140  1972.0   43.7728  -111.0339     1962.0 -1674.794624  0.093125
#
#                                               vector
# ...

# %%
alldata = df3.toPandas()
plt.scatter(alldata.loc[:,'coeff_2'],alldata.loc[:,'elevation']);
plt.xlabel(m+' coeff_2')
plt.ylabel('elevation')
plt.title(m+' Eigenvector 2 Coefficient vs. Elevation')
plt.show();

# %%
# no statistical evidence that coeff_2 differs at elevations above and below 1800
high = alldata.loc[alldata['elevation']>1800,'coeff_2']
low = alldata.loc[alldata['elevation']<1800,'coeff_2']
from scipy import stats
print 'p-value for equal means above and below elevation of 1800 =',str(stats.ttest_ind(high,low).pvalue)

# plot histogram of year values for data points with highest and lowest coeff 1
fig,axes=plt.subplots(2,1,figsize=(5,5),sharex=True);

axes[0].hist(high);
axes[1].hist(low);
# Out:
# p-value for equal means above and below elevation of 1800 = 0.0923843107557

# %%
# get rows where third eigenvector coeff is smallest
df_small_c3 = df3.filter(df3.res_3<0.1).filter(df3.coeff_3<0).sort(df3.coeff_3,ascending=True)
rows=df_small_c3.collect()
print len(rows)
df_small_c3.select('res_mean','res_2','coeff_2','res_3','coeff_3','latitude','longitude').show(4)

# plot
plot_recon_grid(rows,coef='coeff_3')
# Out:
# 93
# +------------------+-------------------+------------------+-------------------+-------------------+--------+---------+
# |          res_mean|              res_2|           coeff_2|              res_3|            coeff_3|latitude|longitude|
# +------------------+-------------------+------------------+-------------------+-------------------+--------+---------+
# |0.6931478021464903|0.14362240422744013|1823.4896724173784|0.05629085435328253|-3305.9138813877253| 43.8567|-110.5889|
# | 0.639672274352799|0.16495572388869065|1821.9979479870035|0.06026372825284292| -2852.393191052072| 43.6536|-110.7169|
# |0.6647354836765952| 0.1440084450593373|1700.8212946208669|0.06270243329031615|-2802.1230694306632|    43.7|-110.7333|
# |0.6669896217871667| 0.1350720635327387| 2806.872960471078|0.05784271132805747|-2688.7285103895597| 43.4136|-110.1631|
# +------------------+-------------------+------------------+-------------------+-------------------+--------+---------+
# only showing top 4 rows

# %%
# get rows where third eigenvector coeff is largest
df_large_c3 = df3.filter(df3.res_3<0.1).filter(df3.coeff_3>0).sort(df3.coeff_3,ascending=False)
rows=df_large_c3.collect()
print len(rows)
df_large_c3.select('res_mean','res_2','coeff_2','res_3','coeff_3','latitude','longitude').show(4)

# plot
plot_recon_grid(rows, coef='coeff_3')
# Out:
# 121
# +-------------------+-------------------+-------------------+--------------------+------------------+--------+---------+
# |           res_mean|              res_2|            coeff_2|               res_3|           coeff_3|latitude|longitude|
# +-------------------+-------------------+-------------------+--------------------+------------------+--------+---------+
# | 0.5332304598832935| 0.1938372692759804|-1249.6503591169069| 0.05047461363305339|2340.8568357394884| 43.2278|-110.4358|
# |0.49767878142554905|0.23925230295905694|  -1703.73588921646| 0.05948600730793566| 2248.232101513241| 43.8567|-110.5889|
# |0.47439599144949257|0.30219449367876644|-1381.0373205801013| 0.08673949765658809| 2228.413641214489| 43.7728|-111.0339|
# | 0.5590835289549365|0.13232896625030033|  750.8418345019934|0.030857639152998523| 2166.940044203865| 42.8667|   -110.9|
# +-------------------+-------------------+-------------------+--------------------+------------------+--------+---------+
# ...

# %%
plt.scatter(alldata.loc[:,'coeff_2'],alldata.loc[:,'coeff_3']);

# %% [markdown]
# ## Interactive plot of reconstruction
#
# Following is an interactive widget which lets you change the coefficients of the eigen-vectors to see the effect on the approximation.
# The initial state of the sliders (in the middle) corresponds to the optimal setting. You can zero a positive coefficient by moving the slider all the way down, zero a negative coefficient by moving it all the way up.

# %%
row=rows[0]
target=np.array(unpackArray(row.vector,np.float16),dtype=np.float64)
eigen_decomp=Eigen_decomp(None,target,Mean,v)
total_var,residuals,reductions,coeff=eigen_decomp.compute_var_explained()
res=residuals[1]
print 'residual normalized norm  after mean:',res[0]
print 'residual normalized norm  after mean + top eigs:',res[1:]

plotter=recon_plot(eigen_decomp,year_axis=True,interactive=True)
display(plotter.get_Interactive())
# Out:
# residual normalized norm  after mean: 0.533230459883
# residual normalized norm  after mean + top eigs: [ 0.23469398  0.19383727  0.05047461]
# Widget Javascript not detected.  It may not be installed or enabled properly.

# %% [markdown]
# ### What is the distribution of the residuals and the coefficients?
#
# To answer this question we extract all of the values of `res_3` which is the residual variance after the Mean and the
# first two Eigen-vectors have been subtracted out. We rely here on the fact that `df3` is already sorted according to `res_3`

# %%
# A function for plotting the CDF of a given feature
def plot_CDF(feat):
    rows=df3.select(feat).sort(feat).collect()
    vals=[r[feat] for r in rows]
    P=np.arange(0,1,1./(len(vals)))
    #vals=[vals[0]]+vals
    #print vals
    #print P
    plot(vals,P)
    title('cumulative distribution of '+feat)
    ylabel('number of instances')
    xlabel(feat)
    grid()

# %%
plot_CDF('res_1')

# %%
plot_CDF('coeff_2')

# %%
filename=data_dir+'/decon_'+file_index+'_'+m+'.parquet'
# !rm -rf $filename
df3.write.parquet(filename)

# %%
# !du -sh $data_dir/*.parquet
# Out:
# 4.6M	../../Data/Weather/US_Weather_BBBSBBBB.parquet
# 4.4M	../../Data/Weather/US_Weather_SBBSSBSB.parquet
# 2.3M	../../Data/Weather/decon_BBBSBBBB.parquet
# 3.9M	../../Data/Weather/decon_BBBSBBBB_PRCP.parquet
# 2.3M	../../Data/Weather/decon_BBBSBBBB_SNWD.parquet
# 3.1M	../../Data/Weather/decon_BBBSBBBB_TOBS.parquet
# 3.1M	../../Data/Weather/decon_SBBSSBSB_PRCP.parquet
# 2.3M	../../Data/Weather/decon_SBBSSBSB_SNWD.parquet
# 3.9M	../../Data/Weather/decon_SBBSSBSB_TMAX.parquet
# 3.9M	../../Data/Weather/decon_SBBSSBSB_TMIN.parquet
# 3.4M	../../Data/Weather/decon_SBBSSBSB_TOBS.parquet
