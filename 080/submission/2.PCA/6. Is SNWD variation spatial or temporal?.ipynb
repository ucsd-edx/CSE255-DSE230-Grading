# %% [markdown]
# ## Analyze whether SNWD varies more from year to year or from place to place.

# %%
import pandas as pd
import numpy as np
import urllib
import math

# %%
import findspark
findspark.init()

from pyspark import SparkContext
#sc.stop()
sc = SparkContext(master="local[3]",pyFiles=['lib/numpy_pack.py','lib/spark_PCA.py','lib/computeStats.py'])

from pyspark import SparkContext
from pyspark.sql import *
sqlContext = SQLContext(sc)

# %%
import sys
sys.path.append('./lib')

import numpy as np
from numpy_pack import packArray,unpackArray
from spark_PCA import computeCov
from computeStats import computeOverAllDist, STAT_Descriptions

# %%
### Read the data frame from pickle file

data_dir='../../Data/Weather'
file_index='SBSBBSSB'
meas='SNWD'

from pickle import load

#read statistics
filename=data_dir+'/STAT_%s.pickle'%file_index
STAT,STAT_Descriptions = load(open(filename,'rb'))
print('keys from STAT=',STAT.keys())

#!ls -ld $data_dir/*.parquet

#read data
filename=data_dir+'/decon_%s_%s.parquet'%(file_index,meas)

df=sqlContext.read.parquet(filename)
print(df.count())
df.show(2)
# Out:
# ('keys from STAT=', ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'SNWD', 'PRCP'])
# 438
# +------------------+-------------------+-------------------+---------+--------+--------+---------+-----------+-------------------+--------------------+-------------------+------------------+-----------+------------+------+--------------------+------+
# |           coeff_1|            coeff_2|            coeff_3|elevation|   label|latitude|longitude|measurement|              res_1|               res_2|              res_3|          res_mean|    station|   total_var|undefs|              vector|  year|
# +------------------+-------------------+-------------------+---------+--------+--------+---------+-----------+-------------------+--------------------+-------------------+------------------+-----------+------------+------+--------------------+------+
# |-9550.204522426688|-333.13090779716777|-2828.7879349546724|    889.4|SBSBBSSB| 46.7744|-116.1761|       SNWD| 0.1084572525440414| 0.10737246002040471|0.02915249653616075|0.8727184053998246|USC00102892|1.17221976E8|     0|[90 5D 28 5D C4 5...|1964.0|
# |-9018.948332125965|-1123.3171094854122|  86.59250231665669|    975.4|SBSBBSSB| 46.6311|-115.8086|       SNWD|0.04488699033869899|0.030246088304911822|0.03015687290487962|0.8530710672981976|USC00104150| 9.9856002E7|     5|[F6 64 29 65 29 6...|1969.0|
# +------------------+-------------------+-------------------+---------+--------+--------+---------+-----------+-------------------+--------------------+-------------------+------------------+-----------+------------+------+--------------------+------+
# only showing top 2 rows

# %%
print df.columns
# Out:
# ['coeff_1', 'coeff_2', 'coeff_3', 'elevation', 'label', 'latitude', 'longitude', 'measurement', 'res_1', 'res_2', 'res_3', 'res_mean', 'station', 'total_var', 'undefs', 'vector', 'year']

# %%
#extract longitude and latitude for each station
feature='coeff_1'
sqlContext.registerDataFrameAsTable(df,'weather')
#Features=', '.join(['coeff_1', 'coeff_2', 'coeff_3', 'elevation', 'latitude', 'longitude',\
#          'res_1', 'res_2', 'res_3', 'res_mean', 'year'])
Features='station, year, coeff_2'
Query="SELECT %s FROM weather"%Features
print(Query)
pdf = sqlContext.sql(Query).toPandas()
pdf.head()
# Out:
# SELECT station, year, coeff_2 FROM weather
#        station    year      coeff_2
# 0  USC00102892  1964.0  -333.130908
# 1  USC00104150  1969.0 -1123.317109
# 2  USC00104150  1964.0  -115.602558
# 3  USC00104150  2000.0  1311.154263
# 4  USC00107046  1986.0  -705.525282

# %%
year_station_table=pdf.pivot(index='year', columns='station', values='coeff_2')
year_station_table.head(20)
# Out:
# station  USC00100528  USC00101831  USC00102246  USC00102513  USC00102845  \
# year
# 1916.0           NaN          NaN          NaN          NaN          NaN
# 1917.0           NaN          NaN          NaN          NaN          NaN
# 1919.0           NaN          NaN          NaN          NaN          NaN
# 1922.0           NaN          NaN          NaN          NaN          NaN
# 1927.0           NaN          NaN          NaN          NaN          NaN
# 1929.0           NaN          NaN          NaN          NaN          NaN
# 1930.0           NaN          NaN          NaN          NaN          NaN
# 1936.0           NaN          NaN          NaN          NaN          NaN
# 1937.0           NaN          NaN          NaN          NaN          NaN
# 1942.0           NaN          NaN          NaN          NaN          NaN
# 1946.0           NaN          NaN          NaN          NaN          NaN
# 1947.0           NaN          NaN          NaN          NaN          NaN
# 1948.0           NaN          NaN          NaN          NaN          NaN
# 1949.0           NaN          NaN          NaN          NaN          NaN
# 1950.0           NaN          NaN          NaN          NaN          NaN
# 1951.0           NaN          NaN          NaN          NaN          NaN
# 1952.0           NaN          NaN          NaN          NaN          NaN
# 1953.0           NaN          NaN          NaN          NaN          NaN
# 1954.0           NaN          NaN          NaN          NaN          NaN
# 1955.0           NaN          NaN          NaN          NaN          NaN
#
# station  USC00102892  USC00104150  USC00105236  USC00106152  USC00106421  \
# year
# 1916.0           NaN          NaN          NaN          NaN          NaN
# 1917.0           NaN          NaN          NaN          NaN          NaN
# 1919.0           NaN          NaN          NaN          NaN          NaN
# 1922.0           NaN          NaN          NaN          NaN          NaN
# 1927.0           NaN          NaN          NaN          NaN          NaN
# 1929.0           NaN          NaN          NaN          NaN          NaN
# 1930.0           NaN          NaN          NaN          NaN          NaN
# 1936.0           NaN          NaN          NaN          NaN          NaN
# 1937.0           NaN          NaN          NaN          NaN          NaN
# 1942.0           NaN          NaN          NaN          NaN          NaN
# 1946.0           NaN          NaN          NaN          NaN          NaN
# 1947.0           NaN          NaN          NaN          NaN          NaN
# 1948.0           NaN          NaN          NaN          NaN          NaN
# 1949.0           NaN          NaN          NaN          NaN  -141.215325
# 1950.0           NaN          NaN  -258.015041          NaN  -605.485478
# 1951.0           NaN          NaN          NaN          NaN          NaN
# 1952.0    -65.862515          NaN          NaN  -420.983887          NaN
# 1953.0   1245.541087          NaN          NaN          NaN          NaN
# 1954.0   -495.080825          NaN          NaN          NaN          NaN
# 1955.0   1184.163979          NaN          NaN          NaN          NaN
#
# station     ...       USC00456789  USC00457015  USC00457059  USC00457180  \
# year        ...
# 1916.0      ...               NaN          NaN          NaN          NaN
# 1917.0      ...               NaN          NaN          NaN          NaN
# 1919.0      ...               NaN          NaN          NaN          NaN
# 1922.0      ...               NaN          NaN          NaN          NaN
# 1927.0      ...               NaN          NaN          NaN          NaN
# 1929.0      ...               NaN          NaN          NaN          NaN
# 1930.0      ...               NaN          NaN          NaN          NaN
# 1936.0      ...               NaN          NaN          NaN          NaN
# 1937.0      ...               NaN          NaN          NaN          NaN
# 1942.0      ...               NaN          NaN          NaN          NaN
# 1946.0      ...               NaN          NaN          NaN          NaN
# 1947.0      ...               NaN          NaN          NaN          NaN
# 1948.0      ...               NaN          NaN          NaN          NaN
# 1949.0      ...               NaN          NaN  -402.672998          NaN
# 1950.0      ...               NaN          NaN  -409.220601          NaN
# 1951.0      ...               NaN          NaN          NaN          NaN
# 1952.0      ...               NaN          NaN  -156.012253          NaN
# 1953.0      ...               NaN          NaN          NaN          NaN
# 1954.0      ...               NaN          NaN  -249.216846          NaN
# 1955.0      ...               NaN          NaN          NaN   137.211189
#
# station  USC00457223  USC00457267  USC00457956  USC00458348  USW00024110  \
# year
# 1916.0           NaN          NaN          NaN          NaN          NaN
# 1917.0           NaN          NaN          NaN          NaN          NaN
# 1919.0           NaN          NaN          NaN          NaN          NaN
# 1922.0           NaN          NaN          NaN          NaN          NaN
# 1927.0           NaN          NaN          NaN          NaN          NaN
# 1929.0           NaN          NaN          NaN          NaN          NaN
# 1930.0           NaN          NaN          NaN          NaN          NaN
# 1936.0           NaN          NaN          NaN          NaN          NaN
# 1937.0           NaN          NaN          NaN          NaN          NaN
# 1942.0           NaN          NaN          NaN          NaN          NaN
# 1946.0           NaN          NaN          NaN          NaN          NaN
# 1947.0           NaN          NaN          NaN          NaN          NaN
# 1948.0           NaN          NaN          NaN          NaN          NaN
# 1949.0           NaN          NaN  -505.969894          NaN          NaN
# 1950.0   -362.907274          NaN  -409.345517          NaN  -179.146383
# 1951.0           NaN          NaN          NaN          NaN          NaN
# 1952.0   -105.139166          NaN  -201.341373          NaN  -195.683865
# 1953.0           NaN          NaN          NaN          NaN          NaN
# 1954.0   -241.489961          NaN          NaN          NaN  -209.608760
# 1955.0    335.780232          NaN          NaN          NaN          NaN
#
# station  USW00024149
# year
# 1916.0           NaN
# 1917.0           NaN
# 1919.0           NaN
# 1922.0           NaN
# 1927.0           NaN
# 1929.0           NaN
# 1930.0           NaN
# 1936.0           NaN
# 1937.0           NaN
# 1942.0           NaN
# 1946.0           NaN
# 1947.0           NaN
# 1948.0           NaN
# 1949.0           NaN
# 1950.0   -232.521988
# 1951.0           NaN
# 1952.0           NaN
# 1953.0           NaN
# 1954.0           NaN
# 1955.0           NaN
#
# [20 rows x 44 columns]

# %% [markdown]
# ### Estimating the effect of the year vs the effect of the station
#
# To estimate the effect of time vs. location on the first eigenvector coefficient we
# compute:
#
# * The average row: `mean-by-station`
# * The average column: `mean-by-year`
#
# We then compute the RMS before and after subtracting either  the row or the column vector.

# %%
def RMS(Mat):
    return np.sqrt(np.nanmean(Mat**2))

mean_by_year=np.nanmean(year_station_table,axis=1)
mean_by_station=np.nanmean(year_station_table,axis=0)
tbl_minus_year = (year_station_table.transpose()-mean_by_year).transpose()
tbl_minus_station = year_station_table-mean_by_station

print 'total RMS                   = ',RMS(year_station_table)
print 'RMS removing mean-by-station= ',RMS(tbl_minus_station)
print 'RMS removing mean-by-year   = ',RMS(tbl_minus_year)
# Out:
#  total RMS                   =  891.646509155
# RMS removing mean-by-station=  860.293896216
# RMS removing mean-by-year   =  497.017351854

# %%
T=year_station_table
print 'initial RMS=',RMS(T)
for i in range(5):
    mean_by_year=np.nanmean(T,axis=1)
    T=(T.transpose()-mean_by_year).transpose()
    print i,'after removing mean by year    =',RMS(T)
    mean_by_station=np.nanmean(T,axis=0)
    T=T-mean_by_station
    print i,'after removing mean by stations=',RMS(T)
# Out:
# initial RMS= 891.646509155
# 0 after removing mean by year    = 497.017351854
# 0 after removing mean by stations= 474.740461516
# 1 after removing mean by year    = 471.739049641
# 1 after removing mean by stations= 471.163964059
# 2 after removing mean by year    = 470.999059311
# 2 after removing mean by stations= 470.930859538
# 3 after removing mean by year    = 470.896314441
# 3 after removing mean by stations= 470.877294211
# 4 after removing mean by year    = 470.866457566
# 4 after removing mean by stations= 470.860175584
