# %% [markdown]
# ## Analyze whether SNWD varies more from year to year or from place to place.

# %%
import pandas as pd
import numpy as np
import urllib
import math

# %%
import findspark
findspark.init()

from pyspark import SparkContext
#sc.stop()
sc = SparkContext(master="local[3]",pyFiles=['lib/numpy_pack.py','lib/spark_PCA.py','lib/computeStats.py'])

from pyspark import SparkContext
from pyspark.sql import *
sqlContext = SQLContext(sc)

# %%
import sys
sys.path.append('./lib')

import numpy as np
from numpy_pack import packArray,unpackArray
from spark_PCA import computeCov
from computeStats import computeOverAllDist, STAT_Descriptions

# %%
### Read the data frame from pickle file

data_dir='../../Data/Weather'
file_index='BBSBSBSB'
meas='PRCP'

from pickle import load

#read statistics
filename=data_dir+'/STAT_%s.pickle'%file_index
STAT,STAT_Descriptions = load(open(filename,'rb'))
print('keys from STAT=',STAT.keys())

#!ls -ld $data_dir/*.parquet

#read data
filename=data_dir+'/decon_%s_%s.parquet'%(file_index,meas)

df=sqlContext.read.parquet(filename)
print(df.count())
df.show(2)
# Out:
# ('keys from STAT=', ['TMIN', 'TOBS', 'TMAX', 'SNOW', 'SNWD', 'PRCP'])
# 3120
# +------------------+------------------+-------------------+---------+--------+--------+---------+-----------+------------------+------------------+------------------+------------------+-----------+---------+------+--------------------+------+
# |           coeff_1|           coeff_2|            coeff_3|elevation|   label|latitude|longitude|measurement|             res_1|             res_2|             res_3|          res_mean|    station|total_var|undefs|              vector|  year|
# +------------------+------------------+-------------------+---------+--------+--------+---------+-----------+------------------+------------------+------------------+------------------+-----------+---------+------+--------------------+------+
# | 46.09987594453827| 295.4098694166294|  49.08482003847832|    405.4|BBSBSBSB| 46.6803| -92.9542|       PRCP| 0.996390186885151| 0.928026709358737|0.9232288716146843|0.8414779903375119|USC00219173|1480672.0|     8|[00 00 00 00 00 0...|2004.0|
# |104.42293954740029|-43.26830611075221|-243.84619525139928|    399.3|BBSBSBSB| 47.2436| -93.4975|       PRCP|0.9884039497099892|0.9864130102787485|0.9231790724012356|0.8681122693301904|USC00213303|1083193.0|     0|[00 42 00 00 00 0...|1945.0|
# +------------------+------------------+-------------------+---------+--------+--------+---------+-----------+------------------+------------------+------------------+------------------+-----------+---------+------+--------------------+------+
# only showing top 2 rows

# %%
print df.columns
# Out:
# ['coeff_1', 'coeff_2', 'coeff_3', 'elevation', 'label', 'latitude', 'longitude', 'measurement', 'res_1', 'res_2', 'res_3', 'res_mean', 'station', 'total_var', 'undefs', 'vector', 'year']

# %%
#extract longitude and latitude for each station
feature='coeff_2'
sqlContext.registerDataFrameAsTable(df,'weather')
#Features=', '.join(['coeff_1', 'coeff_2', 'coeff_3', 'elevation', 'latitude', 'longitude',\
#          'res_1', 'res_2', 'res_3', 'res_mean', 'year'])
Features='station, year, coeff_2'
Query="SELECT %s FROM weather"%Features
print(Query)
pdf = sqlContext.sql(Query).toPandas()
pdf.head()
# Out:
# SELECT station, year, coeff_2 FROM weather
#        station    year     coeff_2
# 0  USC00219173  2004.0  295.409869
# 1  USC00213303  1945.0  -43.268306
# 2  USC00211771  2001.0 -273.350890
# 3  CA006025203  1974.0  173.118918
# 4  CA00602K300  2002.0  -93.153660

# %%
year_station_table=pdf.pivot(index='year', columns='station', values='coeff_2')
year_station_table.head(10)
# Out:
# station  CA006020559  CA006022010  CA006022011  CA006022300  CA006022301  \
# year
# 1889.0           NaN          NaN          NaN          NaN          NaN
#
# station     ...       USC00218621  USC00218700  USC00218763  USC00219015  \
# year        ...
# 1889.0      ...               NaN          NaN          NaN          NaN
# 1890.0      ...               NaN          NaN          NaN          NaN
# 1893.0      ...               NaN          NaN          NaN          NaN
# 1894.0      ...               NaN          NaN          NaN          NaN
# 1895.0      ...               NaN          NaN          NaN          NaN
# 1896.0      ...               NaN          NaN          NaN          NaN
# 1897.0      ...               NaN          NaN          NaN          NaN
# 1898.0      ...               NaN          NaN          NaN          NaN
# 1899.0      ...               NaN          NaN          NaN   167.117391
# 1900.0      ...               NaN          NaN          NaN  -122.191356
# 1901.0      ...               NaN          NaN          NaN    12.215168
# 1902.0      ...               NaN          NaN          NaN    34.534141
# 1903.0      ...               NaN          NaN          NaN          NaN
# 1904.0      ...               NaN          NaN          NaN   109.228586
# 1905.0      ...               NaN          NaN          NaN   -57.817250
# 1906.0      ...               NaN          NaN          NaN          NaN
# 1907.0      ...               NaN          NaN          NaN          NaN
# 1908.0      ...               NaN          NaN          NaN          NaN
# 1909.0      ...               NaN          NaN          NaN          NaN
# 1910.0      ...               NaN          NaN          NaN          NaN
# 1911.0      ...               NaN          NaN          NaN          NaN
# 1912.0      ...               NaN          NaN          NaN          NaN
# 1913.0      ...               NaN          NaN          NaN          NaN
# 1914.0      ...               NaN          NaN          NaN          NaN
# 1915.0      ...               NaN          NaN          NaN          NaN
# 1916.0      ...               NaN          NaN          NaN          NaN
# 1917.0      ...               NaN          NaN          NaN          NaN
# 1918.0      ...               NaN          NaN          NaN          NaN
# 1919.0      ...               NaN          NaN          NaN          NaN
# 1920.0      ...               NaN          NaN          NaN          NaN
# ...         ...               ...          ...          ...          ...
# 1983.0      ...               NaN   -60.598908          NaN          NaN
# 1984.0      ...               NaN   416.581216          NaN          NaN
# 1985.0      ...               NaN    43.744415          NaN          NaN
# 1986.0      ...               NaN          NaN          NaN          NaN
# 1987.0      ...               NaN          NaN          NaN          NaN
# 1988.0      ...               NaN          NaN          NaN          NaN
# 1989.0      ...               NaN          NaN          NaN          NaN
# 1990.0      ...               NaN          NaN          NaN          NaN
# 1991.0      ...               NaN          NaN          NaN          NaN
# 1992.0      ...               NaN   -87.355425          NaN          NaN
# 1993.0      ...               NaN   -55.452545          NaN          NaN
# 1994.0      ...               NaN    37.071213          NaN          NaN
# 1995.0      ...               NaN   119.669661          NaN          NaN
# 1996.0      ...               NaN   204.338277          NaN          NaN
# 1997.0      ...               NaN   -79.124823          NaN          NaN
# 1998.0      ...               NaN   168.149280          NaN          NaN
# 1999.0      ...               NaN    67.998637          NaN          NaN
# 2000.0      ...               NaN  -179.963879          NaN          NaN
# 2001.0      ...               NaN  -103.714543          NaN          NaN
# 2002.0      ...               NaN          NaN          NaN          NaN
# 2003.0      ...               NaN   -29.387008          NaN          NaN
# 2004.0      ...               NaN   226.318250          NaN          NaN
# 2005.0      ...               NaN          NaN          NaN          NaN
# 2006.0      ...               NaN    66.566024          NaN          NaN
# 2007.0      ...               NaN    68.612745          NaN          NaN
# 1997.0    -83.335068  -145.851826   -83.446444   -82.350373          NaN
# 1998.0    219.771074   204.710320   114.926168   117.398989          NaN
# 1999.0    184.937637    87.147556    75.622277   142.426256   240.598379
# 2000.0   -189.561880  -256.150222  -136.160909  -224.558956  -167.290968
# 2001.0   -141.032133  -102.402084   -54.903266   -71.657732   -10.399348
# 2002.0    -87.817537  -147.084650  -100.902055  -140.107631  -107.176223
# 2003.0    -54.320620          NaN     9.925968   -95.081894  -110.532293
# 2004.0    268.953745   295.409869   258.204870   133.386276    66.285174
# 2005.0    153.657878          NaN    24.690689   -16.147481   -49.818998
# 2006.0    109.440828          NaN    32.203832          NaN    13.733111
# 2007.0    142.637878   240.685176   231.338805   126.963254   165.710559
# 2008.0    125.756718   209.085192     5.825090   191.680991   211.744694
# 2009.0     26.272407    67.880767    64.975647    37.226294     1.156346
# 2010.0    -11.675672          NaN    38.792456    -7.720254    94.428469
# 2011.0   -115.704027   -67.601967   -37.429835   -81.847138  -152.752626
# 2012.0   -247.825073  -297.977717  -139.810395  -254.279768  -333.141309
#
# station  USW00094961
# year
# 1889.0           NaN
# 1890.0           NaN
# 1893.0           NaN
# 1894.0           NaN
# 1895.0           NaN
# 1896.0           NaN
# 1897.0           NaN
# 1898.0           NaN
# 1899.0           NaN
# 1900.0           NaN
# 1901.0           NaN
# 1902.0           NaN
# 1903.0           NaN
# 1904.0           NaN
# 1905.0           NaN
# 1906.0           NaN
# 1907.0           NaN
# 1908.0           NaN
# 1909.0           NaN
# 1910.0           NaN
# 1911.0           NaN
# 1912.0           NaN
# 1913.0           NaN
# 1914.0           NaN
# 1915.0           NaN
# 1916.0           NaN
# 1917.0           NaN
# 1918.0           NaN
# 1919.0           NaN
# 1920.0           NaN
# ...              ...
# 1983.0           NaN
# 1984.0           NaN
# 1985.0           NaN
# 1986.0           NaN
# 1987.0           NaN
# 1988.0           NaN
# 1989.0           NaN
# 1990.0           NaN
# 1991.0           NaN
# 1992.0           NaN
# 1993.0           NaN
# 1994.0           NaN
# 1995.0           NaN
# 1996.0           NaN
# 1997.0           NaN
# 1998.0    163.139561
# 1999.0     48.730804
# 2000.0   -199.169536
# 2001.0     -1.465773
# 2002.0   -189.749694
# 2003.0     48.186581
# 2004.0    127.961602
# 2005.0    102.333656
# 2006.0     64.183062
# 2007.0     89.979984
# 2008.0     -8.660983
# 2009.0     50.853454
# 2010.0     80.647425
# 2011.0    -37.408620
# 2012.0    -50.669512
#
# [122 rows x 92 columns]

# %% [markdown]
# ### Estimating the effect of the year vs the effect of the station
#
# To estimate the effect of time vs. location on the first eigenvector coefficient we
# compute:
#
# * The average row: `mean-by-station`
# * The average column: `mean-by-year`
#
# We then compute the RMS before and after subtracting either  the row or the column vector.

# %%
def RMS(Mat):
    return np.sqrt(np.nanmean(Mat**2))

mean_by_year=np.nanmean(year_station_table,axis=1)
mean_by_station=np.nanmean(year_station_table,axis=0)
tbl_minus_year = (year_station_table.transpose()-mean_by_year).transpose()
tbl_minus_station = year_station_table-mean_by_station

print 'total RMS                   = ',RMS(year_station_table)
print 'RMS removing mean-by-station= ',RMS(tbl_minus_station)
print 'RMS removing mean-by-year   = ',RMS(tbl_minus_year)
# Out:
# total RMS                   =  124.694057227
# RMS removing mean-by-station=  123.011805153
# RMS removing mean-by-year   =  64.3647659797

# %%
T=year_station_table
print 'initial RMS=',RMS(T)
for i in range(5):
    mean_by_year=np.nanmean(T,axis=1)
    T=(T.transpose()-mean_by_year).transpose()
    print i,'after removing mean by year    =',RMS(T)
    mean_by_station=np.nanmean(T,axis=0)
    T=T-mean_by_station
    print i,'after removing mean by stations=',RMS(T)
# Out:
# initial RMS= 124.694057227
# 0 after removing mean by year    = 64.3647659797
# 0 after removing mean by stations= 63.0674305023
# 1 after removing mean by year    = 63.0318122134
# 1 after removing mean by stations= 63.0265465677
# 2 after removing mean by year    = 63.0248028106
# 2 after removing mean by stations= 63.0239622867
# 3 after removing mean by year    = 63.023488213
# 3 after removing mean by stations= 63.0232035634
# 4 after removing mean by year    = 63.0230283558
# 4 after removing mean by stations= 63.0229194267

# %% [markdown]
# COEFF 1

# %%
#extract longitude and latitude for each station
feature='coeff_1'
sqlContext.registerDataFrameAsTable(df,'weather')
#Features=', '.join(['coeff_1', 'coeff_2', 'coeff_3', 'elevation', 'latitude', 'longitude',\
#          'res_1', 'res_2', 'res_3', 'res_mean', 'year'])
Features='station, year, coeff_1'
Query="SELECT %s FROM weather"%Features
print(Query)
pdf = sqlContext.sql(Query).toPandas()
pdf.head()
# Out:
# SELECT station, year, coeff_1 FROM weather
#        station    year     coeff_1
# 0  USC00219173  2004.0   46.099876
# 1  USC00213303  1945.0  104.422940
# 2  USC00211771  2001.0 -113.685573
# 3  CA006025203  1974.0  -99.391821
# 4  CA00602K300  2002.0  211.176494

# %%
year_station_table=pdf.pivot(index='year', columns='station', values='coeff_1')
year_station_table.head(10)
# Out:
# station  CA006020559  CA006022010  CA006022011  CA006022300  CA006022301  \
# year
# 1889.0           NaN          NaN          NaN          NaN          NaN
# 1890.0           NaN          NaN          NaN          NaN          NaN
# 1893.0           NaN          NaN          NaN          NaN          NaN
# 1894.0           NaN          NaN          NaN          NaN          NaN
# 1895.0           NaN          NaN          NaN          NaN          NaN
# 1896.0           NaN          NaN          NaN          NaN          NaN
# 1897.0           NaN          NaN          NaN          NaN          NaN
# 1898.0           NaN          NaN          NaN          NaN          NaN
# 1899.0           NaN          NaN          NaN          NaN          NaN
# 1900.0           NaN          NaN          NaN          NaN          NaN
#
# station  CA006022475  CA006022476  CA006025203  CA006025205  CA006026852  \
# year
# 1889.0           NaN          NaN          NaN          NaN          NaN
# 1890.0           NaN          NaN          NaN          NaN          NaN
# 1893.0    -90.800383          NaN          NaN          NaN          NaN
# 1894.0           NaN          NaN          NaN          NaN          NaN
# 1895.0           NaN          NaN          NaN          NaN          NaN
# 1896.0           NaN          NaN          NaN          NaN          NaN
# 1897.0           NaN          NaN          NaN          NaN          NaN
# 1898.0           NaN          NaN          NaN          NaN          NaN
# 1899.0           NaN          NaN          NaN          NaN          NaN
# 1900.0           NaN          NaN          NaN          NaN          NaN
#
# station     ...       USC00218621  USC00218700  USC00218763  USC00219015  \
# year        ...
# 1889.0      ...               NaN          NaN          NaN          NaN
# 1890.0      ...               NaN          NaN          NaN          NaN
# 1893.0      ...               NaN          NaN          NaN          NaN
# 1894.0      ...               NaN          NaN          NaN          NaN
# 1895.0      ...               NaN          NaN          NaN          NaN
# 1896.0      ...               NaN          NaN          NaN          NaN
# 1897.0      ...               NaN          NaN          NaN          NaN
# 1898.0      ...               NaN          NaN          NaN          NaN
# 1899.0      ...               NaN          NaN          NaN    95.500360
# 1900.0      ...               NaN          NaN          NaN   112.407722
#
# station  USC00219059  USC00219173  USW00014918  USW00094931  USW00094938  \
# year
# 1889.0           NaN          NaN          NaN          NaN          NaN
# 1890.0           NaN          NaN          NaN          NaN          NaN
# 1893.0           NaN          NaN          NaN          NaN          NaN
# 1894.0           NaN          NaN          NaN          NaN          NaN
# 1895.0     28.396617          NaN          NaN          NaN          NaN
# 1896.0           NaN          NaN          NaN          NaN          NaN
# 1897.0           NaN          NaN          NaN          NaN          NaN
# 1898.0    -92.595007          NaN          NaN          NaN          NaN
# 1899.0    -24.997521          NaN          NaN          NaN          NaN
# 1900.0    387.145014          NaN          NaN          NaN          NaN
#
# station  USW00094961
# year
# 1889.0           NaN
# 1890.0           NaN
# 1893.0           NaN
# 1894.0           NaN
# 1895.0           NaN
# 1896.0           NaN
# 1897.0           NaN
# 1898.0           NaN
# 1899.0           NaN
# 1900.0           NaN
#
# [10 rows x 92 columns]

# %%
def RMS(Mat):
    return np.sqrt(np.nanmean(Mat**2))

mean_by_year=np.nanmean(year_station_table,axis=1)
mean_by_station=np.nanmean(year_station_table,axis=0)
tbl_minus_year = (year_station_table.transpose()-mean_by_year).transpose()
tbl_minus_station = year_station_table-mean_by_station

print 'total RMS                   = ',RMS(year_station_table)
print 'RMS removing mean-by-station= ',RMS(tbl_minus_station)
print 'RMS removing mean-by-year   = ',RMS(tbl_minus_year)
# Out:
# total RMS                   =  127.972541623
# RMS removing mean-by-station=  126.859158306
# RMS removing mean-by-year   =  69.2308087696

# %%
T=year_station_table
print 'initial RMS=',RMS(T)
for i in range(5):
    mean_by_year=np.nanmean(T,axis=1)
    T=(T.transpose()-mean_by_year).transpose()
    print i,'after removing mean by year    =',RMS(T)
    mean_by_station=np.nanmean(T,axis=0)
    T=T-mean_by_station
    print i,'after removing mean by stations=',RMS(T)
# Out:
# initial RMS= 127.972541623
# 0 after removing mean by year    = 69.2308087696
# 0 after removing mean by stations= 68.3718020025
# 1 after removing mean by year    = 68.3322698634
# 1 after removing mean by stations= 68.3252781919
# 2 after removing mean by year    = 68.3234914859
# 2 after removing mean by stations= 68.3229420396
# 3 after removing mean by year    = 68.3227538735
# 3 after removing mean by stations= 68.3226853091
# 4 after removing mean by year    = 68.32265938
# 4 after removing mean by stations= 68.3226493198
